# %% [markdown]
# ## Run WES workflow on Kids First DRS files searched on NCPI FHIR server
#
# This script demonstrates uses of the NCPI FHIR server to find patients and files from the Familial Leukemia study. The query returns DRS ids allowing the files accessed via the Kid's First Data Resource Center DRS server. The workflow is run on the Seven Bridges Cancer Genomics Cloud WES server.
#
# The FHIR server is accessed through the fhir-py Python client.
#
# ### Set up the FHIR client
# Access is via a cookie obtained as described [here](https://github.com/NIH-NCPI/ncpi-api-fhir-service).

# %%
import os
import sys
import json
import requests
import pandas as pd 
import numpy as np
from pathlib import Path
from datetime import datetime
import pprint

pprint = pprint.PrettyPrinter(indent=1).pprint
# pprint() is now available to pretty-print any JSON

FHIR_SERVER = 'https://kf-api-fhir-service.kidsfirstdrc.org'

# Optional: Turn off SSL verification. Useful when dealing with a corporate proxy with self-signed certificates.
# This should be set to True unless you actually see certificate errors.
VERIFY_SSL = False

if not VERIFY_SSL:
    requests.packages.urllib3.disable_warnings()



# Kids First uses cookie-based authentication, save the cookie locally here.
full_cookie_path = os.path.expanduser('~/.keys/ncpi_prod_fhir_cookie.json')

with open(full_cookie_path) as f:
    cookies = json.load(f)
kf_cookie = cookies['Cookie']
            
# We make a requests.Session to ensure consistent headers/cookie across all the requests we make
s = requests.Session()
s.headers.update({'Accept': 'application/fhir+json'})
s.verify = VERIFY_SSL
s.cookies['AWSELBAuthSessionCookie-0'] = kf_cookie


# Test out the cookie by querying the server metadata
r = s.get(f"{FHIR_SERVER}/metadata")

if "<!DOCTYPE html>" in r.text:
    sys.stderr.write('ERROR: Could not authenticate with Kids First. The cookie may need to be updated')
    

# This helper method allows us to easily switch between printing an entire Bundle, or just the first 20 lines.
# Set truncate_for_github = False for actual use,
# or just replace the function with a `return bundle`

def print_bundle(bundle, truncate_for_github = False):
    if not truncate_for_github:
        return bundle
    
    lines = json.dumps(bundle, indent=2).split('\n')
    if len(lines) <= 20:
        return bundle
    else:   
        print('\n'.join(lines[:20]))
        print('...\nBundle truncated. Change the "print_bundle" function above to print the full content.')

# %%
# Resolves all pages for the bundle. Returns an array with all Bundles, including the original Bundle.
def resolve_pages(bundle):
    next_page_link = next(filter(lambda link: link['relation'] == 'next', bundle['link']), None)
    if next_page_link:
        next_page = s.get(next_page_link['url']).json()
        return [bundle] + resolve_pages(next_page)
    else:
        return [bundle]

# NOTE: No cell output.

# Function to run a query for any kind of resources.
def runQuery(query):
    r = s.get(f"{FHIR_SERVER}/{query}")
    first_bundle = r.json()
    if 'entry' not in first_bundle:
        resources = []
    else:    
        all_bundles = resolve_pages(first_bundle)
        resources = [entry['resource'] for bundle in all_bundles for entry in bundle['entry']]
        
    print(f"Total  Resources: {len(resources)}")
    return resources

# %%
studies = runQuery('ResearchStudy')
studies
# Out:
# Total  Resources: 29
# [{'resourceType': 'ResearchStudy',
#   'id': '687202',
#   'meta': {'versionId': '1',
#    'lastUpdated': '2022-06-20T14:25:32.953+00:00',
#    'source': '#RrhpFw6OupcziLQu',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'use': 'official',
#     'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_HGHFVPFD'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_HGHFVPFD'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs000424.v8.p2'}],
#   'title': 'Common Fund (CF) Genotype-Tissue Expression Project (GTEx)',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-GTEX'}]}]},
#  {'resourceType': 'ResearchStudy',
#   'id': '276195',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:38:53.070+00:00',
#    'source': '#Vi7u1eZZ5de8QLJp',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_9PYZAHHE'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_9PYZAHHE'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001168.v2.p2'}],
#   'title': 'Genomic Studies of Orofacial Cleft Birth Defects',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-OCEA'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/117866'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '272532',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:35:53.533+00:00',
#    'source': '#iyM8irsuxNH9R023',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_7NQ9151J'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_7NQ9151J'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001987.v1.p1'}],
#   'title': 'Genome-wide Sequencing to Identify the Genes Responsible for Enchondromatoses and Related Malignant Tumors',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-ED'}]}]},
#  {'resourceType': 'ResearchStudy',
#   'id': '269246',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:35:07.120+00:00',
#    'source': '#lP4G6TrlFDc3QLh0',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_B8X3C1MX'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_B8X3C1MX'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs002130.v1.p1'}],
#   'title': 'Kids First: Craniofacial Microsomia: Genetic Causes and Pathway Discovery',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-CM'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/268642'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '267437',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:33:08.229+00:00',
#    'source': '#DyQ38hhNWt3svQnd',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_DK0KRWK8'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_DK0KRWK8'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001997.v1.p1'}],
#   'title': 'Whole Genome Sequencing of African and Asian Orofacial Clefts Case-Parent Triads',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-OFCAA'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/265786'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '260974',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:30:12.571+00:00',
#    'source': '#ACpsEgNBIzUZFvRZ',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_NMVV8A1Y'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_NMVV8A1Y'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs002162.v1.p1'}],
#   'title': 'Kids First: Genetics of Structural Defects of the Kidney and Urinary Tract',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-KUT'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/258082'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '125635',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:28:20.867+00:00',
#    'source': '#lxGVxWt5Pnrz3V6B',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_YNSSAPHE'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_YNSSAPHE'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs000467.v17.p7'}],
#   'title': 'TARGET: Neuroblastoma (NBL)',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'TARGET'}]},
#    {'coding': [{'code': 'TARGET-NB'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/96500'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '123556',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:26:25.167+00:00',
#    'source': '#cdPsDsTirYYBOYpQ',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_W0V965XZ'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_W0V965XZ'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001738.v1.p1'}],
#   'title': 'Genomic Analysis of Familial Leukemia',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-FALL'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/122286'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '119523',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:24:24.020+00:00',
#    'source': '#Yq9Eck7A5dgx8r6P',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_R0EPRSGS'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_R0EPRSGS'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001420.v1.p1'}],
#   'title': 'Kids First: Genomics of Orofacial Cleft Birth Defects in Latin American Families',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-OFCLA'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/117866'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '116586',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:19:40.980+00:00',
#    'source': '#AiOJh4qrdW96baX4',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_RM8AFW0R'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_RM8AFW0R'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001410.v1.p1'}],
#   'title': 'Kids First: Genomics of Orthopaedic Disease Program',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-AIS'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/115209'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '114612',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:18:11.425+00:00',
#    'source': '#QuVPEvGz25b5x9Mw',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_DZ4GPQX6'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_DZ4GPQX6'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs002172.v1.p1'}],
#   'title': 'Kids First: The Genetics of Microtia in Hispanic Populations',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-GMHP'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/113832'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '112832',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:15:59.150+00:00',
#    'source': '#3KpEIj9PhLALo6KY',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_ZFGDG5YS'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_ZFGDG5YS'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001683.v2.p1'}],
#   'title': 'Gabriella Miller Kids First Pediatric Research Program in Novel Cancer Susceptibility in Families (from BASIC3)',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-NCSF'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/111363'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '104182',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T01:14:47.204+00:00',
#    'source': '#mzLhrVzqSrERkC7B',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_0TYVY1TW'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_0TYVY1TW'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs002161.v1.p1'}],
#   'title': 'Genomic Analysis of Esophageal Atresia and Tracheoesophageal Fistulas and Associated Congenital Anomalies',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-EATF'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/22423'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '100031',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T00:56:41.161+00:00',
#    'source': '#N1PVao6WQD1cD5rc',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_DYPMEHHF'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_DYPMEHHF'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001436.v1.p1'}],
#   'title': 'Discovering the Genetic Basis of Human Neuroblastoma: A Gabriella Miller Kids First Pediatric Research Program (Kids First) Project',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-NBL'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/96500'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '95270',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-19T00:52:11.476+00:00',
#    'source': '#eeVpydPqbiebrtFz',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_VTTSHWV4'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_VTTSHWV4'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001785.v1.p1'}],
#   'title': 'Kids First: Genomic Analysis of a Cohort with Infantile Hemangiomas Associated with Multi-organ Structural Birth Defects',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-IHMOBD'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/94669'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '55858',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T23:05:53.571+00:00',
#    'source': '#5HNtCYQthZNpzgXb',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_DZTB5HRR'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_DZTB5HRR'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001247.v1.p1'}],
#   'title': 'Kids First: BCH Structural Birth Defects Collaboration: Syndromic cranial dysinnervation disorders',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-SCD'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/53916'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '52326',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T23:02:59.628+00:00',
#    'source': '#jJYgC0B3KRJY7yvf',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_YGVA0E1C'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_YGVA0E1C'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001228.v1.p1'}],
#   'title': 'Kids First: Expanded Ewing sarcoma cohort for tumor genomics and association with DNA repair deficiencies, clinical presentation, and outcome',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-ESGR'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/49919'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '49513',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T23:01:23.369+00:00',
#    'source': '#rYzF3dJlSTbMTjgC',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_6FPYJQBR'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_6FPYJQBR'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001178.v1.p1'}],
#   'title': 'Kids First: Genetic Basis of Disorders/Differences of Sex Development (DSD)',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-DSD'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/48897'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '48656',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T22:57:56.745+00:00',
#    'source': '#83Q7YI9F69RaW6Gn',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_8Y99QZJJ'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_8Y99QZJJ'}],
#   'title': 'Pediatric Brain Tumor Atlas: PNOC',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Pediatric Brain Tumor Atlas'}]},
#    {'coding': [{'code': 'PBTA-PNOC'}]}]},
#  {'resourceType': 'ResearchStudy',
#   'id': '47035',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T22:47:40.542+00:00',
#    'source': '#vIKGnEdkonqdfT7D',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_P445ACHV'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_P445ACHV'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001806.v1.p1'}],
#   'title': 'Kids First: Whole genome sequencing of nonsyndromic craniosynostosis',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-NC'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/44846'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '42776',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T22:41:20.078+00:00',
#    'source': '#EpHvojQubVGr08D2',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_Z6MWD3H0'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_Z6MWD3H0'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs002330.v1.p1'}],
#   'title': 'Kids First: Genomic Analysis of Congenital Heart Defects and Acute Lymphoblastic Leukemia in Children with Down Syndrome',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'},
#      {'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCERANDBIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-CHDALL'}]}]},
#  {'resourceType': 'ResearchStudy',
#   'id': '38019',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T22:39:32.861+00:00',
#    'source': '#ddzEGC1MjOTupWoI',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_46RR9ZR6'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_46RR9ZR6'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs000465.v18.p7'}],
#   'title': 'TARGET: Acute Myeloid Leukemia (AML)',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'TARGET'}]},
#    {'coding': [{'code': 'TARGET-AML'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/37336'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '35326',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T22:27:44.921+00:00',
#    'source': '#sFc745Ch5AES9OlV',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_PET7Q6F2'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_PET7Q6F2'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs002187.v1.p1'}],
#   'title': 'Kids First: Germline and Somatic Variants in Myeloid Malignancies in Children',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-MMC'}]}]},
#  {'resourceType': 'ResearchStudy',
#   'id': '27033',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T22:20:56.107+00:00',
#    'source': '#aXN1I8EeUBCnqZwe',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_46SK55A3'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_46SK55A3'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001110.v3.p1'}],
#   'title': 'Kids First: Genomic Analysis of Congenital Diaphragmatic Hernia',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '276720006',
#       'display': 'Dysmorphism (disorder)'}],
#     'text': 'BIRTHDEFECT'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-CDH'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/22423'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '22088',
#   'meta': {'versionId': '2',
#    'lastUpdated': '2022-01-18T22:19:51.364+00:00',
#    'source': '#OOmTR2zrBaleX830',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_ZXJFFMEF'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_ZXJFFMEF'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001714.v1.p1'}],
#   'title': 'Kids First: An Integrated Clinical and Genomic Analysis of Treatment Failure in Pediatric Osteosarcoma',
#   'status': 'completed',
#   'category': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'CANCER'}],
#   'keyword': [{'coding': [{'code': 'Kids First'}]},
#    {'coding': [{'code': 'KF-OS'}]}],
#   'principalInvestigator': {'reference': 'PractitionerRole/21951'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '281300',
#   'meta': {'versionId': '1',
#    'lastUpdated': '2021-10-15T11:19:45.641+00:00',
#    'source': '#YWSMBscCf7B7QqSD',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_1P41Z782'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_1P41Z782'}],
#   'title': 'OpenDIPG: ICR London',
#   'status': 'completed',
#   'condition': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '86049000',
#       'display': 'Malignant neoplasm, primary (morphologic abnormality)'}],
#     'text': 'Cancer'}],
#   'principalInvestigator': {'reference': 'PractitionerRole/281102'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '144813',
#   'meta': {'versionId': '1',
#    'lastUpdated': '2021-10-15T01:03:03.974+00:00',
#    'source': '#iEnyrOHjD2XNV1zY',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_PREASA7S'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_PREASA7S'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001138.v3.p2'}],
#   'title': 'National Heart, Lung, and Blood Institute (NHLBI) Bench to Bassinet Program: The Gabriella Miller Kids First Pediatric Research Program of the Pediatric Cardiac Genetics Consortium (PCGC)',
#   'status': 'completed',
#   'principalInvestigator': {'reference': 'PractitionerRole/138779'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '130099',
#   'meta': {'versionId': '1',
#    'lastUpdated': '2021-10-15T00:01:50.378+00:00',
#    'source': '#MzLN0bNN80sAsx1H',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_JWS3V24D'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_JWS3V24D'},
#    {'system': 'https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=',
#     'value': 'phs001846.v1.p1'}],
#   'title': 'Kids First: Genetics at the Intersection of Childhood Cancer and Birth Defects',
#   'status': 'completed',
#   'principalInvestigator': {'reference': 'PractitionerRole/126192'}},
#  {'resourceType': 'ResearchStudy',
#   'id': '76758',
#   'meta': {'versionId': '1',
#    'lastUpdated': '2021-10-14T20:38:18.232+00:00',
#    'source': '#1JZeWjbY1aYTteVz',
#    'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchStudy']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/studies/',
#     'value': 'SD_BHJXBDQK'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'ResearchStudy-SD_BHJXBDQK'}],
#   'title': "Pediatric Brain Tumor Atlas - Children's Brain Tumor Tissue Consortium",
#   'status': 'completed'}]

# %% [markdown]
# The Ewings Sarcoma study is id 52326

# %%
study_id = "52326"
subjects = runQuery(f'ResearchSubject?study={study_id}')
pprint(subjects[0])
# Out:
# Total  Resources: 1203
# {'id': '53466',
#  'identifier': [{'value': 'Schiffman-232'},
#                 {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#                  'value': 'PT_SKYS7BYE'},
#                 {'system': 'urn:kids-first:unique-string',
#                  'value': 'ResearchSubject-SD_YGVA0E1C-PT_SKYS7BYE'}],
#  'individual': {'reference': 'Patient/51063'},
#  'meta': {'lastUpdated': '2021-11-16T16:51:37.022+00:00',
#           'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject'],
#           'source': '#6cXjyvyFlK310TS1',
#           'tag': [{'code': 'SD_YGVA0E1C'}],
#           'versionId': '3'},
#  'resourceType': 'ResearchSubject',
#  'status': 'off-study',
#  'study': {'reference': 'ResearchStudy/52326'}}

# %%
patients = runQuery(f'Patient?_has:ResearchSubject:individual:study={study_id}')
pprint(patients[0])
# Out:
# Total  Resources: 1203
# {'extension': [{'extension': [{'url': 'text', 'valueString': 'Not Reported'}],
#                 'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race'},
#                {'extension': [{'url': 'text', 'valueString': 'Not Reported'}],
#                 'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity'}],
#  'gender': 'female',
#  'id': '51063',
#  'identifier': [{'value': 'Schiffman-232'},
#                 {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#                  'value': 'PT_SKYS7BYE'},
#                 {'system': 'urn:kids-first:unique-string',
#                  'value': 'Patient-SD_YGVA0E1C-PT_SKYS7BYE'}],
#  'meta': {'lastUpdated': '2021-11-16T08:31:55.743+00:00',
#           'profile': ['http://hl7.org/fhir/StructureDefinition/Patient'],
#           'source': '#ftuteWwUU3WhzzKW',
#           'tag': [{'code': 'SD_YGVA0E1C'}],
#           'versionId': '2'},
#  'resourceType': 'Patient'}

# %% [markdown]
# ## Retrieve phenotypic data for each subject from FHIR
# Save the results to a DataFrame

# %%
import pandas as pd
drs_data = []
ii=0
for pjson in patients:
    print (f"Patient/{pjson['id']}")
    drs_uri = getFiles(pjson['id'], 'bam')
    #print(drs_uri)
    if drs_uri:
        drs_id = drs_uri.split('/')[-1]
        drs_details = drsClient.getObject(drs_id)
        self_uri = drs_details['self_uri']
        url = drsClient.getAccessURL(drs_id, 's3')
        drs_data.append({'drs_uri':drs_uri, 'patient':pjson['id'], 'self_uri':self_uri, 'url':url})
    
    ii +=1
    if ii > 50: break
df = pd.DataFrame.from_dict(drs_data)
df
# Out:
# Patient/51063
# Total  Resources: 5
# # of documents for subject 51063 :5
# Unauthorized for that DRS id
# Patient/51052
# Total  Resources: 5
# # of documents for subject 51052 :5
# Patient/51059
# Total  Resources: 5
# # of documents for subject 51059 :5
# Patient/51064
# Total  Resources: 0
# # of documents for subject 51064 :0
# Patient/51056
# Total  Resources: 5
# # of documents for subject 51056 :5
# Patient/51051
# Total  Resources: 5
# # of documents for subject 51051 :5
# Patient/51040
# Total  Resources: 0
# # of documents for subject 51040 :0
# Patient/51058
# Total  Resources: 7
# # of documents for subject 51058 :7
# Patient/51060
# Total  Resources: 7
# # of documents for subject 51060 :7
# Patient/51049
# Total  Resources: 5
# # of documents for subject 51049 :5
# Patient/51046
# Total  Resources: 7
# # of documents for subject 51046 :7
# Patient/51047
# Total  Resources: 5
# # of documents for subject 51047 :5
# Patient/51053
# Total  Resources: 0
# # of documents for subject 51053 :0
# Patient/51048
# Total  Resources: 0
# # of documents for subject 51048 :0
# Patient/51045
# Total  Resources: 5
# # of documents for subject 51045 :5
# Patient/51043
# Total  Resources: 5
# # of documents for subject 51043 :5
# Patient/51055
# Total  Resources: 0
# # of documents for subject 51055 :0
# Patient/51039
# Total  Resources: 5
# # of documents for subject 51039 :5
# Patient/51044
# Total  Resources: 5
# # of documents for subject 51044 :5
# Patient/51041
# Total  Resources: 5
# # of documents for subject 51041 :5
# Patient/51031
# Total  Resources: 5
# # of documents for subject 51031 :5
# Patient/51042
# Total  Resources: 0
# # of documents for subject 51042 :0
# Patient/51038
# Total  Resources: 5
# # of documents for subject 51038 :5
# Patient/51032
# Total  Resources: 5
# # of documents for subject 51032 :5
# Patient/51035
# Total  Resources: 0
# # of documents for subject 51035 :0
# Patient/51036
# Total  Resources: 5
# # of documents for subject 51036 :5
# Patient/51037
# Total  Resources: 0
# # of documents for subject 51037 :0
# Patient/51033
# Total  Resources: 7
# # of documents for subject 51033 :7
# Patient/51029
# Total  Resources: 5
# # of documents for subject 51029 :5
# Patient/51030
# Total  Resources: 5
# # of documents for subject 51030 :5
# Patient/51028
# Total  Resources: 5
# # of documents for subject 51028 :5
# Patient/51025
# Total  Resources: 5
# # of documents for subject 51025 :5
# Patient/51034
# Total  Resources: 5
# # of documents for subject 51034 :5
# Patient/51021
# Total  Resources: 5
# # of documents for subject 51021 :5
# Patient/51020
# Total  Resources: 7
# # of documents for subject 51020 :7
# Patient/51026
# Total  Resources: 5
# # of documents for subject 51026 :5
# Patient/51023
# Total  Resources: 5
# # of documents for subject 51023 :5
# Patient/51017
# Total  Resources: 5
# # of documents for subject 51017 :5
# Patient/51027
# Total  Resources: 7
# # of documents for subject 51027 :7
# Patient/51011
# Total  Resources: 5
# # of documents for subject 51011 :5
# Patient/51024
# Total  Resources: 5
# # of documents for subject 51024 :5
# Patient/51022
# Total  Resources: 5
# # of documents for subject 51022 :5
# Patient/51014
# Total  Resources: 0
# # of documents for subject 51014 :0
# Patient/51013
# Total  Resources: 5
# # of documents for subject 51013 :5
# Patient/51012
# Total  Resources: 7
# # of documents for subject 51012 :7
# Patient/51019
# Total  Resources: 5
# # of documents for subject 51019 :5
# Patient/51009
# Total  Resources: 5
# # of documents for subject 51009 :5
# Patient/51018
# Total  Resources: 7
# # of documents for subject 51018 :7
# Patient/51008
# Total  Resources: 0
# # of documents for subject 51008 :0
# Patient/51015
# Total  Resources: 5
# # of documents for subject 51015 :5
# Patient/51004
# Total  Resources: 5
# # of documents for subject 51004 :5
#                                               drs_uri patient  \
# 0   drs://data.kidsfirstdrc.org/520bd083-82c1-4f00...   51063
# 1   drs://data.kidsfirstdrc.org/805860ce-d0e3-406c...   51052
# 2   drs://data.kidsfirstdrc.org/d41fce40-b916-4d28...   51059
# 3   drs://data.kidsfirstdrc.org/938490ec-11b6-4a16...   51056
# 4   drs://data.kidsfirstdrc.org/ea26fe12-a138-4325...   51051
# 5   drs://data.kidsfirstdrc.org/c9b83883-fc86-4ac5...   51058
# 6   drs://data.kidsfirstdrc.org/98eeb3eb-7652-4d74...   51060
# 7   drs://data.kidsfirstdrc.org/a052d1a9-e71c-4ccc...   51049
# 8   drs://data.kidsfirstdrc.org/31ef38aa-98d9-4b98...   51046
# 9   drs://data.kidsfirstdrc.org/05493152-872b-41a4...   51047
# 10  drs://data.kidsfirstdrc.org/8ffe7df7-a325-4697...   51045
# 11  drs://data.kidsfirstdrc.org/57b26440-fe2d-4235...   51043
# 12  drs://data.kidsfirstdrc.org/ee506958-6695-47f1...   51039
# 13  drs://data.kidsfirstdrc.org/39d079b9-ea06-480e...   51044
# 14  drs://data.kidsfirstdrc.org/7a219c23-fe75-4cc6...   51041
# 15  drs://data.kidsfirstdrc.org/414c56ef-4184-4330...   51031
# 16  drs://data.kidsfirstdrc.org/85ec9830-08e4-49e5...   51038
# 17  drs://data.kidsfirstdrc.org/ee35442a-2dfb-4da9...   51032
# 18  drs://data.kidsfirstdrc.org/13e249f5-823c-4374...   51036
# 19  drs://data.kidsfirstdrc.org/92e99c2c-8cee-465f...   51033
# 20  drs://data.kidsfirstdrc.org/8d4c4dff-af6c-453d...   51029
# 21  drs://data.kidsfirstdrc.org/6d69a86b-c7c5-422d...   51030
# 22  drs://data.kidsfirstdrc.org/aeebab10-3512-4fda...   51028
# 23  drs://data.kidsfirstdrc.org/1298e48e-688c-4cea...   51025
# 24  drs://data.kidsfirstdrc.org/dcdcd297-e464-44c3...   51034
# 25  drs://data.kidsfirstdrc.org/b4620d99-b35a-4ecd...   51021
# 26  drs://data.kidsfirstdrc.org/e0bd6fcc-7895-4392...   51020
# 27  drs://data.kidsfirstdrc.org/5f949e7b-7113-4e1f...   51026
# 28  drs://data.kidsfirstdrc.org/7dbc04e6-ac67-4ff5...   51023
# 29  drs://data.kidsfirstdrc.org/1364dca4-1083-40bb...   51017
# 30  drs://data.kidsfirstdrc.org/116209d6-8850-489e...   51027
# 31  drs://data.kidsfirstdrc.org/68b76631-b528-4a65...   51011
# 32  drs://data.kidsfirstdrc.org/e34ec09f-0957-498f...   51024
# 33  drs://data.kidsfirstdrc.org/78dff19c-5bd7-450c...   51022
# 34  drs://data.kidsfirstdrc.org/68549483-5975-49c7...   51013
# 35  drs://data.kidsfirstdrc.org/87c3470c-d977-412b...   51012
# 36  drs://data.kidsfirstdrc.org/35d3bbba-f430-4ff8...   51019
# 37  drs://data.kidsfirstdrc.org/e2624dc8-a5ef-41c1...   51009
# 38  drs://data.kidsfirstdrc.org/4e5af417-bf31-479d...   51018
# 39  drs://data.kidsfirstdrc.org/dfa893c2-8f37-4f4e...   51015
# 40  drs://data.kidsfirstdrc.org/005d8132-d976-40b9...   51004
#
#                                              self_uri  \
# 0   drs://dg.F82A1A:520bd083-82c1-4f00-abf5-ca1783...
# 1   drs://dg.F82A1A:805860ce-d0e3-406c-b652-c60f72...
# 2   drs://dg.F82A1A:d41fce40-b916-4d28-a294-5364ad...
# 3   drs://dg.F82A1A:938490ec-11b6-4a16-ac42-e81df1...
# 4   drs://dg.F82A1A:ea26fe12-a138-4325-a783-d881ed...
# 5   drs://dg.F82A1A:c9b83883-fc86-4ac5-95b2-cb1aab...
# 6   drs://dg.F82A1A:98eeb3eb-7652-4d74-b565-c00aa5...
# 7   drs://dg.F82A1A:a052d1a9-e71c-4ccc-a4ab-e6cdf0...
# 8   drs://dg.F82A1A:31ef38aa-98d9-4b98-ac56-dd7a3a...
# 9   drs://dg.F82A1A:05493152-872b-41a4-b2aa-d7a23b...
# 10  drs://dg.F82A1A:8ffe7df7-a325-4697-9690-a8703c...
# 11  drs://dg.F82A1A:57b26440-fe2d-4235-ae9b-016340...
# 12  drs://dg.F82A1A:ee506958-6695-47f1-a759-5c2f28...
# 13  drs://dg.F82A1A:39d079b9-ea06-480e-8eca-0fd04d...
# 14  drs://dg.F82A1A:7a219c23-fe75-4cc6-b714-88bcc9...
# 15  drs://dg.F82A1A:414c56ef-4184-4330-9775-bb0c6e...
# 16  drs://dg.F82A1A:85ec9830-08e4-49e5-9750-0f48bb...
# 17  drs://dg.F82A1A:ee35442a-2dfb-4da9-8542-010040...
# 18  drs://dg.F82A1A:13e249f5-823c-4374-863f-078759...
# 19  drs://dg.F82A1A:92e99c2c-8cee-465f-a1b0-cf7194...
# 20  drs://dg.F82A1A:8d4c4dff-af6c-453d-ba61-ec844d...
# 21  drs://dg.F82A1A:6d69a86b-c7c5-422d-a7f1-883b31...
# 22  drs://dg.F82A1A:aeebab10-3512-4fda-90b2-470d52...
# 23  drs://dg.F82A1A:1298e48e-688c-4cea-9cbc-edd226...
# 24  drs://dg.F82A1A:dcdcd297-e464-44c3-a10b-80dc44...
# 25  drs://dg.F82A1A:b4620d99-b35a-4ecd-8aef-ceecc2...
# 26  drs://dg.F82A1A:e0bd6fcc-7895-4392-9487-c5559e...
# 27  drs://dg.F82A1A:5f949e7b-7113-4e1f-9107-87aa42...
# 28  drs://dg.F82A1A:7dbc04e6-ac67-4ff5-a49a-eefa54...
# 29  drs://dg.F82A1A:1364dca4-1083-40bb-8f76-228fce...
# 30  drs://dg.F82A1A:116209d6-8850-489e-8289-4cf2bd...
# 31  drs://dg.F82A1A:68b76631-b528-4a65-af94-d12145...
# 32  drs://dg.F82A1A:e34ec09f-0957-498f-b136-834090...
# 33  drs://dg.F82A1A:78dff19c-5bd7-450c-85fe-8baa5a...
# 34  drs://dg.F82A1A:68549483-5975-49c7-bd3d-091c61...
# 35  drs://dg.F82A1A:87c3470c-d977-412b-a36f-8b4e3c...
# 36  drs://dg.F82A1A:35d3bbba-f430-4ff8-8bc1-810ea7...
# 37  drs://dg.F82A1A:e2624dc8-a5ef-41c1-b01b-e6028d...
# 38  drs://dg.F82A1A:4e5af417-bf31-479d-b209-de00bf...
# 39  drs://dg.F82A1A:dfa893c2-8f37-4f4e-ae93-b489c9...
# 40  drs://dg.F82A1A:005d8132-d976-40b9-a747-c80349...
#
#                                                   url
# 0                                                None
# 1   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 2   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 3   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 4   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 5   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 6   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 7   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 8   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 9   https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 10  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 11  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 12  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 13  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 14  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 15  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 16  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 17  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 18  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 19  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 20  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 21  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 22  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 23  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 24  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 25  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 26  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 27  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 28  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 29  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 30  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 31  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 32  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 33  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 34  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 35  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 36  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 37  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 38  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 39  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...
# 40  https://kf-seq-data-washu.s3.amazonaws.com/Ewi...

# %%
patient_id = '51063'
q = f'DocumentReference?subject=Patient/51020'

print(q)
docs = runQuery(q)
print(len(docs))

#f"{FHIR_SERVER}/DocumentReference?subject=Patient/{subject_id}"
# Out:
# DocumentReference?subject=Patient/51020
# Total  Resources: 7
# 7

# %%
q = f'Observation?subject=Patient/{patient_id}'
print(q)
observations = runQuery(q)
print(len(observations))
# Out:
# Observation?subject=Patient/51063
# Total  Resources: 1
# 1

# %%
observations
# Out:
# [{'resourceType': 'Observation',
#   'id': '51331',
#   'meta': {'versionId': '1',
#    'lastUpdated': '2021-10-14T19:15:40.213+00:00',
#    'source': '#fYB2lw2s2oPs1vCF',
#    'profile': ['https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/family-relationship']},
#   'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/family-relationships/',
#     'value': 'FR_XP292D7F'},
#    {'system': 'urn:kids-first:unique-string',
#     'value': 'Observation-PT_28H2AWQ8-Father-PT_MSB54TSM'}],
#   'status': 'final',
#   'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-RoleCode',
#      'code': 'FAMMEMB',
#      'display': 'family member'}],
#    'text': 'Family relationship'},
#   'subject': {'reference': 'Patient/51020'},
#   'focus': [{'reference': 'Patient/51021'}],
#   'valueCodeableConcept': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-RoleCode',
#      'code': 'FTH',
#      'display': 'father'}],
#    'text': 'Father'}}]

# %%
import pandas as pd
mySubjects = []
for pjson in patients:
    #sjson = s.serialize()
    #patientID = sjson['individual']['reference']
    #thisSubject = {"patientID":patientID}
    #patients = client.resources('Patient')
    #p = patients.search(_id=patientID).get()
    #pjson=p.serialize()
    #print(json.dumps(pjson, indent=3))
    

    #print("Observations",'.'*20)
    patientID = f"Patient/{pjson['id']}"
    #resources = client.resources('')
    observations = runQuery(f'Observation?subject=Patient/{patientID}')
    #observations = resources.search(subject=patientID).fetch_all()
    on = 0
    csn = 0
    fmn = 0
    for ojson in observations:
        on = on+1
        #ojson=o.serialize()
        #print(json.dumps(ojson, indent=3))
        if ojson['code']['text'] == 'Clinical status':
            csn +=1
            thisSubject['ClinStatus{}'.format(csn)] = ojson['valueCodeableConcept']['text']
            #thisSubject['CS{}_code'.format(csn)] = ojson['code']['coding'][0]['code']
        '''
        elif ojson['code']['coding'][0]['code'] == 'FAMMEMB':
            fmn +=1
            thisSubject['FamMember{}'.format(fmn)] = ojson['valueCodeableConcept']['text']
            thisSubject['FamMember{}_focus'.format(fmn)] = ojson['focus'][0]['reference']
            #thisSubject['O{}_code'.format(on)] = ojson['code']['coding'][0]['code']

        else:
            thisSubject['O{}_valuetext'.format(on)] = ojson['valueCodeableConcept']['text']
            thisSubject['O{}_code'.format(on)] = ojson['code']['coding'][0]['code']

        print("."*50)
        '''

    #print("Conditions",'+'*20)
    #resources = client.resources('Condition')
    #conditions = resources.search(subject=patientID).fetch_all()
    conditions = runQuery(f'Condition?patientID={patientID}')
    cn = 0
    for cjson in conditions:
        cn += 1
        #cjson=c.serialize()
        #print(json.dumps(cjson, indent=3))
        #print("+"*50)
        thisSubject['Cndtn{}_codetext'.format(cn)] = c['code']['text']
        cdn = 0
        if 'coding' in c['code']:
            for cd in c['code']['coding']:
                cdn +=1
                thisSubject['Cndtn{}_code{}'.format(cn,cdn)] = cd['code']

    mySubjects.append(thisSubject)
    #print('_'*50)
    
df = pd.DataFrame(mySubjects)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_73464/3022108309.py in <module>
#      14     patientID = f"Patient/{pjson['id']}"
#      15     #resources = client.resources('')
# ---> 16     observations = runQuery(f'Observation?patientID={patientID}')
#      17     #observations = resources.search(subject=patientID).fetch_all()
#      18     on = 0
#
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_73464/955695700.py in runQuery(query)
#       2     r = s.get(f"{FHIR_SERVER}/{query}")
#       3     first_bundle = r.json()
# ----> 4     all_bundles = resolve_pages(first_bundle)
#       5
#       6     resources = [entry['resource'] for bundle in all_bundles for entry in bundle['entry']]
#
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_73464/3621109856.py in resolve_pages(bundle)
#       1 # Resolves all pages for the bundle. Returns an array with all Bundles, including the original Bundle.
#       2 def resolve_pages(bundle):
# ----> 3     next_page_link = next(filter(lambda link: link['relation'] == 'next', bundle['link']), None)
#       4     if next_page_link:
#       5         next_page = s.get(next_page_link['url']).json()
#
# KeyError: 'link'

# %%
df
# Out:
#         patientID       ClinStatus1       ClinStatus2     Cndtn1_codetext  \
# 0  Patient/576466             Alive             Alive                 NaN
# 1  Patient/576465             Alive             Alive                 ALL
# 2  Patient/576467             Alive             Alive                 NaN
# 3  Patient/576473             Alive             Alive                 NHL
# 4  Patient/576468             Alive             Alive                  HL
# 5  Patient/576474             Alive             Alive   Hodgkins Lymphoma
# 6  Patient/576470             Alive             Alive  Hodgkin's Lymphoma
# 7  Patient/576469             Alive             Alive                 NaN
# 8  Patient/576472             Alive             Alive                 NaN
# 9  Patient/576450  Reported Unknown  Reported Unknown                  HL
#
#     Cndtn1_code1 Cndtn1_code2
# 0            NaN          NaN
# 1  MONDO:0004967   NCIT:C3167
# 2            NaN          NaN
# 3  MONDO:0018908   NCIT:C3211
# 4  MONDO:0004952   NCIT:C9357
# 5  MONDO:0004952   NCIT:C9357
# 6  MONDO:0004620  NCIT:C24182
# 7            NaN          NaN
# 8            NaN          NaN
# 9  MONDO:0004952   NCIT:C9357

# %% [markdown]
# Use DRSMetaresolver to direct requests for DRS URIs to the right DRS server

# %%
from fasp.loc import DRSMetaResolver
drsClient = DRSMetaResolver()
# Out:
# Searching the GA4GH registry for org.ga4gh:drs services
# GA4GH registry unavailable, cannot get registered DRS services.
# Continuing with locally known DRS services.

# %% [markdown]
# Set up a function to retrieve a DRS id from the FHIR server

# %%
r = s.get(f"{FHIR_SERVER}/DocumentReference?subject=Patient/51063")
bundle = r.json()
print_bundle(bundle)
# Out:
# {'resourceType': 'Bundle',
#  'id': 'ea70c81d-a496-4425-8cba-fa5a7e06b50a',
#  'meta': {'lastUpdated': '2022-06-24T22:38:49.282+00:00'},
#  'type': 'searchset',
#  'total': 5,
#  'link': [{'relation': 'self',
#    'url': 'https://kf-api-fhir-service.kidsfirstdrc.org/DocumentReference?subject=Patient%2F51063'}],
#  'entry': [{'fullUrl': 'https://kf-api-fhir-service.kidsfirstdrc.org/DocumentReference/394851',
#    'resource': {'resourceType': 'DocumentReference',
#     'id': '394851',
#     'meta': {'versionId': '3',
#      'lastUpdated': '2022-01-18T23:05:04.173+00:00',
#      'source': '#pegoPWj2pe9YdkYf',
#      'profile': ['https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference'],
#      'tag': [{'code': 'SD_YGVA0E1C'}]},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/',
#       'value': 'GF_61JFHQKF'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'DocumentReference-SD_YGVA0E1C-GF_61JFHQKF'}],
#     'status': 'current',
#     'docStatus': 'final',
#     'type': {'text': 'gVCF'},
#     'subject': {'reference': 'Patient/51063'},
#     'securityLabel': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#         'code': 'R',
#         'display': 'restricted'}],
#       'text': 'True'},
#      {'text': 'SD_YGVA0E1C'},
#      {'coding': [{'code': 'c999'}], 'text': 'phs001228.c999'}],
#     'content': [{'attachment': {'url': 'drs://data.kidsfirstdrc.org/99ef25b4-c277-4c5a-b1cd-4490be373fdb'}},
#      {'attachment': {'extension': [{'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size',
#          'valueDecimal': 11356427306},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'md5'}],
#           'text': '962fbfde22ed2c8f389230a7d986ecfe'}},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'sha256'}],
#           'text': '6e4abb6c1bb89aefb5e8e502dfa16a75e9fafb37aac3e828c5ee2a888ea165d3'}}],
#        'url': 's3://kf-study-us-east-1-prd-sd-ygva0e1c/harmonized/gvcf/e3cf2dae-d144-422e-a979-ffb935b38001.g.vcf.gz',
#        'title': 'e3cf2dae-d144-422e-a979-ffb935b38001.g.vcf.gz'},
#       'format': {'display': 'gVCF'}}]},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'https://kf-api-fhir-service.kidsfirstdrc.org/DocumentReference/394848',
#    'resource': {'resourceType': 'DocumentReference',
#     'id': '394848',
#     'meta': {'versionId': '3',
#      'lastUpdated': '2022-01-18T23:05:04.265+00:00',
#      'source': '#iVKLr5kiC9K32hHo',
#      'profile': ['https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference'],
#      'tag': [{'code': 'SD_YGVA0E1C'}]},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/',
#       'value': 'GF_GKXYRKB4'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'DocumentReference-SD_YGVA0E1C-GF_GKXYRKB4'}],
#     'status': 'current',
#     'docStatus': 'final',
#     'type': {'text': 'gVCF Index'},
#     'subject': {'reference': 'Patient/51063'},
#     'securityLabel': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#         'code': 'R',
#         'display': 'restricted'}],
#       'text': 'True'},
#      {'text': 'SD_YGVA0E1C'},
#      {'coding': [{'code': 'c999'}], 'text': 'phs001228.c999'}],
#     'content': [{'attachment': {'url': 'drs://data.kidsfirstdrc.org/5d998db4-24a2-41cb-911e-2db41439e33a'}},
#      {'attachment': {'extension': [{'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size',
#          'valueDecimal': 4287606},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'md5'}],
#           'text': '783ea5848609db283c65bb53a78b0577'}},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'sha256'}],
#           'text': 'bc6b358a29fd96fde429f87018322058d0b03a202441c4378134ae4acef210ea'}}],
#        'url': 's3://kf-study-us-east-1-prd-sd-ygva0e1c/harmonized/gvcf/e3cf2dae-d144-422e-a979-ffb935b38001.g.vcf.gz.tbi',
#        'title': 'e3cf2dae-d144-422e-a979-ffb935b38001.g.vcf.gz.tbi'},
#       'format': {'display': 'tbi'}}]},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'https://kf-api-fhir-service.kidsfirstdrc.org/DocumentReference/394846',
#    'resource': {'resourceType': 'DocumentReference',
#     'id': '394846',
#     'meta': {'versionId': '3',
#      'lastUpdated': '2022-01-18T23:05:04.209+00:00',
#      'source': '#iOj7WTL5iCl8q8Sk',
#      'profile': ['https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference'],
#      'tag': [{'code': 'SD_YGVA0E1C'}]},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/',
#       'value': 'GF_6D4KY8PE'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'DocumentReference-SD_YGVA0E1C-GF_6D4KY8PE'}],
#     'status': 'current',
#     'docStatus': 'final',
#     'type': {'text': 'Aligned Reads'},
#     'subject': {'reference': 'Patient/51063'},
#     'securityLabel': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#         'code': 'R',
#         'display': 'restricted'}],
#       'text': 'True'},
#      {'text': 'SD_YGVA0E1C'},
#      {'coding': [{'code': 'c999'}], 'text': 'phs001228.c999'}],
#     'content': [{'attachment': {'url': 'drs://data.kidsfirstdrc.org/520bd083-82c1-4f00-abf5-ca1783d751aa'}},
#      {'attachment': {'extension': [{'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size',
#          'valueDecimal': 59215639645},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'md5'}],
#           'text': '7b595bb3dc46b5df4107c395d12ccb47'}},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'sha256'}],
#           'text': 'ad41e608ed9499b4f410ffdca88fea9e4598d5f0a1f73aebc8d1bc628f7123b8'}}],
#        'url': 's3://kf-seq-data-washu/EwingSarcoma//db3cb5310167464996be1ac9a3cd1468.bam',
#        'title': 'db3cb5310167464996be1ac9a3cd1468.bam'},
#       'format': {'display': 'bam'}}]},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'https://kf-api-fhir-service.kidsfirstdrc.org/DocumentReference/394845',
#    'resource': {'resourceType': 'DocumentReference',
#     'id': '394845',
#     'meta': {'versionId': '3',
#      'lastUpdated': '2022-01-18T23:05:04.270+00:00',
#      'source': '#bmnyzlzZSaBI3uHk',
#      'profile': ['https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference'],
#      'tag': [{'code': 'SD_YGVA0E1C'}]},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/',
#       'value': 'GF_H4ZB2F6F'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'DocumentReference-SD_YGVA0E1C-GF_H4ZB2F6F'}],
#     'status': 'current',
#     'docStatus': 'final',
#     'type': {'text': 'Aligned Reads'},
#     'subject': {'reference': 'Patient/51063'},
#     'securityLabel': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#         'code': 'R',
#         'display': 'restricted'}],
#       'text': 'True'},
#      {'text': 'SD_YGVA0E1C'},
#      {'coding': [{'code': 'c999'}], 'text': 'phs001228.c999'}],
#     'content': [{'attachment': {'url': 'drs://data.kidsfirstdrc.org/5558e693-4dd6-4cd8-a0f9-88417acdbabb'}},
#      {'attachment': {'extension': [{'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size',
#          'valueDecimal': 18142513567},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'md5'}],
#           'text': '99142a3673a964c919522d10c28f224e'}},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'sha256'}],
#           'text': '06c49545bfdf9d3f3971ccaf0d6e997a2eaaef8b8f4fadd0e1d7dc33ad182008'}}],
#        'url': 's3://kf-study-us-east-1-prd-sd-ygva0e1c/harmonized/cram/e3cf2dae-d144-422e-a979-ffb935b38001.cram',
#        'title': 'e3cf2dae-d144-422e-a979-ffb935b38001.cram'},
#       'format': {'display': 'cram'}}]},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'https://kf-api-fhir-service.kidsfirstdrc.org/DocumentReference/394844',
#    'resource': {'resourceType': 'DocumentReference',
#     'id': '394844',
#     'meta': {'versionId': '3',
#      'lastUpdated': '2022-01-18T23:05:04.230+00:00',
#      'source': '#WcReMSjDdWlmRM7Z',
#      'profile': ['https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference'],
#      'tag': [{'code': 'SD_YGVA0E1C'}]},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/',
#       'value': 'GF_78D87PFZ'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'DocumentReference-SD_YGVA0E1C-GF_78D87PFZ'}],
#     'status': 'current',
#     'docStatus': 'final',
#     'type': {'text': 'Aligned Reads Index'},
#     'subject': {'reference': 'Patient/51063'},
#     'securityLabel': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#         'code': 'R',
#         'display': 'restricted'}],
#       'text': 'True'},
#      {'text': 'SD_YGVA0E1C'},
#      {'coding': [{'code': 'c999'}], 'text': 'phs001228.c999'}],
#     'content': [{'attachment': {'url': 'drs://data.kidsfirstdrc.org/7e282897-bbb3-49a2-b940-0e20c67f75f9'}},
#      {'attachment': {'extension': [{'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size',
#          'valueDecimal': 1062966},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'md5'}],
#           'text': 'fb94ae1f2a24a0b96746815759034fc5'}},
#         {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#          'valueCodeableConcept': {'coding': [{'display': 'sha256'}],
#           'text': '1336c3d724bcca2c9b15ea44cd5d4cbf8e95d9a767a9a152ac5555d8a2b3daa2'}}],
#        'url': 's3://kf-study-us-east-1-prd-sd-ygva0e1c/harmonized/cram/e3cf2dae-d144-422e-a979-ffb935b38001.cram.crai',
#        'title': 'e3cf2dae-d144-422e-a979-ffb935b38001.cram.crai'},
#       'format': {'display': 'crai'}}]},
#    'search': {'mode': 'match'}}]}

# %%
def getFiles(subject_id, docFormat):
    #r = s.get(f"{FHIR_SERVER}/DocumentReference?subject=Patient/{subject_id}")
    #bundle = r.json()
    #resources = resources.search(subject=subject_id).limit(1000)
    # The following works for the data for certain studies/patients, but not others
    # resources.search(subject=subject_id, format__text=docFormat)
    # So we do a query just based on subject, and then filter the results ourselves
    # The following filters for the required format
    myDocs = []
    retval = None
    documents =runQuery(f"DocumentReference?subject=Patient/{subject_id}")
    #documents = list(map(lambda e: e['resource'], bundle['entry']))
    #with open("docs.json", "w") as f:
        #print(json.dump(documents, f, indent=3))
        #print(json.dumps(documents[0],indent=3))

    print("# of documents for subject {} :{}".format(subject_id, len(documents)))

    for d in documents:
        #djson = d.json()
        #print(json.dumps(d, indent=3))

        #print(d['content'][0])
        #print(d['content'][1]['format']['display'])


        if d['content'][1]['format']['display'] == docFormat:
           retval = d['content'][0]['attachment']['url']
    return retval

# %%
drsuri = getFiles('51020', 'bam')
drsuri
# Out:
# Total  Resources: 7
# # of documents for subject 51020 :7
# 'drs://data.kidsfirstdrc.org/e0bd6fcc-7895-4392-9487-c5559ec5d9a1'

# %%
drsuri = getFiles('49936', 'bam')
drsuri
drs_id = drsuri.split('/')[-1]
drs_id
# Out:
# Total  Resources: 5
# # of documents for subject 49936 :5
# 'c2bcf2f7-e262-4e37-9262-217a647e9186'

# %% [markdown]
# Iterate over each subject to submit the correspinding bam file to the Seven Bridges WES server. The worflow will execute SAMTools Stats on each file.

# %%
subj_id = {'individual':{'reference':'51020'}}
subjects =[subj_id]
print(subjects)
# Out:
# [{'individual': {'reference': '51020'}}]

# %%
drsuri = getFiles(subjects[0]['individual']['reference'], 'bam')
print(drsuri)
drs_id = drsuri.split('/')[-1]
drs_id
# Out:
# Total  Resources: 7
# # of documents for subject 51020 :7
# drs://data.kidsfirstdrc.org/e0bd6fcc-7895-4392-9487-c5559ec5d9a1
# 'e0bd6fcc-7895-4392-9487-c5559ec5d9a1'

# %%
from fasp.loc import kfDRSClient
drsClient = kfDRSClient("~/.keys/kf_credentials.json")

# %%
drsClient.getObject(drs_id)
# Out:
# {'access_methods': [{'access_id': 's3',
#    'access_url': {'url': 's3://kf-seq-data-washu/EwingSarcoma//db3cb5310167464996be1ac9a3cd1468.bam'},
#    'region': '',
#    'type': 's3'}],
#  'aliases': [],
#  'checksums': [{'checksum': 'ad41e608ed9499b4f410ffdca88fea9e4598d5f0a1f73aebc8d1bc628f7123b8',
#    'type': 'sha256'},
#   {'checksum': '7b595bb3dc46b5df4107c395d12ccb47', 'type': 'md5'}],
#  'created_time': '2021-07-13T17:17:51.162204',
#  'description': None,
#  'form': 'object',
#  'id': '520bd083-82c1-4f00-abf5-ca1783d751aa',
#  'mime_type': 'application/json',
#  'name': 'db3cb5310167464996be1ac9a3cd1468.bam',
#  'self_uri': 'drs://dg.F82A1A:520bd083-82c1-4f00-abf5-ca1783d751aa',
#  'size': 59215639645,
#  'updated_time': '2021-09-14T14:18:21.113043',
#  'version': 'e01b4f4f'}

# %%
drsClient.getAccessURL(drs_id, 's3')
# Out:
# Unauthorized for that DRS id

# %%
from fasp.workflow import sbcgcWESClient
from fasp.runner import FASPRunner
import datetime

faspRunner = FASPRunner()
runNote = 'KF Ewings file retrieved from NCPI FHIR Server and computed on SB'

# Set up WES Client for WES server of our choice
settings = faspRunner.settings
wesClient = sbcgcWESClient(settings['SevenBridgesProject'])

drsClient = kfDRSClient("~/.keys/kf_credentials.json")

run_ids = []

# repeat for each row of the query
limit = 5
nn= 0
for pjson in patients:
    patientID = pjson['id']
    print (f"Patient/{patientID}")
    drsuri = getFiles(patientID, 'bam')
    
    #DRS ids stored in the NCPI FHIR server include the host prefix. Just get the id
    #subjectID = sjson['id']
    
    if drsuri:
        print("subject={}, DRS URI={}".format(patientID, drsuri))
        #drsID = drsuri.split('/')[-1]
        #Call the DRS server to get file details
        # We're going to keep the file size
        drs_id = drsuri.split('/')[-1]
        objInfo = drsClient.getObject(drs_id)
        print(objInfo)
        fileSize = objInfo['size']
        # Use DRS to get the URL
        url = drsClient.getAccessURL(drs_id,'s3')
        # Step 3 - Run a pipeline on the file at the drs url
        if url:
            outfile = "{}.txt".format(patientID)
            pipeline_id = wesClient.runWorkflow(url, outfile)
            print('submitted:{}'.format(pipeline_id))
        else:
            print("could not get URL for subject={}".format(patientID))
    else:
        print("No bam for subject={}".format(patientID))
        pipeline_id = None
        fileSize = None
        

    via = 'WES'
    note = 'WES samtools on KF test'
    time = datetime.datetime.now().strftime("%m/%d/%Y, %H:%M:%S")
    faspRunner.logRun(time, via, note,  pipeline_id, outfile, str(fileSize),
        client, drsClient, wesClient)
    run_ids.append({"patientID":patientID, "run_id":pipeline_id})
    
    nn += 1
    if nn > limit:
        break

runs_df = pd.DataFrame(run_ids)
runs_df
# Out:
# Running /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_73464/261786707.py
# Patient/51063
# Total  Resources: 5
# # of documents for subject 51063 :5
# subject=51063, DRS URI=drs://data.kidsfirstdrc.org/520bd083-82c1-4f00-abf5-ca1783d751aa
# {'access_methods': [{'access_id': 's3', 'access_url': {'url': 's3://kf-seq-data-washu/EwingSarcoma//db3cb5310167464996be1ac9a3cd1468.bam'}, 'region': '', 'type': 's3'}], 'aliases': [], 'checksums': [{'checksum': 'ad41e608ed9499b4f410ffdca88fea9e4598d5f0a1f73aebc8d1bc628f7123b8', 'type': 'sha256'}, {'checksum': '7b595bb3dc46b5df4107c395d12ccb47', 'type': 'md5'}], 'created_time': '2021-07-13T17:17:51.162204', 'description': None, 'form': 'object', 'id': '520bd083-82c1-4f00-abf5-ca1783d751aa', 'mime_type': 'application/json', 'name': 'db3cb5310167464996be1ac9a3cd1468.bam', 'self_uri': 'drs://dg.F82A1A:520bd083-82c1-4f00-abf5-ca1783d751aa', 'size': 59215639645, 'updated_time': '2021-09-14T14:18:21.113043', 'version': 'e01b4f4f'}
# Unauthorized for that DRS id
# could not get URL for subject=51063
# Patient/51052
# Total  Resources: 5
# # of documents for subject 51052 :5
# subject=51052, DRS URI=drs://data.kidsfirstdrc.org/805860ce-d0e3-406c-b652-c60f72305eb9
# {'access_methods': [{'access_id': 's3', 'access_url': {'url': 's3://kf-seq-data-washu/EwingSarcoma//9ac3002273444eb7897911da173092bf.bam'}, 'region': '', 'type': 's3'}], 'aliases': [], 'checksums': [{'checksum': '019701794cba931ae44a5fef6ff7bb01d614d941de5c70754c18e7c12e1c6f5d', 'type': 'sha256'}, {'checksum': '8444b75d5c4e3e659a9f1a056f83f463', 'type': 'md5'}], 'created_time': '2021-07-13T18:36:40.262787', 'description': None, 'form': 'object', 'id': '805860ce-d0e3-406c-b652-c60f72305eb9', 'mime_type': 'application/json', 'name': '9ac3002273444eb7897911da173092bf.bam', 'self_uri': 'drs://dg.F82A1A:805860ce-d0e3-406c-b652-c60f72305eb9', 'size': 63251841828, 'updated_time': '2022-05-10T21:25:07.655571', 'version': 'c633c683'}
# https://cgc-ga4gh-api.sbgenomics.com/ga4gh/wes/v1
# submitted:8f3b22d7-a02e-461b-ae7a-dc2a11e5022a
# Patient/51059
# Total  Resources: 5
# # of documents for subject 51059 :5
# subject=51059, DRS URI=drs://data.kidsfirstdrc.org/d41fce40-b916-4d28-a294-5364adfe08df
# {'access_methods': [{'access_id': 's3', 'access_url': {'url': 's3://kf-seq-data-washu/EwingSarcoma//d443b834e4e6410a97e0d17cd90d539c.bam'}, 'region': '', 'type': 's3'}], 'aliases': [], 'checksums': [{'checksum': 'a2a36e052b5ce7c4f00346f27826c4b257c40d3032709911163dff29e1d6cad2', 'type': 'sha256'}, {'checksum': '3dc21d32e8621627f54678be06792cdc', 'type': 'md5'}], 'created_time': '2021-07-13T17:22:26.613222', 'description': None, 'form': 'object', 'id': 'd41fce40-b916-4d28-a294-5364adfe08df', 'mime_type': 'application/json', 'name': 'd443b834e4e6410a97e0d17cd90d539c.bam', 'self_uri': 'drs://dg.F82A1A:d41fce40-b916-4d28-a294-5364adfe08df', 'size': 52618180450, 'updated_time': '2022-05-10T15:41:21.439920', 'version': '0d2080aa'}
# https://cgc-ga4gh-api.sbgenomics.com/ga4gh/wes/v1
# submitted:5aedde42-7a27-4991-844a-6fbfc17f932e
# Patient/51064
# Total  Resources: 0
# # of documents for subject 51064 :0
# No bam for subject=51064
# Patient/51056
# Total  Resources: 5
# # of documents for subject 51056 :5
# subject=51056, DRS URI=drs://data.kidsfirstdrc.org/938490ec-11b6-4a16-ac42-e81df126b828
# {'access_methods': [{'access_id': 's3', 'access_url': {'url': 's3://kf-seq-data-washu/EwingSarcoma//0c3fca77b8254344902a7db192621977.bam'}, 'region': '', 'type': 's3'}], 'aliases': [], 'checksums': [{'checksum': '70066acc15e890e8e6cfb17f262e196e3a73714260137bf5ae4bd16adbbb068f', 'type': 'sha256'}, {'checksum': 'a36c01e45f15b72007643eb8c153b1e8', 'type': 'md5'}], 'created_time': '2021-07-13T17:43:47.512555', 'description': None, 'form': 'object', 'id': '938490ec-11b6-4a16-ac42-e81df126b828', 'mime_type': 'application/json', 'name': '0c3fca77b8254344902a7db192621977.bam', 'self_uri': 'drs://dg.F82A1A:938490ec-11b6-4a16-ac42-e81df126b828', 'size': 52753914562, 'updated_time': '2022-05-10T16:56:30.248544', 'version': 'd74bbf9c'}
# https://cgc-ga4gh-api.sbgenomics.com/ga4gh/wes/v1
# submitted:46978154-0027-45d0-9818-39fe8fbf702f
# Patient/51051
# Total  Resources: 5
# # of documents for subject 51051 :5
# subject=51051, DRS URI=drs://data.kidsfirstdrc.org/ea26fe12-a138-4325-a783-d881edd7a302
# {'access_methods': [{'access_id': 's3', 'access_url': {'url': 's3://kf-seq-data-washu/EwingSarcoma//27cebfe412624cc39f5e8ea84652ce3b.bam'}, 'region': '', 'type': 's3'}], 'aliases': [], 'checksums': [{'checksum': 'fdc487981c61661ffd97f5f7ff23a4dd4d4d47673eaeb1dd645575df75588654', 'type': 'sha256'}, {'checksum': '4bffc0ab3ec0c6461654530d10a1468d', 'type': 'md5'}], 'created_time': '2021-07-13T17:31:40.159121', 'description': None, 'form': 'object', 'id': 'ea26fe12-a138-4325-a783-d881edd7a302', 'mime_type': 'application/json', 'name': '27cebfe412624cc39f5e8ea84652ce3b.bam', 'self_uri': 'drs://dg.F82A1A:ea26fe12-a138-4325-a783-d881edd7a302', 'size': 49540489536, 'updated_time': '2022-05-10T20:18:11.269841', 'version': '3c4be406'}
# https://cgc-ga4gh-api.sbgenomics.com/ga4gh/wes/v1
# submitted:5ca73a9a-93b3-4950-93cd-7bfcea344065
#   patientID                                run_id
# 0     51063  350180ed-0558-427c-bf71-25d89d666a71
# 1     51052  8f3b22d7-a02e-461b-ae7a-dc2a11e5022a
# 2     51059  5aedde42-7a27-4991-844a-6fbfc17f932e
# 3     51064                                  None
# 4     51056  46978154-0027-45d0-9818-39fe8fbf702f
# 5     51051  5ca73a9a-93b3-4950-93cd-7bfcea344065

# %% [markdown]
# Check status of each run via the WES server

# %%
for index, row in runs_df.iterrows():
    if row['run_id'] != None:
        status = wesClient.getTaskStatus(row['run_id'])
        runs_df.at[index, "status"] = status
    else:
        print ('no run for {}'.format(row['patientID']))
runs_df
# Out:
# no run for 51064
#   patientID                                run_id    status
# 0     51063  350180ed-0558-427c-bf71-25d89d666a71  COMPLETE
# 1     51052  8f3b22d7-a02e-461b-ae7a-dc2a11e5022a  COMPLETE
# 2     51059  5aedde42-7a27-4991-844a-6fbfc17f932e  COMPLETE
# 3     51064                                  None       NaN
# 4     51056  46978154-0027-45d0-9818-39fe8fbf702f  COMPLETE
# 5     51051  5ca73a9a-93b3-4950-93cd-7bfcea344065  COMPLETE

# %% [markdown]
# Define function to download a file and to extract the result from the output file from SAMTools Stats

# %%
import requests
import os
def download(url, file_path):
    '''Download a file from a URL to a local file path'''
    with open(os.path.expanduser(file_path), "wb") as file:
        response = requests.get(url)
        file.write(response.content)
        
def getStats(filePath, statsList):
    ''' Extract values from a SAMTools Stats results file'''
    ### 
    
    retDict = {}
    f = open(filePath, "r")
    for x in f:
        if x.startswith('SN'):   
            parts = x.split('\t')
            statName = parts[1].split(':')[0]
            if statName in statsList:
                retDict[statName] = parts[2].rstrip()
    return retDict

# %% [markdown]
# For the completed workflows retrieve the results file and extract the required result values. Add the result values to a DataFrame.

# %%
from fasp.loc import sbcgcDRSClient
results_drs= sbcgcDRSClient("/Users/forei/.keys/sevenbridges_keys.json", "s3")
statsList = []
for index, row in runs_df.iterrows():
    if row['run_id'] != None and row['status'] == 'COMPLETE':
        log = wesClient.getRunLog(row['run_id'])
        results_drs_uri = log['outputs']['statistics']['path']
        print("DRS URI for results for subject {}: {}".format(row['patientID'] ,results_drs_uri))
        resultsDRSID = results_drs_uri.split('/')[-1]
        url = results_drs.getAccessURL(resultsDRSID,'s3')
        fileName = log['outputs']['statistics']['name']
        download(url, fileName)
        statsRequired = ['insert size average','insert size standard deviation']
        stats = getStats(fileName, statsRequired)
        #print(stats)
        stats['run_id'] = row['run_id']
        stats['patientID'] = row['patientID']
        statsList.append(stats)
        os.remove(fileName)
stats_df =  pd.DataFrame(statsList)
stats_df
# Out:
# DRS URI for results for subject 51063: drs://cgc-ga4gh-api.sbgenomics.com/62b64d6a4e3edb6b1c397b59
# DRS URI for results for subject 51052: drs://cgc-ga4gh-api.sbgenomics.com/62b67ee14e3edb6b1c3988c3
# DRS URI for results for subject 51059: drs://cgc-ga4gh-api.sbgenomics.com/62b67cc24e3edb6b1c398859
# DRS URI for results for subject 51056: drs://cgc-ga4gh-api.sbgenomics.com/62b67cdaf08fea477057664d
# DRS URI for results for subject 51051: drs://cgc-ga4gh-api.sbgenomics.com/62b67ca44e3edb6b1c39883d
#   insert size average insert size standard deviation  \
# 0               364.3                           83.7
# 1               365.8                           78.9
# 2               337.0                           73.6
# 3               405.7                           92.5
# 4               357.8                           82.0
#
#                                  run_id patientID
# 0  350180ed-0558-427c-bf71-25d89d666a71     51063
# 1  8f3b22d7-a02e-461b-ae7a-dc2a11e5022a     51052
# 2  5aedde42-7a27-4991-844a-6fbfc17f932e     51059
# 3  46978154-0027-45d0-9818-39fe8fbf702f     51056
# 4  5ca73a9a-93b3-4950-93cd-7bfcea344065     51051

# %%
final_df = pd.merge(
    df,
    stats_df,
    how="outer",
    left_on='patientID',
    right_on='patientID'
)
final_df.drop('run_id', axis=1, inplace=True)
final_df.drop('ClinStatus2', axis=1, inplace=True)

final_df
# Out:
#         patientID       ClinStatus1     Cndtn1_codetext   Cndtn1_code1  \
# 0  Patient/576466             Alive                 NaN            NaN
# 1  Patient/576465             Alive                 ALL  MONDO:0004967
# 2  Patient/576467             Alive                 NaN            NaN
# 3  Patient/576473             Alive                 NHL  MONDO:0018908
# 4  Patient/576468             Alive                  HL  MONDO:0004952
# 5  Patient/576474             Alive   Hodgkins Lymphoma  MONDO:0004952
# 6  Patient/576470             Alive  Hodgkin's Lymphoma  MONDO:0004620
# 7  Patient/576469             Alive                 NaN            NaN
# 8  Patient/576472             Alive                 NaN            NaN
# 9  Patient/576450  Reported Unknown                  HL  MONDO:0004952
#
#   Cndtn1_code2 insert size average insert size standard deviation
# 0          NaN               360.3                          112.1
# 1   NCIT:C3167               378.4                          116.0
# 2          NaN               365.1                          131.9
# 3   NCIT:C3211               346.4                          107.9
# 4   NCIT:C9357               350.7                          113.6
# 5   NCIT:C9357               371.8                           98.6
# 6  NCIT:C24182               357.5                          100.7
# 7          NaN               338.3                          102.0
# 8          NaN                 NaN                            NaN
# 9   NCIT:C9357               291.8                          130.0
