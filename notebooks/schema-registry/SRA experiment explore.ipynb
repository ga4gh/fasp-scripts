# %% [markdown]
# ## Demonstration of GA4GH schema repository with SRA sequencing Experiment Metadata
#
# NCBI SRA publishes attributes of sequencing runs and experiments in the Cloud via BigQuery and Athena. Details are provided [here](https://www.ncbi.nlm.nih.gov/sra/docs/sra-cloud-based-metadata-table/)
#
# The data in the table above derives from BioProject and BioSample. Besides a set of columns available for all studies in the table, the attributes column allows key-value pairs to be provided for custom attributes for a given study (BioPeoject).
#
# This notebook explores how a schema registry can assist in describing the custom metadata for specific studies. With this information it is possible to reconcile attributes across studies.
#
# For a set of six NCBI and EBI studies a schema was generated to list the project/study specific attributes.
#
# The studies are as follows:
# * sra_PRJEB10573 - [Characterization of RBP9 and RBP10, two developmentally regulated RNA-binding proteins in Trypanosoma brucei](https://www.ebi.ac.uk/ena/browser/view/PRJEB14125)
# * sra_PRJEB37886 - [COVID-19 Genomics UK (COG-UK) consortium](https://www.ebi.ac.uk/ena/browser/view/PRJEB37886)
# * sra_PRJEB1985 - [Whole genome re-sequencing of a single Bos taurus animal for SNP discovery](https://www.ebi.ac.uk/ena/browser/view/PRJEB1985)
# * sra_phs001554 - [dbGaP Colon Cancer study (BioProject PRJNA437032)](https://www.ncbi.nlm.nih.gov/bioproject/437032)
# * sra_scr_icac - [dbGaP Childhood Asthma study (BioProject PRJNA837686)](https://www.ncbi.nlm.nih.gov/bioproject/PRJNA837686)
# * sra_scr_udn_v5 - [dbGaP Undiagnosed Disease Network study (BioProject PRJNA350185)](https://www.ncbi.nlm.nih.gov/bioproject/PRJNA350185)
#
# These are a largely unrelated set of studies selected for the purpose of this demonstration. Others may be added.

# %% [markdown]
# #### Imports

# %%
import requests;

import json;

import xml.etree.ElementTree as ET

def prettyprint(a_dict):
    print(json.dumps(a_dict, indent=3))

def printline(char="_"):
    print(char*80)

# %%
base = "http://localhost:8080"

# %%
url = f"{base}/namespaces"
response = requests.get(url)
namespaces = response.json()['namespaces']
for namespace in namespaces:
    print( namespace['namespace_name'])
# Out:
# dbGaP
# dataconnect-demo
# expt-metadata

# %% [markdown]
# ### Fetch all schemas for the expt-metadata namespace

# %%
namespaces = ["expt-metadata"]
expt_schemas = {}
for namespace in namespaces:
    printline("=")
    print(f"getting schemas for namespace {namespace}")
    url = f"{base}/schemas/{namespace}/"
    response = requests.get(url)
    schemas = response.json()['schemas']
    printline()
    for schema in schemas:
        print( )
        url = f"{base}/schemas/{namespace}/{schema['schema_name']}/versions/v2"
        print(f"fetching schema {schema['schema_name']}")
        response = requests.get(url)
        response_schema = response.json()
        expt_schemas[schema['schema_name']] = response_schema
        #prettyprint( schema)
        printline()
# Out:
# ================================================================================
# getting schemas for namespace expt-metadata
# ________________________________________________________________________________
#
# fetching schema sra_PRJEB10573
# ________________________________________________________________________________
#
# fetching schema sra_PRJEB1985
# ________________________________________________________________________________
#
# fetching schema sra_PRJEB37886
# ________________________________________________________________________________
#
# fetching schema sra_phs001554
# ________________________________________________________________________________
#
# fetching schema sra_scr_icac
# ________________________________________________________________________________
#
# fetching schema sra_scr_udn_v5
# ________________________________________________________________________________

# %%
import pandas as pd

tab_list = []
include_single_values = False
for study_name, study_schema in expt_schemas.items():
    tab_row = {"study":study_name}
    for pname, prop_dict in study_schema['properties'].items():
        if include_single_values and prop_dict['unique_count'] == 1:
            tab_row[pname] = prop_dict['enums'][0]
        else:
            tab_row[pname] = prop_dict['$unique_count']
    tab_list.append(tab_row)
summary_df = pd.DataFrame.from_dict(tab_list)
summary_df.set_index('study', inplace=True)
summary_df
# Out:
#                 bases  broker_name_sam  bytes  cell_line_sam  \
# study
# sra_PRJEB10573      9              1.0      9            1.0
# sra_PRJEB1985      49              NaN     49            NaN
# sra_PRJEB37886   7511              3.0   7511            NaN
# sra_phs001554    2892              NaN   2892            NaN
# sra_scr_icac     1035              NaN   1035            NaN
# sra_scr_udn_v5   9847              NaN  10028            NaN
#
#                 cell_type_sam_ss_dpl37  common_name_sam  ena_first_public_sam  \
# study
# sra_PRJEB10573                     1.0              1.0                   1.0
# sra_PRJEB1985                      NaN              NaN                   NaN
# sra_PRJEB37886                     NaN              NaN                 465.0
# sra_phs001554                      NaN              NaN                   NaN
# sra_scr_icac                       NaN              NaN                   NaN
# sra_scr_udn_v5                     NaN              NaN                   NaN
#
#                 ena_last_update_sam  \
# study
# sra_PRJEB10573                  3.0
# sra_PRJEB1985                   NaN
# sra_PRJEB37886                270.0
# sra_phs001554                   NaN
# sra_scr_icac                    NaN
# sra_scr_udn_v5                  NaN
#
#                 experimental_factor__over_expression_dazl_exp  \
# study
# sra_PRJEB10573                                            2.0
# sra_PRJEB1985                                             NaN
# sra_PRJEB37886                                            NaN
# sra_phs001554                                             NaN
# sra_scr_icac                                              NaN
# sra_scr_udn_v5                                            NaN
#
#                 experimental_factor__over_expression_nanos3_exp  ...  \
# study                                                            ...
# sra_PRJEB10573                                              2.0  ...
# sra_PRJEB1985                                               NaN  ...
# sra_PRJEB37886                                              NaN  ...
# sra_phs001554                                               NaN  ...
# sra_scr_icac                                                NaN  ...
# sra_scr_udn_v5                                              NaN  ...
#
#                 gap_accession_sam  is_tumor_sam  molecular_data_type_sam  phs  \
# study
# sra_PRJEB10573                NaN           NaN                      NaN  NaN
# sra_PRJEB1985                 NaN           NaN                      NaN  NaN
# sra_PRJEB37886                NaN           NaN                      NaN  NaN
# sra_phs001554                 1.0           1.0                      1.0  5.0
# sra_scr_icac                  1.0           1.0                      NaN  1.0
# sra_scr_udn_v5                1.0           NaN                      2.0  1.0
#
#                 sex_calc  study_design_sam  study_disease_sam  study_name_sam  \
# study
# sra_PRJEB10573       NaN               NaN                NaN             NaN
# sra_PRJEB1985        NaN               NaN                NaN             NaN
# sra_PRJEB37886       NaN               NaN                NaN             NaN
# sra_phs001554        2.0               1.0                2.0             1.0
# sra_scr_icac         2.0               1.0                NaN             1.0
# sra_scr_udn_v5       2.0               1.0                2.0             1.0
#
#                 subject_is_affected_sam  submitted_subject_id_sam
# study
# sra_PRJEB10573                      NaN                       NaN
# sra_PRJEB1985                       NaN                       NaN
# sra_PRJEB37886                      NaN                       NaN
# sra_phs001554                       2.0                    2892.0
# sra_scr_icac                        NaN                    1035.0
# sra_scr_udn_v5                      3.0                    6469.0
#
# [6 rows x 66 columns]

# %% [markdown]
# ### Schema comparison across studies
#
# In the following table...
# * Each column represents a different study
# * Each row represents a different attribute key
# * The numbers indicate the number of unique values the given attribute takes for each study
# * A value of 0 indicates that the the attribute is not present in the schema for that study

# %%
pd.set_option('display.max_rows', None)
attribute_summary_df = summary_df.transpose()
attribute_summary_df.fillna(0, inplace=True)
for scname in expt_schemas.keys():
    attribute_summary_df[scname] = attribute_summary_df[scname].astype(int)
attribute_summary_df
# Out:
# study                                              sra_PRJEB10573  \
# bases                                                           9
# broker_name_sam                                                 1
# bytes                                                           9
# cell_line_sam                                                   1
# cell_type_sam_ss_dpl37                                          1
# common_name_sam                                                 1
# ena_first_public_sam                                            1
# ena_last_update_sam                                             3
# experimental_factor__over_expression_dazl_exp                   2
# experimental_factor__over_expression_nanos3_exp                 2
# external_id_sam                                                 9
# genetic_modification_sam                                        1
# genotype_sam_ss_dpl92                                           3
# insdc_center_name_sam                                           1
# insdc_first_public_sam                                          1
# insdc_last_update_sam                                           3
# insdc_status_sam                                                1
# run_file_create_date                                            9
# scientific_name_sam                                             1
# submitter_id_sam                                                9
# alias_sam                                                       0
# description_sam                                                 0
# sra_accession_sam                                               0
# title_sam                                                       0
# artic_primer_version_exp                                        0
# artic_protocol_version_exp                                      0
# assemblyname                                                    0
# collecting_institution_sam                                      0
# collection_date_sam                                             0
# collector_name_sam                                              0
# definition_for_seropositive_sample_sam                          0
# ena_last_update_sam_ss_dpl537                                   0
# geographic_location__country_and_or_sea__sam                    0
# geographic_location__region_and_locality__sam                   0
# host_common_name_sam                                            0
# host_health_state_sam                                           0
# host_scientific_name_sam                                        0
# host_sex_sam                                                    0
# host_subject_id_sam                                             0
# insdc_center_alias_sam                                          0
# isolate_sam_ss_dpl100                                           0
# max_cycle_threshold_sam                                         0
# min_cycle_threshold_sam                                         0
# organism_sam                                                    0
# receipt_date_sam                                                0
# sample_capture_status_sam                                       0
# serotype__required_for_a_seropositive_sample__sam               0
# virus_identifier_sam                                            0
# alignment_software_exp                                          0
# analyte_type_sam                                                0
# avgreadlength_run                                               0
# biospecimen_repository_sam                                      0
# biospecimen_repository_sample_id_sam                            0
# body_site_sam                                                   0
# consent_code                                                    0
# coverage_run                                                    0
# gap_accession_sam                                               0
# is_tumor_sam                                                    0
# molecular_data_type_sam                                         0
# phs                                                             0
# sex_calc                                                        0
# study_design_sam                                                0
# study_disease_sam                                               0
# study_name_sam                                                  0
# subject_is_affected_sam                                         0
# submitted_subject_id_sam                                        0
#
# study                                              sra_PRJEB1985  \
# bases                                                         49
# broker_name_sam                                                0
# bytes                                                         49
# cell_line_sam                                                  0
# cell_type_sam_ss_dpl37                                         0
# common_name_sam                                                0
# ena_first_public_sam                                           0
# ena_last_update_sam                                            0
# experimental_factor__over_expression_dazl_exp                  0
# experimental_factor__over_expression_nanos3_exp                0
# external_id_sam                                                0
# genetic_modification_sam                                       0
# genotype_sam_ss_dpl92                                          0
# insdc_center_name_sam                                          1
# insdc_first_public_sam                                         1
# insdc_last_update_sam                                          1
# insdc_status_sam                                               1
# run_file_create_date                                           8
# scientific_name_sam                                            0
# submitter_id_sam                                               0
# alias_sam                                                      1
# description_sam                                                1
# sra_accession_sam                                              1
# title_sam                                                      1
# artic_primer_version_exp                                       0
# artic_protocol_version_exp                                     0
# assemblyname                                                   0
# collecting_institution_sam                                     0
# collection_date_sam                                            0
# collector_name_sam                                             0
# definition_for_seropositive_sample_sam                         0
# ena_last_update_sam_ss_dpl537                                  0
# geographic_location__country_and_or_sea__sam                   0
# geographic_location__region_and_locality__sam                  0
# host_common_name_sam                                           0
# host_health_state_sam                                          0
# host_scientific_name_sam                                       0
# host_sex_sam                                                   0
# host_subject_id_sam                                            0
# insdc_center_alias_sam                                         0
# isolate_sam_ss_dpl100                                          0
# max_cycle_threshold_sam                                        0
# min_cycle_threshold_sam                                        0
# organism_sam                                                   0
# receipt_date_sam                                               0
# sample_capture_status_sam                                      0
# serotype__required_for_a_seropositive_sample__sam              0
# virus_identifier_sam                                           0
# alignment_software_exp                                         0
# analyte_type_sam                                               0
# avgreadlength_run                                              0
# biospecimen_repository_sam                                     0
# biospecimen_repository_sample_id_sam                           0
# body_site_sam                                                  0
# consent_code                                                   0
# coverage_run                                                   0
# gap_accession_sam                                              0
# is_tumor_sam                                                   0
# molecular_data_type_sam                                        0
# phs                                                            0
# sex_calc                                                       0
# study_design_sam                                               0
# study_disease_sam                                              0
# study_name_sam                                                 0
# subject_is_affected_sam                                        0
# submitted_subject_id_sam                                       0
#
# study                                              sra_PRJEB37886  \
# bases                                                        7511
# broker_name_sam                                                 3
# bytes                                                        7511
# cell_line_sam                                                   0
# cell_type_sam_ss_dpl37                                          0
# common_name_sam                                                 0
# ena_first_public_sam                                          465
# ena_last_update_sam                                           270
# experimental_factor__over_expression_dazl_exp                   0
# experimental_factor__over_expression_nanos3_exp                 0
# external_id_sam                                              7439
# genetic_modification_sam                                        0
# genotype_sam_ss_dpl92                                           0
# insdc_center_name_sam                                          38
# insdc_first_public_sam                                       6734
# insdc_last_update_sam                                        6728
# insdc_status_sam                                                2
# run_file_create_date                                         5106
# scientific_name_sam                                             2
# submitter_id_sam                                             7440
# alias_sam                                                       0
# description_sam                                                 0
# sra_accession_sam                                               0
# title_sam                                                       0
# artic_primer_version_exp                                        9
# artic_protocol_version_exp                                     26
# assemblyname                                                    3
# collecting_institution_sam                                     43
# collection_date_sam                                           748
# collector_name_sam                                              2
# definition_for_seropositive_sample_sam                          2
# ena_last_update_sam_ss_dpl537                                 199
# geographic_location__country_and_or_sea__sam                    2
# geographic_location__region_and_locality__sam                   6
# host_common_name_sam                                            3
# host_health_state_sam                                           2
# host_scientific_name_sam                                        3
# host_sex_sam                                                    2
# host_subject_id_sam                                             2
# insdc_center_alias_sam                                         31
# isolate_sam_ss_dpl100                                           2
# max_cycle_threshold_sam                                       330
# min_cycle_threshold_sam                                       328
# organism_sam                                                    2
# receipt_date_sam                                              337
# sample_capture_status_sam                                       2
# serotype__required_for_a_seropositive_sample__sam               2
# virus_identifier_sam                                            2
# alignment_software_exp                                          0
# analyte_type_sam                                                0
# avgreadlength_run                                               0
# biospecimen_repository_sam                                      0
# biospecimen_repository_sample_id_sam                            0
# body_site_sam                                                   0
# consent_code                                                    0
# coverage_run                                                    0
# gap_accession_sam                                               0
# is_tumor_sam                                                    0
# molecular_data_type_sam                                         0
# phs                                                             0
# sex_calc                                                        0
# study_design_sam                                                0
# study_disease_sam                                               0
# study_name_sam                                                  0
# subject_is_affected_sam                                         0
# submitted_subject_id_sam                                        0
#
# study                                              sra_phs001554  \
# bases                                                       2892
# broker_name_sam                                                0
# bytes                                                       2892
# cell_line_sam                                                  0
# cell_type_sam_ss_dpl37                                         0
# common_name_sam                                                0
# ena_first_public_sam                                           0
# ena_last_update_sam                                            0
# experimental_factor__over_expression_dazl_exp                  0
# experimental_factor__over_expression_nanos3_exp                0
# external_id_sam                                                0
# genetic_modification_sam                                       0
# genotype_sam_ss_dpl92                                          0
# insdc_center_name_sam                                          0
# insdc_first_public_sam                                         0
# insdc_last_update_sam                                          0
# insdc_status_sam                                               0
# run_file_create_date                                           0
# scientific_name_sam                                            0
# submitter_id_sam                                               0
# alias_sam                                                      0
# description_sam                                                0
# sra_accession_sam                                              0
# title_sam                                                      0
# artic_primer_version_exp                                       0
# artic_protocol_version_exp                                     0
# assemblyname                                                   1
# collecting_institution_sam                                     0
# collection_date_sam                                            0
# collector_name_sam                                             0
# definition_for_seropositive_sample_sam                         0
# ena_last_update_sam_ss_dpl537                                  0
# geographic_location__country_and_or_sea__sam                   0
# geographic_location__region_and_locality__sam                  0
# host_common_name_sam                                           0
# host_health_state_sam                                          0
# host_scientific_name_sam                                       0
# host_sex_sam                                                   0
# host_subject_id_sam                                            0
# insdc_center_alias_sam                                         0
# isolate_sam_ss_dpl100                                          0
# max_cycle_threshold_sam                                        0
# min_cycle_threshold_sam                                        0
# organism_sam                                                   0
# receipt_date_sam                                               0
# sample_capture_status_sam                                      0
# serotype__required_for_a_seropositive_sample__sam              0
# virus_identifier_sam                                           0
# alignment_software_exp                                         1
# analyte_type_sam                                               1
# avgreadlength_run                                             58
# biospecimen_repository_sam                                     1
# biospecimen_repository_sample_id_sam                        2892
# body_site_sam                                                  1
# consent_code                                                   5
# coverage_run                                                 130
# gap_accession_sam                                              1
# is_tumor_sam                                                   1
# molecular_data_type_sam                                        1
# phs                                                            5
# sex_calc                                                       2
# study_design_sam                                               1
# study_disease_sam                                              2
# study_name_sam                                                 1
# subject_is_affected_sam                                        2
# submitted_subject_id_sam                                    2892
#
# study                                              sra_scr_icac  \
# bases                                                      1035
# broker_name_sam                                               0
# bytes                                                      1035
# cell_line_sam                                                 0
# cell_type_sam_ss_dpl37                                        0
# common_name_sam                                               0
# ena_first_public_sam                                          0
# ena_last_update_sam                                           0
# experimental_factor__over_expression_dazl_exp                 0
# experimental_factor__over_expression_nanos3_exp               0
# external_id_sam                                               0
# genetic_modification_sam                                      0
# genotype_sam_ss_dpl92                                         0
# insdc_center_name_sam                                         0
# insdc_first_public_sam                                        0
# insdc_last_update_sam                                         0
# insdc_status_sam                                              0
# run_file_create_date                                        950
# scientific_name_sam                                           0
# submitter_id_sam                                              0
# alias_sam                                                     0
# description_sam                                               0
# sra_accession_sam                                             0
# title_sam                                                     0
# artic_primer_version_exp                                      0
# artic_protocol_version_exp                                    0
# assemblyname                                                  1
# collecting_institution_sam                                    0
# collection_date_sam                                           0
# collector_name_sam                                            0
# definition_for_seropositive_sample_sam                        0
# ena_last_update_sam_ss_dpl537                                 0
# geographic_location__country_and_or_sea__sam                  0
# geographic_location__region_and_locality__sam                 0
# host_common_name_sam                                          0
# host_health_state_sam                                         0
# host_scientific_name_sam                                      0
# host_sex_sam                                                  0
# host_subject_id_sam                                           0
# insdc_center_alias_sam                                        0
# isolate_sam_ss_dpl100                                         0
# max_cycle_threshold_sam                                       0
# min_cycle_threshold_sam                                       0
# organism_sam                                                  0
# receipt_date_sam                                              0
# sample_capture_status_sam                                     0
# serotype__required_for_a_seropositive_sample__sam             0
# virus_identifier_sam                                          0
# alignment_software_exp                                        1
# analyte_type_sam                                              1
# avgreadlength_run                                             0
# biospecimen_repository_sam                                    1
# biospecimen_repository_sample_id_sam                       1035
# body_site_sam                                                 1
# consent_code                                                  1
# coverage_run                                                  0
# gap_accession_sam                                             1
# is_tumor_sam                                                  1
# molecular_data_type_sam                                       0
# phs                                                           1
# sex_calc                                                      2
# study_design_sam                                              1
# study_disease_sam                                             0
# study_name_sam                                                1
# subject_is_affected_sam                                       0
# submitted_subject_id_sam                                   1035
#
# study                                              sra_scr_udn_v5
# bases                                                        9847
# broker_name_sam                                                 0
# bytes                                                       10028
# cell_line_sam                                                   0
# cell_type_sam_ss_dpl37                                          0
# common_name_sam                                                 0
# ena_first_public_sam                                            0
# ena_last_update_sam                                             0
# experimental_factor__over_expression_dazl_exp                   0
# experimental_factor__over_expression_nanos3_exp                 0
# external_id_sam                                                 0
# genetic_modification_sam                                        0
# genotype_sam_ss_dpl92                                           0
# insdc_center_name_sam                                           0
# insdc_first_public_sam                                          0
# insdc_last_update_sam                                           0
# insdc_status_sam                                                0
# run_file_create_date                                         8808
# scientific_name_sam                                             0
# submitter_id_sam                                                0
# alias_sam                                                       0
# description_sam                                                 0
# sra_accession_sam                                               0
# title_sam                                                       0
# artic_primer_version_exp                                        0
# artic_protocol_version_exp                                      0
# assemblyname                                                    6
# collecting_institution_sam                                      0
# collection_date_sam                                             0
# collector_name_sam                                              0
# definition_for_seropositive_sample_sam                          0
# ena_last_update_sam_ss_dpl537                                   0
# geographic_location__country_and_or_sea__sam                    0
# geographic_location__region_and_locality__sam                   0
# host_common_name_sam                                            0
# host_health_state_sam                                           0
# host_scientific_name_sam                                        0
# host_sex_sam                                                    0
# host_subject_id_sam                                             0
# insdc_center_alias_sam                                          0
# isolate_sam_ss_dpl100                                           0
# max_cycle_threshold_sam                                         0
# min_cycle_threshold_sam                                         0
# organism_sam                                                    0
# receipt_date_sam                                                0
# sample_capture_status_sam                                       0
# serotype__required_for_a_seropositive_sample__sam               0
# virus_identifier_sam                                            0
# alignment_software_exp                                          3
# analyte_type_sam                                                2
# avgreadlength_run                                               0
# biospecimen_repository_sam                                      1
# biospecimen_repository_sample_id_sam                         7991
# body_site_sam                                                   3
# consent_code                                                    1
# coverage_run                                                    0
# gap_accession_sam                                               1
# is_tumor_sam                                                    0
# molecular_data_type_sam                                         2
# phs                                                             1
# sex_calc                                                        2
# study_design_sam                                                1
# study_disease_sam                                               2
# study_name_sam                                                  1
# subject_is_affected_sam                                         3
# submitted_subject_id_sam                                     6469

# %% [markdown]
# ### Show the table as a heat map
# A quick overview of which attributes are used in which studies can be seen in the following heat map.

# %%
for scname in expt_schemas.keys():
    attribute_summary_df.loc[attribute_summary_df[scname] > 0 , scname] = 1
attribute_summary_df
attribute_summary_df.style.background_gradient(cmap ='viridis').set_properties(**{'font-size': '1px'})
# Out:
# <style type="text/css">
# #T_d0e83_row0_col0, #T_d0e83_row0_col1, #T_d0e83_row0_col2, #T_d0e83_row0_col3, #T_d0e83_row0_col4, #T_d0e83_row0_col5, #T_d0e83_row1_col0, #T_d0e83_row1_col2, #T_d0e83_row2_col0, #T_d0e83_row2_col1, #T_d0e83_row2_col2, #T_d0e83_row2_col3, #T_d0e83_row2_col4, #T_d0e83_row2_col5, #T_d0e83_row3_col0, #T_d0e83_row4_col0, #T_d0e83_row5_col0, #T_d0e83_row6_col0, #T_d0e83_row6_col2, #T_d0e83_row7_col0, #T_d0e83_row7_col2, #T_d0e83_row8_col0, #T_d0e83_row9_col0, #T_d0e83_row10_col0, #T_d0e83_row10_col2, #T_d0e83_row11_col0, #T_d0e83_row12_col0, #T_d0e83_row13_col0, #T_d0e83_row13_col1, #T_d0e83_row13_col2, #T_d0e83_row14_col0, #T_d0e83_row14_col1, #T_d0e83_row14_col2, #T_d0e83_row15_col0, #T_d0e83_row15_col1, #T_d0e83_row15_col2, #T_d0e83_row16_col0, #T_d0e83_row16_col1, #T_d0e83_row16_col2, #T_d0e83_row17_col0, #T_d0e83_row17_col1, #T_d0e83_row17_col2, #T_d0e83_row17_col4, #T_d0e83_row17_col5, #T_d0e83_row18_col0, #T_d0e83_row18_col2, #T_d0e83_row19_col0, #T_d0e83_row19_col2, #T_d0e83_row20_col1, #T_d0e83_row21_col1, #T_d0e83_row22_col1, #T_d0e83_row23_col1, #T_d0e83_row24_col2, #T_d0e83_row25_col2, #T_d0e83_row26_col2, #T_d0e83_row26_col3, #T_d0e83_row26_col4, #T_d0e83_row26_col5, #T_d0e83_row27_col2, #T_d0e83_row28_col2, #T_d0e83_row29_col2, #T_d0e83_row30_col2, #T_d0e83_row31_col2, #T_d0e83_row32_col2, #T_d0e83_row33_col2, #T_d0e83_row34_col2, #T_d0e83_row35_col2, #T_d0e83_row36_col2, #T_d0e83_row37_col2, #T_d0e83_row38_col2, #T_d0e83_row39_col2, #T_d0e83_row40_col2, #T_d0e83_row41_col2, #T_d0e83_row42_col2, #T_d0e83_row43_col2, #T_d0e83_row44_col2, #T_d0e83_row45_col2, #T_d0e83_row46_col2, #T_d0e83_row47_col2, #T_d0e83_row48_col3, #T_d0e83_row48_col4, #T_d0e83_row48_col5, #T_d0e83_row49_col3, #T_d0e83_row49_col4, #T_d0e83_row49_col5, #T_d0e83_row50_col3, #T_d0e83_row51_col3, #T_d0e83_row51_col4, #T_d0e83_row51_col5, #T_d0e83_row52_col3, #T_d0e83_row52_col4, #T_d0e83_row52_col5, #T_d0e83_row53_col3, #T_d0e83_row53_col4, #T_d0e83_row53_col5, #T_d0e83_row54_col3, #T_d0e83_row54_col4, #T_d0e83_row54_col5, #T_d0e83_row55_col3, #T_d0e83_row56_col3, #T_d0e83_row56_col4, #T_d0e83_row56_col5, #T_d0e83_row57_col3, #T_d0e83_row57_col4, #T_d0e83_row58_col3, #T_d0e83_row58_col5, #T_d0e83_row59_col3, #T_d0e83_row59_col4, #T_d0e83_row59_col5, #T_d0e83_row60_col3, #T_d0e83_row60_col4, #T_d0e83_row60_col5, #T_d0e83_row61_col3, #T_d0e83_row61_col4, #T_d0e83_row61_col5, #T_d0e83_row62_col3, #T_d0e83_row62_col5, #T_d0e83_row63_col3, #T_d0e83_row63_col4, #T_d0e83_row63_col5, #T_d0e83_row64_col3, #T_d0e83_row64_col5, #T_d0e83_row65_col3, #T_d0e83_row65_col4, #T_d0e83_row65_col5 {
#   background-color: #fde725;
#   color: #000000;
#   font-size: 1px;
# }
# #T_d0e83_row1_col1, #T_d0e83_row1_col3, #T_d0e83_row1_col4, #T_d0e83_row1_col5, #T_d0e83_row3_col1, #T_d0e83_row3_col2, #T_d0e83_row3_col3, #T_d0e83_row3_col4, #T_d0e83_row3_col5, #T_d0e83_row4_col1, #T_d0e83_row4_col2, #T_d0e83_row4_col3, #T_d0e83_row4_col4, #T_d0e83_row4_col5, #T_d0e83_row5_col1, #T_d0e83_row5_col2, #T_d0e83_row5_col3, #T_d0e83_row5_col4, #T_d0e83_row5_col5, #T_d0e83_row6_col1, #T_d0e83_row6_col3, #T_d0e83_row6_col4, #T_d0e83_row6_col5, #T_d0e83_row7_col1, #T_d0e83_row7_col3, #T_d0e83_row7_col4, #T_d0e83_row7_col5, #T_d0e83_row8_col1, #T_d0e83_row8_col2, #T_d0e83_row8_col3, #T_d0e83_row8_col4, #T_d0e83_row8_col5, #T_d0e83_row9_col1, #T_d0e83_row9_col2, #T_d0e83_row9_col3, #T_d0e83_row9_col4, #T_d0e83_row9_col5, #T_d0e83_row10_col1, #T_d0e83_row10_col3, #T_d0e83_row10_col4, #T_d0e83_row10_col5, #T_d0e83_row11_col1, #T_d0e83_row11_col2, #T_d0e83_row11_col3, #T_d0e83_row11_col4, #T_d0e83_row11_col5, #T_d0e83_row12_col1, #T_d0e83_row12_col2, #T_d0e83_row12_col3, #T_d0e83_row12_col4, #T_d0e83_row12_col5, #T_d0e83_row13_col3, #T_d0e83_row13_col4, #T_d0e83_row13_col5, #T_d0e83_row14_col3, #T_d0e83_row14_col4, #T_d0e83_row14_col5, #T_d0e83_row15_col3, #T_d0e83_row15_col4, #T_d0e83_row15_col5, #T_d0e83_row16_col3, #T_d0e83_row16_col4, #T_d0e83_row16_col5, #T_d0e83_row17_col3, #T_d0e83_row18_col1, #T_d0e83_row18_col3, #T_d0e83_row18_col4, #T_d0e83_row18_col5, #T_d0e83_row19_col1, #T_d0e83_row19_col3, #T_d0e83_row19_col4, #T_d0e83_row19_col5, #T_d0e83_row20_col0, #T_d0e83_row20_col2, #T_d0e83_row20_col3, #T_d0e83_row20_col4, #T_d0e83_row20_col5, #T_d0e83_row21_col0, #T_d0e83_row21_col2, #T_d0e83_row21_col3, #T_d0e83_row21_col4, #T_d0e83_row21_col5, #T_d0e83_row22_col0, #T_d0e83_row22_col2, #T_d0e83_row22_col3, #T_d0e83_row22_col4, #T_d0e83_row22_col5, #T_d0e83_row23_col0, #T_d0e83_row23_col2, #T_d0e83_row23_col3, #T_d0e83_row23_col4, #T_d0e83_row23_col5, #T_d0e83_row24_col0, #T_d0e83_row24_col1, #T_d0e83_row24_col3, #T_d0e83_row24_col4, #T_d0e83_row24_col5, #T_d0e83_row25_col0, #T_d0e83_row25_col1, #T_d0e83_row25_col3, #T_d0e83_row25_col4, #T_d0e83_row25_col5, #T_d0e83_row26_col0, #T_d0e83_row26_col1, #T_d0e83_row27_col0, #T_d0e83_row27_col1, #T_d0e83_row27_col3, #T_d0e83_row27_col4, #T_d0e83_row27_col5, #T_d0e83_row28_col0, #T_d0e83_row28_col1, #T_d0e83_row28_col3, #T_d0e83_row28_col4, #T_d0e83_row28_col5, #T_d0e83_row29_col0, #T_d0e83_row29_col1, #T_d0e83_row29_col3, #T_d0e83_row29_col4, #T_d0e83_row29_col5, #T_d0e83_row30_col0, #T_d0e83_row30_col1, #T_d0e83_row30_col3, #T_d0e83_row30_col4, #T_d0e83_row30_col5, #T_d0e83_row31_col0, #T_d0e83_row31_col1, #T_d0e83_row31_col3, #T_d0e83_row31_col4, #T_d0e83_row31_col5, #T_d0e83_row32_col0, #T_d0e83_row32_col1, #T_d0e83_row32_col3, #T_d0e83_row32_col4, #T_d0e83_row32_col5, #T_d0e83_row33_col0, #T_d0e83_row33_col1, #T_d0e83_row33_col3, #T_d0e83_row33_col4, #T_d0e83_row33_col5, #T_d0e83_row34_col0, #T_d0e83_row34_col1, #T_d0e83_row34_col3, #T_d0e83_row34_col4, #T_d0e83_row34_col5, #T_d0e83_row35_col0, #T_d0e83_row35_col1, #T_d0e83_row35_col3, #T_d0e83_row35_col4, #T_d0e83_row35_col5, #T_d0e83_row36_col0, #T_d0e83_row36_col1, #T_d0e83_row36_col3, #T_d0e83_row36_col4, #T_d0e83_row36_col5, #T_d0e83_row37_col0, #T_d0e83_row37_col1, #T_d0e83_row37_col3, #T_d0e83_row37_col4, #T_d0e83_row37_col5, #T_d0e83_row38_col0, #T_d0e83_row38_col1, #T_d0e83_row38_col3, #T_d0e83_row38_col4, #T_d0e83_row38_col5, #T_d0e83_row39_col0, #T_d0e83_row39_col1, #T_d0e83_row39_col3, #T_d0e83_row39_col4, #T_d0e83_row39_col5, #T_d0e83_row40_col0, #T_d0e83_row40_col1, #T_d0e83_row40_col3, #T_d0e83_row40_col4, #T_d0e83_row40_col5, #T_d0e83_row41_col0, #T_d0e83_row41_col1, #T_d0e83_row41_col3, #T_d0e83_row41_col4, #T_d0e83_row41_col5, #T_d0e83_row42_col0, #T_d0e83_row42_col1, #T_d0e83_row42_col3, #T_d0e83_row42_col4, #T_d0e83_row42_col5, #T_d0e83_row43_col0, #T_d0e83_row43_col1, #T_d0e83_row43_col3, #T_d0e83_row43_col4, #T_d0e83_row43_col5, #T_d0e83_row44_col0, #T_d0e83_row44_col1, #T_d0e83_row44_col3, #T_d0 ...

# %% [markdown]
# ### Stable SRA metadata schema
#
# In addition to the custom set of attributes covered above there are a common set of columns/sttributes for every SRA sequencing run.
#
# The schema for the common columns is described at https://www.ncbi.nlm.nih.gov/sra/docs/sra-cloud-based-metadata-table/
#
# Note that all of the common attributes are populated for all studies. Investigating this would be a useful addition to identifying the experiment/run metadata for a given study.

# %%
namespace ="dataconnect-demo"        
schema_name ="nih_sra_datastore.sra.metadata"        
url = f"{base}/schemas/{namespace}/{schema_name}/versions/v2"
print("fetching schema")
response = requests.get(url)
response_schema = response.json()
prettyprint(response_schema)
# Out:
# fetching schema
# {
#    "$id": "",
#    "description": "Metadata Table (sra.metadata) contains information about the run and biological samples. Metadata Table (sra.metadata) contains information about the run and biological samples. The biological sample data is stored in two different columns.  See Record (array) column that you need to use the command UNNEST to query. See https://www.ncbi.nlm.nih.gov/sra/docs/sra-cloud-based-metadata-table/",
#    "$schema": "http://json-schema.org/draft-07/schema",
#    "properties": {
#       "acc": {
#          "type": "string",
#          "description": "SRA Run accession in the form of SRR######## (ERR or DRR for INSDC partners)"
#       },
#       "assay_type": {
#          "type": "string",
#          "description": "Type of library (i.e. AMPLICON, RNA-Seq, WGS, etc)",
#          "oneOf": [
#             {
#                "title": "RNA-Seq"
#             },
#             {
#                "title": "WGS"
#             },
#             {
#                "title": "EST"
#             },
#             {
#                "title": "SELEX"
#             },
#             {
#                "title": "other"
#             },
#             {
#                "title": "CTS"
#             },
#             {
#                "title": "CLONE"
#             },
#             {
#                "title": "Hi-C"
#             },
#             {
#                "title": "POOLCLONE"
#             },
#             {
#                "title": "GBS"
#             },
#             {
#                "title": "MBD-Seq"
#             },
#             {
#                "title": "miRNA-Seq"
#             },
#             {
#                "title": "MeDIP-Seq"
#             },
#             {
#                "title": "RIP-Seq"
#             },
#             {
#                "title": "ChIP"
#             },
#             {
#                "title": "MRE-Seq"
#             },
#             {
#                "title": "FAIRE-seq"
#             },
#             {
#                "title": "FL-cDNA"
#             },
#             {
#                "title": "DNase-Hypersensitivity"
#             },
#             {
#                "title": "ncRNA-Seq"
#             },
#             {
#                "title": "WCS"
#             },
#             {
#                "title": "MNase-Seq"
#             },
#             {
#                "title": "AMPLICON"
#             },
#             {
#                "title": "WXS"
#             },
#             {
#                "title": "ChIP-Seq"
#             },
#             {
#                "title": "Synthetic-Long-Read"
#             },
#             {
#                "title": "WGA"
#             },
#             {
#                "title": "FINISHING"
#             },
#             {
#                "title": "Tethered Chromatin Conformation Capture"
#             },
#             {
#                "title": "Targeted-Capture"
#             },
#             {
#                "title": "ATAC-seq"
#             },
#             {
#                "title": "RAD-Seq"
#             },
#             {
#                "title": "ChIA-PET"
#             },
#             {
#                "title": "OTHER"
#             },
#             {
#                "title": "Bisulfite-Seq"
#             },
#             {
#                "title": "Tn-Seq"
#             },
#             {
#                "title": "CLONEEND"
#             },
#             {
#                "title": "VALIDATION"
#             }
#          ]
#       },
#       "center_name": {
#          "type": "string",
#          "description": "Name of the sequencing center"
#       },
#       "consent": {
#          "type": "string",
#          "description": "Type of consent need to access the data (i.e. public is available to all, others are for dbGaP)"
#       },
#       "experiment": {
#          "type": "string",
#          "description": "The accession in the form of SRX######## (ERX or DRX for INSDC partners)"
#       },
#       "sample_name": {
#          "type": "string",
#          "description": "Name of the sample"
#       },
#       "instrument": {
#          "type": "string",
#          "description": "Name of the sequencing instrument model"
#       },
#       "librarylayout": {
#          "type": "string",
#          "description": "Whether the data is SINGLE or PAIRED",
#          "oneOf": [
#             {
#                "title": "PAIRED"
#             },
#             {
#                "title": "SINGLE"
#             }
#          ]
#       },
#       "libraryselection": {
#          "type": "string",
#          "description": "Library selection methodology (i.e. PCR, RANDOM, etc)",
#          "oneOf": [
#             {
#                "title": "MF"
#             },
#             {
#                "title": "ChIP-Seq"
#             },
#             {
#                "title": "unspecified"
#             },
#             {
#                "title": "size fractionation"
#             },
#             {
#                "title": "ChIP"
#             },
#             {
#                "title": "CAGE"
#             },
#             {
#                "title": "MSLL"
#             },
#             {
#                "title": "other"
#             },
#             {
#                "title": "DNase"
#             },
#             {
#                "title": "Hybrid Selection"
#             },
#             {
#                "title": "OTHER"
#             },
#             {
#                "title": "RT-PCR"
#             },
#             {
#                "title": "RANDOM"
#             },
#             {
#                "title": "padlock probes capture method"
#             },
#             {
#                "title": "PCR"
#             },
#             {
#                "title": "Oligo-dT"
#             },
#             {
#                "title": "Restriction Digest"
#             },
#             {
#                "title": "Reduced Representation"
#             },
#             {
#                "title": "Inverse rRNA"
#             },
#             {
#                "title": "5-methylcytidine antibody"
#             },
#             {
#                "title": "MNase"
#             },
#             {
#                "title": "MBD2 protein methyl-CpG binding domain"
#             },
#             {
#                "title": "HMPR"
#             },
#             {
#                "title": "cDNA"
#             },
#             {
#                "title": "PolyA"
#             },
#             {
#                "title": "RANDOM PCR"
#             },
#             {
#                "title": "MDA"
#             },
#             {
#                "title": "repeat fractionation"
#             },
#             {
#                "title": "RACE"
#             }
#          ]
#       },
#       "librarysource": {
#          "type": "string",
#          "description": "Source of the biological data (i.e. GENOMIC, METAGENOMIC, etc)",
#          "oneOf": [
#             {
#                "title": "SYNTHETIC"
#             },
#             {
#                "title": "TRANSCRIPTOMIC"
#             },
#             {
#                "title": "OTHER"
#             },
#             {
#                "title": "VIRAL RNA"
#             },
#             {
#                "title": "METATRANSCRIPTOMIC"
#             },
#             {
#                "title": "METAGENOMIC"
#             },
#             {
#                "title": "TRANSCRIPTOMIC SINGLE CELL"
#             },
#             {
#                "title": "GENOMIC"
#             },
#             {
#                "title": "GENOMIC SINGLE CELL"
#             }
#          ]
#       },
#       "platform": {
#          "type": "string",
#          "description": "Name of the sequencing platform (i.e. ILLUMINA)"
#       },
#       "sample_acc": {
#          "type": "string",
#          "description": "SRA Sample accession in the form of SRS######## (ERS or DRS for INSDC partners)"
#       },
#       "biosample": {
#          "type": "string",
#          "description": "BioSample accession in the form of SAMN######## (SAMEA##### or SAMD##### for INSDC partners)"
#       },
#       "organism": {
#          "type": "string",
#          "description": "Scientific name of the organism that was sequenced (as found in the NCBI Taxonomy Browser)"
#       },
#       "sra_study": {
#          "type": "string",
#          "description": "SRA Study accession in the form of SRP######## (ERP or DRP for INSDC partners)"
#       },
#       "releasedate": {
#          "type": "string",
#          "description": "The date on which the data was released"
#       },
#       "bioproject": {
#          "type": "string",
#          "description": "BioProject accession in the form of PRJNA######## (PRJEB####### or PRJDB###### for INSDC partners)"
#       },
#       "mbytes": {
#          "type": "integer",
#          "description": "Number of mega bytes of data in the SRA Run"
#       },
#       "loaddate": {
#          "type": "string",
#          "description": "The date when the data was loaded into SRA"
#       },
#       "avgspotlen": {
#          "type": "integer",
#          "description": "Calculated average read length"
#       },
#       "mbases": {
#          "type": "integer",
#          "description": "Number of mega bases in the SRA Runs"
#       },
#       "insertsize": {
#          "type": "integer",
#          "description": "Submitter provided insert size"
#       },
#       "library_name": {
#          "type": "string",
#          "description": "The name of the library"
#       },
#       "biosamplemodel_sam": {
#          "type": "string",
#          "description": "The BioSample package/model that was picked"
#       },
#       "collection_date_sam": {
#          "type": "string",
#          "description": "The collection date of the sample"
#       },
#       "geo_loc_name_country_calc": {
#          "type": "string",
#          "description": "Name of the country where the sample was collected"
#       },
#       "geo_loc_name_country_continent_calc": {
#          "type": "string",
#          "description": "Name of the continent where the sample was collected"
#       },
#       "geo_loc_name_sam": {
#          "type": "string",
#          "description": "Full location of collection"
#       },
#       "ena_first_public_run": {
#          "type": "string",
#          "description": "Date when INSDC partner record was public"
#       },
#       "ena_last_update_run": {
#          "type": "string",
#          "description": "Date when INSDC partner record was updated"
#       },
#       "sample_name_sam": {
#          "type": "string",
#          "description": "INSDC sample name"
#       },
#       "datastore_filetype": {
#          "type": "string",
#          "description": "Type of files available to download from SRA"
#       },
#       "datastore_provider": {
#          "type": "string",
#          "description": "Locations of where the files are available to download from"
#       },
#       "datastore_region": {
#          "type": "string",
#          "description": "Regions of where the data is located"
#       },
#       "attributes": {
#          "type": "string",
#          "description": "Full list of sample attributes in a nested(array) structure"
#       },
#       "attributes.k": {
#          "type": "string",
#          "description": "Attribute's name"
#       },
#       "attributes.v": {
#          "type": "string",
#          "description": "Attribute's value"
#       },
#       "jattr": {
#          "type": "string",
#          "description": "JSON based string of the sample attributes"
#       }
#    }
# }
