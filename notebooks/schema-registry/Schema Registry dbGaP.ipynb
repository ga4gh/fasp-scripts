# %% [markdown]
# ### Schema Registry - retrieving schemas for multiple dbGaP studies
#
# See https://github.com/ianfore/ga4gh-starter-schema-repository for details of the implementation.

# %%
import requests;

import json;

import xml.etree.ElementTree as ET

def prettyprint(a_dict):
    print(json.dumps(a_dict, indent=3))

def printline(char="_"):
    print(char*80)

# %%
base = "http://localhost:8080"

# %% [markdown]
# ### Get schemas for a dbGaP study
# The syntax below supports the Schema Registry capability to retrieve schema according to specific named parameters.
#
# dbGaP contains schemas for multiple versions of over 2,500 studies. This provides a good use case for the need to retrieve specific subsets of schemas instead of all schemas for a namespace.
#
# **For consideration/discussion:** What should a namespace be? Rather than dbGaP as the namespace, the study could be a namespace.

# %%
namespace = "dbGaP"
endpoint = f"/schemas/{namespace}/?study=phs002921&study_version=v2.p1"
print(endpoint)
response = requests.get(f"{base}{endpoint}")
schemas = response.json()['schemas']
for schema in schemas:
    print( schema['schema_name'])
# Out:
# /schemas/dbGaP/?study=phs002921&study_version=v2.p1
# phs002921.v2.pht012614.v1.ICAC_Subject_Phenotypes
# phs002921.v2.pht012612.v1.ICAC_Subject
# phs002921.v2.pht012613.v1.ICAC_Sample
# phs002921.v2.pht012615.v1.ICAC_Sample_Attributes

# %%
prettyprint(response.json())
# Out:
# {
#    "namespace": "dbGaP",
#    "schemas": [
#       {
#          "schema_name": "phs002921.v2.pht012614.v1.ICAC_Subject_Phenotypes",
#          "latest_version": "v1",
#          "maintainer": [
#             "dbGaP"
#          ],
#          "lifecycle_stage": "released"
#       },
#       {
#          "schema_name": "phs002921.v2.pht012612.v1.ICAC_Subject",
#          "latest_version": "v1",
#          "maintainer": [
#             "dbGaP"
#          ],
#          "lifecycle_stage": "released"
#       },
#       {
#          "schema_name": "phs002921.v2.pht012613.v1.ICAC_Sample",
#          "latest_version": "v1",
#          "maintainer": [
#             "dbGaP"
#          ],
#          "lifecycle_stage": "released"
#       },
#       {
#          "schema_name": "phs002921.v2.pht012615.v1.ICAC_Sample_Attributes",
#          "latest_version": "v1",
#          "maintainer": [
#             "dbGaP"
#          ],
#          "lifecycle_stage": "released"
#       }
#    ]
# }

# %% [markdown]
# ### Finding all dbGaP study versions
# In the absence of an implementation that provides all dbGaP studies there are various ways all dbGaP studies could be found. For demo purposes we will retrieve a list of dbGaP studies from a file.

# %%
with open("data/dbgap_studies_with_schema.json") as f:
    studies = json.load(f)
print(f"{len(studies)} studies loaded")
# Out:
# 2352 studies loaded

# %% [markdown]
# ### An example study from the list

# %%
studies[10]
# Out:
# {'study': 'phs000145', 'study_version': 'v4.p2'}

# %% [markdown]
# ### List schemas for a subset of studies

# %%
import time

printSchemas = True

for sv in studies[2000:2010]:
    study = sv['study']
    study_version = sv['study_version']
    endpoint = f"/schemas/{namespace}/?study={study}&study_version={study_version}"
    print(f"Retrieving schemas at: {endpoint}")
    response = requests.get(f"{base}{endpoint}")
    if 'schemas' in response.json():
        schemas = response.json()['schemas']
        for schema in schemas:
            print( f"Schema: {schema['schema_name']}")
            if printSchemas:
                print( f"Downloading Schema:")
                url = f"{base}/schemas/{namespace}/{schema['schema_name']}/versions/latest"
                response = requests.get(url)
                prettyprint(response.json())
                printline()
    else:
        print('No schemas')
        prettyprint(response.json())
    printline('=')
    #time.sleep(1
# Out:
# Retrieving schemas at: /schemas/dbGaP/?study=phs001956&study_version=v1.p1
# Schema: phs001956.v1.pht009785.v1.sc_Liver_Subject
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009785.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00424150.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00424151.v1",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "2",
#                "title": "Health/Medical/Biomedical (PUB, NPU) (HMB-PUB-NPU)"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001956.v1.pht009786.v1.sc_Liver_Sample
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009786.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00424152.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00424153.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001956.v1.pht009787.v1.sc_Liver_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009787.v1",
#    "properties": {
#       "DIAGNOSIS": {
#          "$id": "dbgap:phv00424158.v1",
#          "description": "Cause of death",
#          "type": "string",
#          "$unit": null
#       },
#       "ALCOHOL": {
#          "$id": "dbgap:phv00424160.v1",
#          "description": "Alcohol drinking history",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "N",
#                "title": "No alcohol history"
#             },
#             {
#                "const": "Y",
#                "title": "Alcohol history"
#             }
#          ]
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00424154.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SEX": {
#          "$id": "dbgap:phv00424155.v1",
#          "description": "Self-reported sex",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Male"
#             },
#             {
#                "const": "2",
#                "title": "Female"
#             }
#          ]
#       },
#       "RACE": {
#          "$id": "dbgap:phv00424156.v1",
#          "description": "Self-reported race",
#          "type": "string",
#          "$unit": null
#       },
#       "DRUG_USE": {
#          "$id": "dbgap:phv00424161.v1",
#          "description": "Drug use history",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "N",
#                "title": "No drug history"
#             },
#             {
#                "const": "Y",
#                "title": "Drug history"
#             }
#          ]
#       },
#       "SEROLOGIES": {
#          "$id": "dbgap:phv00424162.v1",
#          "description": "Serologies type",
#          "type": "string",
#          "$unit": null
#       },
#       "AGE": {
#          "$id": "dbgap:phv00424157.v1",
#          "description": "Subject age at enrollment",
#          "type": "numeric",
#          "$unit": "years"
#       },
#       "TOBACCO": {
#          "$id": "dbgap:phv00424159.v1",
#          "description": "Smoking history",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "N",
#                "title": "No smoking history"
#             },
#             {
#                "const": "Y",
#                "title": "Smoking history"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001956.v1.pht009788.v1.sc_Liver_Sample_Attributes
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009788.v1",
#    "properties": {
#       "HISTOLOGICAL_TYPE": {
#          "$id": "dbgap:phv00424167.v1",
#          "description": "Cell or tissue type or subtype of sample",
#          "type": "string",
#          "$unit": null
#       },
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00424165.v1",
#          "description": "Analyte Type",
#          "type": "string",
#          "$unit": null
#       },
#       "IS_TUMOR": {
#          "$id": "dbgap:phv00424166.v1",
#          "description": "Tumor status",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "N",
#                "title": "Is not a tumor"
#             }
#          ]
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00424164.v1",
#          "description": "Body site where sample was collected",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00424163.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001963&study_version=v3.p1
# Schema: phs001963.v3.pht009826.v2.DEMENTIA_SEQ_Subject
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009826.v2",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00426505.v2",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00426506.v2",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "General Research Use (GRU)"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001963.v3.pht009828.v2.DEMENTIA_SEQ_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009828.v2",
#    "properties": {
#       "CONSENSUS_AGE": {
#          "$id": "dbgap:phv00426518.v2",
#          "description": "Consensus age",
#          "type": "Integer, encoded value",
#          "$unit": "years"
#       },
#       "DIAGNOSIS": {
#          "$id": "dbgap:phv00426513.v2",
#          "description": "Cohort",
#          "type": "string,encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "AD",
#                "title": "Alzheimer's disease"
#             },
#             {
#                "const": null,
#                "title": "Control"
#             },
#             {
#                "const": "FTD",
#                "title": "Frontotemporal dementia"
#             },
#             {
#                "const": "LBD",
#                "title": "Lewy body dementia"
#             },
#             {
#                "const": "MSA",
#                "title": "Multiple system atrophy"
#             },
#             {
#                "const": "PD",
#                "title": "Parkinson's disease"
#             }
#          ]
#       },
#       "DIAGNOSIS_TYPE": {
#          "$id": "dbgap:phv00426514.v2",
#          "description": "Clinically-diagnosed samples are labelled as \"Clinical\" and pathologically-confirmed samples are labelled as \"Pathological\"",
#          "type": "string",
#          "$unit": null
#       },
#       "COUNTRY": {
#          "$id": "dbgap:phv00435267.v2",
#          "description": "Subject's country of origin?",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00426509.v2",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SEX": {
#          "$id": "dbgap:phv00426511.v2",
#          "description": "Self-reported sex",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Male"
#             },
#             {
#                "const": "2",
#                "title": "Female"
#             },
#             {
#                "const": "UNK",
#                "title": "Unknown"
#             }
#          ]
#       },
#       "RACE": {
#          "$id": "dbgap:phv00426512.v2",
#          "description": "Race based upon genotype",
#          "type": "string",
#          "$unit": null
#       },
#       "CONTINENT": {
#          "$id": "dbgap:phv00435268.v2",
#          "description": "Subject's continent of origin?",
#          "type": "string",
#          "$unit": null
#       },
#       "FAMILY_HISTORY": {
#          "$id": "dbgap:phv00426515.v2",
#          "description": "Family history of neurological disease",
#          "type": "string, encoded value",
#          "$unit": null
#       },
#       "AGE_TYPE_IN_CONSENSUS": {
#          "$id": "dbgap:phv00426519.v2",
#          "description": "Age type used for consensus age",
#          "type": "String, encoded value",
#          "$unit": null
#       },
#       "AFFECTION_STATUS": {
#          "$id": "dbgap:phv00426510.v2",
#          "description": "Case-control status of the subject for dementia",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Control"
#             },
#             {
#                "const": "2",
#                "title": "Case"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001963.v3.pht009829.v2.DEMENTIA_SEQ_Sample_Attributes
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009829.v2",
#    "properties": {
#       "SEQUENCING_CENTER": {
#          "$id": "dbgap:phv00426524.v2",
#          "description": "Name of the center which conducted sequencing or genotyping",
#          "type": "string",
#          "$unit": null
#       },
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00426522.v2",
#          "description": "Analyte Type",
#          "type": "string",
#          "$unit": null
#       },
#       "IS_TUMOR": {
#          "$id": "dbgap:phv00426523.v2",
#          "description": "Tumor status",
#          "type": "encoded value",
#          "$unit": null
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00426521.v2",
#          "description": "Body site where sample was collected",
#          "type": "encoded value",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00426520.v2",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001963.v3.pht009827.v2.DEMENTIA_SEQ_Sample
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009827.v2",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00426507.v2",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00426508.v2",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001987&study_version=v3.p1
# Schema: phs001987.v3.pht009928.v2.GMKF_Enchondromatoses_Subject
# Downloading Schema:
# {
#    "description": "This subject consent data table includes subject IDs and consent group information.",
#    "$id": "dbgap:pht009928.v2",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00427223.v2",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00427224.v2",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Health/Medical/Biomedical (IRB, NPU) (HMB-IRB-NPU)"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001987.v3.pht009929.v3.GMKF_Enchondromatoses_Sample
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht009929.v3",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00427225.v3",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00427226.v3",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001395&study_version=v2.p1
# Schema: phs001395.v2.pht006627.v1.TOPMed_WGS_HCHS_SOL_Sample_Attributes
# Downloading Schema:
# {
#    "description": "This sample attributes table includes body site where sample was collected, analyte type, tumor status, sequencing center, funding source, TOPMed phase, project, and study name.",
#    "$id": "dbgap:pht006627.v1",
#    "properties": {
#       "TOPMed_Project": {
#          "$id": "dbgap:phv00420600.v1",
#          "description": "TOPMed Project that funded sequencing",
#          "type": "string",
#          "$unit": null
#       },
#       "SEQUENCING_CENTER": {
#          "$id": "dbgap:phv00420597.v1",
#          "description": "Name of the center which conducted sequencing",
#          "type": "string",
#          "$unit": null
#       },
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00305654.v1",
#          "description": "Analyte Type",
#          "type": "string",
#          "$unit": null
#       },
#       "TOPMed_Phase": {
#          "$id": "dbgap:phv00420599.v1",
#          "description": "TOPMed Phase",
#          "type": "string",
#          "$unit": null
#       },
#       "IS_TUMOR": {
#          "$id": "dbgap:phv00305655.v1",
#          "description": "Tumor status",
#          "type": "string",
#          "$unit": null
#       },
#       "Study_Name": {
#          "$id": "dbgap:phv00420601.v1",
#          "description": "TOPMed-assigned short study name (1:1 with TOPMed phs number)",
#          "type": "string",
#          "$unit": null
#       },
#       "Funding_Source": {
#          "$id": "dbgap:phv00420598.v1",
#          "description": "Project funding source",
#          "type": "string",
#          "$unit": null
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00305653.v1",
#          "description": "Body site where sample was collected",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00305652.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001395.v2.pht006625.v1.TOPMed_WGS_HCHS_SOL_Subject
# Downloading Schema:
# {
#    "description": "The subject consent data table contains subject IDs and consent group information.",
#    "$id": "dbgap:pht006625.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00305647.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00305648.v1",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Health/Medical/Biomedical (NPU) (HMB-NPU)"
#             },
#             {
#                "const": "2",
#                "title": "Health/Medical/Biomedical (HMB)"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001395.v2.pht006626.v1.TOPMed_WGS_HCHS_SOL_Sample
# Downloading Schema:
# {
#    "description": "This subject sample mapping data table includes a mapping of study subject IDs to sample IDs. Samples are the final preps submitted for genotyping, sequencing, and/or expression data. For example, if one patient (subject ID) gave one sample, and that sample was processed differently to generate 2 sequencing runs, there would be two rows, both using the same subject ID, but having 2 unique sample IDs.",
#    "$id": "dbgap:pht006626.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00305649.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00305650.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001415&study_version=v1.p1
# Schema: phs001415.v1.pht006686.v1.CIDR_GECCO_CRC_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "Subject ID, age, race, data about presence ethnicity, sex, study acronym, study collection site, and affection status of participants with or without colorectal cancer and involved in the \"Uncovering the Genetic Architecture of Colorectal Cancer with Focus of Rare and Less Frequent Variant\" project.",
#    "$id": "dbgap:pht006686.v1",
#    "properties": {
#       "STUDY": {
#          "$id": "dbgap:phv00308277.v1",
#          "description": "Study acronym [BWHS, CLUE-II, CPS-II, Czech Republic CCS, EDRN, EPICOLON, Hawaii Adenoma Study, HNPCC, HPFS advanced adenoma, LBS, NCCCSI, NCCCSII, NHS advanced adenoma, NSHDS, OCCPI, OSUMC Controls, PLCO, SELECT, SMS-REACH, WHI]",
#          "type": "string",
#          "$unit": null
#       },
#       "AGE_REF": {
#          "$id": "dbgap:phv00308274.v1",
#          "description": "Participant reference age",
#          "type": "integer",
#          "$unit": "Years"
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00308271.v1",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SEX": {
#          "$id": "dbgap:phv00308273.v1",
#          "description": "Sex of participant [Male or Female]",
#          "type": "string",
#          "$unit": null
#       },
#       "RACE": {
#          "$id": "dbgap:phv00308275.v1",
#          "description": "Race of participant [African American, American Indian or Alaska Native, Asian, Native Hawaiian, Other, Unknown, White]",
#          "type": "string",
#          "$unit": null
#       },
#       "FAMILY_HISTORY": {
#          "$id": "dbgap:phv00379355.v1",
#          "description": "Family history of first-degree relatives with colorectal cancer [No, Yes]",
#          "type": "string",
#          "$unit": null
#       },
#       "ETHNICITY": {
#          "$id": "dbgap:phv00308276.v1",
#          "description": "Presence of data about ethnicity of participant [No, Unknown, Yes]",
#          "type": "string",
#          "$unit": null
#       },
#       "AFFECTION_STATUS": {
#          "$id": "dbgap:phv00308272.v1",
#          "description": "Disease status: case diagnosed with colorectal cancer or control",
#          "type": "string",
#          "$unit": null
#       },
#       "STUDY_SITE": {
#          "$id": "dbgap:phv00308278.v1",
#          "description": "Study collection site [ACS, USA; Barcelona, Spain; Boston University, USA; Chapel Hill, NC, USA; Eastern Canada, Canada; EIS, Austria; FHCRC, USA; GUE, Austria; Harvard, USA; Hawaii Cancer Center, USA; Johns Hopkins University, USA; KI, Austria; Midwest, USA; MUG, Austria; Northeast, USA; OP, Austria; OSUMC, USA; OW, Austria; Prague, Czech Republic; Southeast, USA; Umea, Sweden; University of Pittsburgh; USA, Southwest; VIE, Austria; Western Canada, Canada; West, USA; Yorkshire, UK;",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001415.v1.pht006684.v1.CIDR_GECCO_CRC_Subject
# Downloading Schema:
# {
#    "description": "Subject ID, subject source, source subject ID, and consent group of participants with or without colorectal cancer and involved in the \"Uncovering the Genetic Architecture of Colorectal Cancer with Focus of Rare and Less Frequent Variant\" project.",
#    "$id": "dbgap:pht006684.v1",
#    "properties": {
#       "SUBJECT_SOURCE": {
#          "$id": "dbgap:phv00308264.v1",
#          "description": "Source repository where subjects originate",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00308262.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00308263.v1",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "0",
#                "title": "Subjects did not participate in the study, did not complete a consent document and are included only for the pedigree structure and/or genotype controls, such as HapMap subjects"
#             },
#             {
#                "const": "1",
#                "title": "General Research Use (GRU)"
#             },
#             {
#                "const": "2",
#                "title": "Health/Medical/Biomedical (COL, GSO) (HMB-COL-GSO)"
#             },
#             {
#                "const": "3",
#                "title": "Health/Medical/Biomedical (HMB)"
#             },
#             {
#                "const": "4",
#                "title": "Health/Medical/Biomedical (IRB) (HMB-IRB)"
#             },
#             {
#                "const": "5",
#                "title": "Health/Medical/Biomedical (IRB, NPU) (HMB-IRB-NPU)"
#             },
#             {
#                "const": "6",
#                "title": "Health/Medical/Biomedical (PUB) (HMB-PUB)"
#             },
#             {
#                "const": "7",
#                "title": "Disease-Specific (Bowel Cancer) (DS-BOCA)"
#             },
#             {
#                "const": "8",
#                "title": "General Research Use (GSO) (GRU-GSO)"
#             },
#             {
#                "const": "9",
#                "title": "Disease-Specific (Colorectal and Endometrial Cancer, IRB) (DS-CEC-IRB)"
#             },
#             {
#                "const": "10",
#                "title": "Disease-Specific (Cancer, IRB) (DS-CA-IRB)"
#             },
#             {
#                "const": "11",
#                "title": "Rare and common variants associated with colorectal cancer risk, and methods (RCV-CRC-MDS)"
#             },
#             {
#                "const": "12",
#                "title": "Cancer in all age groups, other diseases in adults only, and methods (CADM)"
#             },
#             {
#                "const": "13",
#                "title": "Health/Medical/Biomedical (PUB, NPU, GSO) (HMB-PUB-NPU-GSO)"
#             }
#          ]
#       },
#       "SOURCE_SUBJECT_ID": {
#          "$id": "dbgap:phv00308265.v1",
#          "description": "Subject ID used in the Source Repository",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001415.v1.pht006685.v1.CIDR_GECCO_CRC_Sample
# Downloading Schema:
# {
#    "description": "Subject ID, sample ID, sample source, source sample ID, and sample use variable obtained from participants with or without colorectal cancer and involved in the \"Uncovering the Genetic Architecture of Colorectal Cancer with Focus of Rare and Less Frequent Variant\" project.",
#    "$id": "dbgap:pht006685.v1",
#    "properties": {
#       "SOURCE_SAMPLE_ID": {
#          "$id": "dbgap:phv00308269.v1",
#          "description": "Sample ID used in the Source Repository",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00308266.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_USE": {
#          "$id": "dbgap:phv00308270.v1",
#          "description": "Sample Use",
#          "type": "encoded values",
#          "$unit": null
#       },
#       "SAMPLE_SOURCE": {
#          "$id": "dbgap:phv00308268.v1",
#          "description": "Source repository (study) where samples originate [SELECT, WHI]",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00308267.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001415.v1.pht006687.v1.CIDR_GECCO_CRC_Sample_Attributes
# Downloading Schema:
# {
#    "description": "Sample ID, analyte type, body site where sample was obtained, DNA concentration, DNA source, genotyping center, tumor status of sample, pate ID, volume, and sample well of participants with or without colorectal cancer and involved in the \"Uncovering the Genetic Architecture of Colorectal Cancer with Focus of Rare and Less Frequent Variant\" project.",
#    "$id": "dbgap:pht006687.v1",
#    "properties": {
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00308281.v1",
#          "description": "Analyte type [DNA]",
#          "type": "string",
#          "$unit": null
#       },
#       "IS_TUMOR": {
#          "$id": "dbgap:phv00308282.v1",
#          "description": "Tumor status",
#          "type": "string",
#          "$unit": null
#       },
#       "WELL": {
#          "$id": "dbgap:phv00308285.v1",
#          "description": "Sample well",
#          "type": "string",
#          "$unit": null
#       },
#       "PLATE_ID": {
#          "$id": "dbgap:phv00308284.v1",
#          "description": "Plate ID that sample was run on",
#          "type": "string",
#          "$unit": null
#       },
#       "VOLUME": {
#          "$id": "dbgap:phv00308287.v1",
#          "description": "Volume",
#          "type": "decimal",
#          "$unit": "uL"
#       },
#       "DNA_SOURCE": {
#          "$id": "dbgap:phv00308283.v1",
#          "description": "DNA origin [Blood, Buccal cells, Buffy coat, Mouth wash, Mucosa]",
#          "type": "string",
#          "$unit": null
#       },
#       "CONCENTRATION": {
#          "$id": "dbgap:phv00308286.v1",
#          "description": "DNA concentration",
#          "type": "decimal",
#          "$unit": "ng/uL"
#       },
#       "GENOTYPING_CENTER": {
#          "$id": "dbgap:phv00308288.v1",
#          "description": "Name of the center which conducted genotyping [CIDR]",
#          "type": "string",
#          "$unit": null
#       },
#       "QC_PIPELINE": {
#          "$id": "dbgap:phv00379356.v1",
#          "description": "QC pipline",
#          "type": null,
#          "$unit": null
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00308280.v1",
#          "description": "Body site where sample was collected [Blood, Gastrointestinal tract, Inner oral cavity]",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00308279.v1",
#          "description": "De-identified sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001447&study_version=v1.p1
# Schema: phs001447.v1.pht007468.v1.MCRPCS_Subject
# Downloading Schema:
# {
#    "description": "Subject ID and consent group of patients with or without prostate cancer and involved in the \"Genomic Resistance Patterns to Second Generation Androgen Blockade in Paired Tumor Biopsies of Metastatic Castrate-Resistant Prostate Cancer\" project.",
#    "$id": "dbgap:pht007468.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00352842.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00352843.v1",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Disease-Specific (Cancer, MDS) (DS-CA-MDS)"
#             },
#             {
#                "const": "2",
#                "title": "Disease-Specific (Prostate Cancer, MDS) (DS-PC-MDS)"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001447.v1.pht007469.v1.MCRPCS_Sample
# Downloading Schema:
# {
#    "description": "Subject ID, sample ID, and sample use variable of patients with or without prostate cancer and involved in the \"Genomic Resistance Patterns to Second Generation Androgen Blockade in Paired Tumor Biopsies of Metastatic Castrate-Resistant Prostate Cancer\" project.",
#    "$id": "dbgap:pht007469.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00352844.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_USE": {
#          "$id": "dbgap:phv00352846.v1",
#          "description": "Sample Use",
#          "type": null,
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "Seq_DNA_WholeExome",
#                "title": "Whole exome sequencing"
#             }
#          ]
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00352845.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001447.v1.pht007470.v1.MCRPCS_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "Subject ID, gender, and primary disease state of patients with or without prostate cancer and involved in the \"Genomic Resistance Patterns to Second Generation Androgen Blockade in Paired Tumor Biopsies of Metastatic Castrate-Resistant Prostate Cancer\" project.",
#    "$id": "dbgap:pht007470.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00352847.v1",
#          "description": "Unique participant identifier",
#          "type": "string",
#          "$unit": null
#       },
#       "Gender": {
#          "$id": "dbgap:phv00352848.v1",
#          "description": "Participant gender as Male or Female",
#          "type": "string",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": null,
#                "title": "Male"
#             }
#          ]
#       },
#       "Primary_Disease": {
#          "$id": "dbgap:phv00352849.v1",
#          "description": "Primary disease state of patient",
#          "type": "string",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": null,
#                "title": "Castrate Resistant Prostate Cancer"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001447.v1.pht007471.v1.MCRPCS_Sample_Attributes
# Downloading Schema:
# {
#    "description": "Sample ID, analyte type, sample type, and tumor type of patients with or without prostate cancer and involved in the \"Genomic Resistance Patterns to Second Generation Androgen Blockade in Paired Tumor Biopsies of Metastatic Castrate-Resistant Prostate Cancer\" project.",
#    "$id": "dbgap:pht007471.v1",
#    "properties": {
#       "TUMOR_TYPE": {
#          "$id": "dbgap:phv00352852.v1",
#          "description": "Indicates tumor type of the studied sample",
#          "type": "string",
#          "$unit": null
#       },
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00352853.v1",
#          "description": "Molecular analyte",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_TYPE": {
#          "$id": "dbgap:phv00352851.v1",
#          "description": "Indicates the Tumor / Normal status of a sample",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00352850.v1",
#          "description": "De-identified sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001451&study_version=v5.p1
# Schema: phs001451.v5.pht007133.v4.Melanoma_Neoantigen_Vaccine_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "This subject phenotype table contains subject IDs, age, ethnicity, subject IDs used in publication, and affection status of the subject for melanoma. All subjects are melanoma patients.",
#    "$id": "dbgap:pht007133.v4",
#    "properties": {
#       "SUBJID": {
#          "$id": "dbgap:phv00328545.v2",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "ETHNICITY": {
#          "$id": "dbgap:phv00328548.v2",
#          "description": "Ethnicity of subject [Caucasian, Hispanic, Arabic, Omani Arabic]",
#          "type": "string",
#          "$unit": null
#       },
#       "PUBLICATION_SUBJID": {
#          "$id": "dbgap:phv00481423.v1",
#          "description": "SUBJID used in publication",
#          "type": "string",
#          "$unit": null
#       },
#       "AFFECTION_STATUS": {
#          "$id": "dbgap:phv00528568.v1",
#          "description": "Affection status of the subject for melanoma; all subjects are melanoma patients.",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "A",
#                "title": "Affected"
#             },
#             {
#                "const": "U",
#                "title": "Unaffected"
#             }
#          ]
#       },
#       "AGE": {
#          "$id": "dbgap:phv00328546.v2",
#          "description": "Age of subject",
#          "type": "Integer, encoded value",
#          "$unit": "Years"
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001451.v5.pht007131.v3.Melanoma_Neoantigen_Vaccine_Subject
# Downloading Schema:
# {
#    "description": "The subject consent file includes subject IDs, consent information, and biological sex.",
#    "$id": "dbgap:pht007131.v3",
#    "properties": {
#       "SEX": {
#          "$id": "dbgap:phv00528567.v1",
#          "description": "Biological sex of subject",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Male"
#             },
#             {
#                "const": "2",
#                "title": "Female"
#             }
#          ]
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00328540.v2",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "General Research Use (GRU)"
#             }
#          ]
#       },
#       "SUBJID": {
#          "$id": "dbgap:phv00328539.v2",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001451.v5.pht007132.v5.Melanoma_Neoantigen_Vaccine_Sample
# Downloading Schema:
# {
#    "description": "This data table contains a mapping of study subject IDs to sample IDs. Samples are the final preps submitted for genotyping, sequencing, and/or expression data. For example, if one patient (subject ID) gave one sample, and that sample was processed differently to generate 2 sequencing runs, there would be two rows, both using the same subject ID, but having 2 unique sample IDs. ",
#    "$id": "dbgap:pht007132.v5",
#    "properties": {
#       "SAMPID": {
#          "$id": "dbgap:phv00328543.v5",
#          "description": "De-identified sample ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJID": {
#          "$id": "dbgap:phv00328542.v5",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001451.v5.pht007134.v5.Melanoma_Neoantigen_Vaccine_Sample_Attributes
# Downloading Schema:
# {
#    "description": "This sample attributes table contains sample IDs, body site where sample was collected, analyte type, histological type, and tumor status.",
#    "$id": "dbgap:pht007134.v5",
#    "properties": {
#       "HISTOLOGICAL_TYPE": {
#          "$id": "dbgap:phv00328552.v5",
#          "description": "Cell or tissue type",
#          "type": "string",
#          "$unit": null
#       },
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00328551.v5",
#          "description": "Analyte type",
#          "type": "string",
#          "$unit": null
#       },
#       "IS_TUMOR": {
#          "$id": "dbgap:phv00328553.v5",
#          "description": "Tumor status of the sample",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "NO",
#                "title": "Samples do not originate from tumor"
#             }
#          ]
#       },
#       "SAMPID": {
#          "$id": "dbgap:phv00328549.v5",
#          "description": "De-identified sample ID",
#          "type": "string",
#          "$unit": null
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00328550.v5",
#          "description": "Body site where sample was collected",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001482&study_version=v1.p1
# Schema: phs001482.v1.pht007125.v1.Carrier_Screening_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "This subject phenotype data table includes subject's ethnicity collected in the requisition form and consult, and ethnicity mapped from consult.",
#    "$id": "dbgap:pht007125.v1",
#    "properties": {
#       "rec_form_ethnicities": {
#          "$id": "dbgap:phv00328391.v1",
#          "description": "Ethnicity collected in requisition form",
#          "type": "string",
#          "$unit": null
#       },
#       "parsed_from_consult": {
#          "$id": "dbgap:phv00328392.v1",
#          "description": "Ethnicity collected in consult",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00328390.v1",
#          "description": "De-identified Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "consult_mapped": {
#          "$id": "dbgap:phv00328393.v1",
#          "description": "Ethnicity mapped from consult",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001482.v1.pht007123.v1.Carrier_Screening_Subject
# Downloading Schema:
# {
#    "description": "This subject consent data table includes subjects IDs and consent group information.",
#    "$id": "dbgap:pht007123.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00328385.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00328386.v1",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "General Research Use (GRU)"
#             }
#          ]
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001482.v1.pht007124.v1.Carrier_Screening_Sample
# Downloading Schema:
# {
#    "description": "This subject sample mapping data table includes a mapping of study subject IDs to sample IDs. Samples are the final preps submitted for genotyping, sequencing, and/or expression data. For example, if one patient (subject ID) gave one sample, and that sample was processed differently to generate 2 sequencing runs, there would be two rows, both using the same subject ID, but having 2 unique sample IDs. The data table also includes sample use.",
#    "$id": "dbgap:pht007124.v1",
#    "properties": {
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00328387.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_USE": {
#          "$id": "dbgap:phv00328389.v1",
#          "description": "Sample Use",
#          "type": "encoded values",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "Array_SNP",
#                "title": "SNP genotypes obtained using standard or custom microarrays"
#             }
#          ]
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00328388.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001482.v1.pht007126.v1.Carrier_Screening_Sample_Attributes
# Downloading Schema:
# {
#    "description": "This sample attributes data table includes body site where sample was collected and analyte type.",
#    "$id": "dbgap:pht007126.v1",
#    "properties": {
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00328395.v1",
#          "description": "Analyte Type",
#          "type": "string",
#          "$unit": null
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00328396.v1",
#          "description": "Body site where sample was collected",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00328394.v1",
#          "description": "De-identified Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001500&study_version=v2.p1
# Schema: phs001500.v2.pht007246.v2.Melanocyte_QTL_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "Subject ID, age, sex, and birthplace of participants involved in the \"National Cancer Institute (NCI) Primary Human Melanocyte QTL Study\" project.",
#    "$id": "dbgap:pht007246.v2",
#    "properties": {
#       "brithplace": {
#          "$id": "dbgap:phv00334423.v1",
#          "description": "Place of subject birth",
#          "type": "string",
#          "$unit": null
#       },
#       "race": {
#          "$id": "dbgap:phv00334424.v1",
#          "description": "Race of participant",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00334421.v1",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "sex": {
#          "$id": "dbgap:phv00334425.v1",
#          "description": "Gender of participant",
#          "type": "encoded value",
#          "$unit": null
#       },
#       "AFFECTION_STATUS": {
#          "$id": "dbgap:phv00487914.v1",
#          "description": "Case control or \"other\" status of the subject [Other=primary human melanocyte cultures]",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Control"
#             },
#             {
#                "const": "2",
#                "title": "Case"
#             },
#             {
#                "const": "3",
#                "title": "Other (primary human melanocyte cultures)"
#             }
#          ]
#       },
#       "age": {
#          "$id": "dbgap:phv00334422.v1",
#          "description": "Subject age",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001500.v2.pht007244.v2.Melanocyte_QTL_Subject
# Downloading Schema:
# {
#    "description": "Subject ID, consent group, subject source, source subject ID, and sex of participants involved in the \"National Cancer Institute (NCI) Primary Human Melanocyte QTL Study\" project.",
#    "$id": "dbgap:pht007244.v2",
#    "properties": {
#       "SUBJECT_SOURCE": {
#          "$id": "dbgap:phv00334413.v1",
#          "description": "Source repository where subjects originate",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00334411.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SEX": {
#          "$id": "dbgap:phv00487913.v1",
#          "description": "Sex",
#          "type": null,
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Male"
#             }
#          ]
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00334412.v2",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "General Research Use (GRU)"
#             }
#          ]
#       },
#       "SOURCE_SUBJECT_ID": {
#          "$id": "dbgap:phv00334414.v1",
#          "description": "Subject ID used in the Source Repository",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001500.v2.pht007245.v2.Melanocyte_QTL_Sample
# Downloading Schema:
# {
#    "description": "Subject ID, sample ID, sample source, source sample ID, and sample use of participants involved in the \"National Cancer Institute (NCI) Primary Human Melanocyte QTL Study\" project.",
#    "$id": "dbgap:pht007245.v2",
#    "properties": {
#       "SOURCE_SAMPLE_ID": {
#          "$id": "dbgap:phv00334419.v1",
#          "description": "Sample ID used in the Source Repository",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJECT_ID": {
#          "$id": "dbgap:phv00334416.v1",
#          "description": "Subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_USE": {
#          "$id": "dbgap:phv00334420.v2",
#          "description": "Sample Use",
#          "type": "encoded values",
#          "$unit": null
#       },
#       "SAMPLE_SOURCE": {
#          "$id": "dbgap:phv00334418.v1",
#          "description": "Source repository where samples originate",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00334417.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001500.v2.pht007247.v2.Melanocyte_QTL_Sample_Attributes
# Downloading Schema:
# {
#    "description": "Sample ID, analyte type, body site where sample was obtained, histological type of sample, tumor status of sample, sequencing center, genotyping center, and methylation center of participants involved in the \"National Cancer Institute (NCI) Primary Human Melanocyte QTL Study\" project.",
#    "$id": "dbgap:pht007247.v2",
#    "properties": {
#       "HISTOLOGICAL_TYPE": {
#          "$id": "dbgap:phv00334428.v1",
#          "description": "Cell or tissue type or subtype of sample",
#          "type": "string",
#          "$unit": null
#       },
#       "SEQUENCING_CENTER": {
#          "$id": "dbgap:phv00334432.v1",
#          "description": "Name of the center which conducted sequencing",
#          "type": "string",
#          "$unit": null
#       },
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00334430.v1",
#          "description": "Analyte type",
#          "type": "string",
#          "$unit": null
#       },
#       "IS_TUMOR": {
#          "$id": "dbgap:phv00334429.v1",
#          "description": "Tumor status",
#          "type": "encoded values",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "N",
#                "title": "Is not a tumor"
#             },
#             {
#                "const": "Y",
#                "title": "Is tumor"
#             }
#          ]
#       },
#       "METHYLATION_CENTER": {
#          "$id": "dbgap:phv00487915.v1",
#          "description": "Methylation Center",
#          "type": null,
#          "$unit": null
#       },
#       "GENOTYPING_CENTER": {
#          "$id": "dbgap:phv00334431.v1",
#          "description": "Name of the center which conducted genotyping",
#          "type": "string",
#          "$unit": null
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00334427.v1",
#          "description": "Body site where sample was collected",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00334426.v1",
#          "description": "De-identified sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001500.v2.pht007257.v1.Melanocyte_QTL_GEO
# Downloading Schema:
# {
#    "description": "Sample ID and GEO accession ID of participants involved in the \"National Cancer Institute (NCI) Primary Human Melanocyte QTL Study\" project.",
#    "$id": "dbgap:pht007257.v1",
#    "properties": {
#       "GEO_ACCESSION": {
#          "$id": "dbgap:phv00334471.v1",
#          "description": "GEO accession ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SAMPLE_ID": {
#          "$id": "dbgap:phv00334470.v1",
#          "description": "Sample ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================
# Retrieving schemas at: /schemas/dbGaP/?study=phs001519&study_version=v2.p1
# Schema: phs001519.v2.pht008433.v2.Neoantigen_Cancer_Vaccine_GBM_Subject
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht008433.v2",
#    "properties": {
#       "SEX": {
#          "$id": "dbgap:phv00527725.v1",
#          "description": "Biological sex",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Male"
#             },
#             {
#                "const": "2",
#                "title": "Female"
#             },
#             {
#                "const": "UNK",
#                "title": "Unknown"
#             }
#          ]
#       },
#       "CONSENT": {
#          "$id": "dbgap:phv00395996.v2",
#          "description": "Consent group as determined by DAC",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "General Research Use (GRU)"
#             },
#             {
#                "const": "2",
#                "title": "Health/Medical/Biomedical (HMB)"
#             }
#          ]
#       },
#       "SUBJID": {
#          "$id": "dbgap:phv00395995.v2",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001519.v2.pht008435.v2.Neoantigen_Cancer_Vaccine_GBM_Subject_Phenotypes
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht008435.v2",
#    "properties": {
#       "SUBJID": {
#          "$id": "dbgap:phv00396001.v2",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       },
#       "ETHNICITY": {
#          "$id": "dbgap:phv00396004.v2",
#          "description": "Ethnicity of subject",
#          "type": "string",
#          "$unit": null
#       },
#       "AFFECTION_STATUS": {
#          "$id": "dbgap:phv00527726.v1",
#          "description": "Affectation status of the subject for Glioblastoma (GBM); All subjects are GBM patients.",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "1",
#                "title": "Case"
#             }
#          ]
#       },
#       "AGE": {
#          "$id": "dbgap:phv00396002.v2",
#          "description": "Age of subject",
#          "type": "Integer, encoded value",
#          "$unit": "Years"
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001519.v2.pht008434.v2.Neoantigen_Cancer_Vaccine_GBM_Sample
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht008434.v2",
#    "properties": {
#       "SAMPID": {
#          "$id": "dbgap:phv00395999.v2",
#          "description": "De-identified sample ID",
#          "type": "string",
#          "$unit": null
#       },
#       "SUBJID": {
#          "$id": "dbgap:phv00395998.v2",
#          "description": "De-identified subject ID",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# Schema: phs001519.v2.pht008436.v2.Neoantigen_Cancer_Vaccine_GBM_Sample_Attributes
# Downloading Schema:
# {
#    "description": "",
#    "$id": "dbgap:pht008436.v2",
#    "properties": {
#       "HISTOLOGICAL_TYPE": {
#          "$id": "dbgap:phv00396008.v2",
#          "description": "Cell or tissue type",
#          "type": "string",
#          "$unit": null
#       },
#       "ANALYTE_TYPE": {
#          "$id": "dbgap:phv00396007.v2",
#          "description": "Analyte type",
#          "type": "string",
#          "$unit": null
#       },
#       "IS_TUMOR": {
#          "$id": "dbgap:phv00396009.v2",
#          "description": "Tumor status of the sample",
#          "type": "encoded value",
#          "$unit": null,
#          "oneOf": [
#             {
#                "const": "NO",
#                "title": "Samples do not originate from tumor"
#             }
#          ]
#       },
#       "SAMPID": {
#          "$id": "dbgap:phv00396005.v2",
#          "description": "De-identified sample ID",
#          "type": "string",
#          "$unit": null
#       },
#       "BODY_SITE": {
#          "$id": "dbgap:phv00396006.v2",
#          "description": "Body site where sample was collected",
#          "type": "string",
#          "$unit": null
#       }
#    }
# }
# ________________________________________________________________________________
# ================================================================================

# %% [markdown]
# ### Listing all dbGaP schemas via schemas/namespace is not currently supported
#
# There are currently over 13,000 schemas

# %%
endpoint = f"/schemas/dbGaP/"
print(endpoint)
response = requests.get(f"{base}{endpoint}")
prettyprint(response.json())
# Out:
# /schemas/dbGaP/
# {
#    "namespace": "dbGaP",
#    "schemas": []
# }
