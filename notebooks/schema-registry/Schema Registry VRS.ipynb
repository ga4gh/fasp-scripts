# %% [markdown]
# ### Demonstration of Schema Registry implementation accessing GitHub Repository
#
# See https://github.com/ianfore/ga4gh-starter-schema-repository for details of the implementation.
#
# These examples use the GitHubSchemaProvider class as a SchemaProvider.

# %%
import requests;

import json;

def prettyprint(a_dict):
    print(json.dumps(a_dict, indent=3))

def printline(char="_"):
    print(char*80)

# %%
base = "http://localhost:8080"

# %% [markdown]
# ### Get schemas for the VRS namespace
#
# The schema are accessed dynamically from the GitHub repository at https://github.com/ga4gh/vrs

# %%
endpoint = f"/schemas/vrs/"
print(endpoint)
response = requests.get(f"{base}{endpoint}")
schemas = response.json()['schemas']
for schema in schemas:
    print( schema['schema_name'])
# Out:
# /schemas/vrs/
# Adjacency
# Allele
# CisPhasedBlock
# CopyNumberChange
# CopyNumberCount
# DerivativeMolecule
# Expression
# LengthExpression
# LiteralSequenceExpression
# Location
# MolecularVariation
# Range
# ReferenceLengthExpression
# SequenceExpression
# SequenceLocation
# SequenceReference
# SystemicVariation
# Terminus
# TraversalBlock
# Variation
# residue
# sequenceString

# %% [markdown]
# ### Get schema as JSON Schema

# %%
namespace = "vrs"
schema_name = "LiteralSequenceExpression"
url = f"{base}/schemas/{namespace}/{schema_name}/versions/latest"
response = requests.get(url)
prettyprint(response.json())
# Out:
# {
#    "$id": "https://w3id.org/ga4gh/schema/vrs/2.x/json/LiteralSequenceExpression",
#    "description": "An explicit expression of a Sequence.",
#    "$schema": "https://json-schema.org/draft/2020-12/schema",
#    "properties": {
#       "id": {
#          "type": "string",
#          "$comment": "Note that it is common for implementers to create their own internal logical ids - typically a serially or randomly generated value like a UUID that is assigned to the data object as it is created in a system. But an implementer may choose to re-use an existing, globally unique id from an external system or authority for this purpose (e.g. an HGNC id for a Gene object) - as long as it is unique within the implementing system, and can be used to reference the identified object in this context.",
#          "description": "The 'logical' identifier of the Entity in the system of record, e.g. a UUID.  This 'id' is unique within a given system, but may or may not be globally unique outside the system. It is used within a system to reference an object from another."
#       },
#       "name": {
#          "type": "string",
#          "description": "A primary name for the entity."
#       },
#       "description": {
#          "type": "string",
#          "description": "A free-text description of the Entity."
#       },
#       "aliases": {
#          "items": {
#             "type": "string"
#          },
#          "type": "array",
#          "ordered": false,
#          "description": "Alternative name(s) for the Entity."
#       },
#       "extensions": {
#          "items": {
#             "$ref": "/ga4gh/schema/gks-core/1.x/json/Extension"
#          },
#          "type": "array",
#          "$comment": "Extension objects have a key-value data structure that allows definition of custom fields in the data itself. Extensions are not expected to be natively understood, but may be used for pre-negotiated exchange of message attributes between systems.",
#          "ordered": false,
#          "description": "A list of extensions to the Entity, that allow for capture of information not directly supported by elements defined in the model."
#       },
#       "type": {
#          "type": "string",
#          "$comment": "MUST be the name of a concrete class from the data model.",
#          "description": "MUST be \"LiteralSequenceExpression\"",
#          "const": "LiteralSequenceExpression",
#          "default": "LiteralSequenceExpression"
#       },
#       "sequence": {
#          "$ref": "/ga4gh/schema/vrs/2.x/json/sequenceString",
#          "description": "the literal sequence"
#       }
#    },
#    "title": "LiteralSequenceExpression",
#    "type": "object",
#    "maturity": "trial use",
#    "ga4gh": {
#       "inherent": [
#          "sequence",
#          "type"
#       ]
#    },
#    "required": [
#       "sequence",
#       "type"
#    ],
#    "additionalProperties": false
# }

# %% [markdown]
# ### Schema versions

# %%
schema_name = "ConceptMapping"
url = f"{base}/schemas/{namespace}/{schema_name}/versions/"
response = requests.get(url)
prettyprint(response.json())
# Out:
# {
#    "schema_name": "ConceptMapping",
#    "versions": [
#       {
#          "version": "2.0.0",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2025-03-14T15:00:54.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0.connect.2024-04.1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2024-04-19T17:45:26.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-snapshot.2025-02.4",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2025-03-11T02:01:46.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-snapshot.2025-02.3",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2025-03-03T01:04:58.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-snapshot.2025-02.2",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2025-02-11T17:53:16.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-snapshot.2025-02.1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2025-02-10T21:56:30.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-connect.2024-09.1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2024-09-18T00:27:50.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-ballot.2024-11.3",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2024-12-19T04:21:27.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-ballot.2024-11.2",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2024-11-27T04:38:02.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-ballot.2024-11.1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2024-11-26T05:01:10.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "2.0.0-ballot.2024-08.1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2024-08-22T00:33:50.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.3.0",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2023-04-16T13:14:23.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.2.1",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2022-02-09T02:30:45.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.2.0",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2021-07-12T14:58:42.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.2.0.rc1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2021-04-09T04:40:18.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.2.0.rc0",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2021-03-01T01:23:49.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.2.0.dev2",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2021-02-28T17:45:29.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.2.0.dev1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2021-02-27T04:58:31.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.2.0.dev0",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2021-02-26T18:42:56.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.1.2",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2021-01-02T17:23:42.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.1.1",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2020-10-04T04:20:30.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.1.0",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2020-09-09T16:42:51.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.0.0",
#          "status": "released",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2019-10-15T04:14:33.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.0.0-rc.2",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2019-08-08T16:53:14.000Z",
#          "release_notes": ""
#       },
#       {
#          "version": "1.0.0-rc.1",
#          "status": "development",
#          "contributors": [
#             "Global Alliance for Genomics and Health"
#          ],
#          "release_date": "2019-07-19T03:24:15.000Z",
#          "release_notes": ""
#       }
#    ]
# }

# %% [markdown]
# ## gks-core
#
# The schema are accessed dynamically from the GitHub repository at https://github.com/ga4gh/gks-core

# %%
endpoint = f"/schemas/gks-core/"
print(endpoint)
response = requests.get(f"{base}{endpoint}")
schemas = response.json()['schemas']
for schema in schemas:
    print( schema['schema_name'])
# Out:
# /schemas/gks-core/
# Code
# Coding
# ConceptMapping
# Extension
# MappableConcept
# date
# datetime
# iriReference

# %% [markdown]
# ### Retrieve the ConceptMapping schema

# %%
schema_name = "ConceptMapping"
url = f"{base}/schemas/gks-core/{schema_name}/versions/latest"
print(url)
response = requests.get(url)
prettyprint(response.json())
# Out:
# https://gap-schema-registry-1089266259229.us-east4.run.app/schemas/gks-core/ConceptMapping/versions/v2
# {
#    "$id": "https://w3id.org/ga4gh/schema/gks-core/1.x/json/ConceptMapping",
#    "description": "A mapping to a concept in a terminology or code system.",
#    "$schema": "https://json-schema.org/draft/2020-12/schema",
#    "properties": {
#       "id": {
#          "type": "string",
#          "description": "The 'logical' identifier of the data element in the system of record, e.g. a UUID.  This 'id' is unique within a given system, but may or may not be globally unique outside the system. It is used within a system to reference an object from another."
#       },
#       "extensions": {
#          "items": {
#             "$ref": "/ga4gh/schema/gks-core/1.x/json/Extension"
#          },
#          "type": "array",
#          "$comment": "Extension objects have a key-value data structure that allows definition of custom fields in the data itself. Extensions are not expected to be natively understood, but may be used for pre-negotiated exchange of message attributes between systems.",
#          "ordered": false,
#          "description": "A list of extensions to the Entity, that allow for capture of information not directly supported by elements defined in the model."
#       },
#       "coding": {
#          "$ref": "/ga4gh/schema/gks-core/1.x/json/Coding",
#          "description": "A structured representation of a code for a defined concept in a terminology or code system."
#       },
#       "relation": {
#          "type": "string",
#          "description": "A mapping relation between concepts as defined by the Simple Knowledge Organization System (SKOS).",
#          "enum": [
#             "closeMatch",
#             "exactMatch",
#             "broadMatch",
#             "narrowMatch",
#             "relatedMatch"
#          ]
#       }
#    },
#    "title": "ConceptMapping",
#    "type": "object",
#    "maturity": "trial use",
#    "required": [
#       "coding",
#       "relation"
#    ],
#    "additionalProperties": false
# }
