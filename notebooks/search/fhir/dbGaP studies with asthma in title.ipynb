# %% [markdown]
# ### dbGaP Asthma datasets for Computable Cohort Representation hackathon
#
# This is a second approach to identify asthma datasets in dbGaP by using the *dbGaP on FHIR* server.
#
# The following steps search for studies in dbGaP with Asthma in the title
#
# Acknowledging use of code snippets from [NIH FHIR training](https://github.com/NIH-ODSS/fhir-exercises/tree/main/Python) Exercise 0.

# %%
import sys
import os
import json
import requests

FHIR_SERVER = 'https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1'

# Optional: Turn off SSL verification. Useful when dealing with a corporate proxy with self-signed certificates.
# This should be set to True unless you actually see certificate errors.
VERIFY_SSL = True

if not VERIFY_SSL:
    requests.packages.urllib3.disable_warnings()

# We make a requests.Session to ensure consistent headers across all the requests we make
sess = requests.Session()
sess.headers.update({'Accept': 'application/fhir+json'})
sess.verify = VERIFY_SSL

# Test out the cookie by querying the server metadata
r = sess.get(f"{FHIR_SERVER}/metadata")

# %% [markdown]
# More background before we get to the real thing.
#
# Define a function to deal with pagination of FHIR results and return results from multiple pages as a single list.

# %%
def run_query(query, page_limit=None):
    response = sess.get(f"{FHIR_SERVER}/{query}")
    bundles = [response.json()]
    next_page_link = next(filter(lambda link: link['relation'] == 'next', bundles[0]['link']), None)
    page_count = 1
    if page_limit:
        if page_count >= page_limit:
            next_page_link = None
    while next_page_link:
        next_page = sess.get(next_page_link['url']).json()
        bundles.append(next_page)
        next_page_link = next(filter(lambda link: link['relation'] == 'next', next_page['link']), None)
        page_count += 1
        if page_limit:
            if page_count >= page_limit:
                next_page_link = None
    
    if 'entry' in bundles[0]:
        resources = [entry['resource'] for sb in bundles for entry in sb['entry']]
        return resources
    else:
        return []

# %% [markdown]
# To help understand what a Research Study resource looks like in dbGaP on FHIR we'll run the following query for a single study and list the whole resource.
#
# This helps see that some of the data we want to extract from the resource are held in extensions to the FHIR model.

# %%
documents = run_query("ResearchStudy?_id=phs001156")
print("# of studies:{}".format(len(documents)))

for s in documents:

    print ("Study id: {}".format(s['id']))
    print ("Study title: {}".format(s['title']))
    print ("Full resource")
    print(json.dumps(s, indent=3))
    print('_'*40)
# Out:
# # of studies:1
# Study id: phs001156
# Study title: The EVE Asthma Genetics Consortium: Building Upon GWAS
# Full resource
# {
#    "resourceType": "ResearchStudy",
#    "id": "phs001156",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2022-04-05T03:01:18.668-04:00",
#       "source": "#cqF99SBP7UR7tFTl",
#       "security": [
#          {
#             "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-SecurityStudyConsent",
#             "code": "public",
#             "display": "public"
#          }
#       ]
#    },
#    "extension": [
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyOverviewUrl",
#          "valueUrl": "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=phs001156.v2.p1"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ReleaseDate",
#          "valueDate": "2018-05-08"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents-StudyConsent",
#                "valueCoding": {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyConsents-StudyConsent",
#                   "code": "phs001156.v2.p1 - 1",
#                   "display": "GRU-NPU"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumPhenotypeDatasets",
#                "valueCount": {
#                   "value": 4,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumMolecularDatasets",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumVariables",
#                "valueCount": {
#                   "value": 19,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumAnalyses",
#                "valueCount": {
#                   "value": 4,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects",
#                "valueCount": {
#                   "value": 296,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSamples",
#                "valueCount": {
#                   "value": 296,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubStudies",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             }
#          ]
#       }
#    ],
#    "identifier": [
#       {
#          "type": {
#             "coding": [
#                {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-DbGaPStudyIdentifier",
#                   "code": "dbgap_study_id",
#                   "display": "dbgap_study_id"
#                }
#             ]
#          },
#          "value": "phs001156.v2.p1"
#       }
#    ],
#    "title": "The EVE Asthma Genetics Consortium: Building Upon GWAS",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyDesign",
#                "code": "Case-Control",
#                "display": "Case-Control"
#             }
#          ],
#          "text": "Case-Control"
#       }
#    ],
#    "focus": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "condition": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: Ara h 3 allergen, Arachis hypogaea",
#                "display": "Ara h 3 allergen, Arachis hypogaea"
#             }
#          ],
#          "text": "Ara h 3 allergen, Arachis hypogaea"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: Ara h3, allergen",
#                "display": "Ara h3, allergen"
#             }
#          ],
#          "text": "Ara h3, allergen"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: Translocase of Outer Mitochondrial Membrane 20 Homolog (Yeast) Gene",
#                "display": "Translocase of Outer Mitochondrial Membrane 20 Homolog (Yeast) Gene"
#             }
#          ],
#          "text": "Translocase of Outer Mitochondrial Membrane 20 Homolog (Yeast) Gene"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: allergen Ara h3",
#                "display": "allergen Ara h3"
#             }
#          ],
#          "text": "allergen Ara h3"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "keyword": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: Ara h 3 allergen, Arachis hypogaea",
#                "display": "Ara h 3 allergen, Arachis hypogaea"
#             }
#          ],
#          "text": "Ara h 3 allergen, Arachis hypogaea"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: Ara h3, allergen",
#                "display": "Ara h3, allergen"
#             }
#          ],
#          "text": "Ara h3, allergen"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: Translocase of Outer Mitochondrial Membrane 20 Homolog (Yeast) Gene",
#                "display": "Translocase of Outer Mitochondrial Membrane 20 Homolog (Yeast) Gene"
#             }
#          ],
#          "text": "Translocase of Outer Mitochondrial Membrane 20 Homolog (Yeast) Gene"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "C118207 entry term: allergen Ara h3",
#                "display": "allergen Ara h3"
#             }
#          ],
#          "text": "allergen Ara h3"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "description": "\nThe EVE Asthma Genetics Consortium comprises U.S. investigators who have conducted genome-wide association studies (GWAS) of asthma; the main objective is to combine results of individual studies to increase the overall power to identify loci for asthma and asthma-associated traits. The consortium includes investigators at 9 U.S. institutions with GWAS results for &gt;10,000 individuals representing European American, African American, African Caribbean, U.S. Hispanic, and Mexican populations and includes the following studies:  - The Study of Asthma Phenotypes and Pharmacogenomic Interactions by Race-Ethnicity (SAPPHIRE) - The Genetic Research on Asthma in the African Diaspora (GRAAD) Study - The Genetics of Asthma in Latino Americans (GALA 1) Study - The Childhood Asthma Management Program (CAMP) - The Childhood Asthma Research and Education (CARE) Network - The Children&#39;s Health Study (CHS) - Mexico City Childhood Asthma Study (MCCAS) - The Chicago Asthma Genetics Study (CAG)* - The National Heart, Lung, and Blood Institute Collaborative Studies of the Genetics of Asthma (CSGA)* - The Severe Asthma Research Program (SARP)*  (*CAG, CSGA, and SARP are part of the NHLBI-supported SNP Typing for Association with Multiple Phenotypes from Existing Epidemiologic Data (STAMPEED) consortium.) \n\nFor the GWAS, we developed a common set of &gt;1 million genotyped and imputed SNPs from the EVE Asthma Genetics Consortium to be tested for association with asthma and associated phenotypes in all samples and combined p-values for a grand meta-analysis for asthma gene discovery. A subset of 296 individuals representing African American, European American, and Latino ancestry were selected for whole genome sequencing.\n\nThe broad goals of this project were to characterize the genetic architecture of asthma and associated quantitative phenotypes (e.g., lung function, total serum IgE) in ethnically diverse populations from the U.S., Mexico, Puerto Rico, and Barbados.\n",
#    "enrollment": [
#       {
#          "reference": "Group/phs001156.v2.p1-all-subjects"
#       }
#    ],
#    "sponsor": {
#       "reference": "Organization/NHLBI",
#       "type": "Organization",
#       "display": "National Heart, Lung, and Blood Institute"
#    }
# }
# ________________________________________

# %% [markdown]
# With the information above we can now run our query for studies with the word asthma in the title. We rely on standard FHIR query syntax for this. According to the FHIR standard the search will be case insensitive.

# %%
documents = run_query("ResearchStudy?title:contains=asthma")

print("# of studies:{}".format(len(documents)))

for s in documents:

    print ("Study id: {}".format(s['id']))
    print ("Study title: {}".format(s['title']))

#    keyValList = ["https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents"]
#    expectedResult = [d for d in s['extension'] if d['url'] in keyValList]

    #print(json.dumps(s, indent=3))
    #print('_'*40)
# Out:
# # of studies:28
# Study id: phs000166
# Study title: SNP Health Association Resource (SHARe) Asthma Resource Project (SHARP)
# {
#    "resourceType": "ResearchStudy",
#    "id": "phs000166",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2022-04-05T02:54:18.255-04:00",
#       "source": "#o497z6NJvlJ1imnP",
#       "security": [
#          {
#             "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-SecurityStudyConsent",
#             "code": "public",
#             "display": "public"
#          }
#       ]
#    },
#    "extension": [
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyOverviewUrl",
#          "valueUrl": "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=phs000166.v2.p1"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ReleaseDate",
#          "valueDate": "2009-09-09"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents-StudyConsent",
#                "valueCoding": {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyConsents-StudyConsent",
#                   "code": "phs000166.v2.p1 - 0",
#                   "display": "NRUP"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents-StudyConsent",
#                "valueCoding": {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyConsents-StudyConsent",
#                   "code": "phs000166.v2.p1 - 1",
#                   "display": "ARR"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumPhenotypeDatasets",
#                "valueCount": {
#                   "value": 9,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumMolecularDatasets",
#                "valueCount": {
#                   "value": 1,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumVariables",
#                "valueCount": {
#                   "value": 348,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumDocuments",
#                "valueCount": {
#                   "value": 39,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects",
#                "valueCount": {
#                   "value": 4046,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSamples",
#                "valueCount": {
#                   "value": 4046,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubStudies",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyMarkersets",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                         "code": "Genome-Wide_Human_SNP_Array_6.0"
#                      }
#                   ]
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                         "code": "SNP Genotypes (Array)"
#                      }
#                   ]
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Functional Variant in the Autophagy-Related 5 Gene Promotor is Associated with Childhood Asthma"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3335039"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Following the footprints of polymorphic inversions on SNP data: from detection to association tests"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4417146"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Genome-Wide Association Study Identifies Novel Pharmacogenomic Loci For Therapeutic Response to Montelukast in Asthma"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4470685"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Measuring the Corticosteroid Responsiveness Endophenotype in Asthma"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4530065"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "African ancestry is associated with cluster-based childhood asthma subphenotypes"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5984446"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "The Pharmacogenetics and Pharmacogenomics of Asthma Therapy"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3298891"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Genome-Wide Association Study of Short-Acting \u00c3\u009f2-Agonists. A Novel Genome-Wide Significant Locus on Chromosome 2 near ASB3"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4384768"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Differences in Candidate Gene Association between European Ancestry and African American Asthmatic Children"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3046166"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Identification of ATPAF1 as a novel candidate gene for asthma in children"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3185108"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Genome-wide Association Identifies the T Gene as a Novel Asthma Pharmacogenetic Locus"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3381232"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Genetic predictors associated with improvement of asthma symptoms in response to inhaled corticosteroids"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4112383"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Rank-based genome-wide analysis reveals the association of Ryanodine receptor-2 gene variants with childhood asthma among human populations"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3708719"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "A Common 16p11.2 Inversion Underlies the Joint Susceptibility to Asthma and Obesity"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3951940"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Epistasis between SPINK5 and TSLP Genes Contributes to Childhood Asthma"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4186896"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "FEATURE SCREENING FOR TIME-VARYING COEFFICIENT MODELS WITH ULTRAHIGH DIMENSIONAL LONGITUDINAL DATA"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5019497"
#                   }
#                ]
#             }
#          ]
#       }
#    ],
#    "identifier": [
#       {
#          "type": {
#             "coding": [
#                {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-DbGaPStudyIdentifier",
#                   "code": "dbgap_study_id",
#                   "display": "dbgap_study_id"
#                }
#             ]
#          },
#          "value": "phs000166.v2.p1"
#       }
#    ],
#    "title": "SNP Health Association Resource (SHARe) Asthma Resource Project (SHARP)",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyDesign",
#                "code": "Cross-Sectional",
#                "display": "Cross-Sectional"
#             }
#          ],
#          "text": "Cross-Sectional"
#       }
#    ],
#    "description": "\nSNP Health Association Resource (SHARe) Asthma Resource project (SHARP) is conducting a genome-wide analysis in adults and children who have participated in National Heart, Lung, and Blood Institute&#39;s clinical research trials on asthma. This includes 1041 children with asthma who participated in the Childhood Asthma Management Program (CAMP), 994 children who participated in one or five clinical trials conducted by the Childhood Asthma Research and Education (CARE) network, and 701 adults who participated in one of six clinical trials conducted by the Asthma Clinical Research Network (ACRN).\n\nThere are three study types. The longitudinal clinical trials can be subsetted for population-based and/or case-control analyses. Each of the childhood asthma studies has a majority of children participating as part of a parent-child trio. The ACRN (adult) studies are probands alone. Control genotypes will be provided for case-control analyses.\n",
#    "enrollment": [
#       {
#          "reference": "Group/phs000166.v2.p1-all-subjects"
#       }
#    ],
#    "sponsor": {
#       "reference": "Organization/NHLBI",
#       "type": "Organization",
#       "display": "National Heart, Lung, and Blood Institute"
#    }
# }
# ________________________________________
# Study id: phs000233
# Study title: Genome Wide Association Study of Asthma
# {
#    "resourceType": "ResearchStudy",
#    "id": "phs000233",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2022-04-05T02:54:26.454-04:00",
#       "source": "#cw6cZAyua7EgBuNR",
#       "security": [
#          {
#             "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-SecurityStudyConsent",
#             "code": "public",
#             "display": "public"
#          }
#       ]
#    },
#    "extension": [
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyOverviewUrl",
#          "valueUrl": "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=phs000233.v1.p1"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ReleaseDate",
#          "valueDate": "2019-09-12"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents-StudyConsent",
#                "valueCoding": {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyConsents-StudyConsent",
#                   "code": "phs000233.v1.p1 - 100",
#                   "display": "Analysis"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumMolecularDatasets",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumAnalyses",
#                "valueCount": {
#                   "value": 1,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubStudies",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             }
#          ]
#       }
#    ],
#    "identifier": [
#       {
#          "type": {
#             "coding": [
#                {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-DbGaPStudyIdentifier",
#                   "code": "dbgap_study_id",
#                   "display": "dbgap_study_id"
#                }
#             ]
#          },
#          "value": "phs000233.v1.p1"
#       }
#    ],
#    "title": "Genome Wide Association Study of Asthma",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyDesign",
#                "code": "Case-Control",
#                "display": "Case-Control"
#             }
#          ],
#          "text": "Case-Control"
#       }
#    ],
#    "focus": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "condition": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "keyword": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "description": "\nThis data forms part of an ongoing genome wide association study into the genetic variants that predispose to pediatric asthma at the Children&#39;s Hospital of Philadelphia (CHOP). All cases and controls were recruited at CHOP and genotyped at the Center for Applied Genomics (CAG). The data set includes 793 cases and 1988 controls. The inclusion criteria to this case control study are detailed below. \n",
#    "enrollment": [
#       {
#          "reference": "Group/phs000233.v1.p1-all-subjects"
#       }
#    ],
#    "sponsor": {
#       "reference": "Organization/NHLBI",
#       "type": "Organization",
#       "display": "National Heart, Lung, and Blood Institute"
#    }
# }
# ________________________________________
# Study id: phs000355
# Study title: Genome Wide Association for Asthma and Lung Function
# {
#    "resourceType": "ResearchStudy",
#    "id": "phs000355",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2022-04-05T02:55:11.040-04:00",
#       "source": "#6kdRtkrpKPaQs6BL",
#       "security": [
#          {
#             "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-SecurityStudyConsent",
#             "code": "public",
#             "display": "public"
#          }
#       ]
#    },
#    "extension": [
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyOverviewUrl",
#          "valueUrl": "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=phs000355.v1.p1"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ReleaseDate",
#          "valueDate": "2011-10-28"
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents-StudyConsent",
#                "valueCoding": {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyConsents-StudyConsent",
#                   "code": "phs000355.v1.p1 - 100",
#                   "display": "Analysis"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumMolecularDatasets",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumAnalyses",
#                "valueCount": {
#                   "value": 2,
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubStudies",
#                "valueCount": {
#                   "system": "http://unitsofmeasure.org",
#                   "code": "1"
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "The Effects of Migration and Assortative Mating on Admixture Linkage Disequilibrium"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5223515"
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Title",
#                      "valueString": "Genome-wide study identifies two loci associated with lung function decline in mild to moderate COPD"
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Citers-Citer-Url",
#                      "valueUrl": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3536920"
#                   }
#                ]
#             }
#          ]
#       }
#    ],
#    "identifier": [
#       {
#          "type": {
#             "coding": [
#                {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-DbGaPStudyIdentifier",
#                   "code": "dbgap_study_id",
#                   "display": "dbgap_study_id"
#                }
#             ]
#          },
#          "value": "phs000355.v1.p1"
#       }
#    ],
#    "title": "Genome Wide Association for Asthma and Lung Function",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyDesign",
#                "code": "Case-Control",
#                "display": "Case-Control"
#             }
#          ],
#          "text": "Case-Control"
#       }
#    ],
#    "condition": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D012129",
#                "display": "Respiratory Function Tests"
#             }
#          ],
#          "text": "Respiratory Function Tests"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Test, Lung",
#                "display": "Function Test, Lung"
#             }
#          ],
#          "text": "Function Test, Lung"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Test, Pulmonary",
#                "display": "Function Test, Pulmonary"
#             }
#          ],
#          "text": "Function Test, Pulmonary"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Test, Respiratory",
#                "display": "Function Test, Respiratory"
#             }
#          ],
#          "text": "Function Test, Respiratory"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Tests, Lung",
#                "display": "Function Tests, Lung"
#             }
#          ],
#          "text": "Function Tests, Lung"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Tests, Pulmonary",
#                "display": "Function Tests, Pulmonary"
#             }
#          ],
#          "text": "Function Tests, Pulmonary"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Tests, Respiratory",
#                "display": "Function Tests, Respiratory"
#             }
#          ],
#          "text": "Function Tests, Respiratory"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Lung Function Test",
#                "display": "Lung Function Test"
#             }
#          ],
#          "text": "Lung Function Test"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Lung Function Tests",
#                "display": "Lung Function Tests"
#             }
#          ],
#          "text": "Lung Function Tests"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Pulmonary Function Test",
#                "display": "Pulmonary Function Test"
#             }
#          ],
#          "text": "Pulmonary Function Test"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Pulmonary Function Tests",
#                "display": "Pulmonary Function Tests"
#             }
#          ],
#          "text": "Pulmonary Function Tests"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Respiratory Function Test",
#                "display": "Respiratory Function Test"
#             }
#          ],
#          "text": "Respiratory Function Test"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Test, Lung Function",
#                "display": "Test, Lung Function"
#             }
#          ],
#          "text": "Test, Lung Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Test, Pulmonary Function",
#                "display": "Test, Pulmonary Function"
#             }
#          ],
#          "text": "Test, Pulmonary Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Test, Respiratory Function",
#                "display": "Test, Respiratory Function"
#             }
#          ],
#          "text": "Test, Respiratory Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Tests, Lung Function",
#                "display": "Tests, Lung Function"
#             }
#          ],
#          "text": "Tests, Lung Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Tests, Pulmonary Function",
#                "display": "Tests, Pulmonary Function"
#             }
#          ],
#          "text": "Tests, Pulmonary Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Tests, Respiratory Function",
#                "display": "Tests, Respiratory Function"
#             }
#          ],
#          "text": "Tests, Respiratory Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
#    "keyword": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D012129",
#                "display": "Respiratory Function Tests"
#             }
#          ],
#          "text": "Respiratory Function Tests"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Test, Lung",
#                "display": "Function Test, Lung"
#             }
#          ],
#          "text": "Function Test, Lung"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Test, Pulmonary",
#                "display": "Function Test, Pulmonary"
#             }
#          ],
#          "text": "Function Test, Pulmonary"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Test, Respiratory",
#                "display": "Function Test, Respiratory"
#             }
#          ],
#          "text": "Function Test, Respiratory"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Tests, Lung",
#                "display": "Function Tests, Lung"
#             }
#          ],
#          "text": "Function Tests, Lung"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Tests, Pulmonary",
#                "display": "Function Tests, Pulmonary"
#             }
#          ],
#          "text": "Function Tests, Pulmonary"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Function Tests, Respiratory",
#                "display": "Function Tests, Respiratory"
#             }
#          ],
#          "text": "Function Tests, Respiratory"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Lung Function Test",
#                "display": "Lung Function Test"
#             }
#          ],
#          "text": "Lung Function Test"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Lung Function Tests",
#                "display": "Lung Function Tests"
#             }
#          ],
#          "text": "Lung Function Tests"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Pulmonary Function Test",
#                "display": "Pulmonary Function Test"
#             }
#          ],
#          "text": "Pulmonary Function Test"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Pulmonary Function Tests",
#                "display": "Pulmonary Function Tests"
#             }
#          ],
#          "text": "Pulmonary Function Tests"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Respiratory Function Test",
#                "display": "Respiratory Function Test"
#             }
#          ],
#          "text": "Respiratory Function Test"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Test, Lung Function",
#                "display": "Test, Lung Function"
#             }
#          ],
#          "text": "Test, Lung Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Test, Pulmonary Function",
#                "display": "Test, Pulmonary Function"
#             }
#          ],
#          "text": "Test, Pulmonary Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Test, Respiratory Function",
#                "display": "Test, Respiratory Function"
#             }
#          ],
#          "text": "Test, Respiratory Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Tests, Lung Function",
#                "display": "Tests, Lung Function"
#             }
#          ],
#          "text": "Tests, Lung Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Tests, Pulmonary Function",
#                "display": "Tests, Pulmonary Function"
#             }
#          ],
#          "text": "Tests, Pulmonary Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D012129 entry term: Tests, Respiratory Function",
#                "display": "Tests, Respiratory Function"
#             }
#          ],
#          "text": "Tests, Respiratory Function"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0004096",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       }
#    ],
# ...
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "AFA"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 35,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "LAC"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 417,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "LEN"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 442,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "OAS"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 1,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount",
#                "extension": [
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-ComputedAncestry-AncestryCount-Ancestry",
#                               "code": "OTR"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-ComputedAncestry-AncestryCount-Count",
#                      "valueCount": {
#                         "value": 56,
#                         "system": "http://unitsofmeasure.org",
#                         "code": "1"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyMarkersets",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyMarkersets-StudyMarkerset",
#                         "code": "WGS_markerset_grc38"
#                      }
#                   ]
#                }
#             }
#          ]
#       },
#       {
#          "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes",
#          "extension": [
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                         "code": "SNP/CNV Genotypes (NGS)"
#                      }
#                   ]
#                }
#             },
#             {
#                "url": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-MolecularDataTypes-MolecularDataType",
#                         "code": "WGS"
#                      }
#                   ]
#                }
#             }
#          ]
#       }
#    ],
#    "identifier": [
#       {
#          "type": {
#             "coding": [
#                {
#                   "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/DbGaPConcept-DbGaPStudyIdentifier",
#                   "code": "dbgap_study_id",
#                   "display": "dbgap_study_id"
#                }
#             ]
#          },
#          "value": "phs001542.v2.p1"
#       }
#    ],
#    "title": "NHLBI TOPMed: Genetics of Asthma in Latino Americans (GALA)",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/CodeSystem/ResearchStudy-StudyDesign",
#                "code": "Case Set",
#                "display": "Case Set"
#             }
#          ],
#          "text": "Case Set"
#       }
#    ],
#    "condition": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D006967",
#                "display": "Hypersensitivity"
#             }
#          ],
#          "text": "Hypersensitivity"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Allergic Reactions",
#                "display": "Allergic Reactions"
#             }
#          ],
#          "text": "Allergic Reactions"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Allergy",
#                "display": "Allergy"
#             }
#          ],
#          "text": "Allergy"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Hypersensitivities",
#                "display": "Hypersensitivities"
#             }
#          ],
#          "text": "Hypersensitivities"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Reaction, Allergic",
#                "display": "Reaction, Allergic"
#             }
#          ],
#          "text": "Reaction, Allergic"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Reactions, Allergic",
#                "display": "Reactions, Allergic"
#             }
#          ],
#          "text": "Reactions, Allergic"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0020517",
#                "display": "Allergies"
#             }
#          ],
#          "text": "Allergies"
#       }
#    ],
#    "keyword": [
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D001249",
#                "display": "Asthma"
#             }
#          ],
#          "text": "Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "urn:oid:2.16.840.1.113883.6.177",
#                "code": "D006967",
#                "display": "Hypersensitivity"
#             }
#          ],
#          "text": "Hypersensitivity"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Allergic Reactions",
#                "display": "Allergic Reactions"
#             }
#          ],
#          "text": "Allergic Reactions"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Allergy",
#                "display": "Allergy"
#             }
#          ],
#          "text": "Allergy"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthma, Bronchial",
#                "display": "Asthma, Bronchial"
#             }
#          ],
#          "text": "Asthma, Bronchial"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Asthmas",
#                "display": "Asthmas"
#             }
#          ],
#          "text": "Asthmas"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D001249 entry term: Bronchial Asthma",
#                "display": "Bronchial Asthma"
#             }
#          ],
#          "text": "Bronchial Asthma"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Hypersensitivities",
#                "display": "Hypersensitivities"
#             }
#          ],
#          "text": "Hypersensitivities"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Reaction, Allergic",
#                "display": "Reaction, Allergic"
#             }
#          ],
#          "text": "Reaction, Allergic"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/NamingSystem/MeshEntryTerm",
#                "code": "D006967 entry term: Reactions, Allergic",
#                "display": "Reactions, Allergic"
#             }
#          ],
#          "text": "Reactions, Allergic"
#       },
#       {
#          "coding": [
#             {
#                "system": "https://uts.nlm.nih.gov/metathesaurus.html",
#                "code": "C0020517",
#                "display": "Allergies"
#             }
#          ],
#          "text": "Allergies"
#       }
#    ],
#    "description": "\nThis is a case pharmacogenetic study of bronchodilator drug response (Albuterol) among racially admixed Latino children with asthma between the ages of 8-40. Lung function testing was performed using the KoKo PFT system and each participant was administered albuterol dependent on age. Participants under 16 years of age, were administered 2 puffs of albuterol from a standard metered dose inhaler and 4 puffs for participants over 16 years old.\n\nThe overall goal is to identify genetic factors which are predictive of drug response in children with asthma. The principal tools include a questionnaire and biological specimen collection. Participants with asthma have physician-diagnosed asthma, symptoms and medications.\n",
#    "enrollment": [
#       {
#          "reference": "Group/phs001542.v2.p1-all-subjects"
#       }
#    ],
#    "sponsor": {
#       "reference": "Organization/NHLBI",
#       "type": "Organization",
#       "display": "National Heart, Lung, and Blood Institute"
#    }
# }
# ________________________________________

# %% [markdown]
# We'll define another function for convenience. Because so much of what we want is in extensions, and there are extensions within extensions, the following function helps us deal with an extension at any level.

# %%
# for a given resource find the extension identified by a given url
# The assumption is that there is only one such extension within a given resource
# For the dbGaP ResearchStudy resource that is true
def getExtension(resource, uri):
    exts = [d for d in resource['extension'] if d['url'] == uri]
    return exts[0]

# %% [markdown]
# We can now use the function above to find the extensions for
# * the number of subjects in the study
# * the consent groups within the study
#
# The following extracts these details and puts them into a list.

# %%
studies = []
for s in documents:

    print (s['id'])
    
    print (s['title'])
    # use our function to find the "study content" extension
    content = getExtension(s, "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content")
    # use our function again to find the "number of subjects" extension nested within the content extension
    subject_ext = getExtension(content, "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-Content-NumSubjects")
    #print(subject_ext)
    # Handle the fact that not all studies may have this extension
    if len(subject_ext) > 0 and 'value' in subject_ext['valueCount']:
        subject_count = subject_ext['valueCount']['value']
    else:
        subject_count = 0
    
    #keyValList = "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents"
    #consent_ext = [d for d in s['extension'] if d['url'] == keyValList]
    # Now find the extension containing the study consents
    consent_ext = getExtension(s, "https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/StructureDefinition/ResearchStudy-StudyConsents")
    #print(json.dumps(consent_ext[0], indent=3))
    # extract the display name for each consent group and print them
    consents = [d['valueCoding']['display'] for d in consent_ext['extension'] ]
    print(consents)
    # Add the relevant details to our list of studies
    study = {"id":s['id'], "title":s["title"], "num_subjects":subject_count, "consents":consents}
    studies.append(study)
    print('_'*40)
# Out:
# phs000166
# SNP Health Association Resource (SHARe) Asthma Resource Project (SHARP)
# ['NRUP', 'ARR']
# ________________________________________
# phs000233
# Genome Wide Association Study of Asthma
# ['Analysis']
# ________________________________________
# phs000355
# Genome Wide Association for Asthma and Lung Function
# ['Analysis']
# ________________________________________
# phs000422
# NHLBI GO-ESP: Lung Cohorts Exome Sequencing Project (Asthma)
# ['GRU']
# ________________________________________
# phs000886
# An Omics View of Asthma through Monozygotic Twins
# ['GRU']
# ________________________________________
# phs001009
# Determinants of Asthma Following RSV Bronchiolitis in Early Life
# ['NRUP', 'DS-AAR-IRB']
# ________________________________________
# phs001216
# A Genome-Wide Association Study for Post-bronchodilator Lung Function in Children with Asthma
# ['DS-ASTHMA-IRB-PUB-NPU-MDS-GSO-RD']
# ________________________________________
# phs001156
# The EVE Asthma Genetics Consortium: Building Upon GWAS
# ['GRU-NPU']
# ________________________________________
# phs001123
# Consortium on Asthma among African-ancestry Populations in the Americas
# ['NRUP', 'GRU-IRB', 'HMB', 'DS-LD', 'HMB-IRB-NPU', 'DS-FDO-IRB-NPU', 'HMB-IRB', 'DS-FDO-IRB']
# ________________________________________
# phs001812
# Genetic and Epigenetic Determinants of Pediatric Obesity-Associated Asthma
# ['NRUP', 'GRU-IRB-COL']
# ________________________________________
# phs000921
# NHLBI TOPMed: Study of African Americans, Asthma, Genes and Environment (SAGE)
# ['DS-LD-IRB-COL']
# ________________________________________
# phs001274
# Genes-environments and Admixture in Latino Asthmatics (GALA II) GWAS Study
# ['DS-LD-IRB-COL']
# ________________________________________
# phs001180
# Genes-Environments and Admixture in Latino Asthmatics (GALA II) Study
# ['NRUP', 'DS-LD-IRB-COL']
# ________________________________________
# phs002224
# Sputum RNA-Seq from Asthmatic Patients for Microbes and Genes
# ['GRU']
# ________________________________________
# phs001143
# NHLBI TOPMed: The Genetics and Epidemiology of Asthma in Barbados
# ['NRUP', 'GRU-IRB']
# ________________________________________
# phs000920
# NHLBI TOPMed - NHGRI CCDG: Genes-Environments and Admixture in Latino Asthmatics (GALA II)
# ['DS-LD-IRB-COL']
# ________________________________________
# phs001726
# NHLBI TOPMed: Childhood Asthma Management Program (CAMP)
# ['NRUP', 'DS-AST-COPD']
# ________________________________________
# phs000988
# NHLBI TOPMed: The Genetic Epidemiology of Asthma in Costa Rica
# ['NRUP', 'DS-ASTHMA-IRB-MDS-RD']
# ________________________________________
# phs001446
# NHLBI TOPMed: Severe Asthma Research Program (SARP)
# ['GRU']
# ________________________________________
# phs001602
# NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genetic Approaches to Gene-Air Pollution Interactions in Asthma (GAP)
# ['GRU']
# ________________________________________
# phs001603
# NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genomics and Environmental Research of Asthma (IGERA)
# ['GRU']
# ________________________________________
# phs001605
# NHLBI TOPMed: Chicago Initiative to Raise Asthma Health Equity (CHIRAH)
# ['DS-ASTHMA-IRB-COL']
# ________________________________________
# phs001727
# NHLBI TOPMed: Pathways to Immunologically Mediated Asthma (PIMA)
# ['DS-ASTHMA-IRB-COL']
# ________________________________________
# phs001732
# NHLBI TOPMed: TReating Children to Prevent EXacerbations of Asthma (TREXA)
# ['DS-ASTHMA-IRB-COL']
# ________________________________________
# phs001467
# NHLBI TOPMed: Study of Asthma Phenotypes and Pharmacogenomic Interactions by Race-Ethnicity (SAPPHIRE)
# ['NRUP', 'HMB-COL']
# ________________________________________
# phs001661
# NHLBI TOPMed: Genetic Causes of Complex Pediatric Disorders - Asthma (GCPD-A)
# ['DS-ASTHMA-GSO']
# ________________________________________
# phs001730
# NHLBI TOPMed: Pediatric Asthma Controller Trial (PACT)
# ['DS-ASTHMA-IRB-COL']
# ________________________________________
# phs001542
# NHLBI TOPMed: Genetics of Asthma in Latino Americans (GALA)
# ['DS-LD-IRB-COL']
# ________________________________________

# %% [markdown]
# We can then put our list of studies into a DataFrame for display.
#
# We're listing the consent so we can see if any of the studies could potentially be used in the Computable Cohort Representation asthma exercise.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 0)
df = pd.DataFrame(studies)
df.sort_values(by=['id'], inplace=True)
df
# Out:
#            id  \
# 0   phs000166
# 1   phs000233
# 2   phs000355
# 3   phs000422
# 4   phs000886
# 15  phs000920
# 10  phs000921
# 17  phs000988
# 5   phs001009
# 8   phs001123
# 14  phs001143
# 7   phs001156
# 12  phs001180
# 6   phs001216
# 11  phs001274
# 18  phs001446
# 24  phs001467
# 27  phs001542
# 19  phs001602
# 20  phs001603
# 21  phs001605
# 25  phs001661
# 16  phs001726
# 22  phs001727
# 26  phs001730
# 23  phs001732
# 9   phs001812
# 13  phs002224
#
#                                                                                                                                 title  \
# 0   SNP Health Association Resource (SHARe) Asthma Resource Project (SHARP)
# 1   Genome Wide Association Study of Asthma
# 2   Genome Wide Association for Asthma and Lung Function
# 3   NHLBI GO-ESP: Lung Cohorts Exome Sequencing Project (Asthma)
# 4   An Omics View of Asthma through Monozygotic Twins
# 15  NHLBI TOPMed - NHGRI CCDG: Genes-Environments and Admixture in Latino Asthmatics (GALA II)
# 10  NHLBI TOPMed: Study of African Americans, Asthma, Genes and Environment (SAGE)
# 17  NHLBI TOPMed: The Genetic Epidemiology of Asthma in Costa Rica
# 5   Determinants of Asthma Following RSV Bronchiolitis in Early Life
# 8   Consortium on Asthma among African-ancestry Populations in the Americas
# 14  NHLBI TOPMed: The Genetics and Epidemiology of Asthma in Barbados
# 7   The EVE Asthma Genetics Consortium: Building Upon GWAS
# 12  Genes-Environments and Admixture in Latino Asthmatics (GALA II) Study
# 6   A Genome-Wide Association Study for Post-bronchodilator Lung Function in Children with Asthma
# 11  Genes-environments and Admixture in Latino Asthmatics (GALA II) GWAS Study
# 18  NHLBI TOPMed: Severe Asthma Research Program (SARP)
# 24  NHLBI TOPMed: Study of Asthma Phenotypes and Pharmacogenomic Interactions by Race-Ethnicity (SAPPHIRE)
# 27  NHLBI TOPMed: Genetics of Asthma in Latino Americans (GALA)
# 19  NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genetic Approaches to Gene-Air Pollution Interactions in Asthma (GAP)
# 20  NHLBI TOPMed: Children&#39;s Health Study (CHS) Integrative Genomics and Environmental Research of Asthma (IGERA)
# 21  NHLBI TOPMed: Chicago Initiative to Raise Asthma Health Equity (CHIRAH)
# 25  NHLBI TOPMed: Genetic Causes of Complex Pediatric Disorders - Asthma (GCPD-A)
# 16  NHLBI TOPMed: Childhood Asthma Management Program (CAMP)
# 22  NHLBI TOPMed: Pathways to Immunologically Mediated Asthma (PIMA)
# 26  NHLBI TOPMed: Pediatric Asthma Controller Trial (PACT)
# 23  NHLBI TOPMed: TReating Children to Prevent EXacerbations of Asthma (TREXA)
# 9   Genetic and Epigenetic Determinants of Pediatric Obesity-Associated Asthma
# 13  Sputum RNA-Seq from Asthmatic Patients for Microbes and Genes
#
#     num_subjects  \
# 0   4046
# 1   0
# 2   0
# 3   191
# 4   74
# 15  4860
# 10  2106
# 17  4230
# 5   178
# 8   14548
# 14  1527
# 7   296
# 12  4458
# 6   447
# 11  4427
# 18  1882
# 24  4857
# 27  1024
# 19  7
# 20  160
# 21  292
# 25  5464
# 16  2640
# 22  73
# 26  41
# 23  89
# 9   115
# 13  116
#
#                                                                          consents
# 0   [NRUP, ARR]
# 1   [Analysis]
# 2   [Analysis]
# 3   [GRU]
# 4   [GRU]
# 15  [DS-LD-IRB-COL]
# 10  [DS-LD-IRB-COL]
# 17  [NRUP, DS-ASTHMA-IRB-MDS-RD]
# 5   [NRUP, DS-AAR-IRB]
# 8   [NRUP, GRU-IRB, HMB, DS-LD, HMB-IRB-NPU, DS-FDO-IRB-NPU, HMB-IRB, DS-FDO-IRB]
# 14  [NRUP, GRU-IRB]
# 7   [GRU-NPU]
# 12  [NRUP, DS-LD-IRB-COL]
# 6   [DS-ASTHMA-IRB-PUB-NPU-MDS-GSO-RD]
# 11  [DS-LD-IRB-COL]
# 18  [GRU]
# 24  [NRUP, HMB-COL]
# 27  [DS-LD-IRB-COL]
# 19  [GRU]
# 20  [GRU]
# 21  [DS-ASTHMA-IRB-COL]
# 25  [DS-ASTHMA-GSO]
# 16  [NRUP, DS-AST-COPD]
# 22  [DS-ASTHMA-IRB-COL]
# 26  [DS-ASTHMA-IRB-COL]
# 23  [DS-ASTHMA-IRB-COL]
# 9   [NRUP, GRU-IRB-COL]
# 13  [GRU]
