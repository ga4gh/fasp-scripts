# %%
from fasp.search import DataConnectClient
from fasp.search import mapping as mp

cl = DataConnectClient('https://ga4gh-search-adapter-presto-public.prod.dnastack.com')

# %% [markdown]
# #### Specify the table to search and run the query, specifying the columns to retrieve
# A data frame is returned

# %%
query = 'select * from search_cloud.cshcodeathon.md_value_map limit 100'
res = cl.runQuery(query, returnType='dataframe')
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
#                                           table_name column_name valuestring  \
# 0                        COPDGene.Subject_Phenotypes      gender           2
# 1                        COPDGene.Subject_Phenotypes      gender           1
# 2  search_cloud.cshcodeathon.organoid_profiling_p...         sex           F
# 3  search_cloud.cshcodeathon.organoid_profiling_p...         sex         N/A
# 4  search_cloud.cshcodeathon.organoid_profiling_p...         sex           M
#
#   maptovalue
# 0     Female
# 1       Male
# 2     Female
# 3        N/A
# 4       Male

# %% [markdown]
# #### Get a mapping for the sex column in the table queried above

# %%
query = 'select * from search_cloud.cshcodeathon.md_mapping limit 100'
res = cl.runQuery(query, returnType='dataframe')
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
#     map_id                                         table_name  \
# 0     1310        GECCO_CRC_Susceptibility.Subject_Phenotypes
# 1     1210        GECCO_CRC_Susceptibility.Subject_Phenotypes
# 2     1200  search_cloud.cshcodeathon.organoid_profiling_p...
# 3     1300  search_cloud.cshcodeathon.organoid_profiling_p...
# 4     1130  search_cloud.cshcodeathon.organoid_profiling_p...
# 5     1100        GECCO_CRC_Susceptibility.Subject_Phenotypes
# 6     1120  search_cloud.cshcodeathon.organoid_profiling_p...
# 7     1080                        COPDGene.Subject_Phenotypes
# 8     1140                        COPDGene.Subject_Phenotypes
# 9     1110                                 MESA.AirNRExamMain
# 10    1090             ESP_LungGO_COPDGene.Subject_Phenotypes
# 11    1230                        COPDGene.Subject_Phenotypes
# ...

# %%
panc = cl.runQuery('select * from dbgap_demo.scr_ega.scr_egapancreatic_sample_multi limit 100', returnType='dataframe' )
panc
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
#    sample_primary_id sample_submitter_id            disease_site  gender  \
# 0         ERS1485101      Pam04_Germline             Skin_Normal  female
# 1         ERS1485076      Pam03_Germline           Muscle_Normal    male
# 2         ERS1485135      Pam13_Germline           Spleen_Normal    male
# 3         ERS1485056          Pam02_LiM7        Liver_Metastasis    male
# 4         ERS1485057          Pam02_LiM8        Liver_Metastasis    male
# 5         ERS1485067          Pam02_PT11  Pancreas_Primary_Tumor    male
# 6         ERS1485070          Pam02_PT14  Pancreas_Primary_Tumor    male
# 7         ERS1485075          Pam02_PT10  Pancreas_Primary_Tumor    male
# 8         ERS1485045          Pam02_NoM1   Lymph_Node_Metastasis    male
# 9         ERS1485046          Pam02_NoM2   Lymph_Node_Metastasis    male
# ...

# %%
cl.listCatalog('dbgap_demo')
# Out:
# _Retrieving the table list_
# ____Page1_______________
# dbgap_demo.scr_ega.scr_egapancreatic_files
# dbgap_demo.scr_ega.scr_egapancreatic_sample_multi
# dbgap_demo.scr_gecco_susceptibility.gecco_sample_acc
# dbgap_demo.scr_gecco_susceptibility.phs001554_gecco_sddp_manifest
# dbgap_demo.scr_gecco_susceptibility.sample_attributes_multi
# dbgap_demo.scr_gecco_susceptibility.sample_multi
# dbgap_demo.scr_gecco_susceptibility.sb_drs_index
# dbgap_demo.scr_gecco_susceptibility.subject_multi
# dbgap_demo.scr_gecco_susceptibility.subject_phenotypes_multi

# %% [markdown]
# #### Transform the column
# Use the replace function of the dataframe to use the data provided by the mapping

# %%
ti = cl.listTableInfo('dbgap_demo.scr_ega.scr_egapancreatic_sample_multi')
props = ti.schema['data_model']['properties']
print (props.keys())
# Out:
# dict_keys(['gender', 'bam_file', 'phenotype', 'subject_id', 'disease_site', 'ena-checklist', 'sample_primary_id', 'sample_submitter_id'])

# %%
panc.describe()
# Out:
#        sample_primary_id sample_submitter_id            disease_site gender  \
# count                 39                  39                      39     39
# unique                39                  39                       9      2
# top           ERS1485138          Pam02_NoM1  Pancreas_Primary_Tumor   male
# freq                   1                   1                      12     30
#
#                         phenotype subject_id ena_checklist  \
# count                          39         39            39
# unique                          4          5             1
# top     pancreatic adenocarcinoma      Pam03     ERC000026
# freq                           36         13            39
#
#                    bam_file
# count                    39
# unique                   39
# top     PAM04/SS6004376.bam
# freq                      1

# %%
panc.dtypes
# Out:
# sample_primary_id      object
# sample_submitter_id    object
# disease_site           object
# gender                 object
# phenotype              object
# subject_id             object
# ena_checklist          object
# bam_file               object
# dtype: object

# %%
panc.size
# Out:
# 312

# %%
panc.keys()
# Out:
# Index(['sample_primary_id', 'sample_submitter_id', 'disease_site', 'gender',
#        'phenotype', 'subject_id', 'ena_checklist', 'bam_file'],
#       dtype='object')

# %%
panc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sample_primary_id    39 non-null     object
#  1   sample_submitter_id  39 non-null     object
#  2   disease_site         39 non-null     object
#  3   gender               39 non-null     object
#  4   phenotype            39 non-null     object
#  5   subject_id           39 non-null     object
#  6   ena_checklist        39 non-null     object
#  7   bam_file             39 non-null     object
# dtypes: object(8)
# memory usage: 2.6+ KB

# %%
panc.shape[0]
# Out:
# 39

# %%
len(panc.index)
# Out:
# 39

# %%
gec = cl.runQuery('select * from dbgap_demo.scr_gecco_susceptibility.subject_phenotypes_multi limit 300', returnType='dataframe')
gec
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
#     dbgap_subject_id subject_id affection_status     sex  age   race  \
# 0            2474312      95363             Case  Female   46  White
# 1            2473610      78277          Control  Female   46  White
# 2            2474054      93264             Case  Female   47  White
# 3            2472925     118146          Control  Female   47  White
# 4            2473792      78473          Control  Female   48  White
# ..               ...        ...              ...     ...  ...    ...
# 295           400369      63319             Case  Female   55  White
# 296           416486      64119             Case  Female   55  White
# 297          2472281      64343             Case  Female   55  White
# 298          2472469     117523             Case  Female   55  White
# ...
