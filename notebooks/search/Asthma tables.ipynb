# %% [markdown]
# ### Online Asthma datasets for Cohort Representation hackathon
# The following lists a number of asthma studies with data that could be explored as part of the Cohort Representation hackathon. These studies are either already set up, or require onlly a few steps to make them available for use both via FHIR and via Data Connect.
#
# #### Data Connect
# At present the data dictionaries for these can be provided via GA4GH Data Connect. Some examples are illustrated below.
#
# #### FHIR
# Synthetic data could be generated or data access obtained to the real data.
#
# ResearchStudy resources are available for the same studies through the dbGaP on FHIR server. See https://github.com/ncbi/DbGaP-FHIR-API-Docs/blob/production/quickstart.md
#
# Patient and Observation resources from these studies should also be available. These data are simulated and harmonized. See https://github.com/ncbi/DbGaP-FHIR-API-Docs/blob/production/quickstart.md#other-objects

# %%
import pandas as pd
df = pd.read_csv("data/asthma_studies.txt", sep="\t")
df
# Out:
# /Users/forei/imfenvs/fasp/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                                           Study name  Subjects  \
# 0  An Omics View of Asthma through Monozygotic Twins        74
# 1  NHLBI TOPMed: Study of African Americans, Asth...      2106
# 2  NHLBI TOPMed: The Genetics and Epidemiology of...      1527
# 3  The EVE Asthma Genetics Consortium: Building U...       296
# 4  NHLBI TOPMed: Severe Asthma Research Program (...      1882
# 5  NHLBI TOPMed: Childhood Asthma Management Prog...      2640
# 6  NHLBI TOPMed: Pediatric Asthma Controller Tria...        41
# 7  NHLBI TOPMed: Pathways to Immunologically Medi...        73
# 8  A Large-Scale, Consortium-Based Genomewide Ass...     26475
#
#                                               Link                         id  \
# 0      http:/identifiers.org/dbgap:phs000886.v1.p1      dbgap:phs000886.v1.p1
# 1      http:/identifiers.org/dbgap:phs000921.v4.p1      dbgap:phs000921.v4.p1
# 2      http:/identifiers.org/dbgap:phs001143.v4.p1      dbgap:phs001143.v4.p1
# 3      http:/identifiers.org/dbgap:phs001156.v2.p1      dbgap:phs001156.v2.p1
# 4      http:/identifiers.org/dbgap:phs001446.v2.p1      dbgap:phs001446.v2.p1
# 5      http:/identifiers.org/dbgap:phs001726.v2.p1      dbgap:phs001726.v2.p1
# 6      http:/identifiers.org/dbgap:phs001730.v2.p1      dbgap:phs001730.v2.p1
# 7       http:/identifiers.org/dbgapphs001727.v2.p1       dbgapphs001727.v2.p1
# 8  http:/identifiers.org/ega.study:EGAS00000000077  ega.study:EGAS00000000077
#
#   Pedigree                                              Notes
# 0        Y                                                NaN
# 1        Y                                                NaN
# 2        Y                                                NaN
# 3        N                                                NaN
# 4        Y                                                NaN
# 5        N  The details for this study report that CARE an...
# 6        N                                                NaN
# 7        N                                                NaN
# 8      NaN                                                NaN

# %% [markdown]
# ### Example FHIR and Data Connect data for these studies
# Get a Data Connect client

# %%
from fasp.search import DataConnectClient
cl = DataConnectClient('http://localhost:8089/')

# %% [markdown]
# ### NHLBI TOPMed: Childhood Asthma Management Program (CAMP)
#
# dbGaP Study Accession: phs001726.v2.p1
#
# The details for this study report that CARE and ACRN standard variables were used.
#
# A FHIR ResearchStudy resource for this study is available at https://dbgap-api.ncbi.nlm.nih.gov/fhir/x1/ResearchStudy/phs001726
#
# Simulated individual level data is also available as Patient and Observation resources.
#
# The following shows the data dictionary for two data tables for this study.

# %%
cl.listTableColumns('TOPMed.CAMP.LData', descriptions=True, enums=False)
# Out:
# tx_grp_fup
# Treatment group at follow-up visit
# _______________________________________
# prefev
# FEV1 at follow-up visit
# _______________________________________
# pos_skintest
# One or more positive skin test at follow-up visit
# _______________________________________
# prefvc
# FVC at follow-up visit
# _______________________________________
# saba_tx_fup
# Treatment group assigned at follow-up visit was SABA (Short acting B-agonist) arm
# _______________________________________
# ige
# Total IgE at follow-up visit
# _______________________________________
# eos
# Blood eosinophils at follow-up visit
# _______________________________________
# laba_tx_fup
# Treatment group assigned at follow-up was LABA (Long acting B-agonist) arm
# _______________________________________
# visit_week
# Number of weeks in relation to Baseline visit
# _______________________________________
# ampf
# Average AM peak flow (L/min) as recorded in daily diary card since last visit
# _______________________________________
# npos_core_skintest
# Number of core positive skin tests at follow-up visit
# _______________________________________
# nall_skintest
# Number of skin tests (all tests) at follow-up visit
# _______________________________________
# amsym
# Average AM symptoms as recorded in daily diary card since last visit
# _______________________________________
# protocol
# Protocol - Study name
# _______________________________________
# bmiz
# BMIZ at follow-up visit
# _______________________________________
# posfvcpp
# Post-FVC percent predicted at follow-up visit
# _______________________________________
# prech
# Change in FEV1 at follow-up visit from Baseline
# _______________________________________
# log10eos
# Log10 blood eosinophils at follow-up visit
# _______________________________________
# log10ige
# Log10 IgE at follow-up visit
# _______________________________________
# bdrabpct
# Bronchodilator percent change. The calculation is: (POSFEV - PREFEV)/PREFEV.
# _______________________________________
# cs_comb_tx_fup
# Participant assigned to Combination Therapy Group (Steroid Treatment + other)
# _______________________________________
# prefevpp
# FEV1 percent predicted at follow-up visit
# _______________________________________
# prefvcpp
# FVC percent predicted at follow-up visit
# _______________________________________
# cs_tx_fup
# Treatment group assigned at follow-up was steroid arm
# _______________________________________
# bursts
# Number of prednisone bursts since last visit
# _______________________________________
# posfev
# Post-FEV1 at follow-up visit
# _______________________________________
# gender
# Gender of participant
# _______________________________________
# pc20
# FEV1 PC20 methacholine at follow-up visit
# _______________________________________
# visit_reference
# This is the reference to the visit in the study
# _______________________________________
# htcm
# Standing height at follow-up visit
# _______________________________________
# prechpp
# Change in FEV1 percent predicted at follow-up visit from Baseline
# _______________________________________
# visit_month
# Number of months in relation to Baseline visit
# _______________________________________
# posff
# Post-FEV1/FVC ratio at follow-up visit
# _______________________________________
# run_in_tx
# Run-In Treatment group at follow-up visit
# _______________________________________
# wtkg
# Weight at follow-up visit
# _______________________________________
# posfvc
# Post-FVC at follow-up visit
# _______________________________________
# n_core_skintest
# Number of core skin tests at follow-up visit
# _______________________________________
# case_control
# Affection status
# _______________________________________
# case_control_peak
# Affection status in PEAK
# _______________________________________
# cs_dose_fup
# Corticosteroid dose
# _______________________________________
# posfevpp
# Post-FEV1 percent predicted at follow-up visit
# _______________________________________
# totres
# Average total rescue use per day as recorded in daily diary card since last visit
# _______________________________________
# race
# Race of participant
# _______________________________________
# eno
# Exhaled nitric oxide at follow-up visit
# _______________________________________
# npos_skintest
# Number of pos skin tests (all tests) at follow-up visit
# _______________________________________
# edhos
# Number of ER visit or hospitalizations since last visit
# _______________________________________
# tanner_stage
# Tanner Stage at follow-up visit
# _______________________________________
# subj_id
# Deidentified Subject ID
# _______________________________________
# preff
# FEV1/FVC ratio at follow-up visit
# _______________________________________
# age
# Age at follow-up visit
# _______________________________________
# lnpc20
# Natural log PC20 at follow-up visit
# _______________________________________
# bmi
# BMI at follow-up visit
# _______________________________________

# %%
cl.listTableColumns('TOPMed.CAMP.CData', descriptions=True, enums=False)
# Out:
# bmiz_baseline
# Baseline BMIZ
# _______________________________________
# pred_bursts_event1_month
# Number of months from Baseline to first prednisone burst.  With the exception of a visit at 2 months, vists are four months apart.  At each visit a participant answers whether prednisone was used since the previous visit.  If prednisone had been used, the value of this variable is the number of months that the visit is from Baseline.  For example, if the first burst was used between the four month and the eight month visit, the pred_bursts_event1_month variable has a value of eight assigned.
# _______________________________________
# edhos_event2_week
# Number of weeks from Baseline to second ER visit or hospitalization.  See week assignments in pred_bursts_event1_week.
# _______________________________________
# edhos_event1_month
# Number of months from Baseline to first ER visit or hospitalization.  See month assignments in pred_bursts_event1_month.
# _______________________________________
# protocol
# Protocol - Study name
# _______________________________________
# tx_grp
# Treatment group as assigned at Baseline.  The following is a map between the CAMP treatment group and this tx_grp: Budesonide: formerly a value of 1 is tx_grp=4; Nedocrimil: formerly a value of 2 is tx_grp=8; Placebo: formerly a value of 3 is tx_grp=9
# _______________________________________
# laba_tx
# Treatment group assigned at Baseline was LABA (Long acting B-agonist) arm
# _______________________________________
# NALL_SKINTEST_baseline
# Number of skin tests (all tests) at Baseline
# _______________________________________
# cs_tx
# Treatment group assigned at Baseline was steroid arm
# _______________________________________
# PREFF_baseline
# Baseline FEV1/FVC ratio
# _______________________________________
# tot_pred_bursts
# Total prednisone bursts during trial
# _______________________________________
# age_baseline
# Age at Baseline
# _______________________________________
# ENV_SMOKE_pretrial
# Home exposure to smoke prior to trial enrollment
# _______________________________________
# SUBJ_ID
# Deidentified Subject ID
# _______________________________________
# IUS
# In utero smoke: mother smoked when pregnant with participant
# _______________________________________
# edhos_event1_week
# Number of weeks from Baseline to first ER visit or hospitalization. See week assignments in pred_bursts_event1_week.
# _______________________________________
# IGE_baseline
# Baseline total IgE
# _______________________________________
# eos_baseline
# Baseline blood eosinophils
# _______________________________________
# age_onset
# Age at first asthma symptoms
# _______________________________________
# ampf_baseline
# Average Baseline AM peak flow (L/min) as recorded in daily diary card data between visits.  Visits are in most cases four months apart.
# _______________________________________
# htcm_baseline
# Baseline standing height
# _______________________________________
# pred_bursts_event2_week
# Number of weeks from Baseline to second prednisone burst.  The assignment is done in the same manner as pred_bursts_event1_week for the second prednisone burst.
# _______________________________________
# POS_SKINTEST_baseline
# One or more skintest positive at Baseline
# _______________________________________
# bmi_baseline
# Baseline BMI
# _______________________________________
# PREFEV_baseline
# Baseline FEV1
# _______________________________________
# tot_edhos
# Total ER visit or hospitalization during CAMP from Baseline to month 48
# _______________________________________
# amsym_baseline
# Average Baseline AM symptoms as recorded in daily diary card data between visits.  Visits are in most cases four months apart.
# _______________________________________
# cs_dose
# Corticosteroid dose
# _______________________________________
# ATOPY
# Child had atopic dermatitus for 2 yrs and was seen by a doctor for it.
# _______________________________________
# totres_baseline
# Baseline total rescue use per day
# _______________________________________
# base_vnum
# Visit number used for Baseline visit in SHARP.  In many studies the first visit was the Baseline visit.  In other studies there were up to five visits before the Baseline visit.
# _______________________________________
# gender
# Gender of participant
# _______________________________________
# PREFEVPP_baseline
# Baseline FEV1 percent predicted
# _______________________________________
# pred_bursts_event1_week
# Number of weeks from Baseline to first prednisone burst.  See description of pred_bursts_event1_month variable.  The same assignment is done using months and then weeks are calculated from the months.
# _______________________________________
# prech_short
# Short term change in Pre-FEV1 between Baseline and two months after Baseline. The calculation is: 100*(Month2 PREFEV - Baseline PREFEV)/Baseline PREFEV.
# _______________________________________
# edhos_event2_month
# Number of months from Baseline to second ER visit or hospitalization.  See month assignments in pred_bursts_event1_month.
# _______________________________________
# PREFVCPP_baseline
# Baseline FVC percent predicted
# _______________________________________
# WTKG_baseline
# Baseline weight
# _______________________________________
# case_control
# Affection status
# _______________________________________
# case_control_peak
# Affection status in PEAK
# _______________________________________
# bdrabpct_baseline
# Baseline bronchodilator percent change. The calculation is: (POSFEV - PREFEV)/PREFEV.
# _______________________________________
# log10eos_baseline
# Baseline log10 blood eosinophils
# _______________________________________
# NPOS_SKINTEST_baseline
# Number of positive skin tests (all tests) at Baseline
# _______________________________________
# pred_bursts_event2_month
# Number of months from Baseline to second prednisone burst.  See description of pre_bursts_event1_month variable.  The assignment is done in the same manner using the second prednisone bursts.
# _______________________________________
# race
# Race of participant
# _______________________________________
# clinic_city
# City of the clinic.  The following is the map of CAMP clinics to CAMP clinic_city: if clinic=5 then clinic_city=8; if clinic=6 then clinic_city=10; if clinic=7 then clinic_city=11; if clinic=8 then clinic_city=12; else clinic_city=clinic
# _______________________________________
# LOG10IGE_baseline
# Baseline log10 IgE
# _______________________________________
# cs_comb_tx
# Participant assigned to Combination Therapy Group (Steroid Treatment + other)
# _______________________________________
# PC20_baseline
# Baseline FEV1 PC20 methacholine
# _______________________________________
# smoke
# Participant smoked during trial
# _______________________________________
# ENV_SMOKE
# Either parent smoked during trial
# _______________________________________
# saba_tx
# Treatment group assigned at Baseline was SABA (Short acting B-agonist) arm
# _______________________________________
# prech_long
# Long term change in Pre-FEV1 between Baseline and a year after Baseline. The calculation is: 100*(Month12 PREFEV - Baseline PREFEV)/Baseline PREFEV.
# _______________________________________
# PREFVC_baseline
# Baseline FVC
# _______________________________________
# eno_baseline
# Baseline exhaled nitric oxide
# _______________________________________
# LNPC20_baseline
# Natural log PC20 at Baseline
# _______________________________________

# %% [markdown]
# ### Full schema listing
#
# The raw listing of the Data Connect schema response for the same table is as follows.

# %%
table_name = 'TOPMed.CAMP.CData'
cl.listTableInfo(table_name, verbose=True)
# Out:
# _Schema for tableTOPMed.CAMP.CData_
# {
#    "name": "TOPMed.CAMP.CData",
#    "data_model": {
#       "$id": "dbgap:pht000700.v1",
#       "properties": {
#          "bmiz_baseline": {
#             "$id": "dbgap:phv00070943.v1",
#             "description": "Baseline BMIZ",
#             "type": "decimal"
#          },
#          "pred_bursts_event1_month": {
#             "$id": "dbgap:phv00070958.v1",
#             "description": "Number of months from Baseline to first prednisone burst.  With the exception of a visit at 2 months, vists are four months apart.  At each visit a participant answers whether prednisone was used since the previous visit.  If prednisone had been used, the value of this variable is the number of months that the visit is from Baseline.  For example, if the first burst was used between the four month and the eight month visit, the pred_bursts_event1_month variable has a value of eight assigned.",
#             "type": "integer",
#             "$unit": "month"
#          },
#          "edhos_event2_week": {
#             "$id": "dbgap:phv00070966.v1",
#             "description": "Number of weeks from Baseline to second ER visit or hospitalization.  See week assignments in pred_bursts_event1_week.",
#             "type": "integer",
#             "$unit": "week"
#          },
#          "edhos_event1_month": {
#             "$id": "dbgap:phv00070963.v1",
#             "description": "Number of months from Baseline to first ER visit or hospitalization.  See month assignments in pred_bursts_event1_month.",
#             "type": "integer",
#             "$unit": "month"
#          },
#          "protocol": {
#             "$id": "dbgap:phv00070932.v1",
#             "description": "Protocol - Study name",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "BAGS"
#                },
#                {
#                   "const": "3",
#                   "title": "SOCS/SLIC run-in"
#                },
#                {
#                   "const": "4",
#                   "title": "SOCS"
#                },
#                {
#                   "const": "5",
#                   "title": "SLIC"
#                },
#                {
#                   "const": "6",
#                   "title": "DICE"
#                },
#                {
#                   "const": "9",
#                   "title": "IMPACT"
#                },
#                {
#                   "const": "12",
#                   "title": "PRICE"
#                },
#                {
#                   "const": "101",
#                   "title": "CAMP"
#                },
#                {
#                   "const": "201",
#                   "title": "PEAK"
#                },
#                {
#                   "const": "202",
#                   "title": "CLIC"
#                },
#                {
#                   "const": "203",
#                   "title": "PACT"
#                },
#                {
#                   "const": "204",
#                   "title": "AIMS"
#                },
#                {
#                   "const": "205",
#                   "title": "MARS"
#                }
#             ]
#          },
#          "tx_grp": {
#             "$id": "dbgap:phv00070944.v1",
#             "description": "Treatment group as assigned at Baseline.  The following is a map between the CAMP treatment group and this tx_grp: Budesonide: formerly a value of 1 is tx_grp=4; Nedocrimil: formerly a value of 2 is tx_grp=8; Placebo: formerly a value of 3 is tx_grp=9",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "Albuterol"
#                },
#                {
#                   "const": "2",
#                   "title": "Azithromycin"
#                },
#                {
#                   "const": "3",
#                   "title": "Beclomethasone"
#                },
#                {
#                   "const": "4",
#                   "title": "Budesonide"
#                },
#                {
#                   "const": "5",
#                   "title": "Flunisolide"
#                },
#                {
#                   "const": "6",
#                   "title": "Fluticasone"
#                },
#                {
#                   "const": "7",
#                   "title": "Montelukast"
#                },
#                {
#                   "const": "8",
#                   "title": "Nedocromil"
#                },
#                {
#                   "const": "9",
#                   "title": "Placebo"
#                },
#                {
#                   "const": "10",
#                   "title": "Placebo+Triamcinolone"
#                },
#                {
#                   "const": "11",
#                   "title": "Prednisone+Budesonide+Zafirlukast"
#                },
#                {
#                   "const": "12",
#                   "title": "Salmeterol"
#                },
#                {
#                   "const": "13",
#                   "title": "Salmeterol/Fluticasone Combination"
#                },
#                {
#                   "const": "14",
#                   "title": "Salmeterol+Triamcinolone"
#                },
#                {
#                   "const": "15",
#                   "title": "Triamcinolone"
#                },
#                {
#                   "const": "16",
#                   "title": "Zafirlukast"
#                }
#             ]
#          },
#          "laba_tx": {
#             "$id": "dbgap:phv00070946.v1",
#             "description": "Treatment group assigned at Baseline was LABA (Long acting B-agonist) arm",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "NALL_SKINTEST_baseline": {
#             "$id": "dbgap:phv00070987.v1",
#             "description": "Number of skin tests (all tests) at Baseline",
#             "type": "integer"
#          },
#          "cs_tx": {
#             "$id": "dbgap:phv00070947.v1",
#             "description": "Treatment group assigned at Baseline was steroid arm",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "PREFF_baseline": {
#             "$id": "dbgap:phv00070974.v1",
#             "description": "Baseline FEV1/FVC ratio",
#             "type": "integer"
#          },
#          "tot_pred_bursts": {
#             "$id": "dbgap:phv00070957.v1",
#             "description": "Total prednisone bursts during trial",
#             "type": "integer"
#          },
#          "age_baseline": {
#             "$id": "dbgap:phv00070938.v1",
#             "description": "Age at Baseline",
#             "type": "decimal",
#             "$unit": "years"
#          },
#          "ENV_SMOKE_pretrial": {
#             "$id": "dbgap:phv00070954.v1",
#             "description": "Home exposure to smoke prior to trial enrollment",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "SUBJ_ID": {
#             "$id": "dbgap:phv00070931.v1",
#             "description": "Deidentified Subject ID",
#             "type": "integer"
#          },
#          "IUS": {
#             "$id": "dbgap:phv00070955.v1",
#             "description": "In utero smoke: mother smoked when pregnant with participant",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "edhos_event1_week": {
#             "$id": "dbgap:phv00070964.v1",
#             "description": "Number of weeks from Baseline to first ER visit or hospitalization. See week assignments in pred_bursts_event1_week.",
#             "type": "integer",
#             "$unit": "week"
#          },
#          "IGE_baseline": {
#             "$id": "dbgap:phv00070981.v1",
#             "description": "Baseline total IgE",
#             "type": "integer",
#             "$unit": "ng/ml"
#          },
#          "eos_baseline": {
#             "$id": "dbgap:phv00070979.v1",
#             "description": "Baseline blood eosinophils",
#             "type": "integer"
#          },
#          "age_onset": {
#             "$id": "dbgap:phv00070939.v1",
#             "description": "Age at first asthma symptoms",
#             "type": "decimal",
#             "$unit": "years"
#          },
#          "ampf_baseline": {
#             "$id": "dbgap:phv00070983.v1",
#             "description": "Average Baseline AM peak flow (L/min) as recorded in daily diary card data between visits.  Visits are in most cases four months apart.",
#             "type": "integer",
#             "$unit": "liters/minute"
#          },
#          "htcm_baseline": {
#             "$id": "dbgap:phv00070940.v1",
#             "description": "Baseline standing height",
#             "type": "decimal",
#             "$unit": "cm"
#          },
#          "pred_bursts_event2_week": {
#             "$id": "dbgap:phv00070961.v1",
#             "description": "Number of weeks from Baseline to second prednisone burst.  The assignment is done in the same manner as pred_bursts_event1_week for the second prednisone burst.",
#             "type": "integer",
#             "$unit": "week"
#          },
#          "POS_SKINTEST_baseline": {
#             "$id": "dbgap:phv00070986.v1",
#             "description": "One or more skintest positive at Baseline",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "bmi_baseline": {
#             "$id": "dbgap:phv00070942.v1",
#             "description": "Baseline BMI",
#             "type": "decimal",
#             "$unit": "kg/m^2"
#          },
#          "PREFEV_baseline": {
#             "$id": "dbgap:phv00070972.v1",
#             "description": "Baseline FEV1",
#             "type": "decimal",
#             "$unit": "liters"
#          },
#          "tot_edhos": {
#             "$id": "dbgap:phv00070962.v1",
#             "description": "Total ER visit or hospitalization during CAMP from Baseline to month 48",
#             "type": "integer"
#          },
#          "amsym_baseline": {
#             "$id": "dbgap:phv00070985.v1",
#             "description": "Average Baseline AM symptoms as recorded in daily diary card data between visits.  Visits are in most cases four months apart.",
#             "type": "decimal"
#          },
#          "cs_dose": {
#             "$id": "dbgap:phv00070949.v1",
#             "description": "Corticosteroid dose",
#             "type": "integer",
#             "$unit": "mcg/day"
#          },
#          "ATOPY": {
#             "$id": "dbgap:phv00070978.v1",
#             "description": "Child had atopic dermatitus for 2 yrs and was seen by a doctor for it.",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "totres_baseline": {
#             "$id": "dbgap:phv00070984.v1",
#             "description": "Baseline total rescue use per day",
#             "type": "integer",
#             "$unit": "puffs"
#          },
#          "base_vnum": {
#             "$id": "dbgap:phv00070933.v1",
#             "description": "Visit number used for Baseline visit in SHARP.  In many studies the first visit was the Baseline visit.  In other studies there were up to five visits before the Baseline visit.",
#             "type": "integer"
#          },
#          "gender": {
#             "$id": "dbgap:phv00070936.v1",
#             "description": "Gender of participant",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "Male"
#                },
#                {
#                   "const": "2",
#                   "title": "Female"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "PREFEVPP_baseline": {
#             "$id": "dbgap:phv00070975.v1",
#             "description": "Baseline FEV1 percent predicted",
#             "type": "integer"
#          },
#          "pred_bursts_event1_week": {
#             "$id": "dbgap:phv00070959.v1",
#             "description": "Number of weeks from Baseline to first prednisone burst.  See description of pred_bursts_event1_month variable.  The same assignment is done using months and then weeks are calculated from the months.",
#             "type": "integer",
#             "$unit": "week"
#          },
#          "prech_short": {
#             "$id": "dbgap:phv00070968.v1",
#             "description": "Short term change in Pre-FEV1 between Baseline and two months after Baseline. The calculation is: 100*(Month2 PREFEV - Baseline PREFEV)/Baseline PREFEV.",
#             "type": "decimal"
#          },
#          "edhos_event2_month": {
#             "$id": "dbgap:phv00070965.v1",
#             "description": "Number of months from Baseline to second ER visit or hospitalization.  See month assignments in pred_bursts_event1_month.",
#             "type": "integer",
#             "$unit": "month"
#          },
#          "PREFVCPP_baseline": {
#             "$id": "dbgap:phv00070976.v1",
#             "description": "Baseline FVC percent predicted",
#             "type": "integer"
#          },
#          "WTKG_baseline": {
#             "$id": "dbgap:phv00070941.v1",
#             "description": "Baseline weight",
#             "type": "decimal",
#             "$unit": "kg"
#          },
#          "case_control": {
#             "$id": "dbgap:phv00070934.v1",
#             "description": "Affection status",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "control"
#                },
#                {
#                   "const": "2",
#                   "title": "case"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "case_control_peak": {
#             "$id": "dbgap:phv00070935.v1",
#             "description": "Affection status in PEAK",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "control"
#                },
#                {
#                   "const": "2",
#                   "title": "case"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "bdrabpct_baseline": {
#             "$id": "dbgap:phv00070977.v1",
#             "description": "Baseline bronchodilator percent change. The calculation is: (POSFEV - PREFEV)/PREFEV.",
#             "type": "decimal"
#          },
#          "log10eos_baseline": {
#             "$id": "dbgap:phv00070980.v1",
#             "description": "Baseline log10 blood eosinophils",
#             "type": "decimal"
#          },
#          "NPOS_SKINTEST_baseline": {
#             "$id": "dbgap:phv00070988.v1",
#             "description": "Number of positive skin tests (all tests) at Baseline",
#             "type": "integer"
#          },
#          "pred_bursts_event2_month": {
#             "$id": "dbgap:phv00070960.v1",
#             "description": "Number of months from Baseline to second prednisone burst.  See description of pre_bursts_event1_month variable.  The assignment is done in the same manner using the second prednisone bursts.",
#             "type": "integer",
#             "$unit": "month"
#          },
#          "race": {
#             "$id": "dbgap:phv00070937.v1",
#             "description": "Race of participant",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "Caucasian"
#                },
#                {
#                   "const": "2",
#                   "title": "African American"
#                },
#                {
#                   "const": "3",
#                   "title": "Hispanic"
#                },
#                {
#                   "const": "4",
#                   "title": "Other"
#                }
#             ]
#          },
#          "clinic_city": {
#             "$id": "dbgap:phv00070951.v1",
#             "description": "City of the clinic.  The following is the map of CAMP clinics to CAMP clinic_city: if clinic=5 then clinic_city=8; if clinic=6 then clinic_city=10; if clinic=7 then clinic_city=11; if clinic=8 then clinic_city=12; else clinic_city=clinic",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "City A"
#                },
#                {
#                   "const": "2",
#                   "title": "City B"
#                },
#                {
#                   "const": "3",
#                   "title": "City C"
#                },
#                {
#                   "const": "4",
#                   "title": "City D"
#                },
#                {
#                   "const": "5",
#                   "title": "City E"
#                },
#                {
#                   "const": "6",
#                   "title": "City F"
#                },
#                {
#                   "const": "7",
#                   "title": "City G"
#                },
#                {
#                   "const": "8",
#                   "title": "City H"
#                },
#                {
#                   "const": "9",
#                   "title": "City I"
#                },
#                {
#                   "const": "10",
#                   "title": "City J"
#                },
#                {
#                   "const": "11",
#                   "title": "City K"
#                },
#                {
#                   "const": "12",
#                   "title": "City L"
#                },
#                {
#                   "const": "13",
#                   "title": "City M"
#                }
#             ]
#          },
#          "LOG10IGE_baseline": {
#             "$id": "dbgap:phv00070982.v1",
#             "description": "Baseline log10 IgE",
#             "type": "decimal"
#          },
#          "cs_comb_tx": {
#             "$id": "dbgap:phv00070948.v1",
#             "description": "Participant assigned to Combination Therapy Group (Steroid Treatment + other)",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "PC20_baseline": {
#             "$id": "dbgap:phv00070970.v1",
#             "description": "Baseline FEV1 PC20 methacholine",
#             "type": "decimal",
#             "$unit": "mg/ml"
#          },
#          "smoke": {
#             "$id": "dbgap:phv00070952.v1",
#             "description": "Participant smoked during trial",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "ENV_SMOKE": {
#             "$id": "dbgap:phv00070953.v1",
#             "description": "Either parent smoked during trial",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "saba_tx": {
#             "$id": "dbgap:phv00070945.v1",
#             "description": "Treatment group assigned at Baseline was SABA (Short acting B-agonist) arm",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "yes"
#                },
#                {
#                   "const": "0",
#                   "title": "no"
#                },
#                {
#                   "const": ".",
#                   "title": "missing"
#                }
#             ]
#          },
#          "prech_long": {
#             "$id": "dbgap:phv00070967.v1",
#             "description": "Long term change in Pre-FEV1 between Baseline and a year after Baseline. The calculation is: 100*(Month12 PREFEV - Baseline PREFEV)/Baseline PREFEV.",
#             "type": "decimal"
#          },
#          "PREFVC_baseline": {
#             "$id": "dbgap:phv00070973.v1",
#             "description": "Baseline FVC",
#             "type": "decimal",
#             "$unit": "liters"
#          },
#          "eno_baseline": {
#             "$id": "dbgap:phv00070969.v1",
#             "description": "Baseline exhaled nitric oxide",
#             "type": "decimal",
#             "$unit": "ppb"
#          },
#          "LNPC20_baseline": {
#             "$id": "dbgap:phv00070971.v1",
#             "description": "Natural log PC20 at Baseline",
#             "type": "decimal"
#          }
#       }
#    }
# }

# %%
template = cl.getMappingTemplate(table_name,['tx_grp'])

# %%
template
# Out:
# {'tx_grp': {'1': 'replaceThis',
#   '2': 'replaceThis',
#   '3': 'replaceThis',
#   '4': 'replaceThis',
#   '5': 'replaceThis',
#   '6': 'replaceThis',
#   '7': 'replaceThis',
#   '8': 'replaceThis',
#   '9': 'replaceThis',
#   '10': 'replaceThis',
#   '11': 'replaceThis',
#   '12': 'replaceThis',
#   '13': 'replaceThis',
#   '14': 'replaceThis',
#   '15': 'replaceThis',
#   '16': 'replaceThis'}}

# %%
{'tx_grp': {'1': '',
  '2': 'replaceThis',
  '3': 'replaceThis',
  '4': 'replaceThis',
  '5': 'replaceThis',
  '6': 'replaceThis',
  '7': 'replaceThis',
  '8': 'replaceThis',
  '9': 'replaceThis',
  '10': 'replaceThis',
  '11': 'replaceThis',
  '12': 'replaceThis',
  '13': 'replaceThis',
  '14': 'replaceThis',
  '15': 'replaceThis',
  '16': 'replaceThis'}}
