# %%
from fasp.search import DiscoverySearchClient
cl = DiscoverySearchClient('https://ga4gh-search-adapter-presto-public.prod.dnastack.com')
cl.listCatalogs()
# Out:
# _Retrieving the catalog list_
# cshcodeathon
# data_lake
# dbgap_demo
# kidsfirst
# sample_phenopackets
# search_cloud
# search_postgres
# search_postgres_pgpc
# thousand_genomes

# %%
cl.listTableColumns('search_cloud.cshcodeathon.tcga_bioclin_v0_clinical')
# Out:
# program_name
# _______________________________________
# case_barcode
# _______________________________________
# case_gdc_id
# _______________________________________
# program_dbgap_accession_number
# _______________________________________
# project_short_name
# _______________________________________
# project_name
# _______________________________________
# disease_code
# _______________________________________
# gender
# _______________________________________
# vital_status
# _______________________________________
# race
# _______________________________________
# ethnicity
# _______________________________________
# age_at_diagnosis
# _______________________________________
# days_to_birth
# _______________________________________
# days_to_death
# _______________________________________
# days_to_initial_pathologic_diagnosis
# _______________________________________
# days_to_last_followup
# _______________________________________
# days_to_last_known_alive
# ...

# %%
cl.listTables('search_cloud')
# Out:
# _Retrieving the table list_
# ____Page1_______________
# search_cloud.brca_exchange.v32
# search_cloud.clinvar.allele_gene
# search_cloud.clinvar.cross_references
# search_cloud.clinvar.gene_specific_summary
# search_cloud.clinvar.hgvs4variation
# search_cloud.clinvar.organization_summary
# search_cloud.clinvar.submission_summary
# search_cloud.clinvar.summary_of_conflicting_interpretations
# search_cloud.clinvar.var_citations
# search_cloud.clinvar.variant_summary
# search_cloud.clinvar.variation_allele
# search_cloud.covid19_jhu_csse.confirmed_cases
# search_cloud.covid19_jhu_csse.deaths
# search_cloud.covid19_jhu_csse.recovered_cases
# search_cloud.covid19_jhu_csse.sandbox_main
# search_cloud.covid19_jhu_csse.summary
# search_cloud.cshcodeathon.gdc_case_file_metadata_filedata_active_current
# search_cloud.cshcodeathon.gdc_case_file_metadata_gdcfileid_to_gcsurl_current
# search_cloud.cshcodeathon.gdc_rel24_filedata_active
# search_cloud.cshcodeathon.gecco_gen3_drs_index
# ...

# %%
cl.listTableInfo('search_cloud.cshcodeathon.tcga_bioclin_v0_clinical')
# Out:
# {'name': 'search_cloud.cshcodeathon.tcga_bioclin_v0_clinical',
#  'description': 'Automatically generated schema',
#  'data_model': {'$id': 'https://ga4gh-search-adapter-presto-public.prod.dnastack.com/table/search_cloud.cshcodeathon.tcga_bioclin_v0_clinical/info',
#   'description': 'Automatically generated schema',
#   '$schema': 'http://json-schema.org/draft-07/schema#',
#   'properties': {'program_name': {'format': 'varchar',
#     'type': 'string',
#     '$comment': 'Program Name, always TCGA (The Cancer Genome Atlas) in this table.'},
#    'case_barcode': {'format': 'varchar',
#     'type': 'string',
#     '$comment': 'TCGA patient/case barcode; e.g. TCGA-06-0119'},
#    'case_gdc_id': {'format': 'varchar',
#     'type': 'string',
# ...
