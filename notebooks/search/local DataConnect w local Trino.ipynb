# %% [markdown]
# ## Using a local GA4GH Data Connect server
# This notebook was run against a DC service running against a local trino server

# %%
from fasp.search import DataConnectClient
cl = DataConnectClient('http://localhost:8089/')
#cl.listTables(verbose=True)
# Out:
# /Users/forei/imfenvs/fasp/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
cl.listCatalogs()
# Out:
# _Retrieving the catalog list_
# bigquery
# mysql

# %%
cl.listCatalog('bigquery')
# Out:
# _Retrieving the table list_
# ____Page1_______________
# bigquery.1000genomes.1000genomes_drs
# bigquery.1000genomes.aligned_read
# bigquery.1000genomes.aliquot
# bigquery.1000genomes.bdc_1000genomes
# bigquery.1000genomes.demographics
# bigquery.1000genomes.germline_variation_index
# bigquery.1000genomes.phenotype_drs
# bigquery.1000genomes.read_group
# bigquery.1000genomes.sample
# bigquery.1000genomes.simple_germline_variation
# bigquery.1000genomes.ssd_drs
# bigquery.1000genomes.ssd_drs_table
# bigquery.1000genomes.subject
# bigquery.100genomes.import2
# bigquery.100genomes.import3
# bigquery.100genomes.testimport
# bigquery.blog_unnest.firebase_raw
# bigquery.cda.cdav3
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample_attributes
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject_phenotypes
# bigquery.copdgene.aligned_read
# bigquery.copdgene.aliquot
# ...

# %% [markdown]
# The listTableColumns function prints a more concise listing

# %%
# init search client
from search_python_client.search import DrsClient, SearchClient
base_url = 'http://localhost:8089/'
search_client = SearchClient(base_url=base_url)

# %%
# get tables
tables_iterator = search_client.get_table_list()
tables = [next(tables_iterator, None) for i in range(10)]
tables = list(filter(None, tables))
print(tables)
# Out:
# [{'name': 'bigquery.blog_unnest.firebase_raw', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.blog_unnest.firebase_raw/info'}}, {'name': 'bigquery.cda.cdav3', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.cda.cdav3/info'}}, {'name': 'bigquery.fasp_scrambled.scr_egapancreatic_sample', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.fasp_scrambled.scr_egapancreatic_sample/info'}}, {'name': 'bigquery.gtex8.program', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.program/info'}}, {'name': 'bigquery.gtex8.project', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.project/info'}}, {'name': 'bigquery.gtex8.sample', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.sample/info'}}, {'name': 'bigquery.gtex8.sequencing', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.sequencing/info'}}, {'name': 'bigquery.gtex8.sraruntable_breast_cram', 'data_model': {'$ref': 'http://localhost:80
# ...

# %%
query1 = '''SELECT sex, age, study
FROM bigquery.scr_gecco_susceptibility.subject_phenotypes_multi
'''

res = cl.runQuery(query1)
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# [['Female', 46, 'NHS'],
#  ['Female', 46, 'NHS'],
#  ['Female', 47, 'NHS'],
#  ['Female', 47, 'NHS'],
#  ['Female', 48, 'NHS'],
#  ['Female', 49, 'NHS'],
#  ['Male', 51, 'NHS'],
#  ['Male', 51, 'NHS'],
#  ['Female', 51, 'NHS'],
#  ['Female', 51, 'NHS'],
#  ['Male', 52, 'NHS'],
#  ['Female', 52, 'NHS'],
#  ['Female', 52, 'NHS'],
#  ['Female', 53, 'NHS'],
#  ['Female', 53, 'NHS'],
#  ['Female', 54, 'NHS'],
#  ['Male', 54, 'NHS'],
#  ['Male', 54, 'NHS'],
#  ['Female', 54, 'NHS'],
#  ['Male', 55, 'NHS'],
#  ['Male', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Male', 55, 'NHS'],
#  ['Female', 56, 'NHS'],
# ...

# %%
cl.listTables('dbgap_demo')
# Out:
# _Retrieving the table list_
# ____Page1_______________
# collections.public_datasets.scr_ega_scr_egapancreatic_files
# collections.public_datasets.scr_ega_scr_egapancreatic_sample_multi
# collections.public_datasets.scr_gecco_susceptibility_gecco_sample_acc
# collections.public_datasets.scr_gecco_susceptibility_phs001554_gecco_sddp_manifest
# collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi
# collections.public_datasets.scr_gecco_susceptibility_sample_multi
# collections.public_datasets.scr_gecco_susceptibility_sb_drs_index
# collections.public_datasets.scr_gecco_susceptibility_subject_multi
# collections.public_datasets.scr_gecco_susceptibility_subject_phenotypes_multi
# ['collections.public_datasets.scr_ega_scr_egapancreatic_files',
#  'collections.public_datasets.scr_ega_scr_egapancreatic_sample_multi',
#  'collections.public_datasets.scr_gecco_susceptibility_gecco_sample_acc',
# ...

# %% [markdown]
# This provides the full schema for sample attributes from the same study.

# %%
cl.listTableInfo('collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi_
# {
#    "name": "collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi",
#    "description": "Automatically generated schema",
#    "data_model": {
#       "$id": "http://localhost:8089/table/collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi/info",
#       "description": "Automatically generated schema",
#       "$schema": "http://json-schema.org/draft-07/schema#",
#       "properties": {
#          "dbgap_sample_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "sample_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "body_site": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
# ...

# %%
cl.listTableColumns('collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi',descriptions=True)
# Out:
# dbgap_sample_id
# varchar
# _______________________________________
# sample_id
# varchar
# _______________________________________
# body_site
# varchar
# _______________________________________
# analyte_type
# varchar
# _______________________________________
# is_tumor
# varchar
# _______________________________________
# dna_source
# varchar
# _______________________________________
# batch
# varchar
# _______________________________________
# read_depth
# double
# _______________________________________
# sequencing_center
# varchar
# _______________________________________

# %% [markdown]
# ### An EGA Table
# The same format of data dictionary was created for an EGA table.

# %%
cl.listTableInfo('collections.public_datasets.scr_ega_scr_egapancreatic_sample_multi',verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.scr_ega_scr_egapancreatic_sample_multi_
# {
#    "name": "collections.public_datasets.scr_ega_scr_egapancreatic_sample_multi",
#    "description": "Automatically generated schema",
#    "data_model": {
#       "$id": "http://localhost:8089/table/collections.public_datasets.scr_ega_scr_egapancreatic_sample_multi/info",
#       "description": "Automatically generated schema",
#       "$schema": "http://json-schema.org/draft-07/schema#",
#       "properties": {
#          "sample_primary_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "sample_submitter_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "disease_site": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "gender": {
# ...

# %%
cl.listTableColumns('bigquery.scr_gecco_susceptibility.subject_phenotypes_multi', descriptions=True, enums=True)
# Out:
# dbgap_subject_id
# varchar
# varchar
# _______________________________________
# subject_id
# varchar
# varchar
# _______________________________________
# affection_status
# varchar
# varchar
# _______________________________________
# sex
# varchar
# varchar
# _______________________________________
# age
# bigint
# bigint
# _______________________________________
# race
# varchar
# varchar
# _______________________________________
# ethnicity
# varchar
# varchar
# _______________________________________
# study
# varchar
# varchar
# _______________________________________

# %%
cl.listTableInfo('bigquery.scr_gecco_susceptibility.subject_phenotypes_multi', verbose=True)
# Out:
# _Schema for tablebigquery.scr_gecco_susceptibility.subject_phenotypes_multi_
# {
#    "name": "bigquery.scr_gecco_susceptibility.subject_phenotypes_multi",
#    "description": "Scrambled version of subject data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007609.v1.GECCO_CRC_Susceptibility_Subject_Phenotypes",
#       "description": "Scrambled version of subject data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "age": {
#             "type": "number",
#             "$comment": "UNIT 'Years'",
#             "maximum": 98.0,
#             "minimum": 37.0,
#             "description": "Participant reference age"
#          },
#          "sex": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "Female"
#                },
#                {
# ...

# %%
cl.listTableInfo('collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi_
# {
#    "name": "collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi",
#    "description": "Scrambled version of sample data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007610.v1.GECCO_CRC_Susceptibility_Sample_Attributes",
#       "description": "Scrambled version of sample data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "batch": {
#             "type": "string",
#             "description": "Sequencing batch"
#          },
#          "is_tumor": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "No"
#                }
#             ],
#             "description": "Tumor status"
#          },
#          "body_site": {
# ...

# %%
cl.listTableInfo('collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi_
# {
#    "name": "collections.public_datasets.scr_gecco_susceptibility_sample_attributes_multi",
#    "description": "Scrambled version of sample data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007610.v1.GECCO_CRC_Susceptibility_Sample_Attributes",
#       "description": "Scrambled version of sample data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "batch": {
#             "type": "string",
#             "description": "Sequencing batch"
#          },
#          "is_tumor": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "No"
#                }
#             ],
#             "description": "Tumor status"
#          },
#          "body_site": {
# ...

# %%
cl.listTableInfo('collections.public_datasets.scr_gecco_susceptibility_subject_phenotypes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.scr_gecco_susceptibility_subject_phenotypes_multi_
# {
#    "name": "collections.public_datasets.scr_gecco_susceptibility_subject_phenotypes_multi",
#    "data_model": {
#       "description": "",
#       "$id": "dbgap:pht007609",
#       "properties": {
#          "STUDY": {
#             "$id": "dbgap:phv00357188.v1",
#             "description": "Study acronym",
#             "type": "string"
#          },
#          "SUBJECT_ID": {
#             "$id": "dbgap:phv00357182.v1",
#             "description": "De-identified subject ID",
#             "type": "string"
#          },
#          "SEX": {
#             "$id": "dbgap:phv00357184.v1",
#             "description": "Sex of participant",
#             "type": "string"
#          },
#          "RACE": {
#             "$id": "dbgap:phv00357186.v1",
#             "description": "Race of participant",
#             "type": "string"
#          },
#          "ETHNICITY": {
# ...

# %%
cl.listTableInfo('collections.public_datasets.scr_ega_scr_egapancreatic_sample_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.scr_ega_scr_egapancreatic_sample_multi_
# {
#    "name": "collections.public_datasets.scr_ega_scr_egapancreatic_sample_multi",
#    "data_model": {
#       "$id": "scr_EGApancreatic_sample.data_dict.xml.scr_EGApancreatic_sample",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "gender": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "female"
#                },
#                {
#                   "const": "male"
#                }
#             ],
#             "description": "Sex of participant"
#          },
#          "bam_file": {
#             "type": "string",
#             "description": "Relative path for alignment file"
#          },
#          "phenotype": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "lung tissue"
#                },
#                {
# ...

# %%
cl.listTableInfo('bigquery.scr_gecco_susceptibility.subject_multi', verbose=True)
# Out:
# _Schema for tablebigquery.scr_gecco_susceptibility.subject_multi_
# {
#    "name": "bigquery.scr_gecco_susceptibility.subject_multi",
#    "description": "Automatically generated schema",
#    "data_model": {
#       "$id": "http://localhost:8089/table/bigquery.scr_gecco_susceptibility.subject_multi/info",
#       "description": "Automatically generated schema",
#       "$schema": "http://json-schema.org/draft-07/schema#",
#       "properties": {
#          "dbgap_subject_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "subject_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "consent": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "subject_source": {
#             "format": "varchar",
#             "type": "string",
# ...

# %%
cl.listTableInfo('bigquery.gecco_crc_susceptibility.subject_phenotypes', verbose=True)
# Out:
# _Schema for tablebigquery.gecco_crc_susceptibility.subject_phenotypes_
# {
#    "name": "bigquery.gecco_crc_susceptibility.subject_phenotypes",
#    "description": "Subject data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007609.v1.GECCO_CRC_Susceptibility_Subject_Phenotypes",
#       "description": "Subject data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "age": {
#             "type": "number",
#             "$comment": "UNIT 'Years'",
#             "maximum": 98.0,
#             "minimum": 37.0,
#             "description": "Participant reference age"
#          },
#          "sex": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "Female"
#                },
#                {
#                   "const": "Male"
#                }
#             ],
# ...

# %%
cl.listTableInfo('bigquery.scr_gecco_susceptibility.subject_phenotypes_multi', verbose=True)
# Out:
# _Schema for tablebigquery.scr_gecco_susceptibility.subject_phenotypes_multi_
# {
#    "name": "bigquery.scr_gecco_susceptibility.subject_phenotypes_multi",
#    "description": "Scrambled version of subject data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007609.v1.GECCO_CRC_Susceptibility_Subject_Phenotypes",
#       "description": "Scrambled version of subject data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "age": {
#             "type": "number",
#             "$comment": "UNIT 'Years'",
#             "maximum": 98.0,
#             "minimum": 37.0,
#             "description": "Participant reference age"
#          },
#          "sex": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "Female"
#                },
#                {
# ...

# %%
cl.runQuery('select current_user, age from bigquery.scr_gecco_susceptibility.subject_phenotypes_multi')
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# [['anonymousUser', 46],
#  ['anonymousUser', 46],
#  ['anonymousUser', 47],
#  ['anonymousUser', 47],
#  ['anonymousUser', 48],
#  ['anonymousUser', 49],
#  ['anonymousUser', 51],
#  ['anonymousUser', 51],
#  ['anonymousUser', 51],
#  ['anonymousUser', 51],
#  ['anonymousUser', 52],
#  ['anonymousUser', 52],
#  ['anonymousUser', 52],
#  ['anonymousUser', 53],
#  ['anonymousUser', 53],
#  ['anonymousUser', 54],
#  ['anonymousUser', 54],
#  ['anonymousUser', 54],
#  ['anonymousUser', 54],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 55],
#  ['anonymousUser', 56],
# ...

# %%
cl.listTableInfo('bigquery.fasp_scrambled.scr_egapancreatic_sample',verbose=True)
# Out:
# _Schema for tablebigquery.fasp_scrambled.scr_egapancreatic_sample_
# {
#    "name": "bigquery.fasp_scrambled.scr_egapancreatic_sample",
#    "description": "Automatically generated schema",
#    "data_model": {
#       "$id": "http://localhost:8089/table/bigquery.fasp_scrambled.scr_egapancreatic_sample/info",
#       "description": "Automatically generated schema",
#       "$schema": "http://json-schema.org/draft-07/schema#",
#       "properties": {
#          "sample_primary_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "sample_submitter_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "disease_site": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "gender": {
#             "format": "varchar",
#             "type": "string",
# ...

# %%
query1 = '''SELECT  gender, count(*) count
FROM bigquery.fasp_scrambled.scr_egapancreatic_sample
group by gender
'''

res = cl.runQuery(query1, returnType='dataframe')
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
#    gender  count
# 0    male     30
# 1  female      9

# %%
cl.listTableInfo('bigquery.pptc.sample_attributes',verbose=True)
# Out:
# _Schema for tablebigquery.pptc.sample_attributes_
# {
#    "errors": [
#       {
#          "status": 500,
#          "title": "Error getting access token for service account: PKIX path building failed: sun.security.provider.certpath.SunCertPathBuilderException: unable to find valid certification path to requested target, iss: service-account-for-big-query@isbcgc-216220.iam.gserviceaccount.com",
#          "details": "b83c94f9c27d5a0c: INTERNAL_ERROR: 65536: GENERIC_INTERNAL_ERROR"
#       }
#    ]
# }
