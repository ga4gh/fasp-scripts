# %% [markdown]
# ## GA4GH Data Connect Level 2 entry point
#
# This notebook illustrates what is possible if you want to implement Data Connect and you have a data dictionary, model or schema for your data.
#
# The following schema lists a subset of the attributes for the CRDC Cancer Data Service Metadata submission template. Three attributes of a subject in that schema are described by Common Data Element identifiers.

# %%
from fasp.search import DataConnectClient
cl = DataConnectClient('http://localhost:8089/')
cl.listTables(verbose=True)
# Out:
# /Users/forei/imfenvs/fasp/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# _Retrieving the table list_
# ____Page1_______________
# bigquery.1000genomes.1000genomes_drs
# bigquery.1000genomes.aligned_read
# bigquery.1000genomes.aliquot
# bigquery.1000genomes.bdc_1000genomes
# bigquery.1000genomes.demographics
# bigquery.1000genomes.germline_variation_index
# bigquery.1000genomes.phenotype_drs
# bigquery.1000genomes.read_group
# bigquery.1000genomes.sample
# bigquery.1000genomes.simple_germline_variation
# bigquery.1000genomes.ssd_drs
# bigquery.1000genomes.ssd_drs_table
# bigquery.1000genomes.subject
# bigquery.100genomes.import2
# bigquery.100genomes.import3
# bigquery.100genomes.testimport
# bigquery.blog_unnest.firebase_raw
# bigquery.cda.cdav3
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample_attributes
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject_phenotypes
# bigquery.cineca.syn_africa_h3abionet_v1
# bigquery.cineca.syn_europe_ch_sib
# bigquery.copdgene.aligned_read
# bigquery.copdgene.aliquot
# bigquery.copdgene.copd_drs
# bigquery.copdgene.copd_gene__hmb_vcf
# bigquery.copdgene.copdgene_hmb_female_90_94kg
# bigquery.copdgene.copdgene_pfb
# bigquery.copdgene.phenotype_drs
# bigquery.copdgene.read_group
# bigquery.copdgene.sample
# bigquery.copdgene.sample_multi
# bigquery.copdgene.subject
# bigquery.copdgene.subject_images_hmb
# bigquery.copdgene.subject_multi
# bigquery.copdgene.subject_phenotypes_hmb
# bigquery.cptac.breastsubjectclinicalphenotypes
# bigquery.cptac.sample_attributes
# bigquery.esp_lunggo_copdgene.sample_attributes_hmb
# bigquery.esp_lunggo_copdgene.subject_phenotypes_hmb
# bigquery.fasp_scrambled.scr_egapancreatic_sample
# bigquery.gecco_crc_susceptibility.public_sample
# bigquery.gecco_crc_susceptibility.sample_attributes
# bigquery.gecco_crc_susceptibility.sample_attributes_cadm
# bigquery.gecco_crc_susceptibility.sample_attributes_ds_cc_npu_gso
# bigquery.gecco_crc_susceptibility.sample_attributes_gru
# bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb
# bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb_npu
# bigquery.gecco_crc_susceptibility.sample_multi
# bigquery.gecco_crc_susceptibility.studies_1554
# bigquery.gecco_crc_susceptibility.subject_multi
# bigquery.gecco_crc_susceptibility.subject_phenotypes
# bigquery.gecco_crc_susceptibility.subject_phenotypes_cadm
# bigquery.gecco_crc_susceptibility.subject_phenotypes_ds_cc_npu_gso
# bigquery.gecco_crc_susceptibility.subject_phenotypes_gru
# bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb
# bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb_npu
# bigquery.gtex8.program
# bigquery.gtex8.project
# bigquery.gtex8.sample
# bigquery.gtex8.sequencing
# bigquery.gtex8.sraruntable_breast_cram
# bigquery.gtex8.sraruntable_nocram
# bigquery.gtex8.sraruntable_nocram_nobam
# bigquery.gtex8.subject
# bigquery.icdc.cotc_sample
# bigquery.kidsfirst.neuroblastoma_participant_family
# bigquery.kidsfirst.pediatric_brain_tumor_atlas
# bigquery.lccc_1108.lccc_drs_map
# bigquery.lccc_1108.sample
# bigquery.lccc_1108.sample_attributes
# bigquery.lccc_1108.subject
# bigquery.lccc_1108.subject_phenotypes
# bigquery.mapped.age_months_view
# bigquery.mapped.age_months_view2
# bigquery.mapped.age_view
# bigquery.mapped.age_years
# bigquery.mapped.subject_disease
# bigquery.mesa.airnrexammain_hmb
# bigquery.mesa.airnrspirometry_hmb
# bigquery.mesa.ancilmesaneighborfoodexam1_hmb
# bigquery.mesa.ancilmesaneighborfoodexam2_hmb
# bigquery.mesa.ancilmesaneighborfoodexam3_hmb
# bigquery.mesa.ancilmesaneighborfoodexam4_hmb
# bigquery.mesa.parent_mesa_hmb_npu
# bigquery.mesa.sample_multi
# bigquery.mesa.subject_multi
# bigquery.mesa_esp_heartgo.parent_mesa
# bigquery.mesa_esp_heartgo.sample_attributes_hmb
# bigquery.mesa_esp_heartgo.sample_attributes_hmb_npu
# bigquery.mesa_esp_heartgo.subject_phenotypes_hmb
# bigquery.mesa_esp_heartgo.subject_phenotypes_hmb_npu
# bigquery.metadata.dbgap_table
# bigquery.metadata.loinc2hpoannotation
# bigquery.metadata.mapping
# bigquery.metadata.mapping2
# bigquery.metadata.mapping2_term
# bigquery.metadata.merged
# bigquery.metadata.s_study
# bigquery.metadata.s_table
# bigquery.metadata.s_variable
# bigquery.metadata.study
# bigquery.metadata.value_map
# bigquery.metadata.vocab
# bigquery.metadata.vocab_term
# bigquery.onek_genomes.bdc_1000genomes
# bigquery.onek_genomes.onek_drs
# bigquery.onek_genomes.onek_recal_variants_drs
# bigquery.onek_genomes.sra_drs_files
# bigquery.onek_genomes.sra_onek_drs
# bigquery.onek_genomes.ssd_drs
# bigquery.onek_genomes.thousand_genomes_meta
# bigquery.organoid_profiling_pc.sample_attributes_gru
# bigquery.organoid_profiling_pc.sample_multi
# bigquery.organoid_profiling_pc.subject_multi
# bigquery.organoid_profiling_pc.subject_phenotypes_gru
# bigquery.pc_rare_variation.sample
# bigquery.pc_rare_variation.sample_attributes
# bigquery.pc_rare_variation.subject
# bigquery.pc_rare_variation.subject_phenotypes
# bigquery.pptc.manifest_small
# bigquery.pptc.sample
# bigquery.pptc.sample_attributes
# bigquery.pptc.subject
# bigquery.pptc.subject_phenotypes
# bigquery.rand_gmkf_cdh.phenotype
# bigquery.scr_ega.scr_egapancreatic_files
# bigquery.scr_ega.scr_egapancreatic_sample_multi
# bigquery.scr_egapancreatic.sample
# bigquery.scr_gecco_susceptibility.gecco_sample_acc
# bigquery.scr_gecco_susceptibility.phs001554_gecco_sddp_manifest
# bigquery.scr_gecco_susceptibility.sample_attributes_multi
# bigquery.scr_gecco_susceptibility.sample_multi
# bigquery.scr_gecco_susceptibility.sb_drs_index
# bigquery.scr_gecco_susceptibility.subject_multi
# bigquery.scr_gecco_susceptibility.subject_phenotypes_multi
# bigquery.scr_organoid.subject_phenotypes_gru
# bigquery.scripts.pipelinelog
# bigquery.scripts.scriptlist
# bigquery.sra.accession_summary
# bigquery.sra.gecco_join
# bigquery.sra.run
# bigquery.sra.run_file
# bigquery.tgtest.program
# bigquery.tgtest.project
# bigquery.tgtest.sample
# bigquery.tgtest.sequencing
# bigquery.tgtest.subject
# bigquery.topmed_wgs_mayo_vte.sample_attributes_gru
# bigquery.topmed_wgs_mayo_vte.subject_multi
# bigquery.topmed_wgs_mayo_vte.subject_phenotypes_gru
# bigquery.topmed_wgs_partners_afgen.sample_attributes_hmb
# bigquery.topmed_wgs_partners_afgen.sample_multi
# bigquery.topmed_wgs_partners_afgen.subject_multi
# bigquery.topmed_wgs_partners_afgen.subject_phenotypes_hmb
# bigquery.transfer.gdc_case_file_metadata_gdcfileid_to_gcsurl_current
# bigquery.transfer.tcga_clinical_gdc_current
# bigquery.transfer.tcga_somatic_mutation_hg38_gdc_current
# ['bigquery.1000genomes.1000genomes_drs',
#  'bigquery.1000genomes.aligned_read',
#  'bigquery.1000genomes.aliquot',
#  'bigquery.1000genomes.bdc_1000genomes',
#  'bigquery.1000genomes.demographics',
#  'bigquery.1000genomes.germline_variation_index',
#  'bigquery.1000genomes.phenotype_drs',
#  'bigquery.1000genomes.read_group',
#  'bigquery.1000genomes.sample',
#  'bigquery.1000genomes.simple_germline_variation',
#  'bigquery.1000genomes.ssd_drs',
#  'bigquery.1000genomes.ssd_drs_table',
#  'bigquery.1000genomes.subject',
#  'bigquery.100genomes.import2',
#  'bigquery.100genomes.import3',
#  'bigquery.100genomes.testimport',
#  'bigquery.blog_unnest.firebase_raw',
#  'bigquery.cda.cdav3',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.sample',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.sample_attributes',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.subject',
#  'bigquery.cidr_gecco_colorectal_cancer_gxe.subject_phenotypes',
#  'bigquery.cineca.syn_africa_h3abionet_v1',
#  'bigquery.cineca.syn_europe_ch_sib',
#  'bigquery.copdgene.aligned_read',
#  'bigquery.copdgene.aliquot',
#  'bigquery.copdgene.copd_drs',
#  'bigquery.copdgene.copd_gene__hmb_vcf',
#  'bigquery.copdgene.copdgene_hmb_female_90_94kg',
#  'bigquery.copdgene.copdgene_pfb',
#  'bigquery.copdgene.phenotype_drs',
#  'bigquery.copdgene.read_group',
#  'bigquery.copdgene.sample',
#  'bigquery.copdgene.sample_multi',
#  'bigquery.copdgene.subject',
#  'bigquery.copdgene.subject_images_hmb',
#  'bigquery.copdgene.subject_multi',
#  'bigquery.copdgene.subject_phenotypes_hmb',
#  'bigquery.cptac.breastsubjectclinicalphenotypes',
#  'bigquery.cptac.sample_attributes',
#  'bigquery.esp_lunggo_copdgene.sample_attributes_hmb',
#  'bigquery.esp_lunggo_copdgene.subject_phenotypes_hmb',
#  'bigquery.fasp_scrambled.scr_egapancreatic_sample',
#  'bigquery.gecco_crc_susceptibility.public_sample',
#  'bigquery.gecco_crc_susceptibility.sample_attributes',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_cadm',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_ds_cc_npu_gso',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_gru',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb',
#  'bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb_npu',
#  'bigquery.gecco_crc_susceptibility.sample_multi',
#  'bigquery.gecco_crc_susceptibility.studies_1554',
#  'bigquery.gecco_crc_susceptibility.subject_multi',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_cadm',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_ds_cc_npu_gso',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_gru',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb',
#  'bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb_npu',
#  'bigquery.gtex8.program',
#  'bigquery.gtex8.project',
#  'bigquery.gtex8.sample',
#  'bigquery.gtex8.sequencing',
#  'bigquery.gtex8.sraruntable_breast_cram',
#  'bigquery.gtex8.sraruntable_nocram',
#  'bigquery.gtex8.sraruntable_nocram_nobam',
#  'bigquery.gtex8.subject',
#  'bigquery.icdc.cotc_sample',
#  'bigquery.kidsfirst.neuroblastoma_participant_family',
#  'bigquery.kidsfirst.pediatric_brain_tumor_atlas',
#  'bigquery.lccc_1108.lccc_drs_map',
#  'bigquery.lccc_1108.sample',
#  'bigquery.lccc_1108.sample_attributes',
#  'bigquery.lccc_1108.subject',
#  'bigquery.lccc_1108.subject_phenotypes',
#  'bigquery.mapped.age_months_view',
#  'bigquery.mapped.age_months_view2',
#  'bigquery.mapped.age_view',
#  'bigquery.mapped.age_years',
#  'bigquery.mapped.subject_disease',
#  'bigquery.mesa.airnrexammain_hmb',
#  'bigquery.mesa.airnrspirometry_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam1_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam2_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam3_hmb',
#  'bigquery.mesa.ancilmesaneighborfoodexam4_hmb',
#  'bigquery.mesa.parent_mesa_hmb_npu',
#  'bigquery.mesa.sample_multi',
#  'bigquery.mesa.subject_multi',
#  'bigquery.mesa_esp_heartgo.parent_mesa',
#  'bigquery.mesa_esp_heartgo.sample_attributes_hmb',
#  'bigquery.mesa_esp_heartgo.sample_attributes_hmb_npu',
#  'bigquery.mesa_esp_heartgo.subject_phenotypes_hmb',
#  'bigquery.mesa_esp_heartgo.subject_phenotypes_hmb_npu',
#  'bigquery.metadata.dbgap_table',
#  'bigquery.metadata.loinc2hpoannotation',
#  'bigquery.metadata.mapping',
#  'bigquery.metadata.mapping2',
#  'bigquery.metadata.mapping2_term',
#  'bigquery.metadata.merged',
#  'bigquery.metadata.s_study',
#  'bigquery.metadata.s_table',
#  'bigquery.metadata.s_variable',
#  'bigquery.metadata.study',
#  'bigquery.metadata.value_map',
#  'bigquery.metadata.vocab',
#  'bigquery.metadata.vocab_term',
#  'bigquery.onek_genomes.bdc_1000genomes',
#  'bigquery.onek_genomes.onek_drs',
#  'bigquery.onek_genomes.onek_recal_variants_drs',
#  'bigquery.onek_genomes.sra_drs_files',
#  'bigquery.onek_genomes.sra_onek_drs',
#  'bigquery.onek_genomes.ssd_drs',
#  'bigquery.onek_genomes.thousand_genomes_meta',
#  'bigquery.organoid_profiling_pc.sample_attributes_gru',
#  'bigquery.organoid_profiling_pc.sample_multi',
#  'bigquery.organoid_profiling_pc.subject_multi',
#  'bigquery.organoid_profiling_pc.subject_phenotypes_gru',
#  'bigquery.pc_rare_variation.sample',
#  'bigquery.pc_rare_variation.sample_attributes',
#  'bigquery.pc_rare_variation.subject',
#  'bigquery.pc_rare_variation.subject_phenotypes',
#  'bigquery.pptc.manifest_small',
#  'bigquery.pptc.sample',
#  'bigquery.pptc.sample_attributes',
#  'bigquery.pptc.subject',
#  'bigquery.pptc.subject_phenotypes',
#  'bigquery.rand_gmkf_cdh.phenotype',
#  'bigquery.scr_ega.scr_egapancreatic_files',
#  'bigquery.scr_ega.scr_egapancreatic_sample_multi',
#  'bigquery.scr_egapancreatic.sample',
#  'bigquery.scr_gecco_susceptibility.gecco_sample_acc',
#  'bigquery.scr_gecco_susceptibility.phs001554_gecco_sddp_manifest',
#  'bigquery.scr_gecco_susceptibility.sample_attributes_multi',
#  'bigquery.scr_gecco_susceptibility.sample_multi',
#  'bigquery.scr_gecco_susceptibility.sb_drs_index',
#  'bigquery.scr_gecco_susceptibility.subject_multi',
#  'bigquery.scr_gecco_susceptibility.subject_phenotypes_multi',
#  'bigquery.scr_organoid.subject_phenotypes_gru',
#  'bigquery.scripts.pipelinelog',
#  'bigquery.scripts.scriptlist',
#  'bigquery.sra.accession_summary',
#  'bigquery.sra.gecco_join',
#  'bigquery.sra.run',
#  'bigquery.sra.run_file',
#  'bigquery.tgtest.program',
#  'bigquery.tgtest.project',
#  'bigquery.tgtest.sample',
#  'bigquery.tgtest.sequencing',
#  'bigquery.tgtest.subject',
#  'bigquery.topmed_wgs_mayo_vte.sample_attributes_gru',
#  'bigquery.topmed_wgs_mayo_vte.subject_multi',
#  'bigquery.topmed_wgs_mayo_vte.subject_phenotypes_gru',
#  'bigquery.topmed_wgs_partners_afgen.sample_attributes_hmb',
#  'bigquery.topmed_wgs_partners_afgen.sample_multi',
#  'bigquery.topmed_wgs_partners_afgen.subject_multi',
#  'bigquery.topmed_wgs_partners_afgen.subject_phenotypes_hmb',
#  'bigquery.transfer.gdc_case_file_metadata_gdcfileid_to_gcsurl_current',
#  'bigquery.transfer.tcga_clinical_gdc_current',
#  'bigquery.transfer.tcga_somatic_mutation_hg38_gdc_current']

# %% [markdown]
# Listing the table information
#
# The following function calls
# http://localhost:8089/table/bigquery.cineca.syn_europe_ch_sib/info

# %%
cl.listTableInfo('bigquery.cineca.syn_europe_ch_sib',verbose=True)
# Out:
# _Schema for tablebigquery.cineca.syn_europe_ch_sib_
# {
#    "name": "bigquery.cineca.syn_europe_ch_sib",
#    "description": "Scrambled version of sample data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007610.v1.GECCO_CRC_Susceptibility_Sample_Attributes",
#       "description": "Scrambled version of sample data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "pt": {
#             "type": "string",
#             "description": "Patient identifier"
#          },
#          "phyact": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": ">3WK"
#                },
#                {
#                   "const": "1WK"
#                },
#                {
#                   "const": "2WK"
#                },
#                {
#                   "const": "K"
#                },
#                {
#                   "const": "N"
#                }
#             ],
#             "description": "physical activity"
#          },
#          "alcfrq": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "1D"
#                },
#                {
#                   "const": "2D"
#                },
#                {
#                   "const": "2WK"
#                },
#                {
#                   "const": "3D"
#                },
#                {
#                   "const": "N"
#                },
#                {
#                   "const": "R"
#                },
#                {
#                   "const": "SW"
#                }
#             ],
#             "description": "alcohol use - frequency"
#          },
#          "sbsmk": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "F"
#                },
#                {
#                   "const": "N"
#                },
#                {
#                   "const": "S"
#                }
#             ],
#             "description": "tobacco  use"
#          },
#          "ethori_self": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "A"
#                },
#                {
#                   "const": "B"
#                },
#                {
#                   "const": "K"
#                },
#                {
#                   "const": "O"
#                },
#                {
#                   "const": "W"
#                },
#                {
#                   "const": "X"
#                }
#             ],
#             "description": "Ethnic origin - self reported"
#          },
#          "wt": {
#             "type": "number",
#             "$unit": "kg",
#             "description": "weight"
#          },
#          "ht": {
#             "type": "number",
#             "$unit": "cm",
#             "description": "height"
#          },
#          "HRTRTE": {
#             "type": "number",
#             "unit": "bpm",
#             "description": "heart rate"
#          },
#          "SBP": {
#             "type": "number",
#             "$unit": "mmHg",
#             "description": "Systolic Blood Pressure"
#          },
#          "DBP": {
#             "type": "number",
#             "$unit": "mmHg",
#             "description": "Diastolic Blood Pressure"
#          },
#          "cmatccd1_2": {
#             "type": "string",
#             "description": "prescription - ATC code"
#          },
#          "cmatccd1_3": {
#             "type": "string",
#             "description": "prescription - ATC code"
#          }
#       },
#       "type": "object"
#    }
# }

# %%
cl.runQuery('select pt, phyact from bigquery.cineca.syn_europe_ch_sib where wt > 90.0')
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# ____Page9_______________
# ____Page10_______________
# ____Page11_______________
# ____Page12_______________
# [['FAKE594', 'N'],
#  ['FAKE2564', 'N'],
#  ['FAKE2291', 'K'],
#  ['FAKE3366', '>3WK'],
#  ['FAKE6472', '>3WK'],
#  ['FAKE3286', 'N'],
#  ['FAKE6716', '>3WK'],
#  ['FAKE956', '1WK'],
#  ['FAKE3227', 'N'],
#  ['FAKE3451', 'N'],
#  ['FAKE4486', 'N'],
#  ['FAKE1790', 'N'],
#  ['FAKE6317', '2WK'],
#  ['FAKE4874', '2WK'],
#  ['FAKE6595', 'N'],
#  ['FAKE1902', '1WK'],
#  ['FAKE2482', 'K'],
#  ['FAKE5017', '>3WK'],
#  ['FAKE6481', '1WK'],
#  ['FAKE608', '1WK'],
#  ['FAKE4555', 'N'],
#  ['FAKE6043', 'N'],
#  ['FAKE285', '2WK'],
#  ['FAKE712', '2WK'],
#  ['FAKE1932', 'N'],
#  ['FAKE2192', 'K'],
#  ['FAKE4158', '1WK'],
#  ['FAKE4685', 'N'],
#  ['FAKE5884', '2WK'],
#  ['FAKE273', '2WK'],
#  ['FAKE2628', '1WK'],
#  ['FAKE4400', 'N'],
#  ['FAKE6210', 'N'],
#  ['FAKE5544', 'N'],
#  ['FAKE2289', '1WK'],
#  ['FAKE3154', 'N'],
#  ['FAKE4356', 'K'],
#  ['FAKE2222', 'N'],
#  ['FAKE4262', '>3WK'],
#  ['FAKE1290', 'K'],
#  ['FAKE2723', '2WK'],
#  ['FAKE703', '>3WK'],
#  ['FAKE1895', 'K'],
#  ['FAKE3199', 'N'],
#  ['FAKE4216', '1WK'],
#  ['FAKE4293', '1WK'],
#  ['FAKE1130', '1WK'],
#  ['FAKE1470', 'N'],
#  ['FAKE6521', '1WK'],
#  ['FAKE4514', 'N'],
#  ['FAKE5305', 'K'],
#  ['FAKE2484', '>3WK'],
#  ['FAKE3155', '>3WK'],
#  ['FAKE974', '>3WK'],
#  ['FAKE1239', '>3WK'],
#  ['FAKE3031', '>3WK'],
#  ['FAKE3958', 'N'],
#  ['FAKE4916', '>3WK'],
#  ['FAKE5880', '>3WK'],
#  ['FAKE6511', 'N'],
#  ['FAKE565', '1WK'],
#  ['FAKE1959', 'K'],
#  ['FAKE899', 'K'],
#  ['FAKE4965', '1WK'],
#  ['FAKE136', '1WK'],
#  ['FAKE235', '2WK'],
#  ['FAKE4973', 'K'],
#  ['FAKE1785', '>3WK'],
#  ['FAKE3321', '2WK'],
#  ['FAKE4807', '>3WK'],
#  ['FAKE1570', '2WK'],
#  ['FAKE4904', '2WK'],
#  ['FAKE5441', '2WK'],
#  ['FAKE6719', '>3WK'],
#  ['FAKE666', 'K'],
#  ['FAKE5538', 'N'],
#  ['FAKE3168', 'K'],
#  ['FAKE1936', 'K'],
#  ['FAKE297', '2WK'],
#  ['FAKE4003', 'K'],
#  ['FAKE5043', '1WK'],
#  ['FAKE1709', '>3WK'],
#  ['FAKE390', '2WK'],
#  ['FAKE589', '>3WK'],
#  ['FAKE2224', '2WK'],
#  ['FAKE4133', '2WK'],
#  ['FAKE105', 'K'],
#  ['FAKE2155', 'K'],
#  ['FAKE2707', '1WK'],
#  ['FAKE5938', 'K'],
#  ['FAKE5418', 'K'],
#  ['FAKE6024', 'N'],
#  ['FAKE6062', '>3WK'],
#  ['FAKE1079', '>3WK'],
#  ['FAKE4869', 'N'],
#  ['FAKE5116', '2WK'],
#  ['FAKE5644', '>3WK'],
#  ['FAKE1831', '>3WK'],
#  ['FAKE2483', '>3WK'],
#  ['FAKE2896', 'N'],
#  ['FAKE3038', 'N'],
#  ['FAKE6225', 'N'],
#  ['FAKE2073', '2WK'],
#  ['FAKE2233', '1WK'],
#  ['FAKE4512', '1WK'],
#  ['FAKE4546', 'K'],
#  ['FAKE352', 'N'],
#  ['FAKE2004', 'N'],
#  ['FAKE2686', '1WK'],
#  ['FAKE2223', 'N'],
#  ['FAKE4500', 'N'],
#  ['FAKE4702', '2WK'],
#  ['FAKE216', 'N'],
#  ['FAKE1032', 'N'],
#  ['FAKE926', '2WK'],
#  ['FAKE4715', 'N'],
#  ['FAKE2067', 'K'],
#  ['FAKE2591', '2WK'],
#  ['FAKE2940', '2WK'],
#  ['FAKE1847', '>3WK'],
#  ['FAKE3577', '2WK'],
#  ['FAKE4437', '1WK'],
#  ['FAKE887', 'K'],
#  ['FAKE2537', 'N'],
#  ['FAKE3479', 'N'],
#  ['FAKE4621', '1WK'],
#  ['FAKE6457', 'N'],
#  ['FAKE4708', '2WK'],
#  ['FAKE3887', '2WK'],
#  ['FAKE5189', '1WK'],
#  ['FAKE1081', '>3WK'],
#  ['FAKE2931', '1WK'],
#  ['FAKE3708', '1WK'],
#  ['FAKE5146', 'N'],
#  ['FAKE2476', '1WK'],
#  ['FAKE2929', 'N'],
#  ['FAKE5957', 'N'],
#  ['FAKE6663', '1WK'],
#  ['FAKE200', 'N'],
#  ['FAKE2365', '2WK'],
#  ['FAKE3174', '1WK'],
#  ['FAKE3826', 'N'],
#  ['FAKE1318', 'N'],
#  ['FAKE1576', '2WK'],
#  ['FAKE5429', '1WK'],
#  ['FAKE5897', 'N'],
#  ['FAKE8', '>3WK'],
#  ['FAKE291', '>3WK'],
#  ['FAKE5523', '1WK'],
#  ['FAKE802', '1WK'],
#  ['FAKE3195', '2WK'],
#  ['FAKE4083', '2WK'],
#  ['FAKE5238', 'N'],
#  ['FAKE5759', 'N'],
#  ['FAKE801', '2WK'],
#  ['FAKE3477', '1WK'],
#  ['FAKE5714', '1WK'],
#  ['FAKE1053', '2WK'],
#  ['FAKE2266', 'N'],
#  ['FAKE4062', 'N'],
#  ['FAKE6498', 'K'],
#  ['FAKE5316', 'N'],
#  ['FAKE5362', '>3WK'],
#  ['FAKE261', 'N'],
#  ['FAKE4429', '>3WK'],
#  ['FAKE5111', 'N'],
#  ['FAKE5657', '1WK'],
#  ['FAKE4887', 'K'],
#  ['FAKE2126', 'N'],
#  ['FAKE3039', '>3WK'],
#  ['FAKE4173', '1WK'],
#  ['FAKE5434', '>3WK'],
#  ['FAKE3906', '>3WK'],
#  ['FAKE5301', 'N'],
#  ['FAKE6690', 'N'],
#  ['FAKE1222', '>3WK'],
#  ['FAKE1726', '2WK'],
#  ['FAKE1940', 'N'],
#  ['FAKE5589', 'K'],
#  ['FAKE5595', 'K'],
#  ['FAKE1128', '>3WK'],
#  ['FAKE1182', '2WK'],
#  ['FAKE1653', 'K'],
#  ['FAKE1135', '>3WK'],
#  ['FAKE2551', 'K'],
#  ['FAKE1242', '>3WK'],
#  ['FAKE2153', '2WK'],
#  ['FAKE6260', '>3WK'],
#  ['FAKE95', 'N'],
#  ['FAKE5764', 'K'],
#  ['FAKE2904', 'N'],
#  ['FAKE4773', 'K'],
#  ['FAKE856', 'N'],
#  ['FAKE1799', '2WK'],
#  ['FAKE2385', 'K'],
#  ['FAKE2421', 'N'],
#  ['FAKE3813', 'N'],
#  ['FAKE4328', '1WK'],
#  ['FAKE4662', '1WK'],
#  ['FAKE3842', 'N'],
#  ['FAKE299', '>3WK'],
#  ['FAKE2242', '2WK'],
#  ['FAKE3419', 'N'],
#  ['FAKE5807', 'K'],
#  ['FAKE6084', '1WK'],
#  ['FAKE6255', '>3WK'],
#  ['FAKE5097', '2WK'],
#  ['FAKE436', 'K'],
#  ['FAKE3616', '2WK'],
#  ['FAKE2165', 'K'],
#  ['FAKE2770', 'K'],
#  ['FAKE334', '>3WK'],
#  ['FAKE4202', '2WK'],
#  ['FAKE1767', 'K'],
#  ['FAKE1976', 'N'],
#  ['FAKE3369', 'K'],
#  ['FAKE4402', '1WK'],
#  ['FAKE5914', '2WK'],
#  ['FAKE6377', '1WK'],
#  ['FAKE5616', 'N'],
#  ['FAKE6091', '1WK'],
#  ['FAKE419', 'N'],
#  ['FAKE883', 'K'],
#  ['FAKE2536', '>3WK'],
#  ['FAKE3240', '1WK'],
#  ['FAKE4282', '>3WK'],
#  ['FAKE4223', 'N'],
#  ['FAKE6160', 'N'],
#  ['FAKE6711', '2WK'],
#  ['FAKE332', '2WK'],
#  ['FAKE1751', '>3WK'],
#  ['FAKE3350', '>3WK'],
#  ['FAKE4113', '>3WK'],
#  ['FAKE5414', '1WK'],
#  ['FAKE4288', 'N'],
#  ['FAKE5709', '>3WK'],
#  ['FAKE2682', '2WK'],
#  ['FAKE2956', '1WK'],
#  ['FAKE1550', '1WK'],
#  ['FAKE5023', 'N'],
#  ['FAKE360', '>3WK'],
#  ['FAKE1388', 'N'],
#  ['FAKE1782', '2WK'],
#  ['FAKE2750', 'N'],
#  ['FAKE4583', '1WK'],
#  ['FAKE981', 'N'],
#  ['FAKE2175', 'N'],
#  ['FAKE2275', '>3WK'],
#  ['FAKE3745', '>3WK'],
#  ['FAKE3882', 'K'],
#  ['FAKE1646', '>3WK'],
#  ['FAKE2784', '>3WK'],
#  ['FAKE4130', '2WK'],
#  ['FAKE4553', '2WK'],
#  ['FAKE3396', 'N'],
#  ['FAKE5197', '2WK'],
#  ['FAKE2298', 'K'],
#  ['FAKE3063', 'N'],
#  ['FAKE4777', '2WK'],
#  ['FAKE5637', '1WK'],
#  ['FAKE4349', '>3WK'],
#  ['FAKE4470', '1WK'],
#  ['FAKE142', '2WK'],
#  ['FAKE3106', '1WK'],
#  ['FAKE312', '1WK'],
#  ['FAKE2930', 'N'],
#  ['FAKE4337', 'K'],
#  ['FAKE5899', 'N'],
#  ['FAKE6146', 'N'],
#  ['FAKE2849', 'K'],
#  ['FAKE3503', '>3WK'],
#  ['FAKE5608', 'N'],
#  ['FAKE6280', 'K'],
#  ['FAKE6603', '1WK'],
#  ['FAKE1890', 'K'],
#  ['FAKE2339', '>3WK'],
#  ['FAKE85', '2WK'],
#  ['FAKE5099', '>3WK'],
#  ['FAKE5806', '>3WK'],
#  ['FAKE6589', '1WK'],
#  ['FAKE1526', '>3WK'],
#  ['FAKE1865', 'K'],
#  ['FAKE5240', '2WK'],
#  ['FAKE6467', 'K'],
#  ['FAKE1572', 'K'],
#  ['FAKE1747', '>3WK'],
#  ['FAKE3680', '2WK'],
#  ['FAKE5367', 'N'],
#  ['FAKE4205', 'N'],
#  ['FAKE4680', 'N'],
#  ['FAKE5688', 'K'],
#  ['FAKE3236', 'N'],
#  ['FAKE6581', '1WK'],
#  ['FAKE6516', 'N'],
#  ['FAKE4335', 'N'],
#  ['FAKE4696', '2WK'],
#  ['FAKE1690', '2WK'],
#  ['FAKE1879', 'N'],
#  ['FAKE3251', 'N'],
#  ['FAKE6217', 'K'],
#  ['FAKE3488', '2WK'],
#  ['FAKE5', 'N'],
#  ['FAKE2815', '1WK'],
#  ['FAKE3915', '>3WK'],
#  ['FAKE5271', '>3WK'],
#  ['FAKE6302', 'K'],
#  ['FAKE1674', 'K'],
#  ['FAKE3869', 'K'],
#  ['FAKE5737', 'N'],
#  ['FAKE784', '>3WK'],
#  ['FAKE2637', '2WK'],
#  ['FAKE5658', 'K'],
#  ['FAKE5999', 'N'],
#  ['FAKE3609', '1WK'],
#  ['FAKE6385', '1WK'],
#  ['FAKE2631', '2WK'],
#  ['FAKE3346', '>3WK'],
#  ['FAKE6411', 'K'],
#  ['FAKE1771', '>3WK'],
#  ['FAKE3703', '>3WK'],
#  ['FAKE3833', '1WK'],
#  ['FAKE921', 'N'],
#  ['FAKE2116', '1WK'],
#  ['FAKE146', '>3WK'],
#  ['FAKE580', 'K'],
#  ['FAKE3682', '>3WK'],
#  ['FAKE1340', '1WK'],
#  ['FAKE5886', '2WK'],
#  ['FAKE6519', '1WK'],
#  ['FAKE2139', 'N'],
#  ['FAKE999', 'K'],
#  ['FAKE1682', 'K'],
#  ['FAKE3026', '1WK'],
#  ['FAKE6555', '>3WK'],
#  ['FAKE110', '>3WK'],
#  ['FAKE2633', '1WK'],
#  ['FAKE3564', '1WK'],
#  ['FAKE3643', '2WK'],
#  ['FAKE5860', 'N'],
#  ['FAKE2936', '1WK'],
#  ['FAKE5752', 'K'],
#  ['FAKE236', '>3WK'],
#  ['FAKE641', 'N'],
#  ['FAKE2292', 'N'],
#  ['FAKE3205', '1WK'],
#  ['FAKE830', '>3WK'],
#  ['FAKE4460', '1WK'],
#  ['FAKE4724', '1WK'],
#  ['FAKE4267', '>3WK'],
#  ['FAKE6704', 'K'],
#  ['FAKE20', 'K'],
#  ['FAKE1103', '1WK'],
#  ['FAKE1280', '1WK'],
#  ['FAKE1986', '1WK'],
#  ['FAKE2830', 'K'],
#  ['FAKE3272', 'K'],
#  ['FAKE6522', 'K'],
#  ['FAKE4761', 'K'],
#  ['FAKE1557', 'N'],
#  ['FAKE2740', 'N'],
#  ['FAKE2887', '>3WK'],
#  ['FAKE1469', '2WK'],
#  ['FAKE4753', '1WK'],
#  ['FAKE6173', 'K'],
#  ['FAKE35', '2WK'],
#  ['FAKE3639', '1WK'],
#  ['FAKE147', 'K'],
#  ['FAKE3649', 'K'],
#  ['FAKE5045', '2WK'],
#  ['FAKE6231', '>3WK'],
#  ['FAKE6463', '1WK'],
#  ['FAKE4951', '>3WK'],
#  ['FAKE411', 'N'],
#  ['FAKE1074', '2WK'],
#  ['FAKE2624', '>3WK'],
#  ['FAKE4453', '>3WK'],
#  ['FAKE5498', '1WK'],
#  ['FAKE6123', 'K'],
#  ['FAKE2056', '2WK'],
#  ['FAKE3294', '2WK'],
#  ['FAKE3298', 'K'],
#  ['FAKE4408', '2WK'],
#  ['FAKE4949', '>3WK'],
#  ['FAKE6019', 'N'],
#  ['FAKE851', '>3WK'],
#  ['FAKE4380', '2WK'],
#  ['FAKE5267', '2WK'],
#  ['FAKE241', '>3WK'],
#  ['FAKE5076', '2WK'],
#  ['FAKE1068', '2WK'],
#  ['FAKE1944', 'N'],
#  ['FAKE4520', '>3WK'],
#  ['FAKE5031', '>3WK'],
#  ['FAKE4104', 'K'],
#  ['FAKE4858', 'N'],
#  ['FAKE6360', '2WK'],
#  ['FAKE3928', '1WK'],
#  ['FAKE3054', '1WK'],
#  ['FAKE6303', 'N'],
#  ['FAKE2856', 'N'],
#  ['FAKE554', 'K'],
#  ['FAKE1649', '>3WK'],
#  ['FAKE4438', '1WK'],
#  ['FAKE515', '2WK'],
#  ['FAKE723', '>3WK'],
#  ['FAKE4383', '2WK'],
#  ['FAKE2843', '1WK'],
#  ['FAKE1070', 'N'],
#  ['FAKE1527', '1WK'],
#  ['FAKE6086', '2WK'],
#  ['FAKE1003', '>3WK'],
#  ['FAKE2345', 'N'],
#  ['FAKE815', '1WK'],
#  ['FAKE1137', '1WK'],
#  ['FAKE6298', 'K'],
#  ['FAKE1206', '2WK'],
#  ['FAKE2640', '2WK'],
#  ['FAKE3460', 'N'],
#  ['FAKE4086', 'N'],
#  ['FAKE79', '1WK'],
#  ['FAKE131', '>3WK'],
#  ['FAKE309', 'K'],
#  ['FAKE3896', '2WK'],
#  ['FAKE567', '>3WK'],
#  ['FAKE4348', 'N'],
#  ['FAKE4457', 'K'],
#  ['FAKE5166', '2WK'],
#  ['FAKE1308', '2WK'],
#  ['FAKE2825', 'N'],
#  ['FAKE4489', '2WK'],
#  ['FAKE2720', 'K'],
#  ['FAKE4969', 'K'],
#  ['FAKE5607', '1WK'],
#  ['FAKE603', '>3WK'],
#  ['FAKE3713', 'N'],
#  ['FAKE5735', '>3WK'],
#  ['FAKE327', '1WK'],
#  ['FAKE1400', 'K'],
#  ['FAKE3072', 'K'],
#  ['FAKE4760', 'K'],
#  ['FAKE2178', 'N'],
#  ['FAKE2279', 'K'],
#  ['FAKE2433', 'N'],
#  ['FAKE6007', '>3WK'],
#  ['FAKE6032', '>3WK'],
#  ['FAKE6431', '2WK'],
#  ['FAKE4397', '2WK'],
#  ['FAKE1020', 'N'],
#  ['FAKE3662', '2WK'],
#  ['FAKE5973', '1WK'],
#  ['FAKE3066', '1WK'],
#  ['FAKE3465', '2WK'],
#  ['FAKE3569', 'K'],
#  ['FAKE4465', 'N'],
#  ['FAKE5751', '1WK'],
#  ['FAKE2652', '2WK'],
#  ['FAKE5855', 'N'],
#  ['FAKE6059', '2WK'],
#  ['FAKE3628', 'K'],
#  ['FAKE2003', '2WK'],
#  ['FAKE4458', 'N'],
#  ['FAKE4963', '2WK'],
#  ['FAKE3798', 'K'],
#  ['FAKE6242', '1WK'],
#  ['FAKE4306', '1WK'],
#  ['FAKE185', '1WK'],
#  ['FAKE1724', '>3WK'],
#  ['FAKE5242', '2WK'],
#  ['FAKE323', '1WK'],
#  ['FAKE1011', '>3WK'],
#  ['FAKE1296', 'N'],
#  ['FAKE5357', 'K'],
#  ['FAKE6185', 'K'],
#  ['FAKE3517', 'N'],
#  ['FAKE3872', '1WK'],
#  ['FAKE4836', '>3WK'],
#  ['FAKE1712', 'K'],
#  ['FAKE3279', '2WK'],
#  ['FAKE947', '2WK'],
#  ['FAKE4367', '>3WK'],
#  ['FAKE6579', '2WK'],
#  ['FAKE933', '2WK'],
#  ['FAKE1714', '>3WK'],
#  ['FAKE6683', '1WK'],
#  ['FAKE150', '>3WK'],
#  ['FAKE1863', 'K'],
#  ['FAKE4835', 'N'],
#  ['FAKE5953', 'K'],
#  ['FAKE6312', 'K'],
#  ['FAKE6632', '>3WK'],
#  ['FAKE129', 'K'],
#  ['FAKE4765', '1WK'],
#  ['FAKE541', 'K'],
#  ['FAKE1534', 'K'],
#  ['FAKE1750', '>3WK'],
#  ['FAKE1759', 'N'],
#  ['FAKE3741', '2WK'],
#  ['FAKE5382', '1WK'],
#  ['FAKE6284', 'N'],
#  ['FAKE6401', 'N'],
#  ['FAKE512', 'N'],
#  ['FAKE1072', '1WK'],
#  ['FAKE1422', 'K'],
#  ['FAKE4480', 'N'],
#  ['FAKE4543', 'K'],
#  ['FAKE6489', '>3WK'],
#  ['FAKE1397', '>3WK'],
#  ['FAKE1027', '1WK'],
#  ['FAKE3216', 'N'],
#  ['FAKE4144', 'K'],
#  ['FAKE5468', '2WK'],
#  ['FAKE5934', 'K'],
#  ['FAKE6436', 'N'],
#  ['FAKE2236', 'N'],
#  ['FAKE2250', '>3WK'],
#  ['FAKE3445', 'N'],
#  ['FAKE5339', 'N'],
#  ['FAKE1009', '>3WK'],
#  ['FAKE2913', 'N'],
#  ['FAKE3646', '1WK'],
#  ['FAKE5004', '1WK'],
#  ['FAKE6148', '2WK'],
#  ['FAKE6391', 'N'],
#  ['FAKE2958', '1WK'],
#  ['FAKE4948', '>3WK'],
#  ['FAKE6089', '>3WK'],
#  ['FAKE6215', 'K'],
#  ['FAKE2066', '2WK'],
#  ['FAKE5890', '>3WK'],
#  ['FAKE6358', 'N'],
#  ['FAKE83', 'K'],
#  ['FAKE2657', 'N'],
#  ['FAKE2584', 'N'],
#  ['FAKE2659', '>3WK'],
#  ['FAKE3777', '2WK'],
#  ['FAKE5618', 'N'],
#  ['FAKE1965', '>3WK'],
#  ['FAKE3176', '2WK'],
#  ['FAKE6108', 'N'],
#  ['FAKE878', 'N'],
#  ['FAKE4256', '2WK'],
#  ['FAKE940', 'K'],
#  ['FAKE4246', '1WK'],
#  ['FAKE574', 'N'],
#  ['FAKE860', 'N'],
#  ['FAKE4343', '1WK'],
#  ['FAKE5893', 'N'],
#  ['FAKE6034', '2WK'],
#  ['FAKE18', 'N'],
#  ['FAKE108', '1WK'],
#  ['FAKE4424', 'K'],
#  ['FAKE1115', '1WK'],
#  ['FAKE82', 'N'],
#  ['FAKE2147', 'K'],
#  ['FAKE6167', '2WK'],
#  ['FAKE1286', '1WK'],
#  ['FAKE2414', '2WK'],
#  ['FAKE2', 'K'],
#  ['FAKE587', '1WK'],
#  ['FAKE5038', 'N'],
#  ['FAKE6147', 'N'],
#  ['FAKE6648', 'N'],
#  ['FAKE139', '2WK'],
#  ['FAKE4711', '>3WK'],
#  ['FAKE5975', '1WK'],
#  ['FAKE694', '>3WK'],
#  ['FAKE820', '1WK'],
#  ['FAKE4971', 'K'],
#  ['FAKE1092', 'K'],
#  ['FAKE3905', 'K'],
#  ['FAKE5527', '1WK'],
#  ['FAKE118', '1WK'],
#  ['FAKE414', '1WK'],
#  ['FAKE4503', 'N'],
#  ['FAKE5655', 'K'],
#  ['FAKE3800', '1WK'],
#  ['FAKE5767', 'N'],
#  ['FAKE6058', 'N'],
#  ['FAKE6294', '2WK'],
#  ['FAKE5033', 'N'],
#  ['FAKE232', 'K'],
#  ['FAKE1196', '1WK'],
#  ['FAKE1769', '1WK'],
#  ['FAKE3399', 'N'],
#  ['FAKE3765', '2WK'],
#  ['FAKE539', 'N'],
#  ['FAKE1107', '1WK'],
#  ['FAKE3944', 'N'],
#  ['FAKE4660', '1WK'],
#  ['FAKE4931', '1WK'],
#  ['FAKE2774', 'N'],
#  ['FAKE1854', 'K'],
#  ['FAKE2870', '1WK'],
#  ['FAKE1266', 'N'],
#  ['FAKE1564', '>3WK'],
#  ['FAKE3832', 'N'],
#  ['FAKE5803', 'N'],
#  ['FAKE2827', 'K'],
#  ['FAKE4107', '2WK'],
#  ['FAKE831', '1WK'],
#  ['FAKE1362', 'K'],
#  ['FAKE1761', '2WK'],
#  ['FAKE2353', 'N'],
#  ['FAKE6010', 'N'],
#  ['FAKE405', 'K'],
#  ['FAKE1523', 'K'],
#  ['FAKE6036', 'N'],
#  ['FAKE3252', '2WK'],
#  ['FAKE96', '2WK'],
#  ['FAKE662', '2WK'],
#  ['FAKE1181', '2WK'],
#  ['FAKE2588', 'N'],
#  ['FAKE3060', '>3WK'],
#  ['FAKE6611', '1WK'],
#  ['FAKE526', '1WK'],
#  ['FAKE2569', 'K'],
#  ['FAKE4085', '1WK'],
#  ['FAKE4736', '2WK'],
#  ['FAKE6239', '2WK'],
#  ['FAKE5467', 'N'],
#  ['FAKE841', 'N'],
#  ['FAKE960', 'K'],
#  ['FAKE2600', 'K'],
#  ['FAKE482', '1WK'],
#  ['FAKE1410', 'N'],
#  ['FAKE1802', '1WK'],
#  ['FAKE3709', '2WK'],
#  ['FAKE5207', '>3WK'],
#  ['FAKE191', '2WK'],
#  ['FAKE773', 'N'],
#  ['FAKE2065', 'N'],
#  ['FAKE2475', 'K'],
#  ['FAKE2618', 'N'],
#  ['FAKE6190', 'K'],
#  ['FAKE24', '1WK'],
#  ['FAKE3234', '2WK'],
#  ['FAKE2541', '1WK'],
#  ['FAKE3623', '>3WK'],
#  ['FAKE4846', 'N'],
#  ['FAKE5165', '1WK'],
#  ['FAKE3539', '1WK'],
#  ['FAKE5089', '>3WK'],
#  ['FAKE5124', 'N'],
#  ['FAKE5221', '>3WK'],
#  ['FAKE6052', '2WK'],
#  ['FAKE3907', '>3WK'],
#  ['FAKE1949', 'N'],
#  ['FAKE2280', '>3WK'],
#  ['FAKE6209', 'N'],
#  ['FAKE1548', '>3WK'],
#  ['FAKE4239', 'K'],
#  ['FAKE1219', 'K'],
#  ['FAKE2243', 'K'],
#  ['FAKE5698', 'K'],
#  ['FAKE6170', '2WK'],
#  ['FAKE716', '1WK'],
#  ['FAKE1665', '1WK'],
#  ['FAKE4310', '>3WK'],
#  ['FAKE5716', '2WK'],
#  ['FAKE5875', '>3WK'],
#  ['FAKE625', '1WK'],
#  ['FAKE777', 'K'],
#  ['FAKE2982', 'K'],
#  ['FAKE4757', '1WK'],
#  ['FAKE5493', 'K'],
#  ['FAKE1824', '2WK'],
#  ['FAKE6318', 'N'],
#  ['FAKE816', '2WK'],
#  ['FAKE4126', '2WK'],
#  ['FAKE4625', '1WK'],
#  ['FAKE21', '2WK'],
#  ['FAKE31', '2WK'],
#  ['FAKE1344', '1WK'],
#  ['FAKE2373', '>3WK'],
#  ['FAKE670', '1WK'],
#  ['FAKE2447', '>3WK'],
#  ['FAKE686', '1WK'],
#  ['FAKE1170', '2WK'],
#  ['FAKE4637', '2WK'],
#  ['FAKE6102', '2WK'],
#  ['FAKE6445', 'K'],
#  ['FAKE5693', '2WK'],
#  ['FAKE1033', 'K'],
#  ['FAKE1683', 'K'],
#  ['FAKE4752', '>3WK'],
#  ['FAKE3305', 'N'],
#  ['FAKE3729', '2WK'],
#  ['FAKE4088', 'N'],
#  ['FAKE4203', '2WK'],
#  ['FAKE5061', '>3WK'],
#  ['FAKE2326', 'N'],
#  ['FAKE5772', '1WK'],
#  ['FAKE5868', '2WK'],
#  ['FAKE6602', 'K'],
#  ['FAKE186', '>3WK'],
#  ['FAKE1476', 'K'],
#  ['FAKE2560', '>3WK'],
#  ['FAKE970', 'K'],
#  ['FAKE991', '2WK'],
#  ['FAKE1373', '>3WK'],
#  ['FAKE1686', '1WK'],
#  ['FAKE4648', 'N'],
#  ['FAKE6207', '2WK'],
#  ['FAKE6518', '1WK'],
#  ['FAKE1243', 'N'],
#  ['FAKE2355', '1WK'],
#  ['FAKE5820', '1WK'],
#  ['FAKE6061', 'K'],
#  ['FAKE6473', '1WK'],
#  ['FAKE1852', '1WK'],
#  ['FAKE4483', '>3WK'],
#  ['FAKE4744', '2WK'],
#  ['FAKE6222', '1WK'],
#  ['FAKE2100', 'K'],
#  ['FAKE3420', '2WK'],
#  ['FAKE4323', '2WK'],
#  ['FAKE6111', '2WK'],
#  ['FAKE6722', '1WK'],
#  ['FAKE3545', 'N'],
#  ['FAKE5478', 'N'],
#  ['FAKE2206', '>3WK'],
#  ['FAKE5506', '1WK'],
#  ['FAKE980', '2WK'],
#  ['FAKE1758', 'N'],
#  ['FAKE5379', '>3WK'],
#  ['FAKE1735', '>3WK'],
#  ['FAKE3494', '1WK'],
#  ['FAKE4983', 'K'],
#  ['FAKE5508', 'K'],
#  ['FAKE269', 'K'],
#  ['FAKE1477', 'K'],
#  ['FAKE1813', '1WK'],
#  ['FAKE2419', '>3WK'],
#  ['FAKE4426', '1WK'],
#  ['FAKE1412', '1WK'],
#  ['FAKE3807', '2WK'],
#  ['FAKE1326', 'K'],
#  ['FAKE3585', '>3WK'],
#  ['FAKE5613', '1WK'],
#  ['FAKE5950', '1WK'],
#  ['FAKE6694', '2WK'],
#  ['FAKE1338', '1WK'],
#  ['FAKE2933', '>3WK'],
#  ['FAKE4977', '>3WK'],
#  ['FAKE5876', '2WK'],
#  ['FAKE2446', '1WK'],
#  ['FAKE5159', '>3WK'],
#  ['FAKE5525', 'N'],
#  ['FAKE2506', 'N'],
#  ['FAKE4781', '2WK'],
#  ['FAKE5585', 'K'],
#  ['FAKE5619', '>3WK'],
#  ['FAKE4496', 'K'],
#  ['FAKE5774', '1WK'],
#  ['FAKE570', 'K'],
#  ['FAKE3467', '>3WK'],
#  ['FAKE3491', '2WK'],
#  ['FAKE3578', 'N'],
#  ['FAKE4290', '>3WK'],
#  ['FAKE3603', 'N'],
#  ['FAKE626', '>3WK'],
#  ['FAKE1370', '2WK'],
#  ['FAKE1697', 'K'],
#  ['FAKE4070', 'N'],
#  ['FAKE5122', '1WK'],
#  ['FAKE1588', 'K'],
#  ['FAKE4884', '1WK'],
#  ['FAKE5858', 'K'],
#  ['FAKE90', '2WK'],
#  ['FAKE2160', 'K'],
#  ['FAKE4612', '2WK'],
#  ['FAKE1483', '1WK'],
#  ['FAKE1796', '>3WK'],
#  ['FAKE3134', '>3WK'],
#  ['FAKE5248', '2WK'],
#  ['FAKE5592', '1WK'],
#  ['FAKE386', '>3WK'],
#  ['FAKE969', 'K'],
#  ['FAKE5552', 'K'],
#  ['FAKE6542', '2WK'],
#  ['FAKE2031', '>3WK'],
#  ['FAKE2140', '2WK'],
#  ['FAKE6262', '2WK'],
#  ['FAKE5459', 'N'],
#  ['FAKE6314', 'N'],
#  ['FAKE6572', 'K'],
#  ['FAKE669', '1WK'],
#  ['FAKE2370', '2WK'],
#  ['FAKE2905', 'K'],
#  ['FAKE6406', '2WK'],
#  ['FAKE6450', 'K'],
#  ['FAKE53', '2WK'],
#  ['FAKE3239', 'K'],
#  ['FAKE3245', 'K'],
#  ['FAKE4129', '>3WK'],
#  ['FAKE4208', '2WK'],
#  ['FAKE2441', '1WK'],
#  ['FAKE5547', 'K'],
#  ['FAKE2505', 'N'],
#  ['FAKE5024', 'K'],
#  ['FAKE6410', 'K'],
#  ['FAKE1188', 'K'],
#  ['FAKE3516', '1WK'],
#  ['FAKE5143', 'K'],
#  ['FAKE5896', '2WK'],
#  ['FAKE6049', '2WK'],
#  ['FAKE5785', 'N'],
#  ['FAKE5842', 'K'],
#  ['FAKE5971', 'N'],
#  ['FAKE2145', '1WK'],
#  ['FAKE3123', 'K'],
#  ['FAKE1129', '1WK'],
#  ['FAKE1442', '>3WK'],
#  ['FAKE3630', 'K'],
#  ['FAKE5063', '>3WK'],
#  ['FAKE1975', '2WK'],
#  ['FAKE2558', '2WK'],
#  ['FAKE4739', 'N'],
#  ['FAKE6064', 'N'],
#  ['FAKE3149', 'K'],
#  ['FAKE3285', 'K'],
#  ['FAKE4653', '1WK'],
#  ['FAKE1491', 'N'],
#  ['FAKE3830', '2WK'],
#  ['FAKE4593', '>3WK'],
#  ['FAKE5069', '>3WK'],
#  ['FAKE6466', 'N'],
#  ['FAKE4548', '2WK'],
#  ['FAKE5900', 'K'],
#  ['FAKE736', 'K'],
#  ['FAKE1333', 'N'],
#  ['FAKE5825', 'N'],
#  ['FAKE6116', '2WK'],
#  ['FAKE4082', '2WK'],
#  ['FAKE5705', 'K'],
#  ['FAKE1624', 'K'],
#  ['FAKE3792', '2WK'],
#  ['FAKE2183', '1WK'],
#  ['FAKE5859', 'N'],
#  ['FAKE6633', '2WK'],
#  ['FAKE2111', '1WK'],
#  ['FAKE3161', '2WK'],
#  ['FAKE64', '>3WK'],
#  ['FAKE396', 'K'],
#  ['FAKE679', '>3WK'],
#  ['FAKE906', 'N'],
#  ['FAKE152', 'K'],
#  ['FAKE4186', '>3WK'],
#  ['FAKE202', '>3WK'],
#  ['FAKE2580', 'N'],
#  ['FAKE5494', 'K'],
#  ['FAKE768', '2WK'],
#  ['FAKE1025', 'K'],
#  ['FAKE5161', 'N'],
#  ['FAKE2571', '1WK'],
#  ['FAKE3475', '2WK'],
#  ['FAKE3775', 'K'],
#  ['FAKE3387', 'N'],
#  ['FAKE1680', '>3WK'],
#  ['FAKE6132', '>3WK'],
#  ['FAKE6186', '>3WK'],
#  ['FAKE1429', 'K'],
#  ['FAKE2939', 'K'],
#  ['FAKE2710', 'N'],
#  ['FAKE6014', '2WK'],
#  ['FAKE4682', 'K'],
#  ['FAKE6686', '>3WK'],
#  ['FAKE3543', 'N'],
#  ['FAKE5548', '1WK'],
#  ['FAKE5328', 'K'],
#  ['FAKE2790', '2WK'],
#  ['FAKE5100', 'K'],
#  ['FAKE3333', 'N'],
#  ['FAKE3768', '1WK'],
#  ['FAKE4694', '2WK'],
#  ['FAKE5198', '>3WK'],
#  ['FAKE141', 'K'],
#  ['FAKE3750', 'N'],
#  ['FAKE4934', 'N'],
#  ['FAKE599', '>3WK'],
#  ['FAKE1923', '2WK'],
#  ['FAKE2226', '2WK'],
#  ['FAKE5801', '>3WK'],
#  ['FAKE1857', 'K'],
#  ['FAKE2225', 'K'],
#  ['FAKE2927', '1WK'],
#  ['FAKE4559', 'K'],
#  ['FAKE6033', '2WK'],
#  ['FAKE37', '>3WK'],
#  ['FAKE4051', '1WK'],
#  ['FAKE225', 'K'],
#  ['FAKE3156', 'N'],
#  ['FAKE3328', 'K'],
#  ['FAKE11', '>3WK'],
#  ['FAKE3898', 'N'],
#  ['FAKE5561', 'K'],
#  ['FAKE592', 'K'],
#  ['FAKE5153', 'N'],
#  ['FAKE6502', '2WK'],
#  ['FAKE4530', '>3WK'],
#  ['FAKE1762', 'N'],
#  ['FAKE636', '>3WK'],
#  ['FAKE3929', 'K'],
#  ['FAKE4109', 'K'],
#  ['FAKE2302', '>3WK'],
#  ['FAKE4586', 'N'],
#  ['FAKE2997', '>3WK'],
#  ['FAKE2702', 'K'],
#  ['FAKE2961', 'N'],
#  ['FAKE3368', '>3WK'],
#  ['FAKE4412', '>3WK'],
#  ['FAKE771', '>3WK'],
#  ['FAKE1586', '2WK'],
#  ['FAKE2136', '>3WK'],
#  ['FAKE2893', '>3WK'],
#  ['FAKE3280', 'K'],
#  ['FAKE4255', 'N'],
#  ['FAKE290', '2WK'],
#  ['FAKE3313', '1WK'],
#  ['FAKE5101', '2WK'],
#  ['FAKE5756', '1WK'],
#  ['FAKE634', 'N'],
#  ['FAKE699', '>3WK'],
#  ['FAKE2490', 'K'],
#  ['FAKE2697', '1WK'],
#  ['FAKE6080', 'N'],
#  ['FAKE3040', '>3WK'],
#  ['FAKE4342', 'K'],
#  ['FAKE5360', 'N'],
#  ['FAKE57', 'N'],
#  ['FAKE807', 'N'],
#  ['FAKE2928', '2WK'],
#  ['FAKE4991', 'K'],
#  ['FAKE5396', '>3WK'],
#  ['FAKE6422', '1WK'],
#  ['FAKE6488', 'N'],
#  ['FAKE6723', 'N'],
#  ['FAKE4374', '2WK'],
#  ['FAKE4423', '1WK'],
#  ['FAKE596', '>3WK'],
#  ['FAKE6657', '2WK'],
#  ['FAKE166', '2WK'],
#  ['FAKE1149', '2WK'],
#  ['FAKE1258', '2WK'],
#  ['FAKE1763', '1WK'],
#  ['FAKE6323', '>3WK'],
#  ['FAKE4574', '2WK'],
#  ['FAKE3075', '1WK'],
#  ['FAKE1287', 'K'],
#  ['FAKE1770', '2WK'],
#  ['FAKE3638', 'N'],
#  ['FAKE4184', '>3WK'],
#  ['FAKE5373', 'N'],
#  ['FAKE756', 'K'],
#  ['FAKE982', '1WK'],
#  ['FAKE4188', '>3WK'],
#  ['FAKE219', '1WK'],
#  ['FAKE4032', 'K'],
#  ['FAKE2429', 'K'],
#  ['FAKE6168', 'N'],
#  ['FAKE1360', '1WK'],
#  ['FAKE2700', 'K'],
#  ['FAKE4320', 'K'],
#  ['FAKE936', '1WK'],
#  ['FAKE1601', '2WK'],
#  ['FAKE5241', 'N'],
#  ['FAKE2169', 'K'],
#  ['FAKE2820', '2WK'],
#  ['FAKE3895', 'K'],
#  ['FAKE3027', '>3WK'],
#  ['FAKE3428', '>3WK'],
#  ['FAKE5563', 'K'],
#  ['FAKE5205', '2WK'],
#  ['FAKE5791', '>3WK'],
#  ['FAKE6233', '2WK'],
#  ['FAKE4701', 'K'],
#  ['FAKE963', '1WK'],
#  ['FAKE3694', '>3WK'],
#  ['FAKE5895', 'K'],
#  ['FAKE6405', '>3WK'],
#  ['FAKE1585', 'N'],
#  ['FAKE3804', '1WK'],
#  ['FAKE951', 'N'],
#  ['FAKE2672', 'N'],
#  ['FAKE2980', 'N'],
#  ['FAKE5250', '>3WK'],
#  ['FAKE707', '2WK'],
#  ['FAKE1006', 'K'],
#  ['FAKE5654', 'K'],
#  ['FAKE1175', '>3WK'],
#  ['FAKE2865', '2WK'],
#  ['FAKE329', '1WK'],
#  ['FAKE2573', '>3WK'],
#  ['FAKE3177', 'K'],
#  ['FAKE6442', '2WK'],
#  ['FAKE2925', 'K'],
#  ['FAKE3480', 'N'],
#  ['FAKE471', '1WK'],
#  ['FAKE3850', '1WK'],
#  ['FAKE964', '2WK'],
#  ...]

# %%
cl.listTableInfo('bigquery.cineca.syn_Africa_H3ABioNet_v1',verbose=True)
# Out:
# _Schema for tablebigquery.cineca.syn_Africa_H3ABioNet_v1_
# {
#    "name": "bigquery.cineca.syn_Africa_H3ABioNet_v1",
#    "description": "CINECA synthetic cohort Africa H3ABioNet v1",
#    "data_model": {
#       "$id": "",
#       "description": "CINECA synthetic cohort Africa H3ABioNet v1",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "pid": {
#             "type": "string",
#             "description": "Participant ID:"
#          },
#          "height_avg": {
#             "type": "number",
#             "description": "Average height:",
#             "$unit": "cm"
#          },
#          "weight_avg": {
#             "type": "number",
#             "description": "Calculated average weight (kg):",
#             "$unit": "kg"
#          },
#          "hypertension": {
#             "type": "string",
#             "description": "Has a healthcare worker ever said that you have high blood pressure or hypertension? ",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't Know"
#                }
#             ]
#          },
#          "hypertension_meds": {
#             "type": "string",
#             "description": "Have you ever taken medication for hypertension/high blood pressure?",
#             "oneOf": [
#                {
#                   "const": "Yes now"
#                },
#                {
#                   "const": "Yes not now"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "bp_systolic1": {
#             "type": "number",
#             "description": "Systolic Pressure measurement 1",
#             "$unit": "mmHg"
#          },
#          "bp_diastolic1": {
#             "type": "number",
#             "description": "Diastolic Pressure measurement 1",
#             "$unit": "mmHg"
#          },
#          "age": {
#             "type": "integer",
#             "description": "About how old are you?\n<i>(Only complete when date of birth is unknown)</i>\n",
#             "$unit": "Enter an integer number and then select unit of measure next."
#          },
#          "sex": {
#             "type": "string",
#             "description": "Are you male or female?",
#             "oneOf": [
#                {
#                   "const": "Male"
#                },
#                {
#                   "const": "Female"
#                },
#                {
#                   "const": "Other"
#                },
#                {
#                   "const": "Refused"
#                }
#             ]
#          },
#          "birthcountry": {
#             "allOf": [
#                {
#                   "description": "In which country were you born?"
#                },
#                {
#                   "$ref": "countries.json"
#                }
#             ]
#          },
#          "language": {
#             "type": "string",
#             "description": "What is your native language?",
#             "oneOf": [
#                {
#                   "const": "english"
#                },
#                {
#                   "const": "afrikaans"
#                },
#                {
#                   "const": "nd?l?isindebele)"
#                },
#                {
#                   "const": "xhosa (isixhosa)"
#                },
#                {
#                   "const": "zoulou (isizulu)"
#                },
#                {
#                   "const": "arabic"
#                },
#                {
#                   "const": "Portuguese"
#                },
#                {
#                   "const": "frensh"
#                },
#                {
#                   "const": "tswana"
#                },
#                {
#                   "const": "moray"
#                },
#                {
#                   "const": "dioula"
#                },
#                {
#                   "const": "peul"
#                },
#                {
#                   "const": "kirundi"
#                },
#                {
#                   "const": "somali"
#                },
#                {
#                   "const": "afar"
#                },
#                {
#                   "const": "amharic"
#                },
#                {
#                   "const": "espanish"
#                },
#                {
#                   "const": "ha?en"
#                },
#                {
#                   "const": "swahili"
#                },
#                {
#                   "const": "sesotho"
#                },
#                {
#                   "const": "malgache"
#                },
#                {
#                   "const": "chichewa"
#                },
#                {
#                   "const": "bambara"
#                },
#                {
#                   "const": "sango"
#                },
#                {
#                   "const": "kinyarwanda"
#                },
#                {
#                   "const": "creaole seychelle"
#                },
#                {
#                   "const": "swati"
#                },
#                {
#                   "const": "shona"
#                },
#                {
#                   "const": "sindebele"
#                },
#                {
#                   "const": "tswana (setswana)"
#                },
#                {
#                   "const": "siswati (siSwati)"
#                },
#                {
#                   "const": "venda (tshivenda)"
#                },
#                {
#                   "const": "tsonga (xitsonga)"
#                },
#                {
#                   "const": "Other"
#                }
#             ]
#          },
#          "ethnicity": {
#             "type": "string",
#             "description": "What is your ethnic or tribal affiliation?",
#             "oneOf": [
#                {
#                   "const": "Berbers"
#                },
#                {
#                   "const": "Copts"
#                },
#                {
#                   "const": "Egyptians"
#                },
#                {
#                   "const": "Fur"
#                },
#                {
#                   "const": "Maghrebis"
#                },
#                {
#                   "const": "Nubians"
#                },
#                {
#                   "const": "Tuareg"
#                },
#                {
#                   "const": "Zaghawa"
#                },
#                {
#                   "const": "Toubou"
#                },
#                {
#                   "const": "Alur"
#                },
#                {
#                   "const": "Anuak"
#                },
#                {
#                   "const": "Acholi"
#                },
#                {
#                   "const": "Banyoro"
#                },
#                {
#                   "const": "Chagga"
#                },
#                {
#                   "const": "Dinka"
#                },
#                {
#                   "const": "Ganda"
#                },
#                {
#                   "const": "Langi"
#                },
#                {
#                   "const": "Hutu"
#                },
#                {
#                   "const": "Kamba"
#                },
#                {
#                   "const": "Kalenjin"
#                },
#                {
#                   "const": "Kikuyu"
#                },
#                {
#                   "const": "Kwama"
#                },
#                {
#                   "const": "Lugbara"
#                },
#                {
#                   "const": "Luo"
#                },
#                {
#                   "const": "Luhya"
#                },
#                {
#                   "const": "Maasai"
#                },
#                {
#                   "const": "Makonde"
#                },
#                {
#                   "const": "Ameru"
#                },
#                {
#                   "const": "Nuer"
#                },
#                {
#                   "const": "Samburu"
#                },
#                {
#                   "const": "Shilluk"
#                },
#                {
#                   "const": "Swahili"
#                },
#                {
#                   "const": "Tutsi"
#                },
#                {
#                   "const": "Twa"
#                },
#                {
#                   "const": "Aka"
#                },
#                {
#                   "const": "Baka"
#                },
#                {
#                   "const": "Banda"
#                },
#                {
#                   "const": "Chewa"
#                },
#                {
#                   "const": "Chokwe"
#                },
#                {
#                   "const": "Ef? 40"
#                },
#                {
#                   "const": "Kongo"
#                },
#                {
#                   "const": "Kanuri"
#                },
#                {
#                   "const": "Lingala"
#                },
#                {
#                   "const": "Luba"
#                },
#                {
#                   "const": "Kotoko"
#                },
#                {
#                   "const": "Mbunda"
#                },
#                {
#                   "const": "Mbundu"
#                },
#                {
#                   "const": "Moghamo"
#                },
#                {
#                   "const": "Mongo"
#                },
#                {
#                   "const": "Ngamambo"
#                },
#                {
#                   "const": "Ovimbundu"
#                },
#                {
#                   "const": "Sara"
#                },
#                {
#                   "const": "Sua"
#                },
#                {
#                   "const": "Zande"
#                },
#                {
#                   "const": "Zaghawa"
#                },
#                {
#                   "const": "Akan"
#                },
#                {
#                   "const": "Aku"
#                },
#                {
#                   "const": "Bambara"
#                },
#                {
#                   "const": "Basaa"
#                },
#                {
#                   "const": "Bassa"
#                },
#                {
#                   "const": "BetiPahuin"
#                },
#                {
#                   "const": "Biafada"
#                },
#                {
#                   "const": "Mole-Dagbani"
#                },
#                {
#                   "const": "Dendi"
#                },
#                {
#                   "const": "Edo"
#                },
#                {
#                   "const": "Efik"
#                },
#                {
#                   "const": "Eket"
#                },
#                {
#                   "const": "Esan"
#                },
#                {
#                   "const": "Ewe"
#                },
#                {
#                   "const": "Fon"
#                },
#                {
#                   "const": "Fulani"
#                },
#                {
#                   "const": "Ga"
#                },
#                {
#                   "const": "Gwari"
#                },
#                {
#                   "const": "Hausa"
#                },
#                {
#                   "const": "Igbo"
#                },
#                {
#                   "const": "Ijaw"
#                },
#                {
#                   "const": "Jola"
#                },
#                {
#                   "const": "Kanuri"
#                },
#                {
#                   "const": "Mandingo"
#                },
#                {
#                   "const": "Mande South"
#                },
#                {
#                   "const": "Marka"
#                },
#                {
#                   "const": "Mende"
#                },
#                {
#                   "const": "Papel"
#                },
#                {
#                   "const": "Serer"
#                },
#                {
#                   "const": "Songhai"
#                },
#                {
#                   "const": "Tiv"
#                },
#                {
#                   "const": "Urhobo"
#                },
#                {
#                   "const": "Wolof"
#                },
#                {
#                   "const": "Yoruba"
#                },
#                {
#                   "const": "Zarma"
#                },
#                {
#                   "const": "Afrikaner"
#                },
#                {
#                   "const": "Ovambo"
#                },
#                {
#                   "const": "Bemba"
#                },
#                {
#                   "const": "CapeColoured"
#                },
#                {
#                   "const": "Herero"
#                },
#                {
#                   "const": "Himba"
#                },
#                {
#                   "const": "Goffal"
#                },
#                {
#                   "const": "Kalanga"
#                },
#                {
#                   "const": "Khoikhoi"
#                },
#                {
#                   "const": "Lemba"
#                },
#                {
#                   "const": "Makua"
#                },
#                {
#                   "const": "Nambya"
#                },
#                {
#                   "const": "North Ndebele"
#                },
#                {
#                   "const": "San"
#                },
#                {
#                   "const": "South Ndebele"
#                },
#                {
#                   "const": "Shona"
#                },
#                {
#                   "const": "Sotho"
#                },
#                {
#                   "const": "Swazi"
#                },
#                {
#                   "const": "Tonga"
#                },
#                {
#                   "const": "Tsonga"
#                },
#                {
#                   "const": "Tswana"
#                },
#                {
#                   "const": "Venda"
#                },
#                {
#                   "const": "Xhosa"
#                },
#                {
#                   "const": "Yeyi"
#                },
#                {
#                   "const": "Zulu"
#                },
#                {
#                   "const": "Afar"
#                },
#                {
#                   "const": "Agaw"
#                },
#                {
#                   "const": "Amhara"
#                },
#                {
#                   "const": "Beja"
#                },
#                {
#                   "const": "Bilen"
#                },
#                {
#                   "const": "Gurage"
#                },
#                {
#                   "const": "Oromo"
#                },
#                {
#                   "const": "Saho"
#                },
#                {
#                   "const": "Sidama"
#                },
#                {
#                   "const": "Somali"
#                },
#                {
#                   "const": "Tigray-Tigrinya"
#                },
#                {
#                   "const": "Tigre"
#                }
#             ]
#          },
#          "fbirthcountry": {
#             "allOf": [
#                {
#                   "description": "In which country were you born?"
#                },
#                {
#                   "$ref": "countries.json"
#                }
#             ]
#          },
#          "flanguage": {
#             "type": "string",
#             "description": "What is your father's native language?",
#             "oneOf": [
#                {
#                   "const": "english"
#                },
#                {
#                   "const": "afrikaans"
#                },
#                {
#                   "const": "nd?l?isindebele)"
#                },
#                {
#                   "const": "xhosa (isixhosa)"
#                },
#                {
#                   "const": "zoulou (isizulu)"
#                },
#                {
#                   "const": "arabic"
#                },
#                {
#                   "const": "Portuguese"
#                },
#                {
#                   "const": "frensh"
#                },
#                {
#                   "const": "tswana"
#                },
#                {
#                   "const": "moray"
#                },
#                {
#                   "const": "dioula"
#                },
#                {
#                   "const": "peul"
#                },
#                {
#                   "const": "kirundi"
#                },
#                {
#                   "const": "somali"
#                },
#                {
#                   "const": "afar"
#                },
#                {
#                   "const": "amharic"
#                },
#                {
#                   "const": "espanish"
#                },
#                {
#                   "const": "ha?en"
#                },
#                {
#                   "const": "swahili"
#                },
#                {
#                   "const": "sesotho"
#                },
#                {
#                   "const": "malgache"
#                },
#                {
#                   "const": "chichewa"
#                },
#                {
#                   "const": "bambara"
#                },
#                {
#                   "const": "sango"
#                },
#                {
#                   "const": "kinyarwanda"
#                },
#                {
#                   "const": "creaole seychelle"
#                },
#                {
#                   "const": "swati"
#                },
#                {
#                   "const": "shona"
#                },
#                {
#                   "const": "sindebele"
#                },
#                {
#                   "const": "tswana (setswana)"
#                },
#                {
#                   "const": "siswati (siSwati)"
#                },
#                {
#                   "const": "venda (tshivenda)"
#                },
#                {
#                   "const": "tsonga (xitsonga)"
#                }
#             ]
#          },
#          "fethnicity": {
#             "type": "string",
#             "description": "What is your father's ethno-linguistic tribal affiliation?",
#             "oneOf": [
#                {
#                   "const": "Berbers"
#                },
#                {
#                   "const": "Copts"
#                },
#                {
#                   "const": "Egyptians"
#                },
#                {
#                   "const": "Fur"
#                },
#                {
#                   "const": "Maghrebis"
#                },
#                {
#                   "const": "Nubians"
#                },
#                {
#                   "const": "Tuareg"
#                },
#                {
#                   "const": "Zaghawa"
#                },
#                {
#                   "const": "Toubou"
#                },
#                {
#                   "const": "Alur"
#                },
#                {
#                   "const": "Anuak"
#                },
#                {
#                   "const": "Acholi"
#                },
#                {
#                   "const": "Banyoro"
#                },
#                {
#                   "const": "Chagga"
#                },
#                {
#                   "const": "Dinka"
#                },
#                {
#                   "const": "Ganda"
#                },
#                {
#                   "const": "Langi"
#                },
#                {
#                   "const": "Hutu"
#                },
#                {
#                   "const": "Kamba"
#                },
#                {
#                   "const": "Kalenjin"
#                },
#                {
#                   "const": "Kikuyu"
#                },
#                {
#                   "const": "Kwama"
#                },
#                {
#                   "const": "Lugbara"
#                },
#                {
#                   "const": "Luo"
#                },
#                {
#                   "const": "Luhya"
#                },
#                {
#                   "const": "Maasai"
#                },
#                {
#                   "const": "Makonde"
#                },
#                {
#                   "const": "Ameru"
#                },
#                {
#                   "const": "Nuer"
#                },
#                {
#                   "const": "Samburu"
#                },
#                {
#                   "const": "Shilluk"
#                },
#                {
#                   "const": "Swahili"
#                },
#                {
#                   "const": "Tutsi"
#                },
#                {
#                   "const": "Twa"
#                },
#                {
#                   "const": "Aka"
#                },
#                {
#                   "const": "Baka"
#                },
#                {
#                   "const": "Banda"
#                },
#                {
#                   "const": "Chewa"
#                },
#                {
#                   "const": "Chokwe"
#                },
#                {
#                   "const": "Ef? 40"
#                },
#                {
#                   "const": "Kongo"
#                },
#                {
#                   "const": "Kanuri"
#                },
#                {
#                   "const": "Lingala"
#                },
#                {
#                   "const": "Luba"
#                },
#                {
#                   "const": "Kotoko"
#                },
#                {
#                   "const": "Mbunda"
#                },
#                {
#                   "const": "Mbundu"
#                },
#                {
#                   "const": "Moghamo"
#                },
#                {
#                   "const": "Mongo"
#                },
#                {
#                   "const": "Ngamambo"
#                },
#                {
#                   "const": "Ovimbundu"
#                },
#                {
#                   "const": "Sara"
#                },
#                {
#                   "const": "Sua"
#                },
#                {
#                   "const": "Zande"
#                },
#                {
#                   "const": "Zaghawa"
#                },
#                {
#                   "const": "Akan"
#                },
#                {
#                   "const": "Aku"
#                },
#                {
#                   "const": "Bambara"
#                },
#                {
#                   "const": "Basaa"
#                },
#                {
#                   "const": "Bassa"
#                },
#                {
#                   "const": "BetiPahuin"
#                },
#                {
#                   "const": "Biafada"
#                },
#                {
#                   "const": "Mole-Dagbani"
#                },
#                {
#                   "const": "Dendi"
#                },
#                {
#                   "const": "Edo"
#                },
#                {
#                   "const": "Efik"
#                },
#                {
#                   "const": "Eket"
#                },
#                {
#                   "const": "Esan"
#                },
#                {
#                   "const": "Ewe"
#                },
#                {
#                   "const": "Fon"
#                },
#                {
#                   "const": "Fulani"
#                },
#                {
#                   "const": "Ga"
#                },
#                {
#                   "const": "Gwari"
#                },
#                {
#                   "const": "Hausa"
#                },
#                {
#                   "const": "Igbo"
#                },
#                {
#                   "const": "Ijaw"
#                },
#                {
#                   "const": "Jola"
#                },
#                {
#                   "const": "Kanuri"
#                },
#                {
#                   "const": "Mandingo"
#                },
#                {
#                   "const": "Mande South"
#                },
#                {
#                   "const": "Marka"
#                },
#                {
#                   "const": "Mende"
#                },
#                {
#                   "const": "Papel"
#                },
#                {
#                   "const": "Serer"
#                },
#                {
#                   "const": "Songhai"
#                },
#                {
#                   "const": "Tiv"
#                },
#                {
#                   "const": "Urhobo"
#                },
#                {
#                   "const": "Wolof"
#                },
#                {
#                   "const": "Yoruba"
#                },
#                {
#                   "const": "Zarma"
#                },
#                {
#                   "const": "Afrikaner"
#                },
#                {
#                   "const": "Ovambo"
#                },
#                {
#                   "const": "Bemba"
#                },
#                {
#                   "const": "CapeColoured"
#                },
#                {
#                   "const": "Herero"
#                },
#                {
#                   "const": "Himba"
#                },
#                {
#                   "const": "Goffal"
#                },
#                {
#                   "const": "Kalanga"
#                },
#                {
#                   "const": "Khoikhoi"
#                },
#                {
#                   "const": "Lemba"
#                },
#                {
#                   "const": "Makua"
#                },
#                {
#                   "const": "Nambya"
#                },
#                {
#                   "const": "North Ndebele"
#                },
#                {
#                   "const": "San"
#                },
#                {
#                   "const": "South Ndebele"
#                },
#                {
#                   "const": "Shona"
#                },
#                {
#                   "const": "Sotho"
#                },
#                {
#                   "const": "Swazi"
#                },
#                {
#                   "const": "Tonga"
#                },
#                {
#                   "const": "Tsonga"
#                },
#                {
#                   "const": "Tswana"
#                },
#                {
#                   "const": "Venda"
#                },
#                {
#                   "const": "Xhosa"
#                },
#                {
#                   "const": "Yeyi"
#                },
#                {
#                   "const": "Zulu"
#                },
#                {
#                   "const": "Afar"
#                },
#                {
#                   "const": "Agaw"
#                },
#                {
#                   "const": "Amhara"
#                },
#                {
#                   "const": "Beja"
#                },
#                {
#                   "const": "Bilen"
#                },
#                {
#                   "const": "Gurage"
#                },
#                {
#                   "const": "Oromo"
#                },
#                {
#                   "const": "Saho"
#                },
#                {
#                   "const": "Sidama"
#                },
#                {
#                   "const": "Somali"
#                },
#                {
#                   "const": "Tigray-Tigrinya"
#                },
#                {
#                   "const": "Tigre"
#                }
#             ]
#          },
#          "mbirthcountry": {
#             "allOf": [
#                {
#                   "description": "In which country were you born?"
#                },
#                {
#                   "$ref": "countries.json"
#                }
#             ]
#          },
#          "mlanguage": {
#             "type": "string",
#             "description": "What is your mother's native language?",
#             "oneOf": [
#                {
#                   "const": "english"
#                },
#                {
#                   "const": "afrikaans"
#                },
#                {
#                   "const": "nd?l?isindebele)"
#                },
#                {
#                   "const": "xhosa (isixhosa)"
#                },
#                {
#                   "const": "zoulou (isizulu)"
#                },
#                {
#                   "const": "arabic"
#                },
#                {
#                   "const": "Portuguese"
#                },
#                {
#                   "const": "frensh"
#                },
#                {
#                   "const": "tswana"
#                },
#                {
#                   "const": "moray"
#                },
#                {
#                   "const": "dioula"
#                },
#                {
#                   "const": "peul"
#                },
#                {
#                   "const": "kirundi"
#                },
#                {
#                   "const": "somali"
#                },
#                {
#                   "const": "afar"
#                },
#                {
#                   "const": "amharic"
#                },
#                {
#                   "const": "espanish"
#                },
#                {
#                   "const": "ha?en"
#                },
#                {
#                   "const": "swahili"
#                },
#                {
#                   "const": "sesotho"
#                },
#                {
#                   "const": "malgache"
#                },
#                {
#                   "const": "chichewa"
#                },
#                {
#                   "const": "bambara"
#                },
#                {
#                   "const": "sango"
#                },
#                {
#                   "const": "kinyarwanda"
#                },
#                {
#                   "const": "creaole seychelle"
#                },
#                {
#                   "const": "swati"
#                },
#                {
#                   "const": "shona"
#                },
#                {
#                   "const": "sindebele"
#                },
#                {
#                   "const": "tswana (setswana)"
#                },
#                {
#                   "const": "siswati (siSwati)"
#                },
#                {
#                   "const": "venda (tshivenda)"
#                },
#                {
#                   "const": "tsonga (xitsonga)"
#                }
#             ]
#          },
#          "methnicity": {
#             "type": "string",
#             "description": "What is your mother's ethnic or tribal affiliation?",
#             "oneOf": [
#                {
#                   "const": "Berbers"
#                },
#                {
#                   "const": "Copts"
#                },
#                {
#                   "const": "Egyptians"
#                },
#                {
#                   "const": "Fur"
#                },
#                {
#                   "const": "Maghrebis"
#                },
#                {
#                   "const": "Nubians"
#                },
#                {
#                   "const": "Tuareg"
#                },
#                {
#                   "const": "Zaghawa"
#                },
#                {
#                   "const": "Toubou"
#                },
#                {
#                   "const": "Alur"
#                },
#                {
#                   "const": "Anuak"
#                },
#                {
#                   "const": "Acholi"
#                },
#                {
#                   "const": "Banyoro"
#                },
#                {
#                   "const": "Chagga"
#                },
#                {
#                   "const": "Dinka"
#                },
#                {
#                   "const": "Ganda"
#                },
#                {
#                   "const": "Langi"
#                },
#                {
#                   "const": "Hutu"
#                },
#                {
#                   "const": "Kamba"
#                },
#                {
#                   "const": "Kalenjin"
#                },
#                {
#                   "const": "Kikuyu"
#                },
#                {
#                   "const": "Kwama"
#                },
#                {
#                   "const": "Lugbara"
#                },
#                {
#                   "const": "Luo"
#                },
#                {
#                   "const": "Luhya"
#                },
#                {
#                   "const": "Maasai"
#                },
#                {
#                   "const": "Makonde"
#                },
#                {
#                   "const": "Ameru"
#                },
#                {
#                   "const": "Nuer"
#                },
#                {
#                   "const": "Samburu"
#                },
#                {
#                   "const": "Shilluk"
#                },
#                {
#                   "const": "Swahili"
#                },
#                {
#                   "const": "Tutsi"
#                },
#                {
#                   "const": "Twa"
#                },
#                {
#                   "const": "Aka"
#                },
#                {
#                   "const": "Baka"
#                },
#                {
#                   "const": "Banda"
#                },
#                {
#                   "const": "Chewa"
#                },
#                {
#                   "const": "Chokwe"
#                },
#                {
#                   "const": "Ef? 40"
#                },
#                {
#                   "const": "Kongo"
#                },
#                {
#                   "const": "Kanuri"
#                },
#                {
#                   "const": "Lingala"
#                },
#                {
#                   "const": "Luba"
#                },
#                {
#                   "const": "Kotoko"
#                },
#                {
#                   "const": "Mbunda"
#                },
#                {
#                   "const": "Mbundu"
#                },
#                {
#                   "const": "Moghamo"
#                },
#                {
#                   "const": "Mongo"
#                },
#                {
#                   "const": "Ngamambo"
#                },
#                {
#                   "const": "Ovimbundu"
#                },
#                {
#                   "const": "Sara"
#                },
#                {
#                   "const": "Sua"
#                },
#                {
#                   "const": "Zande"
#                },
#                {
#                   "const": "Zaghawa"
#                },
#                {
#                   "const": "Akan"
#                },
#                {
#                   "const": "Aku"
#                },
#                {
#                   "const": "Bambara"
#                },
#                {
#                   "const": "Basaa"
#                },
#                {
#                   "const": "Bassa"
#                },
#                {
#                   "const": "BetiPahuin"
#                },
#                {
#                   "const": "Biafada"
#                },
#                {
#                   "const": "Mole-Dagbani"
#                },
#                {
#                   "const": "Dendi"
#                },
#                {
#                   "const": "Edo"
#                },
#                {
#                   "const": "Efik"
#                },
#                {
#                   "const": "Eket"
#                },
#                {
#                   "const": "Esan"
#                },
#                {
#                   "const": "Ewe"
#                },
#                {
#                   "const": "Fon"
#                },
#                {
#                   "const": "Fulani"
#                },
#                {
#                   "const": "Ga"
#                },
#                {
#                   "const": "Gwari"
#                },
#                {
#                   "const": "Hausa"
#                },
#                {
#                   "const": "Igbo"
#                },
#                {
#                   "const": "Ijaw"
#                },
#                {
#                   "const": "Jola"
#                },
#                {
#                   "const": "Kanuri"
#                },
#                {
#                   "const": "Mandingo"
#                },
#                {
#                   "const": "Mande South"
#                },
#                {
#                   "const": "Marka"
#                },
#                {
#                   "const": "Mende"
#                },
#                {
#                   "const": "Papel"
#                },
#                {
#                   "const": "Serer"
#                },
#                {
#                   "const": "Songhai"
#                },
#                {
#                   "const": "Tiv"
#                },
#                {
#                   "const": "Urhobo"
#                },
#                {
#                   "const": "Wolof"
#                },
#                {
#                   "const": "Yoruba"
#                },
#                {
#                   "const": "Zarma"
#                },
#                {
#                   "const": "Afrikaner"
#                },
#                {
#                   "const": "Ovambo"
#                },
#                {
#                   "const": "Bemba"
#                },
#                {
#                   "const": "CapeColoured"
#                },
#                {
#                   "const": "Herero"
#                },
#                {
#                   "const": "Himba"
#                },
#                {
#                   "const": "Goffal"
#                },
#                {
#                   "const": "Kalanga"
#                },
#                {
#                   "const": "Khoikhoi"
#                },
#                {
#                   "const": "Lemba"
#                },
#                {
#                   "const": "Makua"
#                },
#                {
#                   "const": "Nambya"
#                },
#                {
#                   "const": "North Ndebele"
#                },
#                {
#                   "const": "San"
#                },
#                {
#                   "const": "South Ndebele"
#                },
#                {
#                   "const": "Shona"
#                },
#                {
#                   "const": "Sotho"
#                },
#                {
#                   "const": "Swazi"
#                },
#                {
#                   "const": "Tonga"
#                },
#                {
#                   "const": "Tsonga"
#                },
#                {
#                   "const": "Tswana"
#                },
#                {
#                   "const": "Venda"
#                },
#                {
#                   "const": "Xhosa"
#                },
#                {
#                   "const": "Yeyi"
#                },
#                {
#                   "const": "Zulu"
#                },
#                {
#                   "const": "Afar"
#                },
#                {
#                   "const": "Agaw"
#                },
#                {
#                   "const": "Amhara"
#                },
#                {
#                   "const": "Beja"
#                },
#                {
#                   "const": "Bilen"
#                },
#                {
#                   "const": "Gurage"
#                },
#                {
#                   "const": "Oromo"
#                },
#                {
#                   "const": "Saho"
#                },
#                {
#                   "const": "Sidama"
#                },
#                {
#                   "const": "Somali"
#                },
#                {
#                   "const": "Tigray-Tigrinya"
#                },
#                {
#                   "const": "Tigre"
#                }
#             ]
#          },
#          "smoke_collectdate": {
#             "type": "string",
#             "description": "Collection date of smoking status information:"
#          },
#          "smoke_100": {
#             "type": "string",
#             "description": "Have you smoked at least 100 cigarettes in your entire life?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't Know"
#                }
#             ]
#          },
#          "smoke_age": {
#             "type": "integer",
#             "description": "How old were you when you first started smoking cigarettes?",
#             "$unit": "Provide age in years"
#          },
#          "kidney_fail": {
#             "type": "string",
#             "description": "Has a doctor or healthcare worker ever told you that you had kidney failure?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "kidneys_well": {
#             "type": "string",
#             "description": "If Yes, are one or both working well now?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "renal_dialysis": {
#             "type": "string",
#             "description": "Are you currently on renal dialysis?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "smoke_perday": {
#             "type": "integer",
#             "description": "On the days that you smoke, on average, how many cigarettes do you smoke?\n<bold><u><i>OR</bold></u></i>\nIf you are a former smoker, on the days that you smoked, on average, how many cigarettes did you smoke?",
#             "$unit": "Provide average number of cigarettes per day"
#          },
#          "kidney_transplant": {
#             "type": "string",
#             "description": "Have you ever had a kidney transplant?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "smoke_dayspermonth": {
#             "type": "integer",
#             "description": "Over the past 30 days, on how many <u>days</u> did you smoke?\n<bold><u><i>OR</bold></u></i>\nIf you are a former smoker, on average, on how many <u>days</u> did you smoke in a month?",
#             "$unit": "<strong>Every</strong> day smokers or former <strong>every</strong> day smokers should complete with '30'."
#          },
#          "kidney_family": {
#             "type": "string",
#             "description": "Has anyone in your family either had kidney disease or died from it?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "kidney_lowfunc": {
#             "type": "string",
#             "description": "Has a doctor ever told you that your kidneys have low function?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "kidney_disease": {
#             "type": "string",
#             "description": "Has a doctor or healthcare worker told you that you have a kidney disease?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "atrial_fib": {
#             "type": "string",
#             "description": "Have you been told you have/had a heart rhythm problem called atrial fibrillation?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't Know"
#                }
#             ]
#          },
#          "alcohol_any": {
#             "type": "string",
#             "description": "In your entire life, have you had at least 1 drink of any kind of alcohol?\n<i>(not counting small tastes or sips)</i>",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                }
#             ]
#          },
#          "alcohol_age": {
#             "type": "integer",
#             "description": " About how old were you when you first started drinking alcohol?\n<i>(not counting small tastes or sips)</i>",
#             "$unit": "Provide age in years."
#          },
#          "pacemaker": {
#             "type": "string",
#             "description": "Have you got a permanet pacemaker inserted?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "alcohol_30days": {
#             "type": "integer",
#             "description": "During the past 30 days, on how <u>many days</u> did you drink one or more drinks of an alcoholic beverage?",
#             "$unit": "days"
#          },
#          "alcohol_numdrinks": {
#             "type": "integer",
#             "description": "On the days that you drank during the past 30 days, how <u>many drinks</u> did you usually have each day? \n\n<i>(Count as a drink a can or bottle of beer; a wine cooler or a glass of wine, champagne, or sherry; a shot of liquor or a mixed drink or cocktail.)</i>"
#          },
#          "rheumatic_fever": {
#             "type": "string",
#             "description": "Has a doctor ever said you had rheumatic fever (inflammatory rheumatisim)?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "stroke": {
#             "type": "string",
#             "description": "Were you ever told by a doctor or healthcare worker you had a stroke?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "tia": {
#             "type": "string",
#             "description": "Were you ever told by a doctor or healthcare worker you had a TIA, ministroke, or transient ischemic attack?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "hiv_tested": {
#             "type": "string",
#             "description": "Have you ever been tested for HIV?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                },
#                {
#                   "const": "Refused"
#                }
#             ]
#          },
#          "hiv_recent": {
#             "type": "string",
#             "description": "When did you have your most recent HIV  test?"
#          },
#          "hiv_tx": {
#             "type": "string",
#             "description": "Are you currently on HIV treatment?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                },
#                {
#                   "const": "Refused"
#                }
#             ]
#          },
#          "cancer": {
#             "type": "string",
#             "description": "Have you ever had cancer?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                }
#             ]
#          },
#          "cancer_surgery1": {
#             "type": "string",
#             "description": "Did you have surgery for this cancer?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "cancer_treat1": {
#             "type": "string",
#             "description": "What kind of treatment did you have?",
#             "oneOf": [
#                {
#                   "const": "Chemotherapy"
#                },
#                {
#                   "const": "Hormonal Therapy"
#                },
#                {
#                   "const": "Radiotherapy"
#                },
#                {
#                   "const": "Other therapy"
#                }
#             ]
#          },
#          "tb": {
#             "type": "string",
#             "description": "Has a doctor or healthworker ever told you that you have tuberculosis (TB)?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                },
#                {
#                   "const": "Refused"
#                }
#             ]
#          },
#          "malaria": {
#             "type": "string",
#             "description": "Has a doctor or healthworker ever told you that you have malaria?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          },
#          "sleepingsick": {
#             "type": "string",
#             "description": "Has a doctor or healthworker ever told you that you have sleeping sickness?",
#             "oneOf": [
#                {
#                   "const": "Yes"
#                },
#                {
#                   "const": "No"
#                },
#                {
#                   "const": "Don't know"
#                }
#             ]
#          }
#       }
#    }
# }

# %%
cl.runQuery('select sex, count(*) from bigquery.cineca.syn_Africa_H3ABioNet_v1 group by sex',returnType='dataframe')
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
#        sex  _col1
# 0   Female     28
# 1     Male     19
# 2  Refused     27
# 3    Other     26

# %% [markdown]
# #### Load the caDSR list of countries

# %%
import json
 
# Opening JSON file
f = open("./schema generation/cadsr_countries.json")
 
# returns JSON object as
# a dictionary
data = json.load(f)
 
# Iterating through the json
# list
cadsr_countries = [ i['const'] for i in data]
print(countries)
 
# Closing file
f.close()
# Out:
# ['Falkland Islands', 'Faroe Islands', 'France', 'France, Metropolitan', 'Gabon', 'United Kingdom', 'Grenada', 'Georgia', 'French Guiana', 'Guernsey', 'Ghana', 'Gibraltar', 'Greenland', 'Gambia, The', 'Guinea', 'Guadeloupe', 'Equatorial Guinea', 'Greece', 'South Georgia and the Islands', 'Guatemala', 'Guam', 'Guinea-Bissau', 'Guyana', 'Hong Kong', 'Heard Island and McDonald Islands', 'Honduras', 'Croatia', 'Haiti', 'Hungary', 'Indonesia', 'Ireland', 'Israel', 'Isle of Man', 'India', 'British Indian Ocean Territory', 'Iraq', 'Iran', 'Iceland', 'Italy', 'Jersey', 'Jamaica', 'Jordan', 'Japan', 'Kenya', 'Kyrgyzstan', 'Cambodia', 'Kiribati', 'Comoros', 'Saint Kitts and Nevis', 'Korea, North', 'Korea, South', 'Kuwait', 'Cayman Islands', 'Kazakhstan', 'Laos', 'Lebanon', 'Saint Lucia', 'Liechtenstein', 'Sri Lanka', 'Liberia', 'Lesotho', 'Lithuania', 'Luxembourg', 'Latvia', 'Libya', 'Morocco', 'Monaco', 'Moldova', 'Madagascar', 'Marshall Islands', 'Micronesia, Federated States of', 'Macedonia', 'Mali', 'Myanmar', 'Mongolia', 'Macau', 'Northern Mariana Islands', 'Martinique', 'Mauritania', 'Montserrat', 'Malta', 'Mauritius', 'Maldives', 'Malawi', 'Mexico', 'Malaysia', 'Mozambique', 'Namibia', 'New Caledonia', 'Niger', 'Norfolk Island', 'Nigeria', 'Nicaragua', 'Netherlands', 'Norway', 'Nepal', 'Nauru', 'Niue', 'New Zealand', 'Oman', 'Panama', 'Peru', 'French Polynesia', 'Papua New Guinea', 'Philippines', 'Pakistan', 'Poland', 'Saint Pierre and Miquelon', 'Pitcairn Islands', 'Puerto Rico', 'Portugal', 'Palau', 'Paraguay', 'Qatar', 'Romania', 'Russia', 'Reunion', 'Rwanda', 'Saudi Arabia', 'Solomon Islands', 'Seychelles', 'Sudan', 'Sweden', 'Singapore', 'Saint Helena', 'Slovenia', 'Svalbard', 'Slovakia', 'Sierra Leone', 'San Marino', 'Senegal', 'Timor-Leste', 'Somalia', 'Suriname', 'Sao Tome and Principe', 'El Salvador', 'Syria', 'Swaziland', 'Chad', 'French Southern and Antarctic Lands', 'Togo', 'Thailand', 'Tajikistan', 'Tokelau', 'Turkmenistan', 'Tunisia', 'Tonga', 'Turkey', 'Trinidad and Tobago', 'Tuvalu', 'Taiwan', 'Tanzania', 'Ukraine', 'Uganda', 'United States Minor Outlying Islands', 'United States', 'Uruguay', 'Uzbekistan', 'Holy See (Vatican City)', 'Saint Vincent and the Grenadines', 'Virgin Islands (UK)', 'Virgin Islands (US)', 'Vietnam', 'Vanuatu', 'Wallis and Futuna', 'Western Samoa', 'Yemen', 'Mayotte', 'South Africa', 'Zambia', 'Congo, Democratic Republic of the', 'Zimbabwe', 'United Arab Emirates', 'Afghanistan', 'Antigua and Barbuda', 'Anguilla', 'Albania', 'Armenia', 'Netherland Antilles', 'Angola', 'Antarctica', 'Argentina', 'American Samoa', 'Austria', 'Australia', 'Aruba', 'Barbados', 'Bangladesh', 'Belgium', 'Burkina Faso', 'Bulgaria', 'Bahrain', 'Burundi', 'Benin', 'Palmyra Atoll', 'Navassa Island', 'Midway Islands', 'Kosovo', 'Kingman Reef', 'Juan de Nova Island', 'Jarvis Island', 'Jan Mayen', 'Howland Island', 'Glorioso Islands', 'Gaza Strip', 'Europa Island', 'Coral Sea Islands', 'Clipperton Island', 'Burma', 'Brunei', 'Bassas da India', 'Baker Island', 'Ashmore and Cartier Islands', 'Congo, Republic of the', "Cote d'Ivoire", 'Zaire', 'West Bank', 'Wake Island', 'Virgin Islands', 'Spratly Islands', 'Serbia', 'Samoa', 'Saint Martin', 'Saint Barthelemy', 'Paracel Islands', 'Turks and Caicos Islands', 'Venezuela', 'Ascension Island', 'Andorra', 'Bermuda', 'Bolivia', 'Brazil', 'Bahamas, The', 'Bhutan', 'Bouvet Island', 'Botswana', 'Belarus', 'Belize', 'Canada', 'Bosnia and Herzegovina', 'Azerbaijan', 'Central African Republic', 'Switzerland', 'Cook Islands', 'Chile', 'Cameroon', 'China', 'Colombia', 'Cocos (Keeling) Islands', 'Costa Rica', 'Cuba', 'Cape Verde', 'Christmas Island', 'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Denmark', 'Dominica', 'Dominican Republic', 'Algeria', 'Ecuador', 'Estonia', 'Egypt', 'Western Sahara', 'Eritrea', 'Spain', 'Ethiopia', 'Finland', 'Fiji']

# %% [markdown]
# #### Load the Cineca country list

# %%
# Opening JSON file
f = open("./schema generation/bigquery.cineca.syn_Africa_H3ABioNet_v3.json")
 
# returns JSON object as
# a dictionary
data = json.load(f)
 
# Iterating through the json
# list
cineca_countries = [ i['const'] for i in data["def"]["country"]["oneOf"]]
print(cineca_countries)
 
# Closing file
f.close()
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil', 'British Indian Ocean Terr', 'Brunei', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Falkland Islands', 'Faroe Islands', 'Fiji Islands', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'French Southern territori', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heard Island and McDonald', 'Holy See (Vatican City St', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakstan', 'Kenya', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Macedonia', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia', 'Moldova', 'Monaco', 'Mongolia', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'Netherlands Antilles', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'North Korea', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Pierre and Miquelon', 'Saint Vincent and the Gre', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'South Georgia and the Sou', 'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Svalbard and Jan Mayen', 'Swaziland', 'Sweden', 'Switzerland', 'Syria', 'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'United States Minor Outly', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam', 'Virgin Islands', 'Virgin Islands', 'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe']

# %%
difference_1 = set(cineca_countries).difference(set(cadsr_countries))
difference_2 = set(cadsr_countries).difference(set(cineca_countries))

list_difference = list(difference_1.union(difference_2))
print(list_difference)
# Out:
# ['Heard Island and McDonald', 'Saint Vincent and the Gre', 'France, Metropolitan', 'British Indian Ocean Territory', 'West Bank', 'South Sudan', 'Virgin Islands (US)', 'Yugoslavia', 'Serbia', 'Korea, North', 'Congo', 'Paracel Islands', 'Svalbard', 'Gambia, The', 'Congo, Republic of the', 'Russian Federation', 'Western Samoa', 'Kingman Reef', 'Baker Island', 'Juan de Nova Island', 'Spratly Islands', 'Ashmore and Cartier Islands', 'Fiji', 'Pitcairn', 'United States Minor Outlying Islands', 'Netherlands Antilles', 'Palestine', 'Jan Mayen', 'Libya', 'Wake Island', 'Jersey', 'Heard Island and McDonald Islands', 'Timor-Leste', 'North Korea', 'Kazakstan', 'Palmyra Atoll', 'Gaza Strip', 'Europa Island', 'Saint Vincent and the Grenadines', 'South Georgia and the Islands', 'South Georgia and the Sou', 'Congo, Democratic Republic of the', 'Holy See (Vatican City St', 'Zaire', 'Bassas da India', 'Midway Islands', 'Korea, South', 'British Indian Ocean Terr', 'Micronesia, Federated States of', 'Howland Island', 'Saint Barthelemy', 'South Korea', 'Virgin Islands (UK)', 'Glorioso Islands', 'Jarvis Island', 'Micronesia', 'Kosovo', 'United States Minor Outly', 'French Southern and Antarctic Lands', 'Coral Sea Islands', 'Saint Martin', 'Svalbard and Jan Mayen', 'Macau', 'Clipperton Island', 'Bahamas, The', 'East Timor', 'Holy See (Vatican City)', 'Pitcairn Islands', 'Netherland Antilles', 'French Southern territori', 'Macao', 'Kazakhstan', 'Isle of Man', 'Gambia', 'Fiji Islands', 'Burma', 'Guernsey', 'Russia', 'Bahamas', 'Libyan Arab Jamahiriya', 'Ascension Island', 'Navassa Island']

# %%
difference_1
# Out:
# {'Bahamas',
#  'British Indian Ocean Terr',
#  'Congo',
#  'East Timor',
#  'Fiji Islands',
#  'French Southern territori',
#  'Gambia',
#  'Heard Island and McDonald',
#  'Holy See (Vatican City St',
#  'Kazakstan',
#  'Libyan Arab Jamahiriya',
#  'Macao',
#  'Micronesia',
#  'Netherlands Antilles',
#  'North Korea',
#  'Palestine',
#  'Pitcairn',
#  'Russian Federation',
#  'Saint Vincent and the Gre',
#  'South Georgia and the Sou',
#  'South Korea',
#  'South Sudan',
#  'Svalbard and Jan Mayen',
#  'United States Minor Outly',
#  'Yugoslavia'}

# %%
difference_2
# Out:
# {'Ascension Island',
#  'Ashmore and Cartier Islands',
#  'Bahamas, The',
#  'Baker Island',
#  'Bassas da India',
#  'British Indian Ocean Territory',
#  'Burma',
#  'Clipperton Island',
#  'Congo, Democratic Republic of the',
#  'Congo, Republic of the',
#  'Coral Sea Islands',
#  'Europa Island',
#  'Fiji',
#  'France, Metropolitan',
#  'French Southern and Antarctic Lands',
#  'Gambia, The',
#  'Gaza Strip',
#  'Glorioso Islands',
#  'Guernsey',
#  'Heard Island and McDonald Islands',
#  'Holy See (Vatican City)',
#  'Howland Island',
#  'Isle of Man',
#  'Jan Mayen',
#  'Jarvis Island',
#  'Jersey',
#  'Juan de Nova Island',
#  'Kazakhstan',
#  'Kingman Reef',
#  'Korea, North',
#  'Korea, South',
#  'Kosovo',
#  'Libya',
#  'Macau',
#  'Micronesia, Federated States of',
#  'Midway Islands',
#  'Navassa Island',
#  'Netherland Antilles',
#  'Palmyra Atoll',
#  'Paracel Islands',
#  'Pitcairn Islands',
#  'Russia',
#  'Saint Barthelemy',
#  'Saint Martin',
#  'Saint Vincent and the Grenadines',
#  'Serbia',
#  'South Georgia and the Islands',
#  'Spratly Islands',
#  'Svalbard',
#  'Timor-Leste',
#  'United States Minor Outlying Islands',
#  'Virgin Islands (UK)',
#  'Virgin Islands (US)',
#  'Wake Island',
#  'West Bank',
#  'Western Samoa',
#  'Zaire'}
