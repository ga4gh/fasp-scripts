# %% [markdown]
# The following is a description via the Search API of data made available for. The description was curated in this case by the Search team and is not intended to be definitive. It serves to illustrate how Search can provide, in *JSON Schema* form, a rich machine readable description of a data source.

# %%
from fasp.search import DiscoverySearchClient
cl = DiscoverySearchClient('https://ga4gh-search-adapter-presto-public.prod.dnastack.com')
ti = cl.listTableInfo('dbgap_demo.scr_ega.scr_egapancreatic_sample_multi', verbose=True)
# Out:
# _Schema for tabledbgap_demo.scr_ega.scr_egapancreatic_sample_multi_
# {'data_model': {'$id': 'scr_EGApancreatic_sample.data_dict.xml.scr_EGApancreatic_sample',
#                 '$schema': 'http://json-schema.org/draft-07/schema',
#                 'properties': {'bam_file': {'description': 'Relative path for '
#                                                            'alignment file',
#                                             'type': 'string'},
#                                'disease_site': {'description': 'body site '
#                                                                'sample was '
#                                                                'taken from',
#                                                 'oneOf': [{'const': 'Liver_Metastasis'},
#                                                           {'const': 'Lung_Metastasis'},
#                                                           {'const': 'Lung_Normal'},
#                                                           {'const': 'Lymph_Node_Metastasis'},
#                                                           {'const': 'Muscle_Normal'},
#                                                           {'const': 'Normal '
#                                                                     'Pancreas'},
#                                                           {'const': 'Pancreas_Primary_Tumor'},
#                                                           {'const': 'Peritoneal_Metastasis'},
#                                                           {'const': 'Skin_Normal'},
#                                                           {'const': 'Spleen_Normal'}],
#                                                 'type': 'string'},
#                                'ena-checklist': {'description': 'Minimal '
#                                                                 'information '
#                                                                 'checklist '
#                                                                 'used in this '
#                                                                 'study',
#                                                  'type': 'string'},
#                                'gender': {'description': 'Sex of participant',
#                                           'oneOf': [{'const': 'female'},
#                                                     {'const': 'male'}],
#                                           'type': 'string'},
#                                'phenotype': {'description': 'Site independent '
#                                                             'tissue type',
#                                              'oneOf': [{'const': 'lung tissue'},
#                                                        {'const': 'muscle '
#                                                                  'tissue'},
#                                                        {'const': 'pancreatic '
#                                                                  'adenocarcinoma'},
#                                                        {'const': 'skin tissue'},
#                                                        {'const': 'spleen '
#                                                                  'tissue'}],
#                                              'type': 'string'},
#                                'sample_primary_id': {'description': 'De-identified '
#                                                                     'sample ID',
#                                                      'type': 'string'},
#                                'sample_submitter_id': {'description': 'Sample '
#                                                                       'id used '
#                                                                       'locally '
#                                                                       'by '
#                                                                       'submitter',
#                                                        'type': 'string'},
#                                'subject_id': {'description': 'Subject Id used '
#                                                              'locally by '
#                                                              'submitter',
#                                               'type': 'string'}},
#                 'type': 'object'},
#  'name': 'dbgap_demo.scr_ega.scr_egapancreatic_sample_multi'}

# %% [markdown]
# Such information might simply used by an investigator interested in the dataset to inform them about how the data is structured, allowing them, for example to perform simple transformations such as those illustrated in mappings.ipynb. In this case Search serve a useful purpose in making the data well described, available and queryable.
#
# Alternatively, more sophisticated uses of these metadata would also be possible.
#
# Additionally, where data follow particular standards Search has the capability to refer to the standard used.
#
# The following example includes additional data types including numeric types specified by unit.

# %%
gecco_subject = cl.listTableInfo('dbgap_demo.scr_gecco_susceptibility.subject_phenotypes_multi')
# Out:
# _Schema for tabledbgap_demo.scr_gecco_susceptibility.subject_phenotypes_multi_
# {'data_model': {'$id': 'phs001554.v1.pht007609.v1.GECCO_CRC_Susceptibility_Subject_Phenotypes',
#                 '$schema': 'http://json-schema.org/draft-07/schema',
#                 'description': 'Scrambled version of subject data for '
#                                'phs001554 Colorectal cancer susceptibility '
#                                'study.',
#                 'properties': {'affection_status': {'description': 'Case '
#                                                                    'control '
#                                                                    'status of '
#                                                                    'the '
#                                                                    'subject '
#                                                                    'for '
#                                                                    'colorectal '
#                                                                    'cancer',
#                                                     'oneOf': [{'const': 'Case'},
#                                                               {'const': 'Control'}],
#                                                     'type': 'string'},
#                                'age': {'$comment': "UNIT 'Years'",
#                                        'description': 'Participant reference '
#                                                       'age',
#                                        'maximum': 98.0,
#                                        'minimum': 37.0,
#                                        'type': 'number'},
#                                'ethnicity': {'description': 'Ethnicity of '
#                                                             'participant',
#                                              'oneOf': [{'const': 'Unknown'}],
#                                              'type': 'string'},
#                                'race': {'description': 'Race of participant',
#                                         'oneOf': [{'const': 'White'}],
#                                         'type': 'string'},
#                                'sex': {'description': 'Sex of participant',
#                                        'oneOf': [{'const': 'Female'},
#                                                  {'const': 'Male'}],
#                                        'type': 'string'},
#                                'study': {'description': 'Study acronym',
#                                          'oneOf': [{'const': 'CPS-II'},
#                                                    {'const': 'DACHS'},
#                                                    {'const': 'HPFS'},
#                                                    {'const': 'NHS'},
#                                                    {'const': 'PLCO'},
#                                                    {'const': 'WHI'}],
#                                          'type': 'string'},
#                                'subject_id': {'description': 'De-identified '
#                                                              'subject ID',
#                                               'type': 'string'}},
#                 'type': 'object'},
#  'description': 'Scrambled version of subject data for phs001554 Colorectal '
#                 'cancer susceptibility study.',
#  'name': 'dbgap_demo.scr_gecco_susceptibility.subject_phenotypes_multi'}

# %% [markdown]
# ### A more complex schema
# What else could be said about this?

# %%
hcaSchema = cl.listTableInfo('search_cloud.human_cell_atlas.hca')
# Out:
# _Schema for tablesearch_cloud.human_cell_atlas.hca_
# {'data_model': {'$id': 'https://ga4gh-search-adapter-presto-public.prod.dnastack.com/table/search_cloud.human_cell_atlas.hca/info',
#                 '$schema': 'http://json-schema.org/draft-07/schema#',
#                 'description': 'Automatically generated schema',
#                 'properties': {'bundles': {'$comment': 'array[object]',
#                                            'items': {'$comment': 'row(string,string)',
#                                                      'properties': {'bundleUuid': {'$comment': 'varchar',
#                                                                                    'format': 'varchar',
#                                                                                    'type': 'string'},
#                                                                     'bundleVersion': {'$comment': 'varchar',
#                                                                                       'format': 'varchar',
#                                                                                       'type': 'string'}},
#                                                      'type': 'object'},
#                                            'type': 'array'},
#                                'celllines': {'$comment': 'array[object]',
#                                              'items': {'$comment': 'row(array,array,array)',
#                                                        'properties': {'cellLineType': {'$comment': 'array[string]',
#                                                                                        'items': {'$comment': 'varchar',
#                                                                                                  'format': 'varchar',
#                                                                                                  'type': 'string'},
#                                                                                        'type': 'array'},
#                                                                       'id': {'$comment': 'array[string]',
#                                                                              'items': {'$comment': 'varchar',
#                                                                                        'format': 'varchar',
#                                                                                        'type': 'string'},
#                                                                              'type': 'array'},
#                                                                       'modelOrgan': {'$comment': 'array[string]',
#                                                                                      'items': {'$comment': 'varchar',
#                                                                                                'format': 'varchar',
#                                                                                                'type': 'string'},
#                                                                                      'type': 'array'}},
#                                                        'type': 'object'},
#                                              'type': 'array'},
#                                'cellsuspensions': {'$comment': 'array[object]',
#                                                    'items': {'$comment': 'row(array,array,int,array)',
#                                                              'properties': {'organ': {'$comment': 'array[string]',
#                                                                                       'items': {'$comment': 'varchar',
#                                                                                                 'format': 'varchar',
#                                                                                                 'type': 'string'},
#                                                                                       'type': 'array'},
#                                                                             'organPart': {'$comment': 'array[string]',
#                                                                                           'items': {'$comment': 'varchar',
#                                                                                                     'format': 'varchar',
#                                                                                                     'type': 'string'},
#                                                                                           'type': 'array'},
#                                                                             'selectedCellType': {'$comment': 'array[string]',
#                                                                                                  'items': {'$comment': 'varchar',
#                                                                                                            'format': 'varchar',
#                                                                                                            'type': 'string'},
#                                                                                                  'type': 'array'},
#                                                                             'totalCells': {'$comment': 'bigint',
#                                                                                            'format': 'bigint',
#                                                                                            'type': 'int'}},
#                                                              'type': 'object'},
#                                                    'type': 'array'},
#                                'donororganisms': {'$comment': 'array[object]',
#                                                   'items': {'$comment': 'row(array,array,string,array,array,array,array)',
#                                                             'properties': {'biologicalSex': {'$comment': 'array[string]',
#                                                                                              'items': {'$comment': 'varchar',
#                                                                                                        'format': 'varchar',
#                                                                                                        'type': 'string'},
#                                                                                              'type': 'array'},
#                                                                            'disease': {'$comment': 'varchar',
#                                                                                        'format': 'varchar',
#                                                                                        'type': 'string'},
#                                                                            'genusSpecies': {'$comment': 'array[string]',
#                                                                                             'items': {'$comment': 'varchar',
#                                                                                                       'format': 'varchar',
#                                                                                                       'type': 'string'},
#                                                                                             'type': 'array'},
#                                                                            'id': {'$comment': 'array[string]',
#                                                                                   'items': {'$comment': 'varchar',
#                                                                                             'format': 'varchar',
#                                                                                             'type': 'string'},
#                                                                                   'type': 'array'},
#                                                                            'organismAge': {'$comment': 'array[string]',
#                                                                                            'items': {'$comment': 'varchar',
#                                                                                                      'format': 'varchar',
#                                                                                                      'type': 'string'},
#                                                                                            'type': 'array'},
#                                                                            'organismAgeRange': {'$comment': 'array[object]',
#                                                                                                 'items': {'$comment': 'row(number,number)',
#                                                                                                           'properties': {'gte': {'$comment': 'double',
#                                                                                                                                  'format': 'double',
#                                                                                                                                  'type': 'number'},
#                                                                                                                          'lte': {'$comment': 'double',
#                                                                                                                                  'format': 'double',
#                                                                                                                                  'type': 'number'}},
#                                                                                                           'type': 'object'},
#                                                                                                 'type': 'array'},
#                                                                            'organismAgeUnit': {'$comment': 'array[string]',
#                                                                                                'items': {'$comment': 'varchar',
#                                                                                                          'format': 'varchar',
#                                                                                                          'type': 'string'},
#                                                                                                'type': 'array'}},
#                                                             'type': 'object'},
#                                                   'type': 'array'},
#                                'entryid': {'$comment': 'varchar',
#                                            'format': 'varchar',
#                                            'type': 'string'},
#                                'files': {'$comment': 'array[object]',
#                                          'items': {'$comment': 'row(string,string,int,string,string,string,string)',
#                                                    'properties': {'format': {'$comment': 'varchar',
#                                                                              'format': 'varchar',
#                                                                              'type': 'string'},
#                                                                   'name': {'$comment': 'varchar',
#                                                                            'format': 'varchar',
#                                                                            'type': 'string'},
#                                                                   'sha256': {'$comment': 'varchar',
#                                                                              'format': 'varchar',
#                                                                              'type': 'string'},
#                                                                   'size': {'$comment': 'bigint',
#                                                                            'format': 'bigint',
#                                                                            'type': 'int'},
#                                                                   'url': {'$comment': 'varchar',
#                                                                           'format': 'varchar',
#                                                                           'type': 'string'},
#                                                                   'uuid': {'$comment': 'varchar',
#                                                                            'format': 'varchar',
#                                                                            'type': 'string'},
#                                                                   'version': {'$comment': 'varchar',
#                                                                               'format': 'varchar',
#                                                                               'type': 'string'}},
#                                                    'type': 'object'},
#                                          'type': 'array'},
#                                'organoids': {'$comment': 'array[object]',
#                                              'items': {'$comment': 'row(array,array,array)',
#                                                        'properties': {'id': {'$comment': 'array[string]',
#                                                                              'items': {'$comment': 'varchar',
#                                                                                        'format': 'varchar',
#                                                                                        'type': 'string'},
#                                                                              'type': 'array'},
#                                                                       'modelOrgan': {'$comment': 'array[string]',
#                                                                                      'items': {'$comment': 'varchar',
#                                                                                                'format': 'varchar',
#                                                                                                'type': 'string'},
#                                                                                      'type': 'array'},
#                                                                       'modelOrganPart': {'$comment': 'array[string]',
#                                                                                          'items': {'$comment': 'varchar',
#                                                                                                    'format': 'varchar',
#                                                                                                    'type': 'string'},
#                                                                                          'type': 'array'}},
#                                                        'type': 'object'},
#                                              'type': 'array'},
#                                'projects': {'$comment': 'array[object]',
#                                             'items': {'$comment': 'row(array,array,array)',
#                                                       'properties': {'laboratory': {'$comment': 'array[string]',
#                                                                                     'items': {'$comment': 'varchar',
#                                                                                               'format': 'varchar',
#                                                                                               'type': 'string'},
#                                                                                     'type': 'array'},
#                                                                      'projectShortname': {'$comment': 'array[string]',
#                                                                                           'items': {'$comment': 'varchar',
#                                                                                                     'format': 'varchar',
#                                                                                                     'type': 'string'},
#                                                                                           'type': 'array'},
#                                                                      'projectTitle': {'$comment': 'array[string]',
#                                                                                       'items': {'$comment': 'varchar',
#                                                                                                 'format': 'varchar',
#                                                                                                 'type': 'string'},
#                                                                                       'type': 'array'}},
#                                                       'type': 'object'},
#                                             'type': 'array'},
#                                'protocols': {'$comment': 'array[object]',
#                                              'items': {'$comment': 'row(array,array,array,array,array)',
#                                                        'properties': {'assayType': {'$comment': 'array[string]',
#                                                                                     'items': {'$comment': 'varchar',
#                                                                                               'format': 'varchar',
#                                                                                               'type': 'string'},
#                                                                                     'type': 'array'},
#                                                                       'instrumentManufacturerModel': {'$comment': 'array[string]',
#                                                                                                       'items': {'$comment': 'varchar',
#                                                                                                                 'format': 'varchar',
#                                                                                                                 'type': 'string'},
#                                                                                                       'type': 'array'},
#                                                                       'libraryConstructionApproach': {'$comment': 'array[string]',
#                                                                                                       'items': {'$comment': 'varchar',
#                                                                                                                 'format': 'varchar',
#                                                                                                                 'type': 'string'},
#                                                                                                       'type': 'array'},
#                                                                       'pairedEnd': {'$comment': 'array[boolean]',
#                                                                                     'items': {'$comment': 'boolean',
#                                                                                               'format': 'boolean',
#                                                                                               'type': 'boolean'},
#                                                                                     'type': 'array'},
#                                                                       'workflow': {'$comment': 'array[string]',
#                                                                                    'items': {'$comment': 'varchar',
#                                                                                              'format': 'varchar',
#                                                                                              'type': 'string'},
#                                                                                    'type': 'array'}},
#                                                        'type': 'object'},
#                                              'type': 'array'},
#                                'samples': {'$comment': 'array[object]',
#                                            'items': {'$comment': 'row(array,array,array,array,array,array,array,array,array,array,array)',
#                                                      'properties': {'cellLineType': {'$comment': 'array[string]',
#                                                                                      'items': {'$comment': 'varchar',
#                                                                                                'format': 'varchar',
#                                                                                                'type': 'string'},
#                                                                                      'type': 'array'},
#                                                                     'disease': {'$comment': 'array[string]',
#                                                                                 'items': {'$comment': 'varchar',
#                                                                                           'format': 'varchar',
#                                                                                           'type': 'string'},
#                                                                                 'type': 'array'},
#                                                                     'effectiveOrgan': {'$comment': 'array[string]',
#                                                                                        'items': {'$comment': 'varchar',
#                                                                                                  'format': 'varchar',
#                                                                                                  'type': 'string'},
#                                                                                        'type': 'array'},
#                                                                     'id': {'$comment': 'array[string]',
#                                                                            'items': {'$comment': 'varchar',
#                                                                                      'format': 'varchar',
#                                                                                      'type': 'string'},
#                                                                            'type': 'array'},
#                                                                     'modelOrgan': {'$comment': 'array[string]',
#                                                                                    'items': {'$comment': 'varchar',
#                                                                                              'format': 'varchar',
#                                                                                              'type': 'string'},
#                                                                                    'type': 'array'},
#                                                                     'modelOrganPart': {'$comment': 'array[string]',
#                                                                                        'items': {'$comment': 'varchar',
#                                                                                                  'format': 'varchar',
#                                                                                                  'type': 'string'},
#                                                                                        'type': 'array'},
#                                                                     'organ': {'$comment': 'array[string]',
#                                                                               'items': {'$comment': 'varchar',
#                                                                                         'format': 'varchar',
#                                                                                         'type': 'string'},
#                                                                               'type': 'array'},
#                                                                     'organPart': {'$comment': 'array[string]',
#                                                                                   'items': {'$comment': 'varchar',
#                                                                                             'format': 'varchar',
#                                                                                             'type': 'string'},
#                                                                                   'type': 'array'},
#                                                                     'preservationMethod': {'$comment': 'array[string]',
#                                                                                            'items': {'$comment': 'varchar',
#                                                                                                      'format': 'varchar',
#                                                                                                      'type': 'string'},
#                                                                                            'type': 'array'},
#                                                                     'sampleEntityType': {'$comment': 'array[string]',
#                                                                                          'items': {'$comment': 'varchar',
#                                                                                                    'format': 'varchar',
#                                                                                                    'type': 'string'},
#                                                                                          'type': 'array'},
#                                                                     'source': {'$comment': 'array[string]',
#                                                                                'items': {'$comment': 'varchar',
#                                                                                          'format': 'varchar',
#                                                                                          'type': 'string'},
#                                                                                'type': 'array'}},
#                                                      'type': 'object'},
#                                            'type': 'array'},
#                                'specimens': {'$comment': 'array[object]',
#                                              'items': {'$comment': 'row(array,array,array,array,array,array)',
#                                                        'properties': {'disease': {'$comment': 'array[string]',
#                                                                                   'items': {'$comment': 'varchar',
#                                                                                             'format': 'varchar',
#                                                                                             'type': 'string'},
#                                                                                   'type': 'array'},
#                                                                       'id': {'$comment': 'array[string]',
#                                                                              'items': {'$comment': 'varchar',
#                                                                                        'format': 'varchar',
#                                                                                        'type': 'string'},
#                                                                              'type': 'array'},
#                                                                       'organ': {'$comment': 'array[string]',
#                                                                                 'items': {'$comment': 'varchar',
#                                                                                           'format': 'varchar',
#                                                                                           'type': 'string'},
#                                                                                 'type': 'array'},
#                                                                       'organPart': {'$comment': 'array[string]',
#                                                                                     'items': {'$comment': 'varchar',
#                                                                                               'format': 'varchar',
#                                                                                               'type': 'string'},
#                                                                                     'type': 'array'},
#                                                                       'preservationMethod': {'$comment': 'array[string]',
#                                                                                              'items': {'$comment': 'varchar',
#                                                                                                        'format': 'varchar',
#                                                                                                        'type': 'string'},
#                                                                                              'type': 'array'},
#                                                                       'source': {'$comment': 'array[string]',
#                                                                                  'items': {'$comment': 'varchar',
#                                                                                            'format': 'varchar',
#                                                                                            'type': 'string'},
#                                                                                  'type': 'array'}},
#                                                        'type': 'object'},
#                                              'type': 'array'}}},
#  'description': 'Automatically generated schema',
#  'name': 'search_cloud.human_cell_atlas.hca'}

# %% [markdown]
# ### PhenoPackets Example

# %%
ppSchema = cl.listTableInfo('sample_phenopackets.ga4gh_tables.hpo_phenopackets')
# Out:
# _Schema for tablesample_phenopackets.ga4gh_tables.hpo_phenopackets_
# {'data_model': {'$id': 'https://ga4gh-search-adapter-presto-public.prod.dnastack.com/table/sample_phenopackets.ga4gh_tables.hpo_phenopackets/info',
#                 '$schema': 'http://json-schema.org/draft-07/schema#',
#                 'description': 'Automatically generated schema',
#                 'properties': {'id': {'$comment': 'varchar',
#                                       'format': 'varchar',
#                                       'type': 'string'},
#                                'phenopacket': {'$comment': 'json',
#                                                'type': 'object'}}},
#  'description': 'Automatically generated schema',
#  'name': 'sample_phenopackets.ga4gh_tables.hpo_phenopackets'}

# %% [markdown]
# How do we get the schema of the PhenoPacket itself?

# %% [markdown]
# ### SchemaBlock example
# Is there an example of usage of a SchemaBlock in a table?
