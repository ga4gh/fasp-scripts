# %% [markdown]
# ### Using FHIR to find files for genomic analysis
#
# We are imagining here we are a genomic researcher who wants to query on phenotypic attributes of patients within a study and do a compute. We know we can get DRS ids out of the Kids First data - and we know how ot do a compute on those files onve we have a DRS id (see other notebooks for how). So we have a SMART goal to shoot for.
#
# At this point we can't see what study a Patient is part of. The relationship to a study is a relationship that belongs to ResearchSubject not Patient.
#
# Can we find what Research Studies exist?

# %%
import sys
import os
import json
import requests

FHIR_SERVER = 'https://kf-api-fhir-service.kidsfirstdrc.org'
#FHIR_SERVER = 'https://ncpi-api-fhir-service-dev.kidsfirstdrc.org'

# Optional: Turn off SSL verification. Useful when dealing with a corporate proxy with self-signed certificates.
# This should be set to True unless you actually see certificate errors.
VERIFY_SSL = True

if not VERIFY_SSL:
    requests.packages.urllib3.disable_warnings()

# Kids First uses cookie-based authentication
# Get my locally saved cookie
full_cookie_path = os.path.expanduser('~/.keys/ncpi_prod_fhir_cookie.txt')
with open(full_cookie_path) as f:
        kf_cookie = f.read()

# We make a requests.Session to ensure consistent headers/cookie across all the requests we make
sess = requests.Session()
sess.headers.update({'Accept': 'application/fhir+json'})
sess.verify = VERIFY_SSL
sess.cookies['AWSELBAuthSessionCookie-0'] = kf_cookie

# Test out the cookie by querying the server metadata
r = sess.get(f"{FHIR_SERVER}/metadata")

if "<!DOCTYPE html>" in r.text:
    sys.stderr.write('ERROR: Could not authenticate with Kids First. The cookie may need to be updated')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     415
# --> 416         self.sock = ssl_wrap_socket(
#     417             sock=conn,
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# ~/.pyenv/versions/3.9.7/lib/python3.9/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/.pyenv/versions/3.9.7/lib/python3.9/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/.pyenv/versions/3.9.7/lib/python3.9/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='d3b-center.auth0.com', port=443): Max retries exceeded with url: /authorize?client_id=oQHmXPB3ICijjRnK77hQNwjwL5aW536Z&redirect_uri=https%3A%2F%2Fkf-api-fhir-service.kidsfirstdrc.org%2Foauth2%2Fidpresponse&response_type=code&scope=openid&state=TIfCUxK9i4maiNCPU66cguERCMxZzJixqXmvcmDHVyLldXuTSlVMAcxW0OFsLzKCb6pKJAduDhggd5g%2F1N1dDN1a8IZoWsoNbVCfGXebdnNGkrGa2vBqnuxBfQF8JTmbxlEAdT2Bu4D0KVMiIISD2Ug47QBKmczlYIM9o4EiK1HWX5TGBQZAryP9k2UTD4gbshJqB6VupU%2BLNc8QSc0%3D (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_6337/1405566010.py in <module>
#      27
#      28 # Test out the cookie by querying the server metadata
# ---> 29 r = sess.get(f"{FHIR_SERVER}/metadata")
#      30
#      31 if "<!DOCTYPE html>" in r.text:
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='d3b-center.auth0.com', port=443): Max retries exceeded with url: /authorize?client_id=oQHmXPB3ICijjRnK77hQNwjwL5aW536Z&redirect_uri=https%3A%2F%2Fkf-api-fhir-service.kidsfirstdrc.org%2Foauth2%2Fidpresponse&response_type=code&scope=openid&state=TIfCUxK9i4maiNCPU66cguERCMxZzJixqXmvcmDHVyLldXuTSlVMAcxW0OFsLzKCb6pKJAduDhggd5g%2F1N1dDN1a8IZoWsoNbVCfGXebdnNGkrGa2vBqnuxBfQF8JTmbxlEAdT2Bu4D0KVMiIISD2Ug47QBKmczlYIM9o4EiK1HWX5TGBQZAryP9k2UTD4gbshJqB6VupU%2BLNc8QSc0%3D (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))

# %%
r = sess.get(f"{FHIR_SERVER}/ResearchStudy")
study_bundle = r.json()

# In the bundle obtained total is not present
#print(f"Number of matches: {patient_bundle['total']}")
print(f"Number of Studies included in Bundle: {len(study_bundle['entry'])}")
studies = [entry['resource'] for entry in study_bundle['entry']]

for s in studies:

    print (s['id'])
    print (s['identifier'][1]['value'])
    print (s['title'])
    #print(json.dumps(s, indent=3))
    print('_'*40)
# Out:
# Number of Studies included in Bundle: 28
# 276195
# ResearchStudy-SD_9PYZAHHE
# Genomic Studies of Orofacial Cleft Birth Defects
# ________________________________________
# 272532
# ResearchStudy-SD_7NQ9151J
# Genome-wide Sequencing to Identify the Genes Responsible for Enchondromatoses and Related Malignant Tumors
# ________________________________________
# 269246
# ResearchStudy-SD_B8X3C1MX
# Kids First: Craniofacial Microsomia: Genetic Causes and Pathway Discovery
# ________________________________________
# 267437
# ResearchStudy-SD_DK0KRWK8
# Whole Genome Sequencing of African and Asian Orofacial Clefts Case-Parent Triads
# ________________________________________
# 260974
# ResearchStudy-SD_NMVV8A1Y
# Kids First: Genetics of Structural Defects of the Kidney and Urinary Tract
# ________________________________________
# 125635
# ResearchStudy-SD_YNSSAPHE
# TARGET: Neuroblastoma (NBL)
# ________________________________________
# 123556
# ResearchStudy-SD_W0V965XZ
# Genomic Analysis of Familial Leukemia
# ________________________________________
# 119523
# ResearchStudy-SD_R0EPRSGS
# Kids First: Genomics of Orofacial Cleft Birth Defects in Latin American Families
# ________________________________________
# 116586
# ResearchStudy-SD_RM8AFW0R
# Kids First: Genomics of Orthopaedic Disease Program
# ________________________________________
# 114612
# ResearchStudy-SD_DZ4GPQX6
# Kids First: The Genetics of Microtia in Hispanic Populations
# ________________________________________
# 112832
# ResearchStudy-SD_ZFGDG5YS
# Gabriella Miller Kids First Pediatric Research Program in Novel Cancer Susceptibility in Families (from BASIC3)
# ________________________________________
# 104182
# ResearchStudy-SD_0TYVY1TW
# Genomic Analysis of Esophageal Atresia and Tracheoesophageal Fistulas and Associated Congenital Anomalies
# ________________________________________
# 100031
# ResearchStudy-SD_DYPMEHHF
# Discovering the Genetic Basis of Human Neuroblastoma: A Gabriella Miller Kids First Pediatric Research Program (Kids First) Project
# ________________________________________
# 95270
# ResearchStudy-SD_VTTSHWV4
# Kids First: Genomic Analysis of a Cohort with Infantile Hemangiomas Associated with Multi-organ Structural Birth Defects
# ________________________________________
# 55858
# ResearchStudy-SD_DZTB5HRR
# Kids First: BCH Structural Birth Defects Collaboration: Syndromic cranial dysinnervation disorders
# ________________________________________
# 52326
# ResearchStudy-SD_YGVA0E1C
# Kids First: Expanded Ewing sarcoma cohort for tumor genomics and association with DNA repair deficiencies, clinical presentation, and outcome
# ________________________________________
# 49513
# ResearchStudy-SD_6FPYJQBR
# Kids First: Genetic Basis of Disorders/Differences of Sex Development (DSD)
# ________________________________________
# 48656
# ResearchStudy-SD_8Y99QZJJ
# Pediatric Brain Tumor Atlas: PNOC
# ________________________________________
# 47035
# ResearchStudy-SD_P445ACHV
# Kids First: Whole genome sequencing of nonsyndromic craniosynostosis
# ________________________________________
# 42776
# ResearchStudy-SD_Z6MWD3H0
# Kids First: Genomic Analysis of Congenital Heart Defects and Acute Lymphoblastic Leukemia in Children with Down Syndrome
# ________________________________________
# 38019
# ResearchStudy-SD_46RR9ZR6
# TARGET: Acute Myeloid Leukemia (AML)
# ________________________________________
# 35326
# ResearchStudy-SD_PET7Q6F2
# Kids First: Germline and Somatic Variants in Myeloid Malignancies in Children
# ________________________________________
# 27033
# ResearchStudy-SD_46SK55A3
# Kids First: Genomic Analysis of Congenital Diaphragmatic Hernia
# ________________________________________
# 22088
# ResearchStudy-SD_ZXJFFMEF
# Kids First: An Integrated Clinical and Genomic Analysis of Treatment Failure in Pediatric Osteosarcoma
# ________________________________________
# 281300
# ResearchStudy-SD_1P41Z782
# OpenDIPG: ICR London
# ________________________________________
# 144813
# ResearchStudy-SD_PREASA7S
# National Heart, Lung, and Blood Institute (NHLBI) Bench to Bassinet Program: The Gabriella Miller Kids First Pediatric Research Program of the Pediatric Cardiac Genetics Consortium (PCGC)
# ________________________________________
# 130099
# ResearchStudy-SD_JWS3V24D
# Kids First: Genetics at the Intersection of Childhood Cancer and Birth Defects
# ________________________________________
# 76758
# ResearchStudy-SD_BHJXBDQK
# Pediatric Brain Tumor Atlas - Children's Brain Tumor Tissue Consortium
# ________________________________________

# %% [markdown]
# Query for the Familial Leukemia study as I have access to that

# %%
fll_study_id = '123556'
r = sess.get(f"{FHIR_SERVER}/ResearchStudy?_id={fll_study_id}")
study_bundle = r.json()

print(f"Number of Studies included in Bundle: {len(study_bundle['entry'])}")

# Create list of just the Patient Resources in the Bundle
studies = [entry['resource'] for entry in study_bundle['entry']]
print(json.dumps(studies[0], indent=3))
# Out:
# Number of Studies included in Bundle: 1
# {
#    "resourceType": "ResearchStudy",
#    "id": "123556",
#    "meta": {
#       "versionId": "2",
#       "lastUpdated": "2022-01-19T01:26:25.167+00:00",
#       "source": "#cdPsDsTirYYBOYpQ",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchStudy"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/studies/",
#          "value": "SD_W0V965XZ"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchStudy-SD_W0V965XZ"
#       },
#       {
#          "system": "https://www.ncbi.nlm.nih.gov/projects/gap/cgi-bin/study.cgi?study_id=",
#          "value": "phs001738.v1.p1"
#       }
#    ],
#    "title": "Genomic Analysis of Familial Leukemia",
#    "status": "completed",
#    "category": [
#       {
#          "coding": [
#             {
#                "system": "http://snomed.info/sct",
#                "code": "86049000",
#                "display": "Malignant neoplasm, primary (morphologic abnormality)"
#             }
#          ],
#          "text": "CANCER"
#       }
#    ],
#    "keyword": [
#       {
#          "coding": [
#             {
#                "code": "Kids First"
#             }
#          ]
#       },
#       {
#          "coding": [
#             {
#                "code": "KF-FALL"
#             }
#          ]
#       }
#    ],
#    "principalInvestigator": {
#       "reference": "PractitionerRole/122286"
#    }
# }

# %% [markdown]
# ResearchSubject is being used. What do the resources look like.

# %%
r = sess.get(f"{FHIR_SERVER}/ResearchSubject")
subject_bundle = r.json()

# In the bundle obtained total is not present
#print(f"Number of matches: {subject_bundle['total']}")
print(f"Number of Subjects included in Bundle: {len(subject_bundle['entry'])}")
subjects = [entry['resource'] for entry in subject_bundle['entry']]

for sub in subjects:
    print(json.dumps(sub))
    print('_____________________')
# Out:
# Number of Subjects included in Bundle: 50
# {"resourceType": "ResearchSubject", "id": "104225", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:15.838+00:00", "source": "#WtnuAKQbiCsiqGsp", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "360"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_FP981XCW"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_FP981XCW"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103052"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104235", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.284+00:00", "source": "#doWQbZZcKr5YPgyU", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "512"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_6D1TJ139"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_6D1TJ139"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103062"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104241", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.262+00:00", "source": "#65oiSL5Limlnnbqq", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "428"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_3BQZY5W9"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_3BQZY5W9"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103044"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104543", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:11.091+00:00", "source": "#gLUYgKUqT20omoL7", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "405"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_HH76M8KZ"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_HH76M8KZ"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103391"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104570", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:14.365+00:00", "source": "#aiYrRhXdTMA3bQfT", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "536"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_Y5NN6PM6"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_Y5NN6PM6"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103417"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104262", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:14.680+00:00", "source": "#mNoKNBs942fKRQRx", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "419"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_BMG9K9TD"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_BMG9K9TD"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103081"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104528", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.055+00:00", "source": "#r6Aey5dq86ggli5G", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "35815"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_8C83YS07"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_8C83YS07"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103199"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104187", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.954+00:00", "source": "#n0Kty9KVn3ZUxxaA", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "44926"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_DAZFAC5F"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_DAZFAC5F"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103008"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104730", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:10.726+00:00", "source": "#wfXC09EdwfuYT6c7", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "559"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_F43APHDJ"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_F43APHDJ"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103359"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104397", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:14.241+00:00", "source": "#20Dca0TbhvqnFndc", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "35341"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_AJWT7MX1"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_AJWT7MX1"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103232"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104355", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:14.319+00:00", "source": "#nOWICC6YYHkAHJur", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "647"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_31N314T0"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_31N314T0"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103176"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104186", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:14.934+00:00", "source": "#ViD8OODJxvlibpLi", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "233"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_HM03Y0NR"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_HM03Y0NR"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/102997"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104629", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:15.030+00:00", "source": "#tC7s5wnCYc5uJnMe", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "4-6"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_E0TSD407"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_E0TSD407"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103471"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104621", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.415+00:00", "source": "#mVk0IilwzHEPf7Ga", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "4-15M"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_0DBZ00DT"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_0DBZ00DT"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103443"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104253", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:13.319+00:00", "source": "#8v2QJH0Bg5yfv3gm", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "338"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_2FVRJK0D"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_2FVRJK0D"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103051"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104657", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:15.898+00:00", "source": "#FGFIaPuadl23hMzF", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "4-4F"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_AR6BF712"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_AR6BF712"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103496"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104827", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.384+00:00", "source": "#4YsXJMQi9k6QGyna", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "36041"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_MQ2ZRV8R"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_MQ2ZRV8R"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103651"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104358", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:12.762+00:00", "source": "#yNjDb5Ik7EkQf8iQ", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "639"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_J8JF5X26"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_J8JF5X26"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103185"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104794", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:13.146+00:00", "source": "#rxHTwkkw9yMH79uR", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "412"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_7GJ19ZGH"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_7GJ19ZGH"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103615"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104727", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:14.740+00:00", "source": "#4aF83VJLV21yMfnV", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "560"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_ERA8Y8WV"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_ERA8Y8WV"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103367"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104537", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.819+00:00", "source": "#H3zX1zYEZTFOi5Ua", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "599"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_T6YNNJSM"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_T6YNNJSM"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103382"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104223", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.722+00:00", "source": "#rHMc2rpUqLkwKZyd", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "37"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_BK1DWQC4"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_BK1DWQC4"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103032"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104688", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:12.197+00:00", "source": "#73tFTW3TkFraMCID", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "37351"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_C3YF1KZS"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_C3YF1KZS"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103530"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104421", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:13.524+00:00", "source": "#LScLFQUH1RutPUQ6", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "595"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_D8FQN3MX"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_D8FQN3MX"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103245"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104759", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.657+00:00", "source": "#HUH7LOzBET1o7Tto", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "252"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_Y51JP8VH"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_Y51JP8VH"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103584"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104426", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:10.056+00:00", "source": "#66Kx7rP4t44ACVwS", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "349"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_9Z6TBSEN"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_9Z6TBSEN"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103253"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104655", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:11.674+00:00", "source": "#GldQSUJPofQ9AeGd", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "4-4M"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_K6BTR7WS"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_K6BTR7WS"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103493"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104622", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:15.737+00:00", "source": "#zmMNwHnQJzPMcrGY", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "278"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_0NJE0FB1"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_0NJE0FB1"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103458"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104398", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:12.870+00:00", "source": "#HXPQLx0CM7QuvrYy", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "35342"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_5V21FNX7"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_5V21FNX7"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103211"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104205", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.792+00:00", "source": "#ugqvcgklzZlolPDM", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "490"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_ASAX4JJ3"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_ASAX4JJ3"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103020"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104739", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.870+00:00", "source": "#kXknm7tFP7HP7z7N", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "46013"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_ZXVXY748"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_ZXVXY748"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103364"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104717", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.746+00:00", "source": "#ERw0IHHuHBiHbfxu", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "219"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_TQ48BYDK"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_TQ48BYDK"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103357"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104626", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:12.897+00:00", "source": "#YN5oy0ABBA0nWBIz", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "44965"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_S9N7H24Z"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_S9N7H24Z"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103463"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104461", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:13.830+00:00", "source": "#eY14EnNMnRTwpN4W", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "2"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_8DQ15GPZ"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_8DQ15GPZ"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103292"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104417", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.360+00:00", "source": "#prssuxTRa2NfOWnl", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "501"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_VNENF6SF"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_VNENF6SF"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103241"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104763", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.551+00:00", "source": "#TOWMpYG6XenbdQJR", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "285"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_CJV9VKX5"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_CJV9VKX5"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103575"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104524", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.406+00:00", "source": "#eHQWFpByzx0CVWzj", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "302"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_MFAQQZFY"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_MFAQQZFY"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103171"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104542", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:16.617+00:00", "source": "#aDPmeIMmeRNwwmo1", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "404"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_98WNG6Y5"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_98WNG6Y5"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103387"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "104703", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:17.008+00:00", "source": "#ywh3n553NbzetyCf", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"value": "35747"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_W8YDF4Z2"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_0TYVY1TW-PT_W8YDF4Z2"}], "status": "off-study", "study": {"reference": "ResearchStudy/104182"}, "individual": {"reference": "Patient/103559"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112906", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:29.021+00:00", "source": "#6jr7hRk57A99kT1g", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-2261479001"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_VMCM6C0M"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_VMCM6C0M"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111439"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112902", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:29.106+00:00", "source": "#S1jkdUu7t9Ar4u7w", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-461256"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_10VTQ3Y0"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_10VTQ3Y0"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111441"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112876", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:29.227+00:00", "source": "#eMKHaMwI4eLuskYt", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-2797676901"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_5QC7N33G"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_5QC7N33G"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111431"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112856", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:29.892+00:00", "source": "#vN75fJYVWsebQgom", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-196611002"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_Q45HK4N8"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_Q45HK4N8"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111373"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112865", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:32.046+00:00", "source": "#ht6u38kyd8QGwDAx", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-443398001"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_29MQRM9C"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_29MQRM9C"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111402"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112853", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:33.620+00:00", "source": "#gb1OOWShevQOdOz1", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-2301236302"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_C0X4V63F"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_C0X4V63F"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111380"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112884", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:34.044+00:00", "source": "#gju0ZnseokZ8hROi", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-524275702"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_YCYVQD0E"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_YCYVQD0E"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111416"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112898", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:34.330+00:00", "source": "#PVfGgA8bzsxlFaf0", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-65680"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_5ZBDKX8B"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_5ZBDKX8B"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111445"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112861", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:35.528+00:00", "source": "#lmymDd3nt2DS09KW", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-1923648601"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_83CDJYHR"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_83CDJYHR"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111392"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112877", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:36.107+00:00", "source": "#ZFaauDLkP6amR74q", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-504536001"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_SXZY9W9B"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_SXZY9W9B"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111421"}}
# _____________________
# {"resourceType": "ResearchSubject", "id": "112892", "meta": {"versionId": "3", "lastUpdated": "2021-11-16T16:53:38.116+00:00", "source": "#9t8ERkt4aRoda2P5", "profile": ["http://hl7.org/fhir/StructureDefinition/ResearchSubject"], "tag": [{"code": "SD_ZFGDG5YS"}]}, "identifier": [{"value": "BASIC3-1867656"}, {"system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/", "value": "PT_9B8YZJ7P"}, {"system": "urn:kids-first:unique-string", "value": "ResearchSubject-SD_ZFGDG5YS-PT_9B8YZJ7P"}], "status": "off-study", "study": {"reference": "ResearchStudy/112832"}, "individual": {"reference": "Patient/111405"}}
# _____________________

# %% [markdown]
# Getting ourselves a list of the resources actually used in Kids First.

# %%
populatedRes = {'ResearchSubject': 11529,
 'DocumentReference': 81538,
 'PractitionerRole': 3,
 'Practitioner': 4,
 'Group': 1614,
 'Organization': 22,
 'SearchParameter': 1635,
 'Task': 3212,
 'ResearchStudy': 7,
 'Specimen': 55715,
 'StructureDefinition': 664,
 'OperationDefinition': 46,
 'ValueSet': 1329,
 'CodeSystem': 1070,
 'Observation': 7957,
 'DiagnosticReport': 5,
 'Condition': 120405,
 'CompartmentDefinition': 5,
 'Patient': 11538}

# %% [markdown]
# Let's explore some of them.
# Condition would be useful if we eanted to find subjects with a particular disease.

# %%
response = sess.get(f"{FHIR_SERVER}/Condition")
cond_bundle = response.json()

# In the bundle obtained total is not present
#print(f"Number of matches: {subject_bundle['total']}")
print(f"Number of Condition included in Bundle: {len(cond_bundle['entry'])}")
conditions = [entry['resource'] for entry in cond_bundle['entry']]

for condition in conditions:
    print(json.dumps(condition))
    print('_____________________')
# Out:
# Number of Condition included in Bundle: 50
# {"resourceType": "Condition", "id": "104958", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:50.487+00:00", "source": "#FZsSU2fO9pJxG6cc", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/disease"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/diagnoses/", "value": "DG_25PXA42V"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-DG_25PXA42V"}], "clinicalStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-clinical", "code": "active", "display": "Active"}], "text": "Active"}, "category": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-category", "code": "encounter-diagnosis", "display": "Encounter Diagnosis"}]}], "code": {"text": "EA+TEF"}, "bodySite": [{"text": "Not Reported"}], "subject": {"reference": "Patient/103034"}}
# _____________________
# {"resourceType": "Condition", "id": "104895", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:50.694+00:00", "source": "#nMOTcMHbhckKkZ2X", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/disease"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/diagnoses/", "value": "DG_4FY7ZKTW"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-DG_4FY7ZKTW"}], "clinicalStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-clinical", "code": "active", "display": "Active"}], "text": "Active"}, "category": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-category", "code": "encounter-diagnosis", "display": "Encounter Diagnosis"}]}], "code": {"text": "EA+TEF, type C"}, "bodySite": [{"text": "Not Reported"}], "subject": {"reference": "Patient/103111"}}
# _____________________
# {"resourceType": "Condition", "id": "105022", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:55.565+00:00", "source": "#4Y2IglC28Qm2iRv6", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_81MS1PM3"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_81MS1PM3"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001631"}], "text": "Atrial septal defect (ASD)"}, "subject": {"reference": "Patient/102997"}}
# _____________________
# {"resourceType": "Condition", "id": "105028", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:55.772+00:00", "source": "#2aibRHvPubS7Bc9Y", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_5EX7F9JV"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_5EX7F9JV"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "confirmed", "display": "Confirmed"}], "text": "Positive"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0002575"}], "text": "Tracheoesophageal fistula"}, "subject": {"reference": "Patient/102997"}}
# _____________________
# {"resourceType": "Condition", "id": "105081", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:59.419+00:00", "source": "#NtkQ21YEsv1wtqjM", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_445NWC2T"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_445NWC2T"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0002948"}], "text": "Fused vertebrae"}, "subject": {"reference": "Patient/103022"}}
# _____________________
# {"resourceType": "Condition", "id": "105146", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:01.402+00:00", "source": "#kWVVpKNHo8imsbrw", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_221JFGJX"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_221JFGJX"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "confirmed", "display": "Confirmed"}], "text": "Positive"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001631"}], "text": "ASD"}, "subject": {"reference": "Patient/103026"}}
# _____________________
# {"resourceType": "Condition", "id": "105220", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:03.571+00:00", "source": "#UPA2YmC4ruy2UWwG", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_D7R43M8W"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_D7R43M8W"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001699"}], "text": "Sudden death"}, "subject": {"reference": "Patient/103024"}}
# _____________________
# {"resourceType": "Condition", "id": "105353", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:06.433+00:00", "source": "#nsm5jDSL61KrHqwt", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_XBNNVXBD"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_XBNNVXBD"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001651"}], "text": "Dextrocardia"}, "subject": {"reference": "Patient/103050"}}
# _____________________
# {"resourceType": "Condition", "id": "105499", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:09.038+00:00", "source": "#ofXU1ZwEIzXpx4eN", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_KP7DGBZR"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_KP7DGBZR"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0011024"}], "text": "Other GI defect"}, "subject": {"reference": "Patient/103031"}}
# _____________________
# {"resourceType": "Condition", "id": "105596", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:14.115+00:00", "source": "#IO0QWc7ZSejE8s3l", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_160KB0GY"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_160KB0GY"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0008751"}], "text": "Laryngeal cleft"}, "subject": {"reference": "Patient/103059"}}
# _____________________
# {"resourceType": "Condition", "id": "105671", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:15.902+00:00", "source": "#4cqLlUZWeJ9d3JPo", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_F9TFNK3M"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_F9TFNK3M"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0012732"}], "text": "Anorectal malformation"}, "subject": {"reference": "Patient/103065"}}
# _____________________
# {"resourceType": "Condition", "id": "105845", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:19.467+00:00", "source": "#GvG3QN6vQGzXCP4y", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_AP8QJJQY"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_AP8QJJQY"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001601"}], "text": "Laryngomalacia"}, "subject": {"reference": "Patient/103077"}}
# _____________________
# {"resourceType": "Condition", "id": "105436", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:57.371+00:00", "source": "#trLUJJ0BOpF6Eihq", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_4MND0B4J"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_4MND0B4J"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0025023"}], "text": "Rectal atresia/stenosis"}, "subject": {"reference": "Patient/103028"}}
# _____________________
# {"resourceType": "Condition", "id": "105115", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:00.435+00:00", "source": "#EX6d4cQoGpJN7CxM", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_BA4S8PJX"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_BA4S8PJX"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001631"}], "text": "Atrial septal defect (ASD)"}, "subject": {"reference": "Patient/102998"}}
# _____________________
# {"resourceType": "Condition", "id": "105138", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:01.132+00:00", "source": "#oseF74ulLIkbzgr8", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_XATMBXFS"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_XATMBXFS"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001508"}], "text": "Failure to thrive"}, "subject": {"reference": "Patient/102998"}}
# _____________________
# {"resourceType": "Condition", "id": "105177", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:02.304+00:00", "source": "#PguPn8FkbrrN18QQ", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_EGGY4TDW"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_EGGY4TDW"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0000122"}], "text": "Single kidney"}, "subject": {"reference": "Patient/103026"}}
# _____________________
# {"resourceType": "Condition", "id": "105319", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:05.311+00:00", "source": "#WQWnYKJYXIyitT26", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_JZRFR2BH"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_JZRFR2BH"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001651"}], "text": "Dextrocardia"}, "subject": {"reference": "Patient/103042"}}
# _____________________
# {"resourceType": "Condition", "id": "105354", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:06.272+00:00", "source": "#wvYiuLGkoBcftqaK", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_2BFTV96J"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_2BFTV96J"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0410030"}], "text": "Cleft lip"}, "subject": {"reference": "Patient/103050"}}
# _____________________
# {"resourceType": "Condition", "id": "105760", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:12.635+00:00", "source": "#EXfVm7qMA2pQvunp", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_CX2B0MM5"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_CX2B0MM5"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0000085"}], "text": "Horseshoe kidney"}, "subject": {"reference": "Patient/103071"}}
# _____________________
# {"resourceType": "Condition", "id": "105882", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:21.124+00:00", "source": "#t8yBg8XxgmqAjici", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_MXZ0BFZZ"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_MXZ0BFZZ"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0012621"}], "text": "Cloaca"}, "subject": {"reference": "Patient/103081"}}
# _____________________
# {"resourceType": "Condition", "id": "105907", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:22.836+00:00", "source": "#Cho4RrViDYVbzZ7F", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_N8Q3YMFX"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_N8Q3YMFX"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001363"}], "text": "Craniosynostosis"}, "subject": {"reference": "Patient/103083"}}
# _____________________
# {"resourceType": "Condition", "id": "106081", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:26.021+00:00", "source": "#JBvaAvOEKia98hx6", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_AC1FAFT5"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_AC1FAFT5"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0011332"}], "text": "Hemifacial microsomia"}, "subject": {"reference": "Patient/103085"}}
# _____________________
# {"resourceType": "Condition", "id": "106187", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:27.770+00:00", "source": "#F5NnQ43LV16iO1DP", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_K2SZNNGK"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_K2SZNNGK"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001651"}], "text": "Dextrocardia"}, "subject": {"reference": "Patient/103098"}}
# _____________________
# {"resourceType": "Condition", "id": "106617", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:34.325+00:00", "source": "#TBhgldl3cjCI5rMi", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_9X34PQDT"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_9X34PQDT"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0410030"}], "text": "Cleft lip"}, "subject": {"reference": "Patient/103140"}}
# _____________________
# {"resourceType": "Condition", "id": "106635", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:39.142+00:00", "source": "#mh6LXusPhPODz6ML", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_HGH3W20E"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_HGH3W20E"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0004383"}], "text": "Hypoplastic left heart"}, "subject": {"reference": "Patient/103162"}}
# _____________________
# {"resourceType": "Condition", "id": "104897", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:52.260+00:00", "source": "#2aLL6XxN1Pjd6sVW", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/disease"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/diagnoses/", "value": "DG_6NZ66KK8"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-DG_6NZ66KK8"}], "clinicalStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-clinical", "code": "active", "display": "Active"}], "text": "Active"}, "category": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-category", "code": "encounter-diagnosis", "display": "Encounter Diagnosis"}]}], "code": {"text": "EA+TEF"}, "bodySite": [{"text": "Not Reported"}], "subject": {"reference": "Patient/103323"}}
# _____________________
# {"resourceType": "Condition", "id": "105104", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:00.090+00:00", "source": "#lKFYIPj3NOjeO8VB", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_WZT00JND"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_WZT00JND"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001643"}], "text": "Patent ductus arteriosus (PDA)"}, "subject": {"reference": "Patient/102998"}}
# _____________________
# {"resourceType": "Condition", "id": "105222", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:03.712+00:00", "source": "#E6Oh6cL5Wr34FtAy", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_9PA9R0SQ"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_9PA9R0SQ"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "confirmed", "display": "Confirmed"}], "text": "Positive"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0002575"}], "text": "Tracheoesophageal fistula"}, "subject": {"reference": "Patient/103024"}}
# _____________________
# {"resourceType": "Condition", "id": "105333", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:05.634+00:00", "source": "#UCrpkuOpY1dxEK6g", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_2QCP75JK"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_2QCP75JK"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "confirmed", "display": "Confirmed"}], "text": "Positive"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0002575"}], "text": "Tracheoesophageal fistula"}, "subject": {"reference": "Patient/103050"}}
# _____________________
# {"resourceType": "Condition", "id": "105463", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:10.331+00:00", "source": "#Eg1xLW6xZedJDklk", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_HKAJQNV3"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_HKAJQNV3"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001539"}], "text": "Omphalocele"}, "subject": {"reference": "Patient/103044"}}
# _____________________
# {"resourceType": "Condition", "id": "105761", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:14.042+00:00", "source": "#5HCcWOlFiNSoBHSU", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_C0XFPMJY"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_C0XFPMJY"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "confirmed", "display": "Confirmed"}], "text": "Positive"}, "code": {"text": "EA/TEF"}, "subject": {"reference": "Patient/103059"}}
# _____________________
# {"resourceType": "Condition", "id": "105697", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:15.889+00:00", "source": "#FBFDX7HIVPPLd4Dg", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_E1G2PSDY"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_E1G2PSDY"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001651"}], "text": "Dextrocardia"}, "subject": {"reference": "Patient/103065"}}
# _____________________
# {"resourceType": "Condition", "id": "105918", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:16.673+00:00", "source": "#fruJt71RbXGYh3Yi", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_3SAC6G9K"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_3SAC6G9K"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0000717"}], "text": "Autism"}, "subject": {"reference": "Patient/103069"}}
# _____________________
# {"resourceType": "Condition", "id": "105863", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:21.010+00:00", "source": "#mJNE1XlGhuJxX3ZH", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_N8VWBJ4W"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_N8VWBJ4W"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0011332"}], "text": "Hemifacial microsomia"}, "subject": {"reference": "Patient/103081"}}
# _____________________
# {"resourceType": "Condition", "id": "105951", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:24.500+00:00", "source": "#ht3pkb2wE9sfL3M3", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_GNKDYNGE"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_GNKDYNGE"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001636"}], "text": "Tetralogy of Fallot"}, "subject": {"reference": "Patient/103104"}}
# _____________________
# {"resourceType": "Condition", "id": "106247", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:31.006+00:00", "source": "#UkFGUTjVDBdi9oYf", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_5SY51XKP"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_5SY51XKP"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "confirmed", "display": "Confirmed"}], "text": "Positive"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0002575"}], "text": "Tracheoesophageal fistula"}, "subject": {"reference": "Patient/103124"}}
# _____________________
# {"resourceType": "Condition", "id": "106683", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:38.573+00:00", "source": "#nNx9SMcYoyPORD7g", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_AWY0MX54"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_AWY0MX54"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0000717"}], "text": "Autism"}, "subject": {"reference": "Patient/103162"}}
# _____________________
# {"resourceType": "Condition", "id": "106812", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:43.302+00:00", "source": "#yWr20JfM9sQC7P6W", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_HQ7HH4GF"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_HQ7HH4GF"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0000122"}], "text": "Single kidney"}, "subject": {"reference": "Patient/103181"}}
# _____________________
# {"resourceType": "Condition", "id": "104904", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:52.683+00:00", "source": "#Mwttyw951QrfSocN", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/disease"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/diagnoses/", "value": "DG_9JMVPMP0"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-DG_9JMVPMP0"}], "clinicalStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-clinical", "code": "active", "display": "Active"}], "text": "Active"}, "category": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-category", "code": "encounter-diagnosis", "display": "Encounter Diagnosis"}]}], "code": {"text": "EA+TEF, type D"}, "bodySite": [{"text": "Not Reported"}], "subject": {"reference": "Patient/103384"}}
# _____________________
# {"resourceType": "Condition", "id": "105228", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:56.865+00:00", "source": "#63j7xGIDvmuF6jTT", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_HP1EBV5H"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_HP1EBV5H"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "confirmed", "display": "Confirmed"}], "text": "Positive"}, "code": {"text": "TEF"}, "subject": {"reference": "Patient/103028"}}
# _____________________
# {"resourceType": "Condition", "id": "105054", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:49:57.667+00:00", "source": "#Do6TrUFMlmOL6HEE", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_6SXQVDCY"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_6SXQVDCY"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0011332"}], "text": "Hemifacial microsomia"}, "subject": {"reference": "Patient/103022"}}
# _____________________
# {"resourceType": "Condition", "id": "105325", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:04.087+00:00", "source": "#okjEaMnrDfQvy9s5", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_8R5390J2"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_8R5390J2"}], "verificationStatus": {"text": "Not Reported"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0002575"}], "text": "TEF-long gap"}, "subject": {"reference": "Patient/103034"}}
# _____________________
# {"resourceType": "Condition", "id": "105286", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:05.476+00:00", "source": "#nLherRaljDrjIu8G", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_EMGNC68R"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_EMGNC68R"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"text": "Other birth defect"}, "subject": {"reference": "Patient/103042"}}
# _____________________
# {"resourceType": "Condition", "id": "105491", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:07.896+00:00", "source": "#eF8h9f6zcK3Aw8Si", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_36MVVEH0"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_36MVVEH0"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0000085"}], "text": "Horseshoe kidney"}, "subject": {"reference": "Patient/103031"}}
# _____________________
# {"resourceType": "Condition", "id": "105423", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:09.504+00:00", "source": "#R9U9VyrLgyUH8OkW", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_EF0M8ZG0"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_EF0M8ZG0"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0011332"}], "text": "Hemifacial microsomia"}, "subject": {"reference": "Patient/103044"}}
# _____________________
# {"resourceType": "Condition", "id": "105726", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:17.644+00:00", "source": "#nI2tF0woSzQb82Kb", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_4BXMN6HW"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_4BXMN6HW"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0012621"}], "text": "Cloaca"}, "subject": {"reference": "Patient/103069"}}
# _____________________
# {"resourceType": "Condition", "id": "106091", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:23.004+00:00", "source": "#jQi8pJML0pR8RV9j", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_Y6WR8J2P"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_Y6WR8J2P"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0000717"}], "text": "Autism"}, "subject": {"reference": "Patient/103083"}}
# _____________________
# {"resourceType": "Condition", "id": "106140", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:26.701+00:00", "source": "#ellbDV2yZCfrBxD7", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_N34V3H07"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_N34V3H07"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001999"}], "text": "Dysmorphic feature"}, "subject": {"reference": "Patient/103085"}}
# _____________________
# {"resourceType": "Condition", "id": "106320", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:32.447+00:00", "source": "#x1F7RhKTZh9ctHCj", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_1SVZ3T55"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_1SVZ3T55"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0001539"}], "text": "Omphalocele"}, "subject": {"reference": "Patient/103134"}}
# _____________________
# {"resourceType": "Condition", "id": "106678", "meta": {"versionId": "2", "lastUpdated": "2021-11-16T09:50:38.139+00:00", "source": "#lEGLqjqLR2ly1IUj", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/phenotype"], "tag": [{"code": "SD_0TYVY1TW"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/phenotypes/", "value": "PH_C5XB2GTN"}, {"system": "urn:kids-first:unique-string", "value": "Condition-SD_0TYVY1TW-PH_C5XB2GTN"}], "verificationStatus": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/condition-ver-status", "code": "refuted", "display": "Refuted"}], "text": "Negative"}, "code": {"coding": [{"system": "http://purl.obolibrary.org/obo/hp.owl", "code": "HP:0002948"}], "text": "Fused vertebrae"}, "subject": {"reference": "Patient/103162"}}
# _____________________

# %% [markdown]
# ### Getting the BAM files
# It turns out the BAM files have implemented as Documents in FHIR. Their details can be accessed via the DocumentReference resource.
#
# We filter on documents which use a profile defined for NCPI DRS references

# %%
response = sess.get(f'{FHIR_SERVER}/DocumentReference?_profile=https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference')

drs_id_bundle = response.json()

# In the bundle obtained total is not present
#print(f"Number of matches: {doc_bundle['total']}")
print(f"Number of DRS files included in Bundle: {len(drs_id_bundle['entry'])}")
drs_ids = [entry['resource'] for entry in drs_id_bundle['entry']]

for drs_id in drs_ids:
    print(json.dumps(drs_id))
    print('_'*50)
# Out:
# Number of DRS files included in Bundle: 50
# {"resourceType": "DocumentReference", "id": "283186", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:57.062+00:00", "source": "#N2omm298271KBelG", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_AYWGJGRW"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_AYWGJGRW"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls Index"}, "subject": {"reference": "Patient/21953"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/7b70b250-9c33-4822-bd0c-50a308e2f116"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 1956879}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "6e32a77ab28642af6de76b2a6c8cc32c"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/5f52a0ce-5989-4a39-af0c-497bb038e871.CGP.filtered.deNovo.vep.vcf.gz.tbi", "title": "5f52a0ce-5989-4a39-af0c-497bb038e871.CGP.filtered.deNovo.vep.vcf.gz.tbi"}, "format": {"display": "tbi"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283195", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:57.407+00:00", "source": "#gIsCgzAquDo6zAme", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_Z23QHQ69"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_Z23QHQ69"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21953"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/0f00b263-3c85-4aa9-95b7-ee9d0cf5ea7b"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 119035073347}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "45ab72702d876318d68914d09b9a972a"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "3574506e2eb17140bedad20a4c2b276bce9e6fa7aa99c9f0da49e25daf87a131"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteosarcoma/85d053917c3b49039e58f63be65df29a.bam", "title": "85d053917c3b49039e58f63be65df29a.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283202", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:58.517+00:00", "source": "#FXrODZKMA2v1E3RD", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_GZCCK2FT"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_GZCCK2FT"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21966"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/578223c3-2d39-4bb4-a913-b94a2f33e644"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 7267481977}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "2ed2525b1fcc6b61c6b9a1b58be54e13"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "6cd78c36c9894fd6895748171467f2ee263eb226f061bb4080d96e60cbde6fb3"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/c4ab17ecd07141919145057e93324df5.bam", "title": "c4ab17ecd07141919145057e93324df5.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283210", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:57.271+00:00", "source": "#QUe5lRkiWClauyYi", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_0T4XDE3Y"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_0T4XDE3Y"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21959"}, "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/68801202-407c-4301-a953-469b69c24c8c"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 6420680942}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "cb2c4284d6e5191d0b54e7f24b3e71ff"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "753780f37341ef6cf6398a38b9b5f3ab3aa7a7c42b3db1a8879ad60cba5eed26"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/73771f402d05458287b8caafdb286eec.bam", "title": "73771f402d05458287b8caafdb286eec.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283214", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:56.791+00:00", "source": "#dxLrjEoQbX0VRtuj", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_G9DQYQ6Z"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_G9DQYQ6Z"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21963"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/927f9629-13c8-4899-b339-1fbd893ca1c9"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 7210551476}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "cb4980b531fe102ef4060ce93b68c3bc"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "69fc95c22701c7ee0abcd96985dd36ad237b340518f1f430b3b1f5adbd8a1586"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/7f5bc90746c74965a6249a8bdd9d321b.bam", "title": "7f5bc90746c74965a6249a8bdd9d321b.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283220", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:57.564+00:00", "source": "#m45S7F5dX48SHsj1", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_7JB11CDK"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_7JB11CDK"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21957"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/1c47e791-7cec-480c-9217-1c1183347f21"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 6720707941}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "e82e1c066852cc5497d16cd008ae6048"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "1d87db84a6aad5bc5fbd6f94e14f383cd85959528667cd958cda14477bc31658"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/27045cf5dbeb4392b67e68c88cb808ad.bam", "title": "27045cf5dbeb4392b67e68c88cb808ad.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283224", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:58.802+00:00", "source": "#vSOcDlTZ1fcq4NhK", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_64QXSCG4"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_64QXSCG4"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21957"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/a54485bf-6a68-475b-8dad-742a64395df8"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 7632775093}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "00b81a04448edbf57028d962d3eddad5"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "e4e7478e0290c1cb94085165bf2a73dde946e6188eafb05389d69bc0b38c86c2"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/1ad79208a0504030989b89b327d28d98.bam", "title": "1ad79208a0504030989b89b327d28d98.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283230", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:58.879+00:00", "source": "#wrwhnhYJz30bfUyG", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_406QVKWP"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_406QVKWP"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21962"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/a07e921f-dc63-42fb-8ec3-e4146032b127"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 16440552569}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "27911327e8be6d3c813bd4f097c21e27"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "da43029ceced3d7cf1ad15d7bf7320a664cbe531e4dc59930e5938441f78cf53"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/0977a0a1535a4dbdb43988d4232f170e.bam", "title": "0977a0a1535a4dbdb43988d4232f170e.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283237", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:58.335+00:00", "source": "#FTll3OP3ZuYT2K60", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_XXERZHAJ"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_XXERZHAJ"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21962"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/a6b48b6a-cce8-4dfe-a3db-bbb4c63fbf98"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 5523600412}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "d9a490454bc370742797ed03c7b8615a"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "6a191b559f02cece134c8ee5526a3130be240891801628b6d4ec685ca6375dee"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/0a854fb67d364131ace0ef0f60f39214.bam", "title": "0a854fb67d364131ace0ef0f60f39214.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283243", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:59.341+00:00", "source": "#OFm1bULS5oSo95Jt", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_CCYKAMFF"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_CCYKAMFF"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls"}, "subject": {"reference": "Patient/21976"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/d0e6e8cb-d4fa-48ce-9b54-f148c1daafd4"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 650575193}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "fc4f31c91d648f0dd2ebea47da91c656-3"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/544b5046-6594-4bab-97e9-b1c2a5889cc7.postCGP.Gfiltered.vcf.gz", "title": "544b5046-6594-4bab-97e9-b1c2a5889cc7.postCGP.Gfiltered.vcf.gz"}, "format": {"display": "vcf"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283250", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:59.256+00:00", "source": "#VU11QTCQdPD4s9Oa", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_0HHRPHJE"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_0HHRPHJE"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21976"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/793b6afb-4b79-420d-a645-5f213824a902"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 13373342428}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "4f1cd8e75bce78f7d43dfb6f09a8d978"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "f8b3e0aaa8a3a05e95bcfac82a03ce7a7ee6e625438599c1dfa5fd4221318404"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/eab2cbf0bba3475d9d86f66ae1332837.bam", "title": "eab2cbf0bba3475d9d86f66ae1332837.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283255", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:59.999+00:00", "source": "#yVKYIu1SzOO9xttl", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_9Q2308Z4"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_9Q2308Z4"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21976"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/0cf69b99-b0fe-43e8-bce6-82b8267a6f3d"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 7000673803}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "91c1cec05bcf9eb901b561367c049c9e"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "fdc9ce58a9bac3c7fbea25870c69bf9cc6e48fd4232dc2a99131487ef467aecc"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/84ae4893977941b5a8d3704bc1edc086.bam", "title": "84ae4893977941b5a8d3704bc1edc086.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283265", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:00.477+00:00", "source": "#3qAY73EQi48s5d73", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_JAER7603"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_JAER7603"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21967"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/fb93172e-430d-4f33-b54b-86d87ca5e1dc"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 4702336461}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "9634293778ea32884939c44855881917"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "a019ace2dfdb6907f03cfecbd872008a203dcfa9cb13a3095de79823dff13e83"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/44c4a9d80a5a4c02950aaf824f5edb98.bam", "title": "44c4a9d80a5a4c02950aaf824f5edb98.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283272", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:00.716+00:00", "source": "#R5mpIFU8ftQ8PBqR", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_FYH6N2BZ"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_FYH6N2BZ"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21965"}, "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/0a295bbd-4cc3-4b90-9b27-dbb5d08bff23"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 17820828374}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "849900b86abe216505fb7228cc9f9003"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "06f931a04e16328eb7a5fa1e25db62740b76cfeeb14fb67fac48422971684bdb"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/94d4e32ce56c45389613bc5433a35dc4.bam", "title": "94d4e32ce56c45389613bc5433a35dc4.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283277", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:00.873+00:00", "source": "#eVgdZ8LSJxuNCTXU", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_DFSHPAHF"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_DFSHPAHF"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21968"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/8c25e6f0-2ba8-45d9-a309-03f4d1c245b9"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 8080395033}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "5658a96f25524740254cf0487dc6d106"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "bc91ed531d7f3dbf0783df94c127504bb451f09531082e8db08fda62f13ce151"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/a12f3f402726496c949835175dcddae3.bam", "title": "a12f3f402726496c949835175dcddae3.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283283", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:00.634+00:00", "source": "#6fnrVjYBLCyNK8dj", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_53G2X1WA"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_53G2X1WA"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls"}, "subject": {"reference": "Patient/21967"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/86dddce5-cb3c-45b1-8f7a-74c7c8175687"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 666066390}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "6952e747399a260c52a2f4e6d709b8c1-3"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/dbe3cb9e-272a-456d-a8c1-77ff42484c19.CGP.filtered.deNovo.vep.vcf.gz", "title": "dbe3cb9e-272a-456d-a8c1-77ff42484c19.CGP.filtered.deNovo.vep.vcf.gz"}, "format": {"display": "vcf"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283290", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:01.931+00:00", "source": "#ZwHWXUNWypZMHkNH", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_DJ13D2HW"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_DJ13D2HW"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls"}, "subject": {"reference": "Patient/21971"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/62e30124-4b40-47d1-b59d-e458edc9cd82"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 660629220}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "76820ce25475c2f8f8b09b8e75f67177-3"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/a530be51-0a6e-4319-b006-5f8b1fdc0a39.CGP.filtered.deNovo.vep.vcf.gz", "title": "a530be51-0a6e-4319-b006-5f8b1fdc0a39.CGP.filtered.deNovo.vep.vcf.gz"}, "format": {"display": "vcf"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283187", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:56.798+00:00", "source": "#SbpxlpFck3F4wxtJ", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_NE3GS1T4"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_NE3GS1T4"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls"}, "subject": {"reference": "Patient/21953"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/bebb3ba1-4ad9-4d8c-aea5-e52e09b5de59"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 535905881}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "d1682d8d91fc97ef4e1eb6652fa2364e-2"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/ba1606d2-b577-4df9-8ebb-8d6d16c78004.postCGP.Gfiltered.vcf.gz", "title": "ba1606d2-b577-4df9-8ebb-8d6d16c78004.postCGP.Gfiltered.vcf.gz"}, "format": {"display": "vcf"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283194", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:58.335+00:00", "source": "#07n4bczP5OIfgO4h", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_Y6HF9JPW"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_Y6HF9JPW"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls"}, "subject": {"reference": "Patient/21953"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/41af810b-deb5-40a5-af8f-ef9b3d74a731"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 617406460}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "8d9137768ca54e371f4caa5bb5266c95-3"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/5f52a0ce-5989-4a39-af0c-497bb038e871.CGP.filtered.deNovo.vep.vcf.gz", "title": "5f52a0ce-5989-4a39-af0c-497bb038e871.CGP.filtered.deNovo.vep.vcf.gz"}, "format": {"display": "vcf"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283201", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:56.798+00:00", "source": "#7QZenw3GarS2E1OP", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_C3PYRXEC"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_C3PYRXEC"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21956"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/2d9269a8-8c3f-4b2d-b423-0147fe6ef89a"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 4807578386}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "0a6709c1a2ab7decd7b4066a125ba74c"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "85e6bd0a995732fb76755bb9313b97187794b4bc2eeb8182d4d30b50bb7fd89c"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/4f16445311f9434b98e3226d7638f96b.bam", "title": "4f16445311f9434b98e3226d7638f96b.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283215", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:57.522+00:00", "source": "#pCwvMkKk9qiGoN8K", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_EQZCWG89"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_EQZCWG89"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21958"}, "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/94f59944-1649-49f9-af00-696d6fa378aa"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 72408136759}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "e2de418aad221b7a93adb4b7cbb98a9b"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "d4dc0455192b93012805cf63991690ec98df0097245cd2e2d8590823fb85be53"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteosarcoma/e5278d7e0f2e434d8b0b7c30b64b2c03.bam", "title": "e5278d7e0f2e434d8b0b7c30b64b2c03.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283219", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:57.367+00:00", "source": "#4OBAAG51wrLbFaG0", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_Y56652NB"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_Y56652NB"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21966"}, "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/49a01279-8b2b-46e2-bc74-8091d8154dd8"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 115142897320}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "ee3b181f9456c35e7cb9a3c61c00e03e"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "508329399d3e67bb4185e93512360b2790ee02fe13c6797935785bbdac4cc1f0"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_WGS_06Feb2017/a28dcf0e36824fd29609e68306b30746.bam", "title": "a28dcf0e36824fd29609e68306b30746.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283225", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:58.713+00:00", "source": "#DAG5eMNC3aaIgoms", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_FPST0WPE"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_FPST0WPE"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21957"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/ae7657f8-367d-4418-b332-25fbf6267412"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 129614067900}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "868b64f8923b2a4735a323900525afc7"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "067899ec8ceb1134cd7b31f623bbd4c2b2d75b9c723733164378a0be03bf8a2f"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteosarcoma/a458d2a833da45e286b53c14595cf106.bam", "title": "a458d2a833da45e286b53c14595cf106.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283235", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:59.996+00:00", "source": "#pXV2Lb3t8o7WwhDa", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_VYXBTZWX"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_VYXBTZWX"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21961"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/0299bac3-9fec-42fc-8ed4-d75eee9a69ad"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 6562577759}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "f56e94d6b3751b9afff29b60a7437965"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "fab62d64c488d17392d0b27efecac2195274e0a451b37870d67bf736f03c784e"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/c8991926cdcf40d8a57b883d97ea134f.bam", "title": "c8991926cdcf40d8a57b883d97ea134f.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283244", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:59.161+00:00", "source": "#IA5wacgzzo85RgIl", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_KF7C3183"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_KF7C3183"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21976"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/f6d0055d-fb3b-449f-9114-1d9e47d9020e"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 4463652503}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "52705fb868233015c90e81d27bc756d0"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "d6b6b98625c0e8ad7cb5fd2eecad08e38f2f74a325aab2a8354816adbb31bf8e"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/978c41c793584648b0d5a6cb80ffcb21.bam", "title": "978c41c793584648b0d5a6cb80ffcb21.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283257", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:19:59.999+00:00", "source": "#41QGoROQJwCdjYaK", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_XWWAVNWT"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_XWWAVNWT"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21976"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/0965f3bf-2a56-4338-99a7-b74ce4a29f17"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 3396638092}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "394452537f5ffa6af69d48f345a30144"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "99dee4e58ff150ffbad695045c72d93e2c5a252caf6eb826c8a36967035a3822"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/639c65960c1a4831988715ae7d2e0a7d.bam", "title": "639c65960c1a4831988715ae7d2e0a7d.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283266", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:00.441+00:00", "source": "#z6wz1cWIP5FZOvdX", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_CK8A526R"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_CK8A526R"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21967"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/df9aba2d-2567-43a7-ae6f-8267cf43d5a5"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 138396409631}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "7e9d18f21abdf0663329f0e96527c6ee"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "c2b5f378eec4e8bd2838bdf6c08edab26037dbf005656da6374a76ed33ee9378"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteosarcoma/2001885e6c55430e991df624763fb058.bam", "title": "2001885e6c55430e991df624763fb058.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# ...
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283363", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:04.033+00:00", "source": "#llsWFMkwHqTpwmLY", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_NDHCPPYA"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_NDHCPPYA"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21993"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/a1e3b16f-bcd1-4db8-9382-6b9da32dcac9"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 8348212677}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "12150c2992da335cdee556ecdc66acaf"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "1473699eb40401d97d74092a2e2c984ee3831ce7b8bfe192c337b03a832c7166"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/3d6ef0072cda4f89858130232381104b.bam", "title": "3d6ef0072cda4f89858130232381104b.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283364", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:04.083+00:00", "source": "#Fzx6nF7zs9PAbAQ4", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_MC6EE4XN"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_MC6EE4XN"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21997"}, "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/0bf942ce-3dbb-455d-b174-f588dc70b75e"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 74672914109}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "95c13577a647cdb62c41a71694f6e9d1"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "2dc329db08e8ad622a741690665b1a885307e6e19dab4d6506c47f51228d589d"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteosarcoma/eb853f0d4b364beb8fca8eebca3808b8.bam", "title": "eb853f0d4b364beb8fca8eebca3808b8.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283368", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:04.205+00:00", "source": "#XJbBwu5f33GCpCFn", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_V58HX3HY"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_V58HX3HY"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls"}, "subject": {"reference": "Patient/21999"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/500cb7c6-ce92-4d9c-8a73-a9950251cd0a"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 718587894}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "ac6effa61b80e94d4c1e8acde56d998b-3"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/333600c1-1ecc-44d8-b619-a282eda42658.postCGP.Gfiltered.vcf.gz", "title": "333600c1-1ecc-44d8-b619-a282eda42658.postCGP.Gfiltered.vcf.gz"}, "format": {"display": "vcf"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283374", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:04.438+00:00", "source": "#1BpCDCMOiB3w5c2A", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_N2P9K62J"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_N2P9K62J"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/21999"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/a5fe4066-db3c-48ea-85d3-2c79961a5dd5"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 4617218239}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "b8155e9a799fd0c1c32aaa6fac67f5f4"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "7aaf62448b3cd1ed3b091cb0d0c2f413819d078dea20aba10dbcb1459d8e313b"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_2017Dec01/f466627bfde049d4a4e840377fcc2a62.bam", "title": "f466627bfde049d4a4e840377fcc2a62.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283408", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:05.276+00:00", "source": "#rcO9823RfN0UULtG", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_SC0GQ815"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_SC0GQ815"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls Index"}, "subject": {"reference": "Patient/22015"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"text": "SD_ZXJFFMEF"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/a82e8aeb-dcae-4cb8-b0b4-8e661c1a0188"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 2407332}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "5565e7969a5fe0015f5795d6d0e4f047"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/c2579f47-aaa6-4f7d-8700-77a4b32cd584.postCGP.Gfiltered.vcf.gz.tbi", "title": "c2579f47-aaa6-4f7d-8700-77a4b32cd584.postCGP.Gfiltered.vcf.gz.tbi"}, "format": {"display": "tbi"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283413", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:06.015+00:00", "source": "#px5rAnlOjBm8oIgT", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_DWCKXRG3"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_DWCKXRG3"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/22002"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/110a5342-e0ad-4a81-82d8-f5de07574b22"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 4496965659}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "50be5a8112a793ee4d71378556647ea4"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "93af42729b4a6a2ed62c86fbf91d322f4af52641d1ddc42e19f3e84c3a3f06a2"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteo_Exomes_18January2018/b88ad8de9fea44feb518e2f4889e27a1.bam", "title": "b88ad8de9fea44feb518e2f4889e27a1.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283419", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:06.203+00:00", "source": "#zWWvG5IQXuZhV2p7", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_EPZX4FHB"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_EPZX4FHB"}], "status": "current", "docStatus": "final", "type": {"text": "Variant Calls"}, "subject": {"reference": "Patient/22005"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/ef3180ac-d31f-42ba-a153-ede65ca5aaab"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 683880820}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "etag"}], "text": "49b79c74536c08a1f18caf808fe95bc3-3"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/harmonized-data/simple-variants/fbbcdd79-e796-43d0-9758-d05c2f202bb8.CGP.filtered.deNovo.vep.vcf.gz", "title": "fbbcdd79-e796-43d0-9758-d05c2f202bb8.CGP.filtered.deNovo.vep.vcf.gz"}, "format": {"display": "vcf"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283438", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:06.019+00:00", "source": "#orLNagZIijJIw4L4", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_7YNPHC2C"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_7YNPHC2C"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/22009"}, "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/f92818b1-a891-433c-8067-8955c8402971"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 71680523666}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "96164c0dcd87c898aec5fffa984f88d5"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "389e85b234e3317833ded8e04b21afea996031c229f46ebb96ed8ac938fb37b5"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteosarcoma/6a06e7e687894f3dbaf4ea2300d629f7.bam", "title": "6a06e7e687894f3dbaf4ea2300d629f7.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________
# {"resourceType": "DocumentReference", "id": "283448", "meta": {"versionId": "3", "lastUpdated": "2022-01-18T22:20:06.861+00:00", "source": "#mUcsWo0lXAkjFkGj", "profile": ["https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference"], "tag": [{"code": "SD_ZXJFFMEF"}]}, "identifier": [{"system": "https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/", "value": "GF_RKK07S0D"}, {"system": "urn:kids-first:unique-string", "value": "DocumentReference-SD_ZXJFFMEF-GF_RKK07S0D"}], "status": "current", "docStatus": "final", "type": {"text": "Aligned Reads"}, "subject": {"reference": "Patient/22016"}, "securityLabel": [{"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v3-Confidentiality", "code": "R", "display": "restricted"}], "text": "True"}, {"coding": [{"code": "c1"}], "text": "phs001714.c1"}, {"text": "SD_ZXJFFMEF"}, {"coding": [{"code": "c999"}], "text": "phs001714.c999"}], "content": [{"attachment": {"url": "drs://data.kidsfirstdrc.org/180e1ee0-8fe8-46d3-8eea-65a9edcf78ef"}}, {"attachment": {"extension": [{"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size", "valueDecimal": 132113473675}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "md5"}], "text": "e09a9f6a58bfd62af953116978351f07"}}, {"url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes", "valueCodeableConcept": {"coding": [{"display": "sha256"}], "text": "4709c100bc7a8d8b54fca904eaff655959f0fe636f4d09f1f475687a5b2c1b97"}}], "url": "s3://kf-study-us-east-1-prd-sd-zxjffmef/source/washu/Osteosarcoma/33b8e78dcbae4d9ab400e84fe8452bdc.bam", "title": "33b8e78dcbae4d9ab400e84fe8452bdc.bam"}, "format": {"display": "bam"}}]}
# __________________________________________________

# %% [markdown]
# How would we find all the Document References for a patient?

# %% [markdown]
# Define a function that does a couple of things that are a routine part of our approach
# a) deals with pagination
# b) deals with converting one or more bundles to a list of resources
# c) uses the session we created
#
# It takes any query that would be submitted to the server endpoint.
#
# Care should be taken to not submit queries which would return large number of resources e.g. "/Patient"
#
# If you are uncertain use the page_limit to set a maximum number of pages that would be returned.

# %%
def run_query(query, page_limit=None):
    response = sess.get(f"{FHIR_SERVER}/{query}")
    bundles = [response.json()]
    next_page_link = next(filter(lambda link: link['relation'] == 'next', bundles[0]['link']), None)
    page_count = 1
    if page_limit:
        if page_count >= page_limit:
            next_page_link = None
    while next_page_link:
        next_page = sess.get(next_page_link['url']).json()
        bundles.append(next_page)
        next_page_link = next(filter(lambda link: link['relation'] == 'next', next_page['link']), None)
        page_count += 1
        if page_limit:
            if page_count >= page_limit:
                next_page_link = None
    
    resources = [entry['resource'] for sb in bundles for entry in sb['entry']]
    return resources

# NOTE: No cell output.

# %%
documents = run_query("Patient?identifier=Patient-SD_BHJXBDQK-PT_ZRQQC2S9")
print("# of documents:{}".format(len(documents)))
# Out:
# # of documents:1

# %%
for p in documents:
    for i in p['identifier']:
        print(i)
    print(p)
    print('_'*80)
# Out:
# {'value': 'C945009'}
# {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/', 'value': 'PT_ZRQQC2S9'}
# {'system': 'urn:kids-first:unique-string', 'value': 'Patient-SD_BHJXBDQK-PT_ZRQQC2S9'}
# {'resourceType': 'Patient', 'id': '74104', 'meta': {'versionId': '2', 'lastUpdated': '2021-11-16T08:42:36.313+00:00', 'source': '#AUYp4dxWaLedbTb9', 'profile': ['http://hl7.org/fhir/StructureDefinition/Patient'], 'tag': [{'code': 'SD_BHJXBDQK'}]}, 'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race', 'extension': [{'url': 'text', 'valueString': 'White'}, {'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2106-3', 'display': 'White'}}]}, {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity', 'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'}, {'url': 'ombCategory', 'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238', 'code': '2186-5', 'display': 'Not Hispanic or Latino'}}]}], 'identifier': [{'value': 'C945009'}, {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/', 'value': 'PT_ZRQQC2S9'}, {'system': 'urn:kids-first:unique-string', 'value': 'Patient-SD_BHJXBDQK-PT_ZRQQC2S9'}], 'gender': 'female'}
# ________________________________________________________________________________

# %%
documents = run_query("DocumentReference?subject=74104")
print("# of documents:{}".format(len(documents)))
# Out:
# # of documents:71

# %% [markdown]
# Create a dataframe for the files

# %%
documents[1]
# Out:
# {'resourceType': 'DocumentReference',
#  'id': '490694',
#  'meta': {'versionId': '1',
#   'lastUpdated': '2021-10-16T01:24:08.401+00:00',
#   'source': '#dbXRh1FqIuTWfpA0',
#   'profile': ['https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/drs-document-reference']},
#  'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/genomic-files/',
#    'value': 'GF_4RTXDX2E'},
#   {'system': 'urn:kids-first:unique-string',
#    'value': 'DocumentReference-SD_BHJXBDQK-GF_4RTXDX2E'}],
#  'status': 'current',
#  'docStatus': 'final',
#  'type': {'text': 'Pathology Reports'},
#  'subject': {'reference': 'Patient/74104'},
#  'securityLabel': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/v3-Confidentiality',
#      'code': 'R',
#      'display': 'restricted'}],
#    'text': 'True'},
#   {'text': 'SD_BHJXBDQK'},
#   {'coding': [{'code': 'c1'}], 'text': 'SD_BHJXBDQK.c1'}],
#  'content': [{'attachment': {'url': 'drs://data.kidsfirstdrc.org//5f874516-28cb-40da-a356-f1c3c548cc0d'}},
#   {'attachment': {'extension': [{'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size',
#       'valueDecimal': 555176},
#      {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#       'valueCodeableConcept': {'coding': [{'display': 'md5'}],
#        'text': '77ffade22206b7304d0da0c0b9bb10e4'}},
#      {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#       'valueCodeableConcept': {'coding': [{'display': 'sha256'}],
#        'text': 'c1032f11649fbb89ea32421e9455cbea2c9f774372ef9489cc9b5acd2294b319'}}],
#     'url': 's3://kf-study-us-east-1-prd-sd-bhjxbdqk/source/images/7316-3139/Pathology/Path-Report-7316-3139-Redacted.pdf',
#     'title': 'Path-Report-7316-3139-Redacted.pdf'},
#    'format': {'display': 'pdf'}}]}

# %%
documents[1]['content'][1]
# Out:
# {'attachment': {'extension': [{'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size',
#     'valueDecimal': 555176},
#    {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#     'valueCodeableConcept': {'coding': [{'display': 'md5'}],
#      'text': '77ffade22206b7304d0da0c0b9bb10e4'}},
#    {'url': 'https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes',
#     'valueCodeableConcept': {'coding': [{'display': 'sha256'}],
#      'text': 'c1032f11649fbb89ea32421e9455cbea2c9f774372ef9489cc9b5acd2294b319'}}],
#   'url': 's3://kf-study-us-east-1-prd-sd-bhjxbdqk/source/images/7316-3139/Pathology/Path-Report-7316-3139-Redacted.pdf',
#   'title': 'Path-Report-7316-3139-Redacted.pdf'},
#  'format': {'display': 'pdf'}}

# %%
details = [c for c in documents[1]['content'] if 'format' in c]
print(json.dumps(details, indent =3))
# Out:
# [
#    {
#       "attachment": {
#          "extension": [
#             {
#                "url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/file-size",
#                "valueDecimal": 555176
#             },
#             {
#                "url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "display": "md5"
#                      }
#                   ],
#                   "text": "77ffade22206b7304d0da0c0b9bb10e4"
#                }
#             },
#             {
#                "url": "https://nih-ncpi.github.io/ncpi-fhir-ig/StructureDefinition/hashes",
#                "valueCodeableConcept": {
#                   "coding": [
#                      {
#                         "display": "sha256"
#                      }
#                   ],
#                   "text": "c1032f11649fbb89ea32421e9455cbea2c9f774372ef9489cc9b5acd2294b319"
#                }
#             }
#          ],
#          "url": "s3://kf-study-us-east-1-prd-sd-bhjxbdqk/source/images/7316-3139/Pathology/Path-Report-7316-3139-Redacted.pdf",
#          "title": "Path-Report-7316-3139-Redacted.pdf"
#       },
#       "format": {
#          "display": "pdf"
#       }
#    }
# ]

# %%
details[0]['attachment']['title']
# Out:
# 'Path-Report-7316-3139-Redacted.pdf'

# %%
import pandas as pd

myDocs = []
for d in documents:
    kfid = [did for did in d['identifier'] if did['system']=='urn:kids-first:unique-string']
    details = [c for c in d['content'] if 'format' in c]
    if len(details) > 0:
        fmat = details[0]['format']['display']
        title = details[0]['attachment']['title']
    else:
        title = ""
        fmat = ""
    myDocs.append({
        #"kfid":kfid[0]['value'],
    "type":d['type']['text'],
    "format":fmat,
    "title":title

    #"drs":djson['content'][0]['attachment']['url']
                  }
    )

docsDF = pd.DataFrame(myDocs)
docsDF = docsDF.sort_values(["type", "format"])
from IPython.display import display, HTML
docsDF.style.set_properties(subset=['title'], **{'width': '12px'})
display (docsDF)
# Out:
# /Users/forei/imfenvs/fasp/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                    type format  \
# 2         Aligned Reads    bam
# 15        Aligned Reads    bam
# 63        Aligned Reads    bam
# 66        Aligned Reads    bam
# 67        Aligned Reads    bam
# ..                  ...    ...
# 51  Variant Calls Index    tbi
# 13                 gVCF   gVCF
# 53                 gVCF   gVCF
# 11           gVCF Index    tbi
# 56           gVCF Index    tbi
#
#                                                 title
# 2            1f2e4474-09f7-4cd0-b9eb-dca358bf16af.bam
# 15           01933cf0-982d-456e-ba21-bccbbbaacea7.bam
# 63           81526ece-87af-4885-925e-105fd8e7f8b4.bam
# 66  81526ece-87af-4885-925e-105fd8e7f8b4.local.tra...
# 67  9fbd4b22-d4c0-4b3d-a8cf-a2cf5c347d1f.Aligned.o...
# ..                                                ...
# 51  ebd9c103-0ffe-466c-b573-ac01fa6b264d.consensus...
# 13      882e7692-5b48-4249-acc6-e93a4f10d232.g.vcf.gz
# 53      88afb639-3022-42aa-8e53-0a8b6c8e1329.g.vcf.gz
# 11  882e7692-5b48-4249-acc6-e93a4f10d232.g.vcf.gz.tbi
# 56  88afb639-3022-42aa-8e53-0a8b6c8e1329.g.vcf.gz.tbi
#
# [71 rows x 3 columns]

# %%
docsDF.to_csv('subject_74104_files.tsv', sep="\t")

# %% [markdown]
# For these 71 files
# Nothing tells us what the different bam files are.
# Nothing tells us which crai applies to which cram.
#
# Perhaps looking at samples for this subject might tell us that sequencing was done on more than one sample, e.g. tumor and somatic.
#
# How do we query for samples. We've seen that there are Specimen resources.
#
# The following is a guess - based on what worked for Documents

# %%
specimens = run_query("Specimen?subject=74104")
print("# of specimens:{}".format(len(specimens)))
# Out:
# # of specimens:19

# %% [markdown]
# OK! Let's look at the specimens

# %%
print (len(specimens))
for s in specimens:
    print(json.dumps(s, indent=3))
    print ('_'*50)
# Out:
# 19
# {
#    "resourceType": "Specimen",
#    "id": "457487",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T23:46:51.221+00:00",
#       "source": "#zJ9auAJadjNul0rs",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_EJG0RFX6"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_EJG0RFX6"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "text": "Not Reported"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "bodySite": {
#          "text": "Not Reported"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "457486",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T23:46:51.081+00:00",
#       "source": "#QtYDSYWXmLnq19SX",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_PEFRDKDZ"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_PEFRDKDZ"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "coding": [
#             {
#                "system": "http://purl.obolibrary.org/obo/uberon.owl",
#                "code": "UBERON:0001017"
#             }
#          ],
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "457484",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T23:46:50.979+00:00",
#       "source": "#9LGCuRfx3yUFFrnL",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_QX8PTX5X"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_QX8PTX5X"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "122551003",
#             "display": "Peripheral blood specimen (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Peripheral Whole Blood"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "457482",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T23:46:50.944+00:00",
#       "source": "#faJPcoVr33FDuWNM",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_4EN8D8Y4"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_4EN8D8Y4"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "27888000",
#             "display": "Ribonucleic acid (substance)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "coding": [
#             {
#                "system": "http://purl.obolibrary.org/obo/uberon.owl",
#                "code": "UBERON:0001017"
#             }
#          ],
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "427006",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:01.503+00:00",
#       "source": "#n5IOpcuibyMEZkG5",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_CWA50RW8"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_CWA50RW8"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "427005",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:01.415+00:00",
#       "source": "#JEn2jkGZZkpj9vgF",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_2WDK6MWX"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_2WDK6MWX"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "27888000",
#             "display": "Ribonucleic acid (substance)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "427004",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:01.363+00:00",
#       "source": "#fpnuh8zjnfWrQTqu",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_T839VVYW"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_T839VVYW"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "122551003",
#             "display": "Peripheral blood specimen (specimen)"
#          }
#       ],
#       "text": "Peripheral Whole Blood"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "quantity": {
#          "value": 1000.0,
#          "unit": "microliters",
#          "system": "http://unitsofmeasure.org",
#          "code": "uL"
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "427003",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:01.359+00:00",
#       "source": "#3NsOGz92mJSFqeuB",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_32VYKVBS"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_32VYKVBS"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426999",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:01.233+00:00",
#       "source": "#ZZabaX32kKfhnRJZ",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_5D77A3Q6"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_5D77A3Q6"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426997",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:01.108+00:00",
#       "source": "#u7Y1O9wdDCgL1TCT",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_VE5XA4X1"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_VE5XA4X1"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426996",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.995+00:00",
#       "source": "#IrQp1QO0PxqvvmMj",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_X54J8PGD"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_X54J8PGD"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426994",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.939+00:00",
#       "source": "#jOE7uTuTJl4sa3FD",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_K31YK6C9"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_K31YK6C9"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "122551003",
#             "display": "Peripheral blood specimen (specimen)"
#          }
#       ],
#       "text": "Peripheral Whole Blood"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "quantity": {
#          "value": 1000.0,
#          "unit": "microliters",
#          "system": "http://unitsofmeasure.org",
#          "code": "uL"
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426992",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.914+00:00",
#       "source": "#WF169cIhEScBVGgs",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_8RNAR5N3"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_8RNAR5N3"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426990",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.866+00:00",
#       "source": "#U2ouCmUJEvNCUdb2",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_9A8NPXQ0"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_9A8NPXQ0"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "122551003",
#             "display": "Peripheral blood specimen (specimen)"
#          }
#       ],
#       "text": "Peripheral Whole Blood"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "quantity": {
#          "value": 1000.0,
#          "unit": "microliters",
#          "system": "http://unitsofmeasure.org",
#          "code": "uL"
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426991",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.881+00:00",
#       "source": "#z6zI8ploHOX54prI",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_RPX5N18B"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_RPX5N18B"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "27888000",
#             "display": "Ribonucleic acid (substance)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426988",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.741+00:00",
#       "source": "#VzPEnK8yk1dTi3qt",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_7HM52B6P"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_7HM52B6P"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "122551003",
#             "display": "Peripheral blood specimen (specimen)"
#          }
#       ],
#       "text": "Peripheral Whole Blood"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "quantity": {
#          "value": 1000.0,
#          "unit": "microliters",
#          "system": "http://unitsofmeasure.org",
#          "code": "uL"
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426987",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.737+00:00",
#       "source": "#R9pPlgMcfp2T1IV5",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_Y07YTCPA"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_Y07YTCPA"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426986",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.659+00:00",
#       "source": "#WfmFW6A2bevcxtvD",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_4Q972C4Q"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_4Q972C4Q"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "122551003",
#             "display": "Peripheral blood specimen (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Peripheral Whole Blood"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________
# {
#    "resourceType": "Specimen",
#    "id": "426984",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T21:43:00.634+00:00",
#       "source": "#s37OwP6ISr8GppGk",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_KXYENVYY"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_KXYENVYY"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "122551003",
#             "display": "Peripheral blood specimen (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Peripheral Whole Blood"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "text": "Frontal Lobe"
#       }
#    }
# }
# __________________________________________________

# %% [markdown]
# It's hard to see what's going on there. Let's see if we can summarize. First it looks like there may have been specimens collected at more than one time. There's an extension used to record age. It's done in a complicated way - by defining and event birth, a relationship "after" and an offset a value and unit. (Wouldn't a CDE for days after birth have been easier?)
#
# Let's look at when the specimens were collected.

# %%
specimenCollection =[]
for s in specimens:
    if '_collectedDateTime' in s['collection']:
        offsetDuration = s['collection']['_collectedDateTime']['extension'][0]['extension'][2]['valueDuration']
        specimenCollection.append ({
    "id": s['id'],
    "time": offsetDuration['value'],
    "unit": offsetDuration['unit']
            })
        
    else:
            specimenCollection.append ({
    "id": s['id'],
    "time": None,
    "unit": None
            })    
            
            
specimenCollectionDF = pd.DataFrame(specimenCollection)
specimenCollectionDF
# Out:
#         id    time  unit
# 0   457487     NaN  None
# 1   457486  5407.0  days
# 2   457484  5407.0  days
# 3   457482  5407.0  days
# 4   427006  5407.0  days
# 5   427005  5407.0  days
# 6   427004  5407.0  days
# 7   427003  5407.0  days
# 8   426999  5407.0  days
# 9   426997  5407.0  days
# 10  426996  5407.0  days
# 11  426994  5407.0  days
# 12  426992  5407.0  days
# 13  426990  5407.0  days
# 14  426991  5407.0  days
# 15  426988  5407.0  days
# 16  426987  5407.0  days
# 17  426986  5407.0  days
# 18  426984  5407.0  days

# %% [markdown]
# Apart from one unknown specimen all were collected on the same day.
#
# What was collected?

# %% [markdown]
# That still doesn't tell us a lot. What was different about the solid tissue samples. Tumor? Normal? And the multiple blood samples can't be distinguished. There's also nothing linking the files to the specimens. Which were used for the sequencing and prodcued the bam files?
#
# The Collection method and site. The blood may have been collected during the surgical procedure

# %%
specimenDetails = []
for specimen in specimens:
    kfid = [did for did in specimen['identifier'] if did['system']=='urn:kids-first:unique-string']
    specimenDetails.append ({
    "id": specimen['id'],
    "urn:kids-first:unique-string": kfid[0]['value'],
    "type": specimen['type']['text'],
    "site": specimen['collection']['bodySite']['text']
    #"method": specimen['collection']['method']['text']
    })
specimensDF = pd.DataFrame(specimenDetails)
specimensDF = specimensDF.sort_values(["urn:kids-first:unique-string"])
specimensDF
# Out:
#         id      urn:kids-first:unique-string                    type  \
# 5   427005  Specimen-SD_BHJXBDQK-BS_2WDK6MWX            Solid Tissue
# 7   427003  Specimen-SD_BHJXBDQK-BS_32VYKVBS            Solid Tissue
# 3   457482  Specimen-SD_BHJXBDQK-BS_4EN8D8Y4            Solid Tissue
# 17  426986  Specimen-SD_BHJXBDQK-BS_4Q972C4Q  Peripheral Whole Blood
# 8   426999  Specimen-SD_BHJXBDQK-BS_5D77A3Q6            Solid Tissue
# 15  426988  Specimen-SD_BHJXBDQK-BS_7HM52B6P  Peripheral Whole Blood
# 12  426992  Specimen-SD_BHJXBDQK-BS_8RNAR5N3            Solid Tissue
# 13  426990  Specimen-SD_BHJXBDQK-BS_9A8NPXQ0  Peripheral Whole Blood
# 4   427006  Specimen-SD_BHJXBDQK-BS_CWA50RW8            Solid Tissue
# 0   457487  Specimen-SD_BHJXBDQK-BS_EJG0RFX6            Not Reported
# 11  426994  Specimen-SD_BHJXBDQK-BS_K31YK6C9  Peripheral Whole Blood
# 18  426984  Specimen-SD_BHJXBDQK-BS_KXYENVYY  Peripheral Whole Blood
# 1   457486  Specimen-SD_BHJXBDQK-BS_PEFRDKDZ            Solid Tissue
# 2   457484  Specimen-SD_BHJXBDQK-BS_QX8PTX5X  Peripheral Whole Blood
# 14  426991  Specimen-SD_BHJXBDQK-BS_RPX5N18B            Solid Tissue
# 6   427004  Specimen-SD_BHJXBDQK-BS_T839VVYW  Peripheral Whole Blood
# 9   426997  Specimen-SD_BHJXBDQK-BS_VE5XA4X1            Solid Tissue
# 10  426996  Specimen-SD_BHJXBDQK-BS_X54J8PGD            Solid Tissue
# 16  426987  Specimen-SD_BHJXBDQK-BS_Y07YTCPA            Solid Tissue
#
#             site
# 5   Frontal Lobe
# 7   Frontal Lobe
# 3   Frontal Lobe
# 17  Frontal Lobe
# 8   Frontal Lobe
# 15  Frontal Lobe
# 12  Frontal Lobe
# 13  Frontal Lobe
# 4   Frontal Lobe
# 0   Not Reported
# 11  Frontal Lobe
# 18  Frontal Lobe
# 1   Frontal Lobe
# 2   Frontal Lobe
# 14  Frontal Lobe
# 6   Frontal Lobe
# 9   Frontal Lobe
# 10  Frontal Lobe
# 16  Frontal Lobe

# %%
print(json.dumps(specimens[1],indent=3))
# Out:
# {
#    "resourceType": "Specimen",
#    "id": "457486",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-10-15T23:46:51.081+00:00",
#       "source": "#QtYDSYWXmLnq19SX",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/Specimen"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/biospecimens/",
#          "value": "BS_PEFRDKDZ"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "Specimen-SD_BHJXBDQK-BS_PEFRDKDZ"
#       }
#    ],
#    "status": "available",
#    "type": {
#       "coding": [
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258435002",
#             "display": "Tumor tissue sample (specimen)"
#          },
#          {
#             "system": "http://snomed.info/sct",
#             "code": "258566005",
#             "display": "Deoxyribonucleic acid sample (specimen)"
#          }
#       ],
#       "text": "Solid Tissue"
#    },
#    "subject": {
#       "reference": "Patient/74104"
#    },
#    "collection": {
#       "_collectedDateTime": {
#          "extension": [
#             {
#                "url": "http://hl7.org/fhir/StructureDefinition/relative-date",
#                "extension": [
#                   {
#                      "url": "event",
#                      "valueCodeableConcept": {
#                         "coding": [
#                            {
#                               "system": "http://snomed.info/sct",
#                               "code": "3950001",
#                               "display": "Birth"
#                            }
#                         ]
#                      }
#                   },
#                   {
#                      "url": "relationship",
#                      "valueCode": "after"
#                   },
#                   {
#                      "url": "offset",
#                      "valueDuration": {
#                         "value": 5407,
#                         "unit": "days",
#                         "system": "http://unitsofmeasure.org",
#                         "code": "d"
#                      }
#                   }
#                ]
#             }
#          ]
#       },
#       "bodySite": {
#          "coding": [
#             {
#                "system": "http://purl.obolibrary.org/obo/uberon.owl",
#                "code": "UBERON:0001017"
#             }
#          ],
#          "text": "Frontal Lobe"
#       }
#    }
# }

# %% [markdown]
# ### Back to Genomics
# Which is our goal, and the leukemia study
#
# Find the subjects in the study

# %%
studyid = 123556
subjects = run_query(f"ResearchSubject?study={studyid}")
print("# of subjects:{}".format(len(subjects)))

print("# of subjects in study {}:{}".format(studyid, len(subjects)))
for s in subjects[30:40]:
    print(json.dumps(s, indent=3))
    print('_'*50)
# Out:
# # of subjects:620
# # of subjects in study 123556:620
# {
#    "resourceType": "ResearchSubject",
#    "id": "124146",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:47.863+00:00",
#       "source": "#33wdBTeajVBdfxma",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "56830.003"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_SEK700X2"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_SEK700X2"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122881"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124145",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:45.945+00:00",
#       "source": "#0DVpfnSaWIvBGDKA",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "4643.01-006"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_9AS4N1EW"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_9AS4N1EW"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122871"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124144",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:44.254+00:00",
#       "source": "#A3njMAgUQndZG2dL",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "4643.01-005"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_THF70VGJ"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_THF70VGJ"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122868"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124143",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:48.264+00:00",
#       "source": "#ESx0WkYBp0Os4fwe",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "56830.004"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_KX4ZSEC4"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_KX4ZSEC4"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122875"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124142",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:44.644+00:00",
#       "source": "#GIClDwRHb0BBlgED",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "24124.017"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_FCEHBG2S"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_FCEHBG2S"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122870"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124141",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:47.963+00:00",
#       "source": "#JaEuiOo4g15p0yZ3",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "696-06-002"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_ZS6TW9P0"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_ZS6TW9P0"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122878"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124140",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:43.941+00:00",
#       "source": "#5DltWLtSad3INlD6",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "SJALL057890"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_0WHRNB5R"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_0WHRNB5R"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122874"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124139",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:46.042+00:00",
#       "source": "#1RZVYNGMdrvgTUPc",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "SJNORM057893"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_9E2YZB1Y"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_9E2YZB1Y"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122872"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124138",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:43.628+00:00",
#       "source": "#ou1FexlAn2JpwYuh",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "10993.024"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_QB6A9HYW"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_QB6A9HYW"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122864"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "124137",
#    "meta": {
#       "versionId": "3",
#       "lastUpdated": "2021-11-16T16:54:43.709+00:00",
#       "source": "#OyoGCujOdMNmqJ90",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ],
#       "tag": [
#          {
#             "code": "SD_W0V965XZ"
#          }
#       ]
#    },
#    "identifier": [
#       {
#          "value": "SJNORM057892"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_SJC42CH8"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_W0V965XZ-PT_SJC42CH8"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/123556"
#    },
#    "individual": {
#       "reference": "Patient/122865"
#    }
# }
# __________________________________________________

# %% [markdown]
# Define a function to get Files

# %%
def getFiles(sess, subject_id):
    response = sess.get(f"{FHIR_SERVER}/DocumentReference?subject={subject_id}")
    bundle = response.json()
    documents = [entry['resource'] for entry in bundle['entry']]

    print("# of documents for subject {} :{}".format(subject_id, len(documents)))

    myDocs = []
    for d in documents:
        #print(json.dumps(d, indent=3))
        myDocs.append({

        "type":d['type']['text'],
        "format":d['content'][0]['format']['display']
        })

    docsDF = pd.DataFrame(myDocs)
    docsDF = docsDF.sort_values(["type", "format"])
    print(docsDF)

# %% [markdown]
# And use that function to get the files for the patients above

# %%
response = sess.get(f"{FHIR_SERVER}/DocumentReference?subject=122881")
bundle = response.json()
if 'entry' in bundle:
    documents = [entry['resource'] for entry in bundle['entry']]
else:
    documents = []
print("# of documents:{}".format(len(documents)))
# Out:
# # of documents:0

# %%
documents = run_query("DocumentReference?subject=122881")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_9701/3893163486.py in <module>
# ----> 1 documents = run_query("DocumentReference?subject=122881")
#
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_9701/2562613823.py in run_query(query, page_limit)
#      16                 next_page_link = None
#      17
# ---> 18     return resources
#      19
#      20 # NOTE: No cell output.
#
# NameError: name 'resources' is not defined

# %%
for s in subjects[30:40]:
    patient = s['individual']['reference']
    print(patient)
    getFiles(sess, patient)
    print('_'*50)
# Out:
# Patient/122881
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_9701/4272514292.py in <module>
#       2     patient = s['individual']['reference']
#       3     print(patient)
# ----> 4     getFiles(sess, patient)
#       5     print('_'*50)
#
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_9701/2228775310.py in getFiles(sess, subject_id)
#       2     response = sess.get(f"{FHIR_SERVER}/DocumentReference?subject={subject_id}")
#       3     bundle = response.json()
# ----> 4     documents = [entry['resource'] for entry in bundle['entry']]
#       5
#       6     print("# of documents for subject {} :{}".format(subject_id, len(documents)))
#
# KeyError: 'entry'

# %% [markdown]
# ### Can we search for bams specifically?
#
# #TODO fix this

# %%
response = sess.get(f"{FHIR_SERVER}/DocumentReference?format__text=bam")
bundle = response.json()

bams = [entry['resource'] for entry in bundle['entry']]
print("# of bams:{}".format(len(bams)))

import pandas as pd

file1 = open("bam_subjects.txt","w") 
for d in bams:
    #print(djson['subject'])
    file1.write(d['subject']['reference']+'\n')

file1.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_10017/1859935365.py in <module>
#       2 bundle = response.json()
#       3
# ----> 4 bams = [entry['resource'] for entry in bundle['entry']]
#       5 print("# of bams:{}".format(len(bams)))
#       6
#
# KeyError: 'entry'

# %% [markdown]
# Try getting everything and inspect the results

# %%
response = sess.get(f"{FHIR_SERVER}/DocumentReference")
bundle = response.json()

documents = [entry['resource'] for entry in bundle['entry']]
print("# of documents:{}".format(len(documents)))

#import pandas as pd

file1 = open("all_docs.txt","w") 
for d in documents:
    if 'format' in d['content'][0]:
        fmt = d['content'][0]['format']['display']
    else:
        fmt = 'none'
    file1.write("{}\t{}\n".format(fmt,d['subject']['reference']))                
file1.close()
# Out:
# # of documents:50

# %% [markdown]
# Try a different study

# %%
studyid = 701322
response = sess.get(f"{FHIR_SERVER}/ResearchSubject?study={studyid}")
bundle = response.json()

subjects = [entry['resource'] for entry in bundle['entry']]
print("# of subjects:{}".format(len(subjects)))

print("# of subjects in study {}:{}".format(studyid, len(subjects)))
for s in subjects[30:40]:
    print(json.dumps(s, indent=3))
    print('_'*50)
# Out:
# # of subjects:50
# # of subjects in study 701322:50
# {
#    "resourceType": "ResearchSubject",
#    "id": "705462",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.838+00:00",
#       "source": "#Djd3HyXDFStZyuOw",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_41TVK406"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C3291480"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C3291480"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701278"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705461",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.804+00:00",
#       "source": "#goWKSesmQcjQBNqy",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_GJGB2TCX"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C1263702"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C1263702"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701284"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705460",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.763+00:00",
#       "source": "#817qgdXNcvVfRAHa",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_MYNNNN3E"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C165066"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C165066"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701297"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705459",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.741+00:00",
#       "source": "#E3x5DyOTWqhBsAXw",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_WVF8D0JE"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C773178"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C773178"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701272"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705458",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.726+00:00",
#       "source": "#FtEYGPFdIbbe3HX5",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_FF0NV7ZM"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C124599"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C124599"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701290"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705457",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.660+00:00",
#       "source": "#C9eyRUnM3MTJIMf2",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_R96GGC66"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C153996"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C153996"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701280"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705456",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.581+00:00",
#       "source": "#AdULX5BvDrdl2cXe",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_JKHNRED1"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C515124"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C515124"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701279"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705455",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.579+00:00",
#       "source": "#GEhs8au8ZlKSnxfi",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_0F3RHT8J"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C692244"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C692244"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701319"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705454",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.552+00:00",
#       "source": "#ycgE7COz7MtHYzPZ",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_8QH9FV9J"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C227058"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C227058"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701271"
#    }
# }
# __________________________________________________
# {
#    "resourceType": "ResearchSubject",
#    "id": "705453",
#    "meta": {
#       "versionId": "1",
#       "lastUpdated": "2021-06-16T02:04:43.477+00:00",
#       "source": "#GKGUgWtl1IDVjVPN",
#       "profile": [
#          "http://hl7.org/fhir/StructureDefinition/ResearchSubject"
#       ]
#    },
#    "identifier": [
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "PT_JQPMACNZ"
#       },
#       {
#          "system": "https://kf-api-dataservice.kidsfirstdrc.org/participants/",
#          "value": "?study_id=SD_BHJXBDQK&external_id=C2734905"
#       },
#       {
#          "system": "urn:kids-first:unique-string",
#          "value": "ResearchSubject-SD_BHJXBDQK-C2734905"
#       }
#    ],
#    "status": "off-study",
#    "study": {
#       "reference": "ResearchStudy/701322"
#    },
#    "individual": {
#       "reference": "Patient/701292"
#    }
# }
# __________________________________________________

# %%
#TODO - fix the query by format below

# %%
def getFiles2(sess, subject_id, file_type):
    response = sess.get(f"{FHIR_SERVER}/DocumentReference?subject={subject_id}&format_display={file_type}")
    bundle = response.json()
    myDocs = []
    if 'entry' in bundle:
        documents = [entry['resource'] for entry in bundle['entry']]

        print("# of {} files for subject {} :{}".format(file_type, subject_id, len(documents)))

        
        for d in documents:
            #print(json.dumps(d, indent=3))
            myDocs.append({

            "type":d['type']['text'],
            "format":d['content'][0]['format']['display']
            })

    if len(myDocs) > 0:
        docsDF = pd.DataFrame(myDocs)
        docsDF = docsDF.sort_values(["type", "format"])
        print(docsDF)
    else:
        print("No {} files found for subject {}".format(file_type, subject_id))

# %%
for s in subjects[30:40]:
    patient = s['individual']['reference']
    getFiles2(sess, patient, 'bam')
    print('_'*50)
# Out:
# No bam files found for subject Patient/701278
# __________________________________________________
# No bam files found for subject Patient/701284
# __________________________________________________
# No bam files found for subject Patient/701297
# __________________________________________________
# No bam files found for subject Patient/701272
# __________________________________________________
# No bam files found for subject Patient/701290
# __________________________________________________
# No bam files found for subject Patient/701280
# __________________________________________________
# No bam files found for subject Patient/701279
# __________________________________________________
# No bam files found for subject Patient/701319
# __________________________________________________
# No bam files found for subject Patient/701271
# __________________________________________________
# No bam files found for subject Patient/701292
# __________________________________________________
