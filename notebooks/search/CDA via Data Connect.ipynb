# %% [markdown]
# This GA4GH Data Connect table represents the NCI Cancer Data Aggregator (CDA) Minimal Viable Product (MVP) v3 used in CDA testing in May 2021.
#
# The aim of this notebook is to explore queries via Data Connect in comparison with use of the CDA API directly. Looking at both the Data Connect and CDA APIs explore the data integration and aggregation can be performed. These two APIs may help inform one another.
#
# Some of the equivalent queries in this notebook were explored in CDA in the following GitHub repository https://github.com/ianfore/cdatest.
#
#
# ## Schema as represented in Data Connect
# What information does the schema contain for the CDA table? The following shows that the schema duplicates the BigQuery definition of the table.
#
# Reading a machine readable schema from CDA may allow creation of a schema which provides more information to a) a human user and b) a query toolset which can make use of machine readable schema. See below.

# %%
from fasp.search import DataConnectClient
cl = DataConnectClient('https://data.publisher.dnastack.com/data-connect')
cl.listTableInfo('collections.public_datasets.cshcodeathon_cda_mvp_v3', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.cshcodeathon_cda_mvp_v3_
# {
#    "name": "collections.public_datasets.cshcodeathon_cda_mvp_v3",
#    "description": "Automatically generated schema",
#    "data_model": {
#       "$id": "https://data.publisher.dnastack.com/table/collections.public_datasets.cshcodeathon_cda_mvp_v3/info",
#       "description": "Automatically generated schema",
#       "$schema": "http://json-schema.org/draft-07/schema#",
#       "properties": {
#          "days_to_birth": {
#             "format": "bigint",
#             "type": "int",
#             "$comment": "bigint"
#          },
#          "race": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "sex": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "ethnicity": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "researchsubject": {
#             "items": {
#                "type": "object",
#                "$comment": "row(array,array,string,string,string,array,string)",
#                "properties": {
#                   "Diagnosis": {
#                      "items": {
#                         "type": "object",
#                         "$comment": "row(string,string,string,array,string,string,int)",
#                         "properties": {
#                            "morphology": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "tumor_stage": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "tumor_grade": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "Treatment": {
#                               "items": {
#                                  "type": "object",
#                                  "$comment": "row(string,string)",
#                                  "properties": {
#                                     "type": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "outcome": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     }
#                                  }
#                               },
#                               "type": "array",
#                               "$comment": "array[object]"
#                            },
#                            "id": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "primary_diagnosis": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "age_at_diagnosis": {
#                               "format": "bigint",
#                               "type": "int",
#                               "$comment": "bigint"
#                            }
#                         }
#                      },
#                      "type": "array",
#                      "$comment": "array[object]"
#                   },
#                   "Specimen": {
#                      "items": {
#                         "type": "object",
#                         "$comment": "row(array,string,string,int,string,string,string,string,string,string,array)",
#                         "properties": {
#                            "File": {
#                               "items": {
#                                  "type": "object",
#                                  "$comment": "row(string,array,string,array,string,int,string,string,string,string,string)",
#                                  "properties": {
#                                     "label": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "associated_project": {
#                                        "items": {
#                                           "format": "varchar",
#                                           "type": "string",
#                                           "$comment": "varchar"
#                                        },
#                                        "type": "array",
#                                        "$comment": "array[string]"
#                                     },
#                                     "drs_uri": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "identifier": {
#                                        "items": {
#                                           "type": "object",
#                                           "$comment": "row(string,string)",
#                                           "properties": {
#                                              "system": {
#                                                 "format": "varchar",
#                                                 "type": "string",
#                                                 "$comment": "varchar"
#                                              },
#                                              "value": {
#                                                 "format": "varchar",
#                                                 "type": "string",
#                                                 "$comment": "varchar"
#                                              }
#                                           }
#                                        },
#                                        "type": "array",
#                                        "$comment": "array[object]"
#                                     },
#                                     "data_category": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "byte_size": {
#                                        "format": "bigint",
#                                        "type": "int",
#                                        "$comment": "bigint"
#                                     },
#                                     "type": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "file_format": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "checksum": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "id": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "data_type": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     }
#                                  }
#                               },
#                               "type": "array",
#                               "$comment": "array[object]"
#                            },
#                            "derived_from_specimen": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "associated_project": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "age_at_collection": {
#                               "format": "bigint",
#                               "type": "int",
#                               "$comment": "bigint"
#                            },
#                            "anatomical_site": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "source_material_type": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "derived_from_subject": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "specimen_type": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "id": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "primary_disease_type": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "identifier": {
#                               "items": {
#                                  "type": "object",
#                                  "$comment": "row(string,string)",
#                                  "properties": {
#                                     "system": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     },
#                                     "value": {
#                                        "format": "varchar",
#                                        "type": "string",
#                                        "$comment": "varchar"
#                                     }
#                                  }
#                               },
#                               "type": "array",
#                               "$comment": "array[object]"
#                            }
#                         }
#                      },
#                      "type": "array",
#                      "$comment": "array[object]"
#                   },
#                   "associated_project": {
#                      "format": "varchar",
#                      "type": "string",
#                      "$comment": "varchar"
#                   },
#                   "id": {
#                      "format": "varchar",
#                      "type": "string",
#                      "$comment": "varchar"
#                   },
#                   "primary_disease_type": {
#                      "format": "varchar",
#                      "type": "string",
#                      "$comment": "varchar"
#                   },
#                   "identifier": {
#                      "items": {
#                         "type": "object",
#                         "$comment": "row(string,string)",
#                         "properties": {
#                            "system": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            },
#                            "value": {
#                               "format": "varchar",
#                               "type": "string",
#                               "$comment": "varchar"
#                            }
#                         }
#                      },
#                      "type": "array",
#                      "$comment": "array[object]"
#                   },
#                   "primary_disease_site": {
#                      "format": "varchar",
#                      "type": "string",
#                      "$comment": "varchar"
#                   }
#                }
#             },
#             "type": "array",
#             "$comment": "array[object]"
#          }
#       }
#    }
# }

# %% [markdown]
# Save the schema to a file

# %%
tableInfo = cl.listTableInfo('collections.public_datasets.cshcodeathon_cda_mvp_v3')
with open('data/cda_mvp_v3_dc_schema.json', 'w', encoding='utf-8') as f:
    json.dump(tableInfo.schema, f, ensure_ascii=False, indent=3)

# %% [markdown]
# As in other cases the schema above loaded from BigQuery provides only limited information. In those other cases the Data Connect schema has been enhanced by importing from machine readble schema provided by the source system, for example by reading dbGaP data dictionaries. For CDA MVP v3 json schemas were published [here](https://github.com/CancerDataAggregator/cda-data-model). Separate JSON Schema were provided for different CDA objects as opposed to the single nested schema above. For example, this is the [CDA schema for Specimen](https://github.com/CancerDataAggregator/cda-data-model/blob/main/src/schema/json/Specimen.json). Automated translation of the schema may be possible. For now a [manually integrated schema](cda_mvp_v3_dc_schema_integrated.json) was created incorporating descriptions from the CDA schemas.

# %% [markdown]
# ## Queries
#
# The following repeats one of the queries conducted using the CDA API. In that case the query required the use of SQL rather than the json query the CDA API provides. The json approach only provides limited capability to combine the criteria within a query.
#
# The query identifies unique subjects with data in the CPTAC-2 study with Stage IIB colon cancer.

# %%
query1 = '''SELECT distinct p.id FROM collections.public_datasets.cshcodeathon_cda_mvp_v3 AS p, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis 
WHERE (((_ResearchSubject.associated_project = 'CPTAC-2') 
AND (_Diagnosis.tumor_stage = 'Stage IIB')) 
AND (_ResearchSubject.primary_disease_site = 'Colon'))'''

res = cl.runQuery(query1)
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# ____Page9_______________
# ____Page10_______________
# ____Page11_______________
# ____Page12_______________
# ____Page13_______________
# ____Page14_______________
# ____Page15_______________
# ____Page16_______________
# [['09CO022'], ['15CO002'], ['05CO039'], ['05CO044']]

# %% [markdown]
# The second query obtains all attributes for the subjects in the query above. It uses the previous query as a sub query.

# %%
query2 = ''' select * from collections.public_datasets.cshcodeathon_cda_mvp_v3
where id in
(SELECT distinct p.id FROM collections.public_datasets.cshcodeathon_cda_mvp_v3 AS p, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis 
WHERE (((_ResearchSubject.associated_project = 'CPTAC-2') 
AND (_Diagnosis.tumor_stage = 'Stage IIB')) 
AND (_ResearchSubject.primary_disease_site = 'Colon')) )'''

res2 = cl.runQuery(query2)
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# ____Page9_______________
# ____Page10_______________
# ____Page11_______________
# ____Page12_______________
# ____Page13_______________
# ____Page14_______________
# ____Page15_______________
# ____Page16_______________
# ____Page17_______________
# ____Page18_______________
# ____Page19_______________
# ____Page20_______________
# ____Page21_______________
# ____Page22_______________
# ____Page23_______________

# %% [markdown]
# Export the query results to a file.

# %%
import json
with open('data/data.json', 'w', encoding='utf-8') as f:
    json.dump(res2, f, ensure_ascii=False, indent=3)

# %% [markdown]
# Also dump the schema to a file

# %%
tableInfo = cl.listTableInfo('collections.public_datasets.cshcodeathon_cda_mvp_v3')
with open('data/cda_mvp_v3_dc_schema.json', 'w', encoding='utf-8') as f:
    json.dump(tableInfo.schema, f, ensure_ascii=False, indent=3)

# %% [markdown]
# Same where clause but requesting some named columns.

# %%
cl2 = DataConnectClient('https://data.publisher.dnastack.com/data-connect', debug=True)
query3 = ''' select days_to_birth, race, sex, researchsubject
from collections.public_datasets.cshcodeathon_cda_mvp_v3
where id in
(SELECT distinct p.id FROM collections.public_datasets.cshcodeathon_cda_mvp_v3 AS p, 
UNNEST(ResearchSubject) AS _ResearchSubject, 
UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis 
WHERE (((_ResearchSubject.associated_project = 'CPTAC-2') 
AND (_Diagnosis.tumor_stage = 'Stage IIB')) 
AND (_ResearchSubject.primary_disease_site = 'Colon')) )'''

res = cl.runQuery(query3)
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# ____Page9_______________
# ____Page10_______________
# ____Page11_______________
# ____Page12_______________
# ____Page13_______________
# ____Page14_______________
# ____Page15_______________
# ____Page16_______________
# ____Page17_______________
# ____Page18_______________
# ____Page19_______________
# ____Page20_______________
# ____Page21_______________
# ____Page22_______________
# ____Page23_______________
# ____Page24_______________
# ____Page25_______________
# ____Page26_______________
# ____Page27_______________
# ____Page28_______________
# ____Page29_______________
# ____Page30_______________
# ____Page31_______________
# ____Page32_______________
# ____Page33_______________
# ____Page34_______________
# ____Page35_______________
# ____Page36_______________
# ____Page37_______________
# [[None,
#   'white',
#   'male',
#   [{'Diagnosis': [{'morphology': '8140/3',
#       'tumor_stage': 'Stage IIB',
#       'tumor_grade': 'Not Reported',
#       'Treatment': [],
#       'id': '49674766-d911-4896-8978-c01ed945c4e9',
#       'primary_diagnosis': 'Adenocarcinoma, NOS',
#       'age_at_diagnosis': None}],
#     'Specimen': [{'File': [{'label': '7fb3b3a3-8dba-4ecd-8e7b-d61c9f7627a0.wxs.MuTect2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'identifier': [{'system': 'GDC',
#           'value': '098e18d4-5ece-4bc6-9a79-68f5082da9bc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 11606042,
#         'type': None,
#         'file_format': None,
#         'checksum': '351a76a43d5614d938045d9ff028c4ac',
#         'id': '098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '3bb17a95-aa01-4a01-97f5-1f02907d7bf1.wxs.MuSE.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'identifier': [{'system': 'GDC',
#           'value': '0d2a8f3e-86b4-4313-860c-7239b4ab413d'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1217587,
#         'type': None,
#         'file_format': None,
#         'checksum': '81c6251d98eddc493b9518c0f690ff2d',
#         'id': '0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'ebc9d464-3f9d-4733-b297-dd95c0fb1b87.mirnaseq.mirnas.quantification.txt',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:16049ed5-c8c6-4e5e-a8f0-8308ce8e0ae7',
#         'identifier': [{'system': 'GDC',
#           'value': '16049ed5-c8c6-4e5e-a8f0-8308ce8e0ae7'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 49648,
#         'type': None,
#         'file_format': None,
#         'checksum': '15c16690be1c1de203eef066f6c4c70b',
#         'id': '16049ed5-c8c6-4e5e-a8f0-8308ce8e0ae7',
#         'data_type': 'miRNA Expression Quantification'},
#        {'label': 'a4eb372e-09e2-4cb7-88ce-a7cd8ad7ec5e.FPKM-UQ.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1ed03c63-ec3c-4f06-be23-db6e6337bdde',
#         'identifier': [{'system': 'GDC',
#           'value': '1ed03c63-ec3c-4f06-be23-db6e6337bdde'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 384566,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c3d7d7317b5d598160145cecd7304560',
#         'id': '1ed03c63-ec3c-4f06-be23-db6e6337bdde',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'identifier': [{'system': 'GDC',
#           'value': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4628316,
#         'type': None,
#         'file_format': None,
#         'checksum': '9f12be88e380786e25dd6ea3b18066ef',
#         'id': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '89608678-9e71-4462-b5a2-f3724ce60ea6_mirnaseq_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:23ad96a5-aab4-4a81-ab61-3d5c925da652',
#         'identifier': [{'system': 'GDC',
#           'value': '23ad96a5-aab4-4a81-ab61-3d5c925da652'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 212239994,
#         'type': None,
#         'file_format': None,
#         'checksum': '1e6723e564bb9d3f229753dd398f7aa3',
#         'id': '23ad96a5-aab4-4a81-ab61-3d5c925da652',
#         'data_type': 'Aligned Reads'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.star_splice_junctions.tsv.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:259fc59f-6257-4222-a863-7c4501b81d4a',
#         'identifier': [{'system': 'GDC',
#           'value': '259fc59f-6257-4222-a863-7c4501b81d4a'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 2837616,
#         'type': None,
#         'file_format': None,
#         'checksum': '68cbbd381f6f8082c961671ce5b966af',
#         'id': '259fc59f-6257-4222-a863-7c4501b81d4a',
#         'data_type': 'Splice Junction Quantification'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_raw.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'identifier': [{'system': 'GDC',
#           'value': '4ae9d0da-721e-4de0-b6c7-06129b58ba45'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2458998,
#         'type': None,
#         'file_format': None,
#         'checksum': '029ae023b0ee3f2886062d6429658f37',
#         'id': '4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'data_type': 'Aggregated Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.chimeric.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4c6c170f-541d-471e-9ffe-e930d5a5d2eb',
#         'identifier': [{'system': 'GDC',
#           'value': '4c6c170f-541d-471e-9ffe-e930d5a5d2eb'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 45369677,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e0b96cbf0304b8ba19171d4a0f28d776',
#         'id': '4c6c170f-541d-471e-9ffe-e930d5a5d2eb',
#         'data_type': 'Aligned Reads'},
#        {'label': 'a4eb372e-09e2-4cb7-88ce-a7cd8ad7ec5e.htseq_counts.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:5b3f6db8-1b15-4b84-918f-a0f4f56ebf5b',
#         'identifier': [{'system': 'GDC',
#           'value': '5b3f6db8-1b15-4b84-918f-a0f4f56ebf5b'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 243946,
#         'type': None,
#         'file_format': None,
#         'checksum': 'b06964e35ef75daa6f5ce40c52a36c47',
#         'id': '5b3f6db8-1b15-4b84-918f-a0f4f56ebf5b',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '0a83021e-719e-4a82-b34a-ed86bac24748.wxs.VarScan2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:6862a7ed-794d-451d-b440-d893345ab893',
#         'identifier': [{'system': 'GDC',
#           'value': '6862a7ed-794d-451d-b440-d893345ab893'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4385332,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e60b6ae2628466dae941b83c8996faec',
#         'id': '6862a7ed-794d-451d-b440-d893345ab893',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.transcriptome.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:71cfbbc1-6379-4b33-85d2-2d59e5fbb9b1',
#         'identifier': [{'system': 'GDC',
#           'value': '71cfbbc1-6379-4b33-85d2-2d59e5fbb9b1'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 8734976957,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c793e25bc29b882bc9d7a09280ebca96',
#         'id': '71cfbbc1-6379-4b33-85d2-2d59e5fbb9b1',
#         'data_type': 'Aligned Reads'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'identifier': [{'system': 'GDC',
#           'value': '73f3b9e5-7521-4481-b476-ee361ff4c897'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2075565,
#         'type': None,
#         'file_format': None,
#         'checksum': '8a065d1b98c1d54e4e9506d0859bab98',
#         'id': '73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '5d1ca0c3-0520-4196-9103-99da010ed8af.wxs.pindel.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:74b844c9-11f1-48c5-a089-db959d9eca67',
#         'identifier': [{'system': 'GDC',
#           'value': '74b844c9-11f1-48c5-a089-db959d9eca67'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 298047,
#         'type': None,
#         'file_format': None,
#         'checksum': '7941308189e3b798c241c3f482f8aaa6',
#         'id': '74b844c9-11f1-48c5-a089-db959d9eca67',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.star_gene_counts.tsv.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:795b631d-1749-443f-9ddd-92cf4e799a70',
#         'identifier': [{'system': 'GDC',
#           'value': '795b631d-1749-443f-9ddd-92cf4e799a70'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 383403,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c61135e60809da41b41ad35fa051b9fc',
#         'id': '795b631d-1749-443f-9ddd-92cf4e799a70',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.muse.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'identifier': [{'system': 'GDC',
#           'value': '7e381e13-3847-49f5-b87e-be3fe62d23d0'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 129735,
#         'type': None,
#         'file_format': None,
#         'checksum': '6e2440c00e756adfb77d9104fee25a28',
#         'id': '7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '1f11224d-481b-4b7b-b395-6a34b414cd23.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'identifier': [{'system': 'GDC',
#           'value': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5227821,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a5e6aae0d0605f4fe67b2ca7d08843e',
#         'id': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '84851345-5ecf-4c02-b23e-1561bfafac9b.wxs.Pindel.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:80640356-8c20-4f3c-a300-4e4ac566f847',
#         'identifier': [{'system': 'GDC',
#           'value': '80640356-8c20-4f3c-a300-4e4ac566f847'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 893708,
#         'type': None,
#         'file_format': None,
#         'checksum': '0ed7ef1a0ed1894e693d0b749d307824',
#         'id': '80640356-8c20-4f3c-a300-4e4ac566f847',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'identifier': [{'system': 'GDC',
#           'value': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 517263,
#         'type': None,
#         'file_format': None,
#         'checksum': '132d17e0c385ba71c07ccb35d08c07f0',
#         'id': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': 'dddd8a00-b906-4975-aa83-a5c9e29f57af_wxs_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:8af77dd8-2787-41e3-8daf-e2843a87d61f',
#         'identifier': [{'system': 'GDC',
#           'value': '8af77dd8-2787-41e3-8daf-e2843a87d61f'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 55765843838,
#         'type': None,
#         'file_format': None,
#         'checksum': '1e23b9f0c56fc188719cb94ec20194b6',
#         'id': '8af77dd8-2787-41e3-8daf-e2843a87d61f',
#         'data_type': 'Aligned Reads'},
#        {'label': 'd686d9b8-23d7-4257-a854-54bc96a341da.wxs.MuSE.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'identifier': [{'system': 'GDC',
#           'value': '9744c86b-79a6-4121-9345-7c3bb685e8ef'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1841513,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c4daed4b22be8f2101de3fcc3d32f064',
#         'id': '9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'a4eb372e-09e2-4cb7-88ce-a7cd8ad7ec5e.FPKM.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:a321a327-b199-487d-a3c7-aa2e7f584857',
#         'identifier': [{'system': 'GDC',
#           'value': 'a321a327-b199-487d-a3c7-aa2e7f584857'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 304235,
#         'type': None,
#         'file_format': None,
#         'checksum': '2c10b87e6d6101dbd86bb9b5fa8f5d95',
#         'id': 'a321a327-b199-487d-a3c7-aa2e7f584857',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': 'c0f7f91d-6833-4821-8bf9-f7ad362de934.wxs.MuTect2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b93db769-02d9-4618-84d2-84639a134811',
#         'identifier': [{'system': 'GDC',
#           'value': 'b93db769-02d9-4618-84d2-84639a134811'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 8778875,
#         'type': None,
#         'file_format': None,
#         'checksum': 'bcd7e870a144d124a64982f22796db67',
#         'id': 'b93db769-02d9-4618-84d2-84639a134811',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '628fef11-6e60-4a36-9467-e60dc8389def.wxs.VarScan2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'identifier': [{'system': 'GDC',
#           'value': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3092401,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c889cca976c2f6325cd094ae543ab7a6',
#         'id': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_masked.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'identifier': [{'system': 'GDC',
#           'value': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 518784,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a579159c70fe48f479d5d5d82b0f1fa',
#         'id': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'data_type': 'Masked Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.genomic.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:e0d9ef90-36e6-416a-a8c8-a52e1c6b8584',
#         'identifier': [{'system': 'GDC',
#           'value': 'e0d9ef90-36e6-416a-a8c8-a52e1c6b8584'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 4270116957,
#         'type': None,
#         'file_format': None,
#         'checksum': '05e5bfb9988f99f2ecb5eea1cdb3a7ac',
#         'id': 'e0d9ef90-36e6-416a-a8c8-a52e1c6b8584',
#         'data_type': 'Aligned Reads'},
#        {'label': 'ebc9d464-3f9d-4733-b297-dd95c0fb1b87.mirnaseq.isoforms.quantification.txt',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:e3aa1e7f-f69c-4a7b-b5df-3cf8cfea5f1f',
#         'identifier': [{'system': 'GDC',
#           'value': 'e3aa1e7f-f69c-4a7b-b5df-3cf8cfea5f1f'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 433610,
#         'type': None,
#         'file_format': None,
#         'checksum': '8bd25182148a7a4f8e9dfedb1e16c276',
#         'id': 'e3aa1e7f-f69c-4a7b-b5df-3cf8cfea5f1f',
#         'data_type': 'Isoform Expression Quantification'},
#        {'label': '35b8d346-d6b2-473a-985d-96e552e5f8ad.wxs.SomaticSniper.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'identifier': [{'system': 'GDC',
#           'value': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3969992,
#         'type': None,
#         'file_format': None,
#         'checksum': 'cc66ce1f1cd3a43710710efd48cdd48b',
#         'id': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'd41bd840-2828-49c9-a9d0-0a6b3527851b.wxs.Pindel.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:fc17d77e-623d-422e-8643-7dd560f802cc',
#         'identifier': [{'system': 'GDC',
#           'value': 'fc17d77e-623d-422e-8643-7dd560f802cc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1065112,
#         'type': None,
#         'file_format': None,
#         'checksum': '564c4059d3e0989bba3a98bb1a970bb6',
#         'id': 'fc17d77e-623d-422e-8643-7dd560f802cc',
#         'data_type': 'Annotated Somatic Mutation'}],
#       'derived_from_specimen': 'Initial sample',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'sample',
#       'id': '18f23b20-a975-47e4-942c-7c246f9ff91b',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '18f23b20-a975-47e4-942c-7c246f9ff91b'}]},
#      {'File': [],
#       'derived_from_specimen': '18f23b20-a975-47e4-942c-7c246f9ff91b',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'portion',
#       'id': '99bb081e-44de-5138-abd5-3057553e77c6',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '99bb081e-44de-5138-abd5-3057553e77c6'}]},
#      {'File': [],
#       'derived_from_specimen': '99bb081e-44de-5138-abd5-3057553e77c6',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'analyte',
#       'id': '6d8a997e-27ce-599e-a70a-b436f9f18607',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '6d8a997e-27ce-599e-a70a-b436f9f18607'}]},
#      {'File': [],
#       'derived_from_specimen': '6d8a997e-27ce-599e-a70a-b436f9f18607',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'aliquot',
#       'id': '89608678-9e71-4462-b5a2-f3724ce60ea6',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '89608678-9e71-4462-b5a2-f3724ce60ea6'}]},
#      {'File': [],
#       'derived_from_specimen': '18f23b20-a975-47e4-942c-7c246f9ff91b',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'portion',
#       'id': 'd246cd58-c045-5b40-9c61-006110e22421',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'd246cd58-c045-5b40-9c61-006110e22421'}]},
#      {'File': [],
#       'derived_from_specimen': 'd246cd58-c045-5b40-9c61-006110e22421',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'analyte',
#       'id': '8b092388-fd16-5d5d-a3a1-2bcf330b7339',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '8b092388-fd16-5d5d-a3a1-2bcf330b7339'}]},
#      {'File': [],
#       'derived_from_specimen': '8b092388-fd16-5d5d-a3a1-2bcf330b7339',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'aliquot',
#       'id': 'dddd8a00-b906-4975-aa83-a5c9e29f57af',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'dddd8a00-b906-4975-aa83-a5c9e29f57af'}]},
#      {'File': [{'label': '7fb3b3a3-8dba-4ecd-8e7b-d61c9f7627a0.wxs.MuTect2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'identifier': [{'system': 'GDC',
#           'value': '098e18d4-5ece-4bc6-9a79-68f5082da9bc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 11606042,
#         'type': None,
#         'file_format': None,
#         'checksum': '351a76a43d5614d938045d9ff028c4ac',
#         'id': '098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '3bb17a95-aa01-4a01-97f5-1f02907d7bf1.wxs.MuSE.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'identifier': [{'system': 'GDC',
#           'value': '0d2a8f3e-86b4-4313-860c-7239b4ab413d'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1217587,
#         'type': None,
#         'file_format': None,
#         'checksum': '81c6251d98eddc493b9518c0f690ff2d',
#         'id': '0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'ef2e9c7f-f17e-4a98-abb3-04cae63e55d2_wxs_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1c5dfba4-2894-439a-bcab-986d75dd62f0',
#         'identifier': [{'system': 'GDC',
#           'value': '1c5dfba4-2894-439a-bcab-986d75dd62f0'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 48169707235,
#         'type': None,
#         'file_format': None,
#         'checksum': '18fb3eb80a7441182a014d056ca14df2',
#         'id': '1c5dfba4-2894-439a-bcab-986d75dd62f0',
#         'data_type': 'Aligned Reads'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'identifier': [{'system': 'GDC',
#           'value': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4628316,
#         'type': None,
#         'file_format': None,
#         'checksum': '9f12be88e380786e25dd6ea3b18066ef',
#         'id': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_raw.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'identifier': [{'system': 'GDC',
#           'value': '4ae9d0da-721e-4de0-b6c7-06129b58ba45'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2458998,
#         'type': None,
#         'file_format': None,
#         'checksum': '029ae023b0ee3f2886062d6429658f37',
#         'id': '4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'data_type': 'Aggregated Somatic Mutation'},
#        {'label': '0a83021e-719e-4a82-b34a-ed86bac24748.wxs.VarScan2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:6862a7ed-794d-451d-b440-d893345ab893',
#         'identifier': [{'system': 'GDC',
#           'value': '6862a7ed-794d-451d-b440-d893345ab893'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4385332,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e60b6ae2628466dae941b83c8996faec',
#         'id': '6862a7ed-794d-451d-b440-d893345ab893',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'identifier': [{'system': 'GDC',
#           'value': '73f3b9e5-7521-4481-b476-ee361ff4c897'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2075565,
#         'type': None,
#         'file_format': None,
#         'checksum': '8a065d1b98c1d54e4e9506d0859bab98',
#         'id': '73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '5d1ca0c3-0520-4196-9103-99da010ed8af.wxs.pindel.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:74b844c9-11f1-48c5-a089-db959d9eca67',
#         'identifier': [{'system': 'GDC',
#           'value': '74b844c9-11f1-48c5-a089-db959d9eca67'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 298047,
#         'type': None,
#         'file_format': None,
#         'checksum': '7941308189e3b798c241c3f482f8aaa6',
#         'id': '74b844c9-11f1-48c5-a089-db959d9eca67',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.muse.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'identifier': [{'system': 'GDC',
#           'value': '7e381e13-3847-49f5-b87e-be3fe62d23d0'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 129735,
#         'type': None,
#         'file_format': None,
#         'checksum': '6e2440c00e756adfb77d9104fee25a28',
#         'id': '7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '1f11224d-481b-4b7b-b395-6a34b414cd23.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'identifier': [{'system': 'GDC',
#           'value': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5227821,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a5e6aae0d0605f4fe67b2ca7d08843e',
#         'id': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '84851345-5ecf-4c02-b23e-1561bfafac9b.wxs.Pindel.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:80640356-8c20-4f3c-a300-4e4ac566f847',
#         'identifier': [{'system': 'GDC',
#           'value': '80640356-8c20-4f3c-a300-4e4ac566f847'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 893708,
#         'type': None,
#         'file_format': None,
#         'checksum': '0ed7ef1a0ed1894e693d0b749d307824',
#         'id': '80640356-8c20-4f3c-a300-4e4ac566f847',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'identifier': [{'system': 'GDC',
#           'value': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 517263,
#         'type': None,
#         'file_format': None,
#         'checksum': '132d17e0c385ba71c07ccb35d08c07f0',
#         'id': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': 'd686d9b8-23d7-4257-a854-54bc96a341da.wxs.MuSE.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'identifier': [{'system': 'GDC',
#           'value': '9744c86b-79a6-4121-9345-7c3bb685e8ef'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1841513,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c4daed4b22be8f2101de3fcc3d32f064',
#         'id': '9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'c0f7f91d-6833-4821-8bf9-f7ad362de934.wxs.MuTect2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b93db769-02d9-4618-84d2-84639a134811',
#         'identifier': [{'system': 'GDC',
#           'value': 'b93db769-02d9-4618-84d2-84639a134811'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 8778875,
#         'type': None,
#         'file_format': None,
#         'checksum': 'bcd7e870a144d124a64982f22796db67',
#         'id': 'b93db769-02d9-4618-84d2-84639a134811',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '628fef11-6e60-4a36-9467-e60dc8389def.wxs.VarScan2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'identifier': [{'system': 'GDC',
#           'value': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3092401,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c889cca976c2f6325cd094ae543ab7a6',
#         'id': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_masked.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'identifier': [{'system': 'GDC',
#           'value': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 518784,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a579159c70fe48f479d5d5d82b0f1fa',
#         'id': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'data_type': 'Masked Somatic Mutation'},
#        {'label': '35b8d346-d6b2-473a-985d-96e552e5f8ad.wxs.SomaticSniper.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'identifier': [{'system': 'GDC',
#           'value': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3969992,
#         'type': None,
#         'file_format': None,
#         'checksum': 'cc66ce1f1cd3a43710710efd48cdd48b',
#         'id': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'd41bd840-2828-49c9-a9d0-0a6b3527851b.wxs.Pindel.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:fc17d77e-623d-422e-8643-7dd560f802cc',
#         'identifier': [{'system': 'GDC',
#           'value': 'fc17d77e-623d-422e-8643-7dd560f802cc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1065112,
#         'type': None,
#         'file_format': None,
#         'checksum': '564c4059d3e0989bba3a98bb1a970bb6',
#         'id': 'fc17d77e-623d-422e-8643-7dd560f802cc',
#         'data_type': 'Annotated Somatic Mutation'}],
#       'derived_from_specimen': 'Initial sample',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'sample',
#       'id': '8388a834-d343-43b3-94ef-2def34217a19',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '8388a834-d343-43b3-94ef-2def34217a19'}]},
#      {'File': [],
#       'derived_from_specimen': '8388a834-d343-43b3-94ef-2def34217a19',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'portion',
#       'id': 'd4ae69c4-6643-514d-a19e-452cc3453e50',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'd4ae69c4-6643-514d-a19e-452cc3453e50'}]},
#      {'File': [],
#       'derived_from_specimen': 'd4ae69c4-6643-514d-a19e-452cc3453e50',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'analyte',
#       'id': 'ef40d91c-54ca-5367-9046-689288115c46',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'ef40d91c-54ca-5367-9046-689288115c46'}]},
#      {'File': [],
#       'derived_from_specimen': 'ef40d91c-54ca-5367-9046-689288115c46',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'aliquot',
#       'id': 'ef2e9c7f-f17e-4a98-abb3-04cae63e55d2',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'ef2e9c7f-f17e-4a98-abb3-04cae63e55d2'}]}],
#     'associated_project': 'CPTAC-2',
#     'id': '997475b1-6648-494a-9322-79aa17be272e',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': '997475b1-6648-494a-9322-79aa17be272e'}],
#     'primary_disease_site': 'Colon'},
#    {'Diagnosis': [{'morphology': '8140/3',
#       'tumor_stage': 'Stage IIB',
#       'tumor_grade': 'Not Reported',
#       'Treatment': [],
#       'id': 'ff2f357b-70ca-11e8-bcf1-0a2705229b82',
#       'primary_diagnosis': 'Adenocarcinoma, NOS',
#       'age_at_diagnosis': None}],
#     'Specimen': [{'File': [],
#       'derived_from_specimen': 'Initial specimen',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': 'Not Reported',
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': None,
#       'specimen_type': 'sample',
#       'id': '8b9f3cff-641b-11e8-bcf1-0a2705229b82',
#       'primary_disease_type': 'Colon Adenocarcinoma',
#       'identifier': [{'system': 'PDC',
#         'value': '8b9f3cff-641b-11e8-bcf1-0a2705229b82'}]},
#      {'File': [{'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:017e0e6e-a191-4135-a5f0-07a2819096f5',
#         'identifier': [{'system': 'PDC',
#           'value': '017e0e6e-a191-4135-a5f0-07a2819096f5'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 793619198,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '775c63f5560e10e30b319bec74a8c23b',
#         'id': '017e0e6e-a191-4135-a5f0-07a2819096f5',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:02a335f5-ea48-4d29-94b4-e1f50c94eb47',
#         'identifier': [{'system': 'PDC',
#           'value': '02a335f5-ea48-4d29-94b4-e1f50c94eb47'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8025509,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '9aa20115f7ce6d1de1cf18738bb5096a',
#         'id': '02a335f5-ea48-4d29-94b4-e1f50c94eb47',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:06b6f850-b3b6-492b-88a5-214906b71338',
#         'identifier': [{'system': 'PDC',
#           'value': '06b6f850-b3b6-492b-88a5-214906b71338'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1770001590,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '10e89c22c721d8fb3aa5bb0c72c1200b',
#         'id': '06b6f850-b3b6-492b-88a5-214906b71338',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:07dde26b-a6b4-4758-8f7d-483bb4340a95',
#         'identifier': [{'system': 'PDC',
#           'value': '07dde26b-a6b4-4758-8f7d-483bb4340a95'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 815359890,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '3340b297f69fa42ec8cf040aa1241c17',
#         'id': '07dde26b-a6b4-4758-8f7d-483bb4340a95',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:15c78167-3f73-45a1-ac95-f9a426cc1da8',
#         'identifier': [{'system': 'PDC',
#           'value': '15c78167-3f73-45a1-ac95-f9a426cc1da8'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6013332,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '89a9f28daa4066226ccc3b53952f53e7',
#         'id': '15c78167-3f73-45a1-ac95-f9a426cc1da8',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1f63a16d-ee0b-496f-a3cc-52eda4f199b1',
#         'identifier': [{'system': 'PDC',
#           'value': '1f63a16d-ee0b-496f-a3cc-52eda4f199b1'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 212959925,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '738459c88ef36a856b20ae8cebd6a46f',
#         'id': '1f63a16d-ee0b-496f-a3cc-52eda4f199b1',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:22634cb8-c4a5-40a5-a9d6-e447896e8681',
#         'identifier': [{'system': 'PDC',
#           'value': '22634cb8-c4a5-40a5-a9d6-e447896e8681'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5828812,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '9417890237e4ad537f99758cd5d24634',
#         'id': '22634cb8-c4a5-40a5-a9d6-e447896e8681',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:299bd409-a638-4e96-967d-1811b3f0a0ce',
#         'identifier': [{'system': 'PDC',
#           'value': '299bd409-a638-4e96-967d-1811b3f0a0ce'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5738281,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '10fa93c1364b3a4cbd4d59e53cc02ea5',
#         'id': '299bd409-a638-4e96-967d-1811b3f0a0ce',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2cec8163-ac36-45ba-bdf6-ece8372dd44a',
#         'identifier': [{'system': 'PDC',
#           'value': '2cec8163-ac36-45ba-bdf6-ece8372dd44a'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1675806496,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'c5fec55840ce4ab0723466120294cc4f',
#         'id': '2cec8163-ac36-45ba-bdf6-ece8372dd44a',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2e3a8f56-e8a1-4679-9ff6-1720613027d2',
#         'identifier': [{'system': 'PDC',
#           'value': '2e3a8f56-e8a1-4679-9ff6-1720613027d2'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 206027184,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '156eb01edc1622046f71876d8369d4b6',
#         'id': '2e3a8f56-e8a1-4679-9ff6-1720613027d2',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2e9d7ff3-5614-4a6b-bd9b-6a3c2303bfd1',
#         'identifier': [{'system': 'PDC',
#           'value': '2e9d7ff3-5614-4a6b-bd9b-6a3c2303bfd1'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7577002,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'c6a97eb4619acca5a0b356da69947230',
#         'id': '2e9d7ff3-5614-4a6b-bd9b-6a3c2303bfd1',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2f4abf53-ee6c-43d7-82f9-7b5d7a055ff7',
#         'identifier': [{'system': 'PDC',
#           'value': '2f4abf53-ee6c-43d7-82f9-7b5d7a055ff7'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5034214,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '2f8e87b42639d6cb16bfc190b0acfc11',
#         'id': '2f4abf53-ee6c-43d7-82f9-7b5d7a055ff7',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:306b5a13-abdd-4e87-a86c-b67409f5d0ab',
#         'identifier': [{'system': 'PDC',
#           'value': '306b5a13-abdd-4e87-a86c-b67409f5d0ab'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5661793,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'f2cea2f725f418fc238faae9ba1770cb',
#         'id': '306b5a13-abdd-4e87-a86c-b67409f5d0ab',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:34f3b35d-056e-458e-805d-aa9eddc8fcc9',
#         'identifier': [{'system': 'PDC',
#           'value': '34f3b35d-056e-458e-805d-aa9eddc8fcc9'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1766931360,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '6ab426f2302bb1b30419c0383db6ebca',
#         'id': '34f3b35d-056e-458e-805d-aa9eddc8fcc9',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:35a15436-ecdd-46f4-8122-7a93d55f8130',
#         'identifier': [{'system': 'PDC',
#           'value': '35a15436-ecdd-46f4-8122-7a93d55f8130'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 851443784,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '94f102e8530a9214544c91d19f8d31a1',
#         'id': '35a15436-ecdd-46f4-8122-7a93d55f8130',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:3e267db7-9882-49bf-a98c-6db89d6bda35',
#         'identifier': [{'system': 'PDC',
#           'value': '3e267db7-9882-49bf-a98c-6db89d6bda35'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7730272,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '51bbe735042c6a3a1a78e1c943e51489',
#         'id': '3e267db7-9882-49bf-a98c-6db89d6bda35',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:3f3383b2-97a7-4db3-9055-ef1190adca92',
#         'identifier': [{'system': 'PDC',
#           'value': '3f3383b2-97a7-4db3-9055-ef1190adca92'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1854084087,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '853956e3d7ce8b07b07050eed9a93d14',
#         'id': '3f3383b2-97a7-4db3-9055-ef1190adca92',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:44768877-bb13-4dd9-90f0-9258cdcb92ca',
#         'identifier': [{'system': 'PDC',
#           'value': '44768877-bb13-4dd9-90f0-9258cdcb92ca'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 173267282,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'e21759b1ae6675eab00e4f0e16d1294e',
#         'id': '44768877-bb13-4dd9-90f0-9258cdcb92ca',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:45cba06f-441b-4ae5-8449-13a4d77805b1',
#         'identifier': [{'system': 'PDC',
#           'value': '45cba06f-441b-4ae5-8449-13a4d77805b1'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 3300039,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'ff8462f92174d402924ae69dd2cef91e',
#         'id': '45cba06f-441b-4ae5-8449-13a4d77805b1',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4e2eb376-2f18-4e39-b42e-bd76a829f230',
#         'identifier': [{'system': 'PDC',
#           'value': '4e2eb376-2f18-4e39-b42e-bd76a829f230'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 176936660,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '82ef869a7f8292ca6cb9850ef923bbed',
# ...
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '4dd5098670b51c75287444b3a551d5ba',
#         'id': 'a637f33b-4c2a-4e74-8273-bc5920ea8d42',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f01.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:a6e94151-e1fd-413a-9079-87577221e683',
#         'identifier': [{'system': 'PDC',
#           'value': 'a6e94151-e1fd-413a-9079-87577221e683'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8689467,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'ee163ba4a597f138aba73eb3c00f79c3',
#         'id': 'a6e94151-e1fd-413a-9079-87577221e683',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f05.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b25674f4-4ac7-4e08-80d3-981c88a9121c',
#         'identifier': [{'system': 'PDC',
#           'value': 'b25674f4-4ac7-4e08-80d3-981c88a9121c'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 2742054,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '83df04b6726b39ae9e303325a4bad20a',
#         'id': 'b25674f4-4ac7-4e08-80d3-981c88a9121c',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f12.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b57f663c-47f9-48a5-b1ab-889e0e889c69',
#         'identifier': [{'system': 'PDC',
#           'value': 'b57f663c-47f9-48a5-b1ab-889e0e889c69'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 196559698,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '49ca1b7841b7cb30c72b1a749e4c1e5a',
#         'id': 'b57f663c-47f9-48a5-b1ab-889e0e889c69',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f12.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b7c60c93-1e0f-4dce-98b5-ccd6bc1c8ddd',
#         'identifier': [{'system': 'PDC',
#           'value': 'b7c60c93-1e0f-4dce-98b5-ccd6bc1c8ddd'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8511821,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'b941e7a43f63b6529981ce6f4b294e58',
#         'id': 'b7c60c93-1e0f-4dce-98b5-ccd6bc1c8ddd',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f11.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b7d7f196-2b2b-4095-88fa-b88b46a50198',
#         'identifier': [{'system': 'PDC',
#           'value': 'b7d7f196-2b2b-4095-88fa-b88b46a50198'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6621064,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '89915d4c55c3492dd1ecece4f0010b96',
#         'id': 'b7d7f196-2b2b-4095-88fa-b88b46a50198',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f03.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b9971835-6f55-44f9-ba44-01e5957335d6',
#         'identifier': [{'system': 'PDC',
#           'value': 'b9971835-6f55-44f9-ba44-01e5957335d6'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 206540918,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '134c0e4b184efc12c74ec9a3c9628758',
#         'id': 'b9971835-6f55-44f9-ba44-01e5957335d6',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f01.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:bb50fa9f-49c3-4888-abd5-4247424ed75c',
#         'identifier': [{'system': 'PDC',
#           'value': 'bb50fa9f-49c3-4888-abd5-4247424ed75c'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 752482574,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '4573d28a89786a180b838b15b37ffdaf',
#         'id': 'bb50fa9f-49c3-4888-abd5-4247424ed75c',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f03.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:bec7ff01-15dd-4053-b78b-5720b46ee9bc',
#         'identifier': [{'system': 'PDC',
#           'value': 'bec7ff01-15dd-4053-b78b-5720b46ee9bc'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6780678,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'a5f4f8cea73b82b3528a7aed854ea80a',
#         'id': 'bec7ff01-15dd-4053-b78b-5720b46ee9bc',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f06.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c0a28a7c-630b-47f5-9bd7-0990d3a95b5b',
#         'identifier': [{'system': 'PDC',
#           'value': 'c0a28a7c-630b-47f5-9bd7-0990d3a95b5b'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 2554072,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'ea62c1d17208e2e88321226ddfdff663',
#         'id': 'c0a28a7c-630b-47f5-9bd7-0990d3a95b5b',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f04.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c1802b78-415b-49c2-a47f-068732b66f1f',
#         'identifier': [{'system': 'PDC',
#           'value': 'c1802b78-415b-49c2-a47f-068732b66f1f'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6988452,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'fee3b1ab824cc0a4d0d98f0506ed870e',
#         'id': 'c1802b78-415b-49c2-a47f-068732b66f1f',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f04.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c776f526-0b55-4a9e-a83c-1f437fb3bbc3',
#         'identifier': [{'system': 'PDC',
#           'value': 'c776f526-0b55-4a9e-a83c-1f437fb3bbc3'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8884901,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '50390aae87c50d3408cd5e6fefff1332',
#         'id': 'c776f526-0b55-4a9e-a83c-1f437fb3bbc3',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f06.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c79f89d2-08d2-4e85-aece-24a527d19ece',
#         'identifier': [{'system': 'PDC',
#           'value': 'c79f89d2-08d2-4e85-aece-24a527d19ece'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 221674470,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '681089c1bda56e57b21c978cde5a4ea3',
#         'id': 'c79f89d2-08d2-4e85-aece-24a527d19ece',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f09.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c95a192e-7533-4591-8410-ddada33aa81e',
#         'identifier': [{'system': 'PDC',
#           'value': 'c95a192e-7533-4591-8410-ddada33aa81e'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1612379608,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'a671cd33bc68dbaed7fdf83c7fdfc235',
#         'id': 'c95a192e-7533-4591-8410-ddada33aa81e',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:cab1ae56-4a61-44a2-88ee-112630d1334e',
#         'identifier': [{'system': 'PDC',
#           'value': 'cab1ae56-4a61-44a2-88ee-112630d1334e'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 199149953,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '8d00e46832f51be064d9c15bcb5c1760',
#         'id': 'cab1ae56-4a61-44a2-88ee-112630d1334e',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f05.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:caeb12bd-6bba-4548-9c77-b785d69dbb11',
#         'identifier': [{'system': 'PDC',
#           'value': 'caeb12bd-6bba-4548-9c77-b785d69dbb11'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 665168164,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '173d3890cb3bc3b29f9c877444c33029',
#         'id': 'caeb12bd-6bba-4548-9c77-b785d69dbb11',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f05.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:cc2bb858-ecbd-4a91-9f0e-fe5ddf9461e4',
#         'identifier': [{'system': 'PDC',
#           'value': 'cc2bb858-ecbd-4a91-9f0e-fe5ddf9461e4'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1608313133,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '30c72308039b454a072cfb756bb85ee5',
#         'id': 'cc2bb858-ecbd-4a91-9f0e-fe5ddf9461e4',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f03.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:cd11e778-a37e-4953-91be-e42a78debbc4',
#         'identifier': [{'system': 'PDC',
#           'value': 'cd11e778-a37e-4953-91be-e42a78debbc4'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8389501,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '59de171467b68342fc5ddb183b9a4596',
#         'id': 'cd11e778-a37e-4953-91be-e42a78debbc4',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f02.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d3e7b7c0-7300-4f84-b68f-6e250e8b2ce6',
#         'identifier': [{'system': 'PDC',
#           'value': 'd3e7b7c0-7300-4f84-b68f-6e250e8b2ce6'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 207762371,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '1784fe5c1234eb5e01fe99c72def040c',
#         'id': 'd3e7b7c0-7300-4f84-b68f-6e250e8b2ce6',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d2ed4f1f-ed81-4934-926d-bc2bc12c070c',
#         'identifier': [{'system': 'PDC',
#           'value': 'd2ed4f1f-ed81-4934-926d-bc2bc12c070c'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 147168685,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'd1227c30125275b512dd868cf540ba0d',
#         'id': 'd2ed4f1f-ed81-4934-926d-bc2bc12c070c',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f03.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d3aedaaa-510a-417e-8167-061eaa7b76e4',
#         'identifier': [{'system': 'PDC',
#           'value': 'd3aedaaa-510a-417e-8167-061eaa7b76e4'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 4408773,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '4ec5994c4dcbc2f4d30ec3ee60ea2799',
#         'id': 'd3aedaaa-510a-417e-8167-061eaa7b76e4',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f08.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d46ef454-141b-44ed-b504-1c99c351dcc5',
#         'identifier': [{'system': 'PDC',
#           'value': 'd46ef454-141b-44ed-b504-1c99c351dcc5'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8215128,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'b80b59c78bf36edf600d6d497491b612',
#         'id': 'd46ef454-141b-44ed-b504-1c99c351dcc5',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f06.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d9b50ed4-3e0e-4870-8960-1f37d6d691a9',
#         'identifier': [{'system': 'PDC',
#           'value': 'd9b50ed4-3e0e-4870-8960-1f37d6d691a9'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 4060523,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'ee174935223a320597bea7524504a00a',
#         'id': 'd9b50ed4-3e0e-4870-8960-1f37d6d691a9',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f08.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dbacaa3c-5e5b-407f-86d2-1728c4aa7000',
#         'identifier': [{'system': 'PDC',
#           'value': 'dbacaa3c-5e5b-407f-86d2-1728c4aa7000'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1587240450,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'e34a4d6593c1d064f7591b8b19d9c443',
#         'id': 'dbacaa3c-5e5b-407f-86d2-1728c4aa7000',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f07.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:de019e8a-c93b-4fff-a5a0-81b485b45a31',
#         'identifier': [{'system': 'PDC',
#           'value': 'de019e8a-c93b-4fff-a5a0-81b485b45a31'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8532642,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '3d2f1a8bcba4571a3358bb63d8050893',
#         'id': 'de019e8a-c93b-4fff-a5a0-81b485b45a31',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f04.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:e06f366b-a275-48f7-9ab4-8fd8d4603c07',
#         'identifier': [{'system': 'PDC',
#           'value': 'e06f366b-a275-48f7-9ab4-8fd8d4603c07'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 700367870,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '10f171ced4e3d8d1bd7805952fdf46aa',
#         'id': 'e06f366b-a275-48f7-9ab4-8fd8d4603c07',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f11.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:f48ac837-e028-4f9f-aabf-9647e8681384',
#         'identifier': [{'system': 'PDC',
#           'value': 'f48ac837-e028-4f9f-aabf-9647e8681384'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 195503848,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'b9f639056cb21c23fa4f8ab398e05390',
#         'id': 'f48ac837-e028-4f9f-aabf-9647e8681384',
#         'data_type': 'Open Standard'}],
#       'derived_from_specimen': 'Initial specimen',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': 'Not Reported',
#       'source_material_type': 'Solid Tissue Normal',
#       'derived_from_subject': None,
#       'specimen_type': 'sample',
#       'id': '986bfc0f-641b-11e8-bcf1-0a2705229b82',
#       'primary_disease_type': 'Colon Adenocarcinoma',
#       'identifier': [{'system': 'PDC',
#         'value': '986bfc0f-641b-11e8-bcf1-0a2705229b82'}]}],
#     'associated_project': 'CPTAC-2',
#     'id': '24cb0fcb-63d6-11e8-bcf1-0a2705229b82',
#     'primary_disease_type': 'Colon Adenocarcinoma',
#     'identifier': [{'system': 'PDC',
#       'value': '24cb0fcb-63d6-11e8-bcf1-0a2705229b82'}],
#     'primary_disease_site': 'Colon'}]]]

# %% [markdown]
# Note that in the result above the attribute names are missing at the top level.
#
# We can get the attribute names by specifying a return type of json.

# %%
res = cl.runQuery(query2,returnType='json')
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# ____Page9_______________
# ____Page10_______________
# ____Page11_______________
# ____Page12_______________
# ____Page13_______________
# ____Page14_______________
# ____Page15_______________
# ____Page16_______________
# ____Page17_______________
# ____Page18_______________
# ____Page19_______________
# ____Page20_______________
# ____Page21_______________
# ____Page22_______________
# ____Page23_______________
# ____Page24_______________
# ____Page25_______________
# ____Page26_______________
# ____Page27_______________
# ____Page28_______________
# ____Page29_______________
# ____Page30_______________
# ____Page31_______________
# ____Page32_______________
# ____Page33_______________
# ____Page34_______________
# ____Page35_______________
# ____Page36_______________
# ____Page37_______________
# ____Page38_______________
# [{'days_to_birth': None,
#   'race': 'white',
#   'sex': 'male',
#   'ethnicity': 'not hispanic or latino',
#   'id': '05CO039',
#   'researchsubject': [{'Diagnosis': [{'morphology': '8140/3',
#       'tumor_stage': 'Stage IIB',
#       'tumor_grade': 'Not Reported',
#       'Treatment': [],
#       'id': '49674766-d911-4896-8978-c01ed945c4e9',
#       'primary_diagnosis': 'Adenocarcinoma, NOS',
#       'age_at_diagnosis': None}],
#     'Specimen': [{'File': [{'label': '7fb3b3a3-8dba-4ecd-8e7b-d61c9f7627a0.wxs.MuTect2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'identifier': [{'system': 'GDC',
#           'value': '098e18d4-5ece-4bc6-9a79-68f5082da9bc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 11606042,
#         'type': None,
#         'file_format': None,
#         'checksum': '351a76a43d5614d938045d9ff028c4ac',
#         'id': '098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '3bb17a95-aa01-4a01-97f5-1f02907d7bf1.wxs.MuSE.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'identifier': [{'system': 'GDC',
#           'value': '0d2a8f3e-86b4-4313-860c-7239b4ab413d'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1217587,
#         'type': None,
#         'file_format': None,
#         'checksum': '81c6251d98eddc493b9518c0f690ff2d',
#         'id': '0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'ebc9d464-3f9d-4733-b297-dd95c0fb1b87.mirnaseq.mirnas.quantification.txt',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:16049ed5-c8c6-4e5e-a8f0-8308ce8e0ae7',
#         'identifier': [{'system': 'GDC',
#           'value': '16049ed5-c8c6-4e5e-a8f0-8308ce8e0ae7'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 49648,
#         'type': None,
#         'file_format': None,
#         'checksum': '15c16690be1c1de203eef066f6c4c70b',
#         'id': '16049ed5-c8c6-4e5e-a8f0-8308ce8e0ae7',
#         'data_type': 'miRNA Expression Quantification'},
#        {'label': 'a4eb372e-09e2-4cb7-88ce-a7cd8ad7ec5e.FPKM-UQ.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1ed03c63-ec3c-4f06-be23-db6e6337bdde',
#         'identifier': [{'system': 'GDC',
#           'value': '1ed03c63-ec3c-4f06-be23-db6e6337bdde'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 384566,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c3d7d7317b5d598160145cecd7304560',
#         'id': '1ed03c63-ec3c-4f06-be23-db6e6337bdde',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'identifier': [{'system': 'GDC',
#           'value': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4628316,
#         'type': None,
#         'file_format': None,
#         'checksum': '9f12be88e380786e25dd6ea3b18066ef',
#         'id': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '89608678-9e71-4462-b5a2-f3724ce60ea6_mirnaseq_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:23ad96a5-aab4-4a81-ab61-3d5c925da652',
#         'identifier': [{'system': 'GDC',
#           'value': '23ad96a5-aab4-4a81-ab61-3d5c925da652'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 212239994,
#         'type': None,
#         'file_format': None,
#         'checksum': '1e6723e564bb9d3f229753dd398f7aa3',
#         'id': '23ad96a5-aab4-4a81-ab61-3d5c925da652',
#         'data_type': 'Aligned Reads'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.star_splice_junctions.tsv.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:259fc59f-6257-4222-a863-7c4501b81d4a',
#         'identifier': [{'system': 'GDC',
#           'value': '259fc59f-6257-4222-a863-7c4501b81d4a'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 2837616,
#         'type': None,
#         'file_format': None,
#         'checksum': '68cbbd381f6f8082c961671ce5b966af',
#         'id': '259fc59f-6257-4222-a863-7c4501b81d4a',
#         'data_type': 'Splice Junction Quantification'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_raw.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'identifier': [{'system': 'GDC',
#           'value': '4ae9d0da-721e-4de0-b6c7-06129b58ba45'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2458998,
#         'type': None,
#         'file_format': None,
#         'checksum': '029ae023b0ee3f2886062d6429658f37',
#         'id': '4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'data_type': 'Aggregated Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.chimeric.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4c6c170f-541d-471e-9ffe-e930d5a5d2eb',
#         'identifier': [{'system': 'GDC',
#           'value': '4c6c170f-541d-471e-9ffe-e930d5a5d2eb'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 45369677,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e0b96cbf0304b8ba19171d4a0f28d776',
#         'id': '4c6c170f-541d-471e-9ffe-e930d5a5d2eb',
#         'data_type': 'Aligned Reads'},
#        {'label': 'a4eb372e-09e2-4cb7-88ce-a7cd8ad7ec5e.htseq_counts.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:5b3f6db8-1b15-4b84-918f-a0f4f56ebf5b',
#         'identifier': [{'system': 'GDC',
#           'value': '5b3f6db8-1b15-4b84-918f-a0f4f56ebf5b'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 243946,
#         'type': None,
#         'file_format': None,
#         'checksum': 'b06964e35ef75daa6f5ce40c52a36c47',
#         'id': '5b3f6db8-1b15-4b84-918f-a0f4f56ebf5b',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '0a83021e-719e-4a82-b34a-ed86bac24748.wxs.VarScan2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:6862a7ed-794d-451d-b440-d893345ab893',
#         'identifier': [{'system': 'GDC',
#           'value': '6862a7ed-794d-451d-b440-d893345ab893'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4385332,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e60b6ae2628466dae941b83c8996faec',
#         'id': '6862a7ed-794d-451d-b440-d893345ab893',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.transcriptome.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:71cfbbc1-6379-4b33-85d2-2d59e5fbb9b1',
#         'identifier': [{'system': 'GDC',
#           'value': '71cfbbc1-6379-4b33-85d2-2d59e5fbb9b1'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 8734976957,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c793e25bc29b882bc9d7a09280ebca96',
#         'id': '71cfbbc1-6379-4b33-85d2-2d59e5fbb9b1',
#         'data_type': 'Aligned Reads'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'identifier': [{'system': 'GDC',
#           'value': '73f3b9e5-7521-4481-b476-ee361ff4c897'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2075565,
#         'type': None,
#         'file_format': None,
#         'checksum': '8a065d1b98c1d54e4e9506d0859bab98',
#         'id': '73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '5d1ca0c3-0520-4196-9103-99da010ed8af.wxs.pindel.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:74b844c9-11f1-48c5-a089-db959d9eca67',
#         'identifier': [{'system': 'GDC',
#           'value': '74b844c9-11f1-48c5-a089-db959d9eca67'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 298047,
#         'type': None,
#         'file_format': None,
#         'checksum': '7941308189e3b798c241c3f482f8aaa6',
#         'id': '74b844c9-11f1-48c5-a089-db959d9eca67',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.star_gene_counts.tsv.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:795b631d-1749-443f-9ddd-92cf4e799a70',
#         'identifier': [{'system': 'GDC',
#           'value': '795b631d-1749-443f-9ddd-92cf4e799a70'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 383403,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c61135e60809da41b41ad35fa051b9fc',
#         'id': '795b631d-1749-443f-9ddd-92cf4e799a70',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.muse.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'identifier': [{'system': 'GDC',
#           'value': '7e381e13-3847-49f5-b87e-be3fe62d23d0'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 129735,
#         'type': None,
#         'file_format': None,
#         'checksum': '6e2440c00e756adfb77d9104fee25a28',
#         'id': '7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '1f11224d-481b-4b7b-b395-6a34b414cd23.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'identifier': [{'system': 'GDC',
#           'value': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5227821,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a5e6aae0d0605f4fe67b2ca7d08843e',
#         'id': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '84851345-5ecf-4c02-b23e-1561bfafac9b.wxs.Pindel.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:80640356-8c20-4f3c-a300-4e4ac566f847',
#         'identifier': [{'system': 'GDC',
#           'value': '80640356-8c20-4f3c-a300-4e4ac566f847'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 893708,
#         'type': None,
#         'file_format': None,
#         'checksum': '0ed7ef1a0ed1894e693d0b749d307824',
#         'id': '80640356-8c20-4f3c-a300-4e4ac566f847',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'identifier': [{'system': 'GDC',
#           'value': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 517263,
#         'type': None,
#         'file_format': None,
#         'checksum': '132d17e0c385ba71c07ccb35d08c07f0',
#         'id': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': 'dddd8a00-b906-4975-aa83-a5c9e29f57af_wxs_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:8af77dd8-2787-41e3-8daf-e2843a87d61f',
#         'identifier': [{'system': 'GDC',
#           'value': '8af77dd8-2787-41e3-8daf-e2843a87d61f'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 55765843838,
#         'type': None,
#         'file_format': None,
#         'checksum': '1e23b9f0c56fc188719cb94ec20194b6',
#         'id': '8af77dd8-2787-41e3-8daf-e2843a87d61f',
#         'data_type': 'Aligned Reads'},
#        {'label': 'd686d9b8-23d7-4257-a854-54bc96a341da.wxs.MuSE.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'identifier': [{'system': 'GDC',
#           'value': '9744c86b-79a6-4121-9345-7c3bb685e8ef'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1841513,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c4daed4b22be8f2101de3fcc3d32f064',
#         'id': '9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'a4eb372e-09e2-4cb7-88ce-a7cd8ad7ec5e.FPKM.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:a321a327-b199-487d-a3c7-aa2e7f584857',
#         'identifier': [{'system': 'GDC',
#           'value': 'a321a327-b199-487d-a3c7-aa2e7f584857'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 304235,
#         'type': None,
#         'file_format': None,
#         'checksum': '2c10b87e6d6101dbd86bb9b5fa8f5d95',
#         'id': 'a321a327-b199-487d-a3c7-aa2e7f584857',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': 'c0f7f91d-6833-4821-8bf9-f7ad362de934.wxs.MuTect2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b93db769-02d9-4618-84d2-84639a134811',
#         'identifier': [{'system': 'GDC',
#           'value': 'b93db769-02d9-4618-84d2-84639a134811'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 8778875,
#         'type': None,
#         'file_format': None,
#         'checksum': 'bcd7e870a144d124a64982f22796db67',
#         'id': 'b93db769-02d9-4618-84d2-84639a134811',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '628fef11-6e60-4a36-9467-e60dc8389def.wxs.VarScan2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'identifier': [{'system': 'GDC',
#           'value': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3092401,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c889cca976c2f6325cd094ae543ab7a6',
#         'id': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_masked.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'identifier': [{'system': 'GDC',
#           'value': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 518784,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a579159c70fe48f479d5d5d82b0f1fa',
#         'id': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'data_type': 'Masked Somatic Mutation'},
#        {'label': '9ddc5472-7e79-4396-a5ae-089ca2872021.rna_seq.genomic.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:e0d9ef90-36e6-416a-a8c8-a52e1c6b8584',
#         'identifier': [{'system': 'GDC',
#           'value': 'e0d9ef90-36e6-416a-a8c8-a52e1c6b8584'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 4270116957,
#         'type': None,
#         'file_format': None,
#         'checksum': '05e5bfb9988f99f2ecb5eea1cdb3a7ac',
#         'id': 'e0d9ef90-36e6-416a-a8c8-a52e1c6b8584',
#         'data_type': 'Aligned Reads'},
#        {'label': 'ebc9d464-3f9d-4733-b297-dd95c0fb1b87.mirnaseq.isoforms.quantification.txt',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:e3aa1e7f-f69c-4a7b-b5df-3cf8cfea5f1f',
#         'identifier': [{'system': 'GDC',
#           'value': 'e3aa1e7f-f69c-4a7b-b5df-3cf8cfea5f1f'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 433610,
#         'type': None,
#         'file_format': None,
#         'checksum': '8bd25182148a7a4f8e9dfedb1e16c276',
#         'id': 'e3aa1e7f-f69c-4a7b-b5df-3cf8cfea5f1f',
#         'data_type': 'Isoform Expression Quantification'},
#        {'label': '35b8d346-d6b2-473a-985d-96e552e5f8ad.wxs.SomaticSniper.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'identifier': [{'system': 'GDC',
#           'value': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3969992,
#         'type': None,
#         'file_format': None,
#         'checksum': 'cc66ce1f1cd3a43710710efd48cdd48b',
#         'id': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'd41bd840-2828-49c9-a9d0-0a6b3527851b.wxs.Pindel.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:fc17d77e-623d-422e-8643-7dd560f802cc',
#         'identifier': [{'system': 'GDC',
#           'value': 'fc17d77e-623d-422e-8643-7dd560f802cc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1065112,
#         'type': None,
#         'file_format': None,
#         'checksum': '564c4059d3e0989bba3a98bb1a970bb6',
#         'id': 'fc17d77e-623d-422e-8643-7dd560f802cc',
#         'data_type': 'Annotated Somatic Mutation'}],
#       'derived_from_specimen': 'Initial sample',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'sample',
#       'id': '18f23b20-a975-47e4-942c-7c246f9ff91b',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '18f23b20-a975-47e4-942c-7c246f9ff91b'}]},
#      {'File': [],
#       'derived_from_specimen': '18f23b20-a975-47e4-942c-7c246f9ff91b',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'portion',
#       'id': '99bb081e-44de-5138-abd5-3057553e77c6',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '99bb081e-44de-5138-abd5-3057553e77c6'}]},
#      {'File': [],
#       'derived_from_specimen': '99bb081e-44de-5138-abd5-3057553e77c6',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'analyte',
#       'id': '6d8a997e-27ce-599e-a70a-b436f9f18607',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '6d8a997e-27ce-599e-a70a-b436f9f18607'}]},
#      {'File': [],
#       'derived_from_specimen': '6d8a997e-27ce-599e-a70a-b436f9f18607',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'aliquot',
#       'id': '89608678-9e71-4462-b5a2-f3724ce60ea6',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '89608678-9e71-4462-b5a2-f3724ce60ea6'}]},
#      {'File': [],
#       'derived_from_specimen': '18f23b20-a975-47e4-942c-7c246f9ff91b',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'portion',
#       'id': 'd246cd58-c045-5b40-9c61-006110e22421',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'd246cd58-c045-5b40-9c61-006110e22421'}]},
#      {'File': [],
#       'derived_from_specimen': 'd246cd58-c045-5b40-9c61-006110e22421',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'analyte',
#       'id': '8b092388-fd16-5d5d-a3a1-2bcf330b7339',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '8b092388-fd16-5d5d-a3a1-2bcf330b7339'}]},
#      {'File': [],
#       'derived_from_specimen': '8b092388-fd16-5d5d-a3a1-2bcf330b7339',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'aliquot',
#       'id': 'dddd8a00-b906-4975-aa83-a5c9e29f57af',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'dddd8a00-b906-4975-aa83-a5c9e29f57af'}]},
#      {'File': [{'label': '7fb3b3a3-8dba-4ecd-8e7b-d61c9f7627a0.wxs.MuTect2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'identifier': [{'system': 'GDC',
#           'value': '098e18d4-5ece-4bc6-9a79-68f5082da9bc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 11606042,
#         'type': None,
#         'file_format': None,
#         'checksum': '351a76a43d5614d938045d9ff028c4ac',
#         'id': '098e18d4-5ece-4bc6-9a79-68f5082da9bc',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '3bb17a95-aa01-4a01-97f5-1f02907d7bf1.wxs.MuSE.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'identifier': [{'system': 'GDC',
#           'value': '0d2a8f3e-86b4-4313-860c-7239b4ab413d'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1217587,
#         'type': None,
#         'file_format': None,
#         'checksum': '81c6251d98eddc493b9518c0f690ff2d',
#         'id': '0d2a8f3e-86b4-4313-860c-7239b4ab413d',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'ef2e9c7f-f17e-4a98-abb3-04cae63e55d2_wxs_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1c5dfba4-2894-439a-bcab-986d75dd62f0',
#         'identifier': [{'system': 'GDC',
#           'value': '1c5dfba4-2894-439a-bcab-986d75dd62f0'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 48169707235,
#         'type': None,
#         'file_format': None,
#         'checksum': '18fb3eb80a7441182a014d056ca14df2',
#         'id': '1c5dfba4-2894-439a-bcab-986d75dd62f0',
#         'data_type': 'Aligned Reads'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'identifier': [{'system': 'GDC',
#           'value': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4628316,
#         'type': None,
#         'file_format': None,
#         'checksum': '9f12be88e380786e25dd6ea3b18066ef',
#         'id': '2320b2cc-f5b0-4ac9-b718-8a03057c55d3',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_raw.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'identifier': [{'system': 'GDC',
#           'value': '4ae9d0da-721e-4de0-b6c7-06129b58ba45'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2458998,
#         'type': None,
#         'file_format': None,
#         'checksum': '029ae023b0ee3f2886062d6429658f37',
#         'id': '4ae9d0da-721e-4de0-b6c7-06129b58ba45',
#         'data_type': 'Aggregated Somatic Mutation'},
#        {'label': '0a83021e-719e-4a82-b34a-ed86bac24748.wxs.VarScan2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:6862a7ed-794d-451d-b440-d893345ab893',
#         'identifier': [{'system': 'GDC',
#           'value': '6862a7ed-794d-451d-b440-d893345ab893'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4385332,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e60b6ae2628466dae941b83c8996faec',
#         'id': '6862a7ed-794d-451d-b440-d893345ab893',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'identifier': [{'system': 'GDC',
#           'value': '73f3b9e5-7521-4481-b476-ee361ff4c897'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 2075565,
#         'type': None,
#         'file_format': None,
#         'checksum': '8a065d1b98c1d54e4e9506d0859bab98',
#         'id': '73f3b9e5-7521-4481-b476-ee361ff4c897',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '5d1ca0c3-0520-4196-9103-99da010ed8af.wxs.pindel.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:74b844c9-11f1-48c5-a089-db959d9eca67',
#         'identifier': [{'system': 'GDC',
#           'value': '74b844c9-11f1-48c5-a089-db959d9eca67'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 298047,
#         'type': None,
#         'file_format': None,
#         'checksum': '7941308189e3b798c241c3f482f8aaa6',
#         'id': '74b844c9-11f1-48c5-a089-db959d9eca67',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.muse.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'identifier': [{'system': 'GDC',
#           'value': '7e381e13-3847-49f5-b87e-be3fe62d23d0'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 129735,
#         'type': None,
#         'file_format': None,
#         'checksum': '6e2440c00e756adfb77d9104fee25a28',
#         'id': '7e381e13-3847-49f5-b87e-be3fe62d23d0',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '1f11224d-481b-4b7b-b395-6a34b414cd23.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'identifier': [{'system': 'GDC',
#           'value': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5227821,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a5e6aae0d0605f4fe67b2ca7d08843e',
#         'id': '7ef26ca8-f6ca-43f0-b8ca-ca1813401d1f',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '84851345-5ecf-4c02-b23e-1561bfafac9b.wxs.Pindel.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:80640356-8c20-4f3c-a300-4e4ac566f847',
#         'identifier': [{'system': 'GDC',
#           'value': '80640356-8c20-4f3c-a300-4e4ac566f847'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 893708,
#         'type': None,
#         'file_format': None,
#         'checksum': '0ed7ef1a0ed1894e693d0b749d307824',
#         'id': '80640356-8c20-4f3c-a300-4e4ac566f847',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '4e1cdb70-7318-493f-a21d-bc2a22dcda57.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'identifier': [{'system': 'GDC',
#           'value': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 517263,
#         'type': None,
#         'file_format': None,
#         'checksum': '132d17e0c385ba71c07ccb35d08c07f0',
#         'id': '81b7aa4c-ed94-4335-bec3-6f5f7065ff66',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': 'd686d9b8-23d7-4257-a854-54bc96a341da.wxs.MuSE.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'identifier': [{'system': 'GDC',
#           'value': '9744c86b-79a6-4121-9345-7c3bb685e8ef'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1841513,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c4daed4b22be8f2101de3fcc3d32f064',
#         'id': '9744c86b-79a6-4121-9345-7c3bb685e8ef',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'c0f7f91d-6833-4821-8bf9-f7ad362de934.wxs.MuTect2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b93db769-02d9-4618-84d2-84639a134811',
#         'identifier': [{'system': 'GDC',
#           'value': 'b93db769-02d9-4618-84d2-84639a134811'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 8778875,
#         'type': None,
#         'file_format': None,
#         'checksum': 'bcd7e870a144d124a64982f22796db67',
#         'id': 'b93db769-02d9-4618-84d2-84639a134811',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '628fef11-6e60-4a36-9467-e60dc8389def.wxs.VarScan2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'identifier': [{'system': 'GDC',
#           'value': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3092401,
#         'type': None,
#         'file_format': None,
#         'checksum': 'c889cca976c2f6325cd094ae543ab7a6',
#         'id': 'dd3b0a3f-76d7-4613-8565-3edcbb3222f8',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '30667140-0606-438f-911d-31666cad8afb.wxs.aliquot_ensemble_masked.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'identifier': [{'system': 'GDC',
#           'value': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 518784,
#         'type': None,
#         'file_format': None,
#         'checksum': '2a579159c70fe48f479d5d5d82b0f1fa',
#         'id': 'dee39b68-a0f4-43cb-90f1-b1b2b6b44223',
#         'data_type': 'Masked Somatic Mutation'},
#        {'label': '35b8d346-d6b2-473a-985d-96e552e5f8ad.wxs.SomaticSniper.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'identifier': [{'system': 'GDC',
#           'value': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 3969992,
#         'type': None,
#         'file_format': None,
#         'checksum': 'cc66ce1f1cd3a43710710efd48cdd48b',
#         'id': 'f7d6abf4-f250-43b5-bc1d-e11fe87d63ae',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'd41bd840-2828-49c9-a9d0-0a6b3527851b.wxs.Pindel.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:fc17d77e-623d-422e-8643-7dd560f802cc',
#         'identifier': [{'system': 'GDC',
#           'value': 'fc17d77e-623d-422e-8643-7dd560f802cc'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1065112,
#         'type': None,
#         'file_format': None,
#         'checksum': '564c4059d3e0989bba3a98bb1a970bb6',
#         'id': 'fc17d77e-623d-422e-8643-7dd560f802cc',
#         'data_type': 'Annotated Somatic Mutation'}],
#       'derived_from_specimen': 'Initial sample',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'sample',
#       'id': '8388a834-d343-43b3-94ef-2def34217a19',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '8388a834-d343-43b3-94ef-2def34217a19'}]},
#      {'File': [],
#       'derived_from_specimen': '8388a834-d343-43b3-94ef-2def34217a19',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'portion',
#       'id': 'd4ae69c4-6643-514d-a19e-452cc3453e50',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'd4ae69c4-6643-514d-a19e-452cc3453e50'}]},
#      {'File': [],
#       'derived_from_specimen': 'd4ae69c4-6643-514d-a19e-452cc3453e50',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'analyte',
#       'id': 'ef40d91c-54ca-5367-9046-689288115c46',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'ef40d91c-54ca-5367-9046-689288115c46'}]},
#      {'File': [],
#       'derived_from_specimen': 'ef40d91c-54ca-5367-9046-689288115c46',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '05CO039',
#       'specimen_type': 'aliquot',
#       'id': 'ef2e9c7f-f17e-4a98-abb3-04cae63e55d2',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'ef2e9c7f-f17e-4a98-abb3-04cae63e55d2'}]}],
#     'associated_project': 'CPTAC-2',
#     'id': '997475b1-6648-494a-9322-79aa17be272e',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': '997475b1-6648-494a-9322-79aa17be272e'}],
#     'primary_disease_site': 'Colon'},
#    {'Diagnosis': [{'morphology': '8140/3',
#       'tumor_stage': 'Stage IIB',
#       'tumor_grade': 'Not Reported',
#       'Treatment': [],
#       'id': 'ff2f357b-70ca-11e8-bcf1-0a2705229b82',
#       'primary_diagnosis': 'Adenocarcinoma, NOS',
#       'age_at_diagnosis': None}],
#     'Specimen': [{'File': [],
#       'derived_from_specimen': 'Initial specimen',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': 'Not Reported',
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': None,
#       'specimen_type': 'sample',
#       'id': '8b9f3cff-641b-11e8-bcf1-0a2705229b82',
#       'primary_disease_type': 'Colon Adenocarcinoma',
#       'identifier': [{'system': 'PDC',
#         'value': '8b9f3cff-641b-11e8-bcf1-0a2705229b82'}]},
#      {'File': [{'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:017e0e6e-a191-4135-a5f0-07a2819096f5',
#         'identifier': [{'system': 'PDC',
#           'value': '017e0e6e-a191-4135-a5f0-07a2819096f5'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 793619198,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '775c63f5560e10e30b319bec74a8c23b',
#         'id': '017e0e6e-a191-4135-a5f0-07a2819096f5',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:02a335f5-ea48-4d29-94b4-e1f50c94eb47',
#         'identifier': [{'system': 'PDC',
#           'value': '02a335f5-ea48-4d29-94b4-e1f50c94eb47'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8025509,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '9aa20115f7ce6d1de1cf18738bb5096a',
#         'id': '02a335f5-ea48-4d29-94b4-e1f50c94eb47',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f02.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:06b6f850-b3b6-492b-88a5-214906b71338',
#         'identifier': [{'system': 'PDC',
#           'value': '06b6f850-b3b6-492b-88a5-214906b71338'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1770001590,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '10e89c22c721d8fb3aa5bb0c72c1200b',
#         'id': '06b6f850-b3b6-492b-88a5-214906b71338',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:07dde26b-a6b4-4758-8f7d-483bb4340a95',
#         'identifier': [{'system': 'PDC',
#           'value': '07dde26b-a6b4-4758-8f7d-483bb4340a95'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 815359890,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '3340b297f69fa42ec8cf040aa1241c17',
#         'id': '07dde26b-a6b4-4758-8f7d-483bb4340a95',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:15c78167-3f73-45a1-ac95-f9a426cc1da8',
#         'identifier': [{'system': 'PDC',
#           'value': '15c78167-3f73-45a1-ac95-f9a426cc1da8'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6013332,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '89a9f28daa4066226ccc3b53952f53e7',
#         'id': '15c78167-3f73-45a1-ac95-f9a426cc1da8',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1f63a16d-ee0b-496f-a3cc-52eda4f199b1',
#         'identifier': [{'system': 'PDC',
#           'value': '1f63a16d-ee0b-496f-a3cc-52eda4f199b1'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 212959925,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '738459c88ef36a856b20ae8cebd6a46f',
#         'id': '1f63a16d-ee0b-496f-a3cc-52eda4f199b1',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:22634cb8-c4a5-40a5-a9d6-e447896e8681',
#         'identifier': [{'system': 'PDC',
#           'value': '22634cb8-c4a5-40a5-a9d6-e447896e8681'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5828812,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '9417890237e4ad537f99758cd5d24634',
#         'id': '22634cb8-c4a5-40a5-a9d6-e447896e8681',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f03.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:299bd409-a638-4e96-967d-1811b3f0a0ce',
#         'identifier': [{'system': 'PDC',
#           'value': '299bd409-a638-4e96-967d-1811b3f0a0ce'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5738281,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '10fa93c1364b3a4cbd4d59e53cc02ea5',
#         'id': '299bd409-a638-4e96-967d-1811b3f0a0ce',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f09.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2cec8163-ac36-45ba-bdf6-ece8372dd44a',
#         'identifier': [{'system': 'PDC',
#           'value': '2cec8163-ac36-45ba-bdf6-ece8372dd44a'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1675806496,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'c5fec55840ce4ab0723466120294cc4f',
#         'id': '2cec8163-ac36-45ba-bdf6-ece8372dd44a',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2e3a8f56-e8a1-4679-9ff6-1720613027d2',
#         'identifier': [{'system': 'PDC',
#           'value': '2e3a8f56-e8a1-4679-9ff6-1720613027d2'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 206027184,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '156eb01edc1622046f71876d8369d4b6',
#         'id': '2e3a8f56-e8a1-4679-9ff6-1720613027d2',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2e9d7ff3-5614-4a6b-bd9b-6a3c2303bfd1',
#         'identifier': [{'system': 'PDC',
#           'value': '2e9d7ff3-5614-4a6b-bd9b-6a3c2303bfd1'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7577002,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'c6a97eb4619acca5a0b356da69947230',
#         'id': '2e9d7ff3-5614-4a6b-bd9b-6a3c2303bfd1',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2f4abf53-ee6c-43d7-82f9-7b5d7a055ff7',
#         'identifier': [{'system': 'PDC',
#           'value': '2f4abf53-ee6c-43d7-82f9-7b5d7a055ff7'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5034214,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '2f8e87b42639d6cb16bfc190b0acfc11',
#         'id': '2f4abf53-ee6c-43d7-82f9-7b5d7a055ff7',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:306b5a13-abdd-4e87-a86c-b67409f5d0ab',
#         'identifier': [{'system': 'PDC',
#           'value': '306b5a13-abdd-4e87-a86c-b67409f5d0ab'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5661793,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'f2cea2f725f418fc238faae9ba1770cb',
#         'id': '306b5a13-abdd-4e87-a86c-b67409f5d0ab',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f01.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:34f3b35d-056e-458e-805d-aa9eddc8fcc9',
#         'identifier': [{'system': 'PDC',
#           'value': '34f3b35d-056e-458e-805d-aa9eddc8fcc9'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1766931360,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '6ab426f2302bb1b30419c0383db6ebca',
#         'id': '34f3b35d-056e-458e-805d-aa9eddc8fcc9',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:35a15436-ecdd-46f4-8122-7a93d55f8130',
#         'identifier': [{'system': 'PDC',
#           'value': '35a15436-ecdd-46f4-8122-7a93d55f8130'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 851443784,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '94f102e8530a9214544c91d19f8d31a1',
#         'id': '35a15436-ecdd-46f4-8122-7a93d55f8130',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:3e267db7-9882-49bf-a98c-6db89d6bda35',
#         'identifier': [{'system': 'PDC',
#           'value': '3e267db7-9882-49bf-a98c-6db89d6bda35'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7730272,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '51bbe735042c6a3a1a78e1c943e51489',
#         'id': '3e267db7-9882-49bf-a98c-6db89d6bda35',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:3f3383b2-97a7-4db3-9055-ef1190adca92',
#         'identifier': [{'system': 'PDC',
#           'value': '3f3383b2-97a7-4db3-9055-ef1190adca92'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1854084087,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '853956e3d7ce8b07b07050eed9a93d14',
#         'id': '3f3383b2-97a7-4db3-9055-ef1190adca92',
#         'data_type': 'Proprietary'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f02.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:44768877-bb13-4dd9-90f0-9258cdcb92ca',
#         'identifier': [{'system': 'PDC',
#           'value': '44768877-bb13-4dd9-90f0-9258cdcb92ca'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 173267282,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'e21759b1ae6675eab00e4f0e16d1294e',
#         'id': '44768877-bb13-4dd9-90f0-9258cdcb92ca',
#         'data_type': 'Open Standard'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:45cba06f-441b-4ae5-8449-13a4d77805b1',
#         'identifier': [{'system': 'PDC',
#           'value': '45cba06f-441b-4ae5-8449-13a4d77805b1'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 3300039,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'ff8462f92174d402924ae69dd2cef91e',
#         'id': '45cba06f-441b-4ae5-8449-13a4d77805b1',
#         'data_type': 'Text'},
#        {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4e2eb376-2f18-4e39-b42e-bd76a829f230',
#         'identifier': [{'system': 'PDC',
#           'value': '4e2eb376-2f18-4e39-b42e-bd76a829f230'}],
#         'data_category': 'Processed Mass Spectra',
# ...
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '4dd5098670b51c75287444b3a551d5ba',
#         'id': 'a637f33b-4c2a-4e74-8273-bc5920ea8d42',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f01.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:a6e94151-e1fd-413a-9079-87577221e683',
#         'identifier': [{'system': 'PDC',
#           'value': 'a6e94151-e1fd-413a-9079-87577221e683'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8689467,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'ee163ba4a597f138aba73eb3c00f79c3',
#         'id': 'a6e94151-e1fd-413a-9079-87577221e683',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f05.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b25674f4-4ac7-4e08-80d3-981c88a9121c',
#         'identifier': [{'system': 'PDC',
#           'value': 'b25674f4-4ac7-4e08-80d3-981c88a9121c'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 2742054,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '83df04b6726b39ae9e303325a4bad20a',
#         'id': 'b25674f4-4ac7-4e08-80d3-981c88a9121c',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f12.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b57f663c-47f9-48a5-b1ab-889e0e889c69',
#         'identifier': [{'system': 'PDC',
#           'value': 'b57f663c-47f9-48a5-b1ab-889e0e889c69'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 196559698,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '49ca1b7841b7cb30c72b1a749e4c1e5a',
#         'id': 'b57f663c-47f9-48a5-b1ab-889e0e889c69',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f12.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b7c60c93-1e0f-4dce-98b5-ccd6bc1c8ddd',
#         'identifier': [{'system': 'PDC',
#           'value': 'b7c60c93-1e0f-4dce-98b5-ccd6bc1c8ddd'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8511821,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'b941e7a43f63b6529981ce6f4b294e58',
#         'id': 'b7c60c93-1e0f-4dce-98b5-ccd6bc1c8ddd',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f11.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b7d7f196-2b2b-4095-88fa-b88b46a50198',
#         'identifier': [{'system': 'PDC',
#           'value': 'b7d7f196-2b2b-4095-88fa-b88b46a50198'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6621064,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '89915d4c55c3492dd1ecece4f0010b96',
#         'id': 'b7d7f196-2b2b-4095-88fa-b88b46a50198',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f03.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b9971835-6f55-44f9-ba44-01e5957335d6',
#         'identifier': [{'system': 'PDC',
#           'value': 'b9971835-6f55-44f9-ba44-01e5957335d6'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 206540918,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '134c0e4b184efc12c74ec9a3c9628758',
#         'id': 'b9971835-6f55-44f9-ba44-01e5957335d6',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f01.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:bb50fa9f-49c3-4888-abd5-4247424ed75c',
#         'identifier': [{'system': 'PDC',
#           'value': 'bb50fa9f-49c3-4888-abd5-4247424ed75c'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 752482574,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '4573d28a89786a180b838b15b37ffdaf',
#         'id': 'bb50fa9f-49c3-4888-abd5-4247424ed75c',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f03.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:bec7ff01-15dd-4053-b78b-5720b46ee9bc',
#         'identifier': [{'system': 'PDC',
#           'value': 'bec7ff01-15dd-4053-b78b-5720b46ee9bc'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6780678,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'a5f4f8cea73b82b3528a7aed854ea80a',
#         'id': 'bec7ff01-15dd-4053-b78b-5720b46ee9bc',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f06.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c0a28a7c-630b-47f5-9bd7-0990d3a95b5b',
#         'identifier': [{'system': 'PDC',
#           'value': 'c0a28a7c-630b-47f5-9bd7-0990d3a95b5b'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 2554072,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'ea62c1d17208e2e88321226ddfdff663',
#         'id': 'c0a28a7c-630b-47f5-9bd7-0990d3a95b5b',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f04.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c1802b78-415b-49c2-a47f-068732b66f1f',
#         'identifier': [{'system': 'PDC',
#           'value': 'c1802b78-415b-49c2-a47f-068732b66f1f'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6988452,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'fee3b1ab824cc0a4d0d98f0506ed870e',
#         'id': 'c1802b78-415b-49c2-a47f-068732b66f1f',
#         'data_type': 'Text'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f04.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c776f526-0b55-4a9e-a83c-1f437fb3bbc3',
#         'identifier': [{'system': 'PDC',
#           'value': 'c776f526-0b55-4a9e-a83c-1f437fb3bbc3'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8884901,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '50390aae87c50d3408cd5e6fefff1332',
#         'id': 'c776f526-0b55-4a9e-a83c-1f437fb3bbc3',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f06.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c79f89d2-08d2-4e85-aece-24a527d19ece',
#         'identifier': [{'system': 'PDC',
#           'value': 'c79f89d2-08d2-4e85-aece-24a527d19ece'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 221674470,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '681089c1bda56e57b21c978cde5a4ea3',
#         'id': 'c79f89d2-08d2-4e85-aece-24a527d19ece',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f09.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c95a192e-7533-4591-8410-ddada33aa81e',
#         'identifier': [{'system': 'PDC',
#           'value': 'c95a192e-7533-4591-8410-ddada33aa81e'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1612379608,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'a671cd33bc68dbaed7fdf83c7fdfc235',
#         'id': 'c95a192e-7533-4591-8410-ddada33aa81e',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:cab1ae56-4a61-44a2-88ee-112630d1334e',
#         'identifier': [{'system': 'PDC',
#           'value': 'cab1ae56-4a61-44a2-88ee-112630d1334e'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 199149953,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '8d00e46832f51be064d9c15bcb5c1760',
#         'id': 'cab1ae56-4a61-44a2-88ee-112630d1334e',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f05.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:caeb12bd-6bba-4548-9c77-b785d69dbb11',
#         'identifier': [{'system': 'PDC',
#           'value': 'caeb12bd-6bba-4548-9c77-b785d69dbb11'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 665168164,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '173d3890cb3bc3b29f9c877444c33029',
#         'id': 'caeb12bd-6bba-4548-9c77-b785d69dbb11',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f05.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:cc2bb858-ecbd-4a91-9f0e-fe5ddf9461e4',
#         'identifier': [{'system': 'PDC',
#           'value': 'cc2bb858-ecbd-4a91-9f0e-fe5ddf9461e4'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1608313133,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '30c72308039b454a072cfb756bb85ee5',
#         'id': 'cc2bb858-ecbd-4a91-9f0e-fe5ddf9461e4',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f03.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:cd11e778-a37e-4953-91be-e42a78debbc4',
#         'identifier': [{'system': 'PDC',
#           'value': 'cd11e778-a37e-4953-91be-e42a78debbc4'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8389501,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '59de171467b68342fc5ddb183b9a4596',
#         'id': 'cd11e778-a37e-4953-91be-e42a78debbc4',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f02.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d3e7b7c0-7300-4f84-b68f-6e250e8b2ce6',
#         'identifier': [{'system': 'PDC',
#           'value': 'd3e7b7c0-7300-4f84-b68f-6e250e8b2ce6'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 207762371,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '1784fe5c1234eb5e01fe99c72def040c',
#         'id': 'd3e7b7c0-7300-4f84-b68f-6e250e8b2ce6',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f05.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d2ed4f1f-ed81-4934-926d-bc2bc12c070c',
#         'identifier': [{'system': 'PDC',
#           'value': 'd2ed4f1f-ed81-4934-926d-bc2bc12c070c'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 147168685,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'd1227c30125275b512dd868cf540ba0d',
#         'id': 'd2ed4f1f-ed81-4934-926d-bc2bc12c070c',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f03.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d3aedaaa-510a-417e-8167-061eaa7b76e4',
#         'identifier': [{'system': 'PDC',
#           'value': 'd3aedaaa-510a-417e-8167-061eaa7b76e4'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 4408773,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '4ec5994c4dcbc2f4d30ec3ee60ea2799',
#         'id': 'd3aedaaa-510a-417e-8167-061eaa7b76e4',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f08.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d46ef454-141b-44ed-b504-1c99c351dcc5',
#         'identifier': [{'system': 'PDC',
#           'value': 'd46ef454-141b-44ed-b504-1c99c351dcc5'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8215128,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'b80b59c78bf36edf600d6d497491b612',
#         'id': 'd46ef454-141b-44ed-b504-1c99c351dcc5',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f06.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d9b50ed4-3e0e-4870-8960-1f37d6d691a9',
#         'identifier': [{'system': 'PDC',
#           'value': 'd9b50ed4-3e0e-4870-8960-1f37d6d691a9'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 4060523,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'ee174935223a320597bea7524504a00a',
#         'id': 'd9b50ed4-3e0e-4870-8960-1f37d6d691a9',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f08.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dbacaa3c-5e5b-407f-86d2-1728c4aa7000',
#         'identifier': [{'system': 'PDC',
#           'value': 'dbacaa3c-5e5b-407f-86d2-1728c4aa7000'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1587240450,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'e34a4d6593c1d064f7591b8b19d9c443',
#         'id': 'dbacaa3c-5e5b-407f-86d2-1728c4aa7000',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f07.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:de019e8a-c93b-4fff-a5a0-81b485b45a31',
#         'identifier': [{'system': 'PDC',
#           'value': 'de019e8a-c93b-4fff-a5a0-81b485b45a31'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 8532642,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '3d2f1a8bcba4571a3358bb63d8050893',
#         'id': 'de019e8a-c93b-4fff-a5a0-81b485b45a31',
#         'data_type': 'Open Standard'},
#        {'label': '04CPTAC_COprospective_P_PNNL_20170215_B1S4_f04.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:e06f366b-a275-48f7-9ab4-8fd8d4603c07',
#         'identifier': [{'system': 'PDC',
#           'value': 'e06f366b-a275-48f7-9ab4-8fd8d4603c07'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 700367870,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '10f171ced4e3d8d1bd7805952fdf46aa',
#         'id': 'e06f366b-a275-48f7-9ab4-8fd8d4603c07',
#         'data_type': 'Proprietary'},
#        {'label': '04CPTAC_COprospective_W_PNNL_20170123_B1S4_f11.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:f48ac837-e028-4f9f-aabf-9647e8681384',
#         'identifier': [{'system': 'PDC',
#           'value': 'f48ac837-e028-4f9f-aabf-9647e8681384'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 195503848,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'b9f639056cb21c23fa4f8ab398e05390',
#         'id': 'f48ac837-e028-4f9f-aabf-9647e8681384',
#         'data_type': 'Open Standard'}],
#       'derived_from_specimen': 'Initial specimen',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': 'Not Reported',
#       'source_material_type': 'Solid Tissue Normal',
#       'derived_from_subject': None,
#       'specimen_type': 'sample',
#       'id': '986bfc0f-641b-11e8-bcf1-0a2705229b82',
#       'primary_disease_type': 'Colon Adenocarcinoma',
#       'identifier': [{'system': 'PDC',
#         'value': '986bfc0f-641b-11e8-bcf1-0a2705229b82'}]}],
#     'associated_project': 'CPTAC-2',
#     'id': '24cb0fcb-63d6-11e8-bcf1-0a2705229b82',
#     'primary_disease_type': 'Colon Adenocarcinoma',
#     'identifier': [{'system': 'PDC',
#       'value': '24cb0fcb-63d6-11e8-bcf1-0a2705229b82'}],
#     'primary_disease_site': 'Colon'}]}]

# %% [markdown]
# and save to file

# %%
with open('data/data2.json', 'w', encoding='utf-8') as f:
    json.dump(res, f, ensure_ascii=False, indent=3)
