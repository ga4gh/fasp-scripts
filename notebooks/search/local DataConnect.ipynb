# %% [markdown]
# ## Using a local GA4GH Data Connect server

# %%
from fasp.search import DataConnectClient
cl = DataConnectClient('http://localhost:8089/')
cl.listTables(verbose=True)
# Out:
# /Users/forei/imfenvs/fasp/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# _Retrieving the table list_
# ____Page1_______________
# bigquery.1000genomes.1000genomes_drs
# bigquery.1000genomes.aligned_read
# bigquery.1000genomes.aliquot
# bigquery.1000genomes.bdc_1000genomes
# bigquery.1000genomes.demographics
# bigquery.1000genomes.germline_variation_index
# bigquery.1000genomes.phenotype_drs
# bigquery.1000genomes.read_group
# bigquery.1000genomes.sample
# bigquery.1000genomes.simple_germline_variation
# bigquery.1000genomes.ssd_drs
# bigquery.1000genomes.ssd_drs_table
# bigquery.1000genomes.subject
# bigquery.100genomes.import2
# bigquery.100genomes.import3
# bigquery.100genomes.testimport
# bigquery.blog_unnest.firebase_raw
# bigquery.cda.cdav3
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample
# bigquery.cidr_gecco_colorectal_cancer_gxe.sample_attributes
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject
# bigquery.cidr_gecco_colorectal_cancer_gxe.subject_phenotypes
# bigquery.copdgene.aligned_read
# bigquery.copdgene.aliquot
# bigquery.copdgene.copd_drs
# bigquery.copdgene.copd_gene__hmb_vcf
# bigquery.copdgene.copdgene_hmb_female_90_94kg
# bigquery.copdgene.copdgene_pfb
# bigquery.copdgene.phenotype_drs
# bigquery.copdgene.read_group
# bigquery.copdgene.sample
# bigquery.copdgene.sample_multi
# bigquery.copdgene.subject
# bigquery.copdgene.subject_images_hmb
# bigquery.copdgene.subject_multi
# bigquery.copdgene.subject_phenotypes_hmb
# bigquery.cptac.breastsubjectclinicalphenotypes
# bigquery.cptac.sample_attributes
# bigquery.esp_lunggo_copdgene.sample_attributes_hmb
# bigquery.esp_lunggo_copdgene.subject_phenotypes_hmb
# bigquery.fasp_scrambled.scr_egapancreatic_sample
# bigquery.gecco_crc_susceptibility.public_sample
# bigquery.gecco_crc_susceptibility.sample_attributes
# bigquery.gecco_crc_susceptibility.sample_attributes_cadm
# bigquery.gecco_crc_susceptibility.sample_attributes_ds_cc_npu_gso
# bigquery.gecco_crc_susceptibility.sample_attributes_gru
# bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb
# bigquery.gecco_crc_susceptibility.sample_attributes_hmb_irb_npu
# bigquery.gecco_crc_susceptibility.sample_multi
# bigquery.gecco_crc_susceptibility.studies_1554
# bigquery.gecco_crc_susceptibility.subject_multi
# bigquery.gecco_crc_susceptibility.subject_phenotypes
# bigquery.gecco_crc_susceptibility.subject_phenotypes_cadm
# bigquery.gecco_crc_susceptibility.subject_phenotypes_ds_cc_npu_gso
# bigquery.gecco_crc_susceptibility.subject_phenotypes_gru
# bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb
# bigquery.gecco_crc_susceptibility.subject_phenotypes_hmb_irb_npu
# bigquery.gtex8.program
# bigquery.gtex8.project
# bigquery.gtex8.sample
# bigquery.gtex8.sequencing
# bigquery.gtex8.sraruntable_breast_cram
# bigquery.gtex8.sraruntable_nocram
# bigquery.gtex8.sraruntable_nocram_nobam
# bigquery.gtex8.subject
# bigquery.icdc.cotc_sample
# bigquery.kidsfirst.neuroblastoma_participant_family
# bigquery.kidsfirst.pediatric_brain_tumor_atlas
# bigquery.lccc_1108.lccc_drs_map
# bigquery.lccc_1108.sample
# bigquery.lccc_1108.sample_attributes
# bigquery.lccc_1108.subject
# bigquery.lccc_1108.subject_phenotypes
# bigquery.mapped.age_months_view
# bigquery.mapped.age_months_view2
# bigquery.mapped.age_view
# bigquery.mapped.age_years
# bigquery.mapped.subject_disease
# bigquery.mesa.airnrexammain_hmb
# bigquery.mesa.airnrspirometry_hmb
# bigquery.mesa.ancilmesaneighborfoodexam1_hmb
# bigquery.mesa.ancilmesaneighborfoodexam2_hmb
# bigquery.mesa.ancilmesaneighborfoodexam3_hmb
# bigquery.mesa.ancilmesaneighborfoodexam4_hmb
# bigquery.mesa.parent_mesa_hmb_npu
# bigquery.mesa.sample_multi
# bigquery.mesa.subject_multi
# bigquery.mesa_esp_heartgo.parent_mesa
# bigquery.mesa_esp_heartgo.sample_attributes_hmb
# bigquery.mesa_esp_heartgo.sample_attributes_hmb_npu
# bigquery.mesa_esp_heartgo.subject_phenotypes_hmb
# bigquery.mesa_esp_heartgo.subject_phenotypes_hmb_npu
# bigquery.metadata.dbgap_table
# bigquery.metadata.loinc2hpoannotation
# bigquery.metadata.mapping
# bigquery.metadata.mapping2
# bigquery.metadata.mapping2_term
# bigquery.metadata.merged
# bigquery.metadata.s_study
# bigquery.metadata.s_table
# bigquery.metadata.s_variable
# bigquery.metadata.study
# bigquery.metadata.value_map
# bigquery.metadata.vocab
# bigquery.metadata.vocab_term
# bigquery.onek_genomes.bdc_1000genomes
# bigquery.onek_genomes.onek_drs
# bigquery.onek_genomes.onek_recal_variants_drs
# bigquery.onek_genomes.sra_drs_files
# bigquery.onek_genomes.sra_onek_drs
# bigquery.onek_genomes.ssd_drs
# bigquery.onek_genomes.thousand_genomes_meta
# bigquery.organoid_profiling_pc.sample_attributes_gru
# bigquery.organoid_profiling_pc.sample_multi
# bigquery.organoid_profiling_pc.subject_multi
# bigquery.organoid_profiling_pc.subject_phenotypes_gru
# bigquery.pc_rare_variation.sample
# bigquery.pc_rare_variation.sample_attributes
# bigquery.pc_rare_variation.subject
# bigquery.pc_rare_variation.subject_phenotypes
# bigquery.pptc.manifest_small
# bigquery.pptc.sample
# bigquery.pptc.sample_attributes
# bigquery.pptc.subject
# bigquery.pptc.subject_phenotypes
# bigquery.rand_gmkf_cdh.phenotype
# bigquery.scr_ega.scr_egapancreatic_files
# bigquery.scr_ega.scr_egapancreatic_sample_multi
# bigquery.scr_egapancreatic.sample
# bigquery.scr_gecco_susceptibility.gecco_sample_acc
# bigquery.scr_gecco_susceptibility.phs001554_gecco_sddp_manifest
# bigquery.scr_gecco_susceptibility.sample_attributes_multi
# bigquery.scr_gecco_susceptibility.sample_multi
# bigquery.scr_gecco_susceptibility.sb_drs_index
# bigquery.scr_gecco_susceptibility.subject_multi
# bigquery.scr_gecco_susceptibility.subject_phenotypes_multi
# bigquery.scr_organoid.subject_phenotypes_gru
# bigquery.scripts.pipelinelog
# bigquery.scripts.scriptlist
# bigquery.sra.accession_summary
# bigquery.sra.gecco_join
# bigquery.sra.run
# bigquery.sra.run_file
# bigquery.tgtest.program
# bigquery.tgtest.project
# bigquery.tgtest.sample
# bigquery.tgtest.sequencing
# bigquery.tgtest.subject
# bigquery.topmed_wgs_mayo_vte.sample_attributes_gru
# bigquery.topmed_wgs_mayo_vte.subject_multi
# bigquery.topmed_wgs_mayo_vte.subject_phenotypes_gru
# bigquery.topmed_wgs_partners_afgen.sample_attributes_hmb
# bigquery.topmed_wgs_partners_afgen.sample_multi
# bigquery.topmed_wgs_partners_afgen.subject_multi
# bigquery.topmed_wgs_partners_afgen.subject_phenotypes_hmb
# bigquery.transfer.gdc_case_file_metadata_gdcfileid_to_gcsurl_current
# bigquery.transfer.tcga_clinical_gdc_current
# bigquery.transfer.tcga_somatic_mutation_hg38_gdc_current
# ____Page2_______________
# jmx.current.com.sun.management:type=diagnosticcommand
# jmx.current.com.sun.management:type=hotspotdiagnostic
# jmx.current.io.airlift.discovery.client:name=announcer
# jmx.current.io.airlift.discovery.client:name=serviceinventory
# jmx.current.io.airlift.discovery.store:name=dynamic,type=distributedstore
# jmx.current.io.airlift.discovery.store:name=dynamic,type=httpremotestore
# jmx.current.io.airlift.discovery.store:name=dynamic,type=replicator
# jmx.current.io.airlift.http.client:name=fordiscoveryclient,type=httpclient
# jmx.current.io.airlift.http.client:name=fordynamicstore,type=httpclient
# jmx.current.io.airlift.http.client:name=forexchange,type=httpclient
# jmx.current.io.airlift.http.client:name=forfailuredetector,type=httpclient
# jmx.current.io.airlift.http.client:name=formemorymanager,type=httpclient
# jmx.current.io.airlift.http.client:name=fornodemanager,type=httpclient
# jmx.current.io.airlift.http.client:name=forscheduler,type=httpclient
# jmx.current.io.airlift.http.client:name=forworkerinfo,type=httpclient
# jmx.current.io.airlift.http.server:context=http_1_1_h2c@5543d800,id=0,type=httpserverchannellistener
# jmx.current.io.airlift.http.server:id=0,type=statsrecordinghandler
# jmx.current.io.airlift.http.server:name=httpserver
# jmx.current.io.airlift.http.server:name=requeststats
# jmx.current.io.airlift.jmx:name=stacktracembean
# jmx.current.io.airlift.log:name=logging
# jmx.current.io.airlift.node:name=nodeinfo
# jmx.current.io.airlift.stats:name=gcmonitor
# jmx.current.io.airlift.stats:name=pausemeter
# jmx.current.io.trino.plugin.jdbc:name=mysql,type=cachingjdbcclient
# jmx.current.io.trino.plugin.jdbc:name=mysql,type=connectionfactory
# jmx.current.io.trino.plugin.jdbc:name=mysql,type=jdbcclient
# jmx.current.java.lang:name=codecachemanager,type=memorymanager
# jmx.current.java.lang:name=codeheap 'non-nmethods',type=memorypool
# jmx.current.java.lang:name=codeheap 'non-profiled nmethods',type=memorypool
# jmx.current.java.lang:name=codeheap 'profiled nmethods',type=memorypool
# jmx.current.java.lang:name=compressed class space,type=memorypool
# jmx.current.java.lang:name=g1 eden space,type=memorypool
# jmx.current.java.lang:name=g1 old gen,type=memorypool
# jmx.current.java.lang:name=g1 old generation,type=garbagecollector
# jmx.current.java.lang:name=g1 survivor space,type=memorypool
# jmx.current.java.lang:name=g1 young generation,type=garbagecollector
# jmx.current.java.lang:name=metaspace manager,type=memorymanager
# jmx.current.java.lang:name=metaspace,type=memorypool
# jmx.current.java.lang:type=classloading
# jmx.current.java.lang:type=compilation
# jmx.current.java.lang:type=memory
# jmx.current.java.lang:type=operatingsystem
# jmx.current.java.lang:type=runtime
# jmx.current.java.lang:type=threading
# jmx.current.java.nio:name=direct,type=bufferpool
# jmx.current.java.nio:name=mapped,type=bufferpool
# jmx.current.java.util.logging:type=logging
# jmx.current.jdk.management.jfr:type=flightrecorder
# jmx.current.jmimplementation:type=mbeanserverdelegate
# jmx.current.org.eclipse.jetty.http2.server:context=http_1_1_h2c@5543d800,id=0,type=abstracthttp2serverconnectionfactory$http2sessioncontainer
# jmx.current.org.eclipse.jetty.http2.server:context=http_1_1_h2c@5543d800,id=0,type=http2cserverconnectionfactory
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=0,type=arraybytebufferpool
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=0,type=connectionstatistics
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=0,type=managedselector
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=0,type=managedselector$selectorproducer
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=1,type=managedselector
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=1,type=managedselector$selectorproducer
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=2,type=managedselector
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=2,type=managedselector$selectorproducer
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=3,type=managedselector
# jmx.current.org.eclipse.jetty.io:context=http_1_1_h2c@5543d800,id=3,type=managedselector$selectorproducer
# jmx.current.org.eclipse.jetty.jmx:id=0,type=mbeancontainer
# jmx.current.org.eclipse.jetty.server.handler.gzip:context=_root@@http_,id=0,type=gziphandler
# jmx.current.org.eclipse.jetty.server.handler:id=0,type=errorhandler
# jmx.current.org.eclipse.jetty.server.handler:id=0,type=handlercollection
# jmx.current.org.eclipse.jetty.server.handler:id=0,type=handlerlist
# jmx.current.org.eclipse.jetty.server.handler:id=0,type=requestloghandler
# jmx.current.org.eclipse.jetty.server.handler:id=0,type=statisticshandler
# jmx.current.org.eclipse.jetty.server:context=http_1_1_h2c@5543d800,id=0,type=abstractconnector$acceptor
# jmx.current.org.eclipse.jetty.server:context=http_1_1_h2c@5543d800,id=0,type=httpconfiguration
# jmx.current.org.eclipse.jetty.server:context=http_1_1_h2c@5543d800,id=0,type=httpconnectionfactory
# jmx.current.org.eclipse.jetty.server:context=http_1_1_h2c@5543d800,id=0,type=serverconnector
# jmx.current.org.eclipse.jetty.server:context=http_1_1_h2c@5543d800,id=0,type=serverconnector$serverconnectormanager
# jmx.current.org.eclipse.jetty.server:id=0,type=server
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=io_airlift_http_server_timingfilter-32f45e15,type=filterholder
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=io_airlift_http_server_timingfilter-32f45e15,type=filtermapping
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=io_airlift_http_server_tracetokenfilter-524dd373,type=filterholder
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=io_airlift_http_server_tracetokenfilter-524dd373,type=filtermapping
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=org_eclipse_jetty_servlet_servlethandler$default404servlet-78c23ade,type=servletholder
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=org_eclipse_jetty_servlet_servlethandler$default404servlet-78c23ade,type=servletmapping
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=org_glassfish_jersey_servlet_servletcontainer-ad585fb,type=servletholder
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,name=org_glassfish_jersey_servlet_servletcontainer-ad585fb,type=servletmapping
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,type=servletcontexthandler
# jmx.current.org.eclipse.jetty.servlet:context=_root@@http_,id=0,type=servlethandler
# jmx.current.org.eclipse.jetty.util.compression:context=_root@@http_,id=0,type=deflaterpool
# jmx.current.org.eclipse.jetty.util.thread.strategy:context=http_1_1_h2c@5543d800,id=0,type=eatwhatyoukill
# jmx.current.org.eclipse.jetty.util.thread.strategy:context=http_1_1_h2c@5543d800,id=1,type=eatwhatyoukill
# jmx.current.org.eclipse.jetty.util.thread.strategy:context=http_1_1_h2c@5543d800,id=2,type=eatwhatyoukill
# jmx.current.org.eclipse.jetty.util.thread.strategy:context=http_1_1_h2c@5543d800,id=3,type=eatwhatyoukill
# jmx.current.org.eclipse.jetty.util.thread:context=http_1_1_h2c@5543d800,id=0,type=scheduledexecutorscheduler
# jmx.current.org.eclipse.jetty.util.thread:id=0,type=queuedthreadpool
# jmx.current.org.eclipse.jetty.util.thread:id=0,type=reservedthreadexecutor
# jmx.current.org.eclipse.jetty.util.thread:id=0,type=threadpoolbudget
# jmx.current.sun.nio.ch:context=http_1_1_h2c@5543d800,id=0,type=serversocketchannelimpl
# jmx.current.trino.execution.executor:name=multilevelsplitqueue
# jmx.current.trino.execution.executor:name=taskexecutor
# jmx.current.trino.execution.resourcegroups:name=internalresourcegroupmanager
# jmx.current.trino.execution.scheduler:name=nodescheduler
# jmx.current.trino.execution.scheduler:name=splitschedulerstats
# jmx.current.trino.execution:name=clustersizemonitor
# jmx.current.trino.execution:name=queryexecution
# jmx.current.trino.execution:name=querymanager
# jmx.current.trino.execution:name=remotetaskfactory
# jmx.current.trino.execution:name=taskmanager
# jmx.current.trino.failuredetector:name=heartbeatfailuredetector
# jmx.current.trino.memory:name=clustermemorymanager
# jmx.current.trino.memory:name=general,type=clustermemorypool
# jmx.current.trino.memory:name=general,type=memorypool
# jmx.current.trino.metadata:name=discoverynodemanager
# jmx.current.trino.operator.index:name=indexjoinlookupstats
# jmx.current.trino.security:name=accesscontrolmanager
# jmx.current.trino.server.remotetask:name=remotetaskstats
# jmx.current.trino.server:name=asynchttpexecutionmbean
# jmx.current.trino.server:name=exchangeexecutionmbean
# jmx.current.trino.server:name=statementhttpexecutionmbean
# jmx.current.trino.server:name=taskexecutorresource
# jmx.current.trino.server:name=taskresource
# jmx.current.trino.spi.type:name=typeoperators
# jmx.current.trino.spiller:name=spillerfactory
# jmx.current.trino.sql.gen:name=expressioncompiler
# jmx.current.trino.sql.gen:name=joincompiler
# jmx.current.trino.sql.gen:name=joinfilterfunctioncompiler
# jmx.current.trino.sql.gen:name=orderingcompiler
# jmx.current.trino.sql.gen:name=pagefunctioncompiler
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=addexchangesbelowexchangepartialaggregationgroupid
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=addexchangesbelowprojectionpartialaggregationgroupid
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=addintermediateaggregations
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=aggregationexpressionrewrite
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=applypreferredtableexecutepartitioning
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=applypreferredtablewriterpartitioning
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=applytablescanredirection
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=createpartialtopn
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=decorrelateinnerunnestwithglobalaggregation
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=decorrelateleftunnestwithglobalaggregation
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=decorrelateunnest
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=determinejoindistributiontype
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=determinesemijoindistributiontype
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=determinetablescannodepartitioning
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=eliminatecrossjoins
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=evaluateemptyintersect
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=evaluatezerosample
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=extractdereferencesfromfilterabovescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=extractspatialinnerjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=extractspatialleftjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=filterexpressionrewrite
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementbernoullisampleasfilter
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementexceptall
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementexceptdistinctasunion
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementfilteredaggregations
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementintersectall
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementintersectdistinctasunion
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementlimitwithties
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=implementoffset
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=inlineprojectintofilter
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=inlineprojections
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=joinexpressionrewrite
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergeadjacentwindowsoverprojects
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergeexcept
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergefilters
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergeintersect
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergelimitoverprojectwithsort
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergelimits
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergelimitwithdistinct
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergelimitwithsort
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergelimitwithtopn
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergepatternrecognitionnodeswithoutproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergepatternrecognitionnodeswithproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergeprojectwithvalues
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=mergeunion
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=multipledistinctaggregationtomarkdistinct
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=optimizeduplicateinsensitivejoins
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=optimizerowpattern
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=patternrecognitionexpressionrewrite
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=projectexpressionrewrite
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneaggregationcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneaggregationsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneapplycolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneapplycorrelation
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneapplysourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneassignuniqueidcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunecorrelatedjoincolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunecorrelatedjoincorrelation
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunecountaggregationoverscalar
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunedeletesourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunedistinctaggregation
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunedistinctlimitsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneenforcesinglerowcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneexceptsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneexchangecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneexchangesourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneexplainanalyzesourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunefiltercolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunegroupidcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunegroupidsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneindexjoincolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneindexsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneintersectsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunejoinchildrencolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunejoincolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunelimitcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunemarkdistinctcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneoffsetcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneorderbyinaggregation
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneoutputsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunepattenrecognitioncolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunepatternrecognitionsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneprojectcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunerownumbercolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunesamplecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunesemijoincolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunesemijoinfilteringsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunesortcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunespatialjoinchildrencolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunespatialjoincolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunetableexecutesourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunetablescancolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunetablewritersourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunetopncolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunetopnrankingcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneunioncolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneunionsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneunnestcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneunnestsourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pruneupdatesourcecolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunevaluescolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=prunewindowcolumns
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushaggregationintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushaggregationthroughouterjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdeleteintoconnector
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdistinctlimitintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencesthroughassignuniqueid
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencesthroughlimit
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencesthroughrownumber
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencesthroughsort
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencesthroughtopn
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencesthroughtopnranking
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencesthroughwindow
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencethroughfilter
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencethroughjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencethroughproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencethroughsemijoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdowndereferencethroughunnest
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdownfilterintorownumber
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdownfilterintowindow
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdownlimitintorownumber
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdownlimitintowindow
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushdownprojectionsfrompatternrecognition
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushjoinintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushlimitintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushlimitthroughmarkdistinct
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushlimitthroughoffset
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushlimitthroughouterjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushlimitthroughproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushlimitthroughsemijoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushlimitthroughunion
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushoffsetthroughproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushpartialaggregationthroughexchange
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushpartialaggregationthroughjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushpredicateintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushpredicatethroughprojectintorownumber
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushpredicatethroughprojectintowindow
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushprojectionintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushprojectionthroughexchange
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushprojectionthroughunion
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushremoteexchangethroughassignuniqueid
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushsampleintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushtablewritethroughunion
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushtopnintotablescan
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushtopnthroughouterjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushtopnthroughproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=pushtopnthroughunion
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeaggregationinsemijoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeemptydelete
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeemptyexceptbranches
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeemptytableexecute
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeemptyunionbranches
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removefullsample
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantdistinctlimit
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantenforcesinglerownode
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantexists
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantidentityprojections
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantlimit
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantoffset
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantsort
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundantsortbelowlimitwithties
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundanttablescanpredicate
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeredundanttopn
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removetrivialfilters
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeunreferencedscalarapplynodes
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=removeunreferencedscalarsubqueries
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=reorderjoins
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=replacejoinoverconstantwithproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=replaceredundantjoinwithproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=replaceredundantjoinwithsource
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=replacewindowwithrownumber
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=rewritespatialpartitioningaggregation
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=simplifycountoverconstant
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=simplifyfilterpredicate
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=singledistinctaggregationtogroupby
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=swapadjacentwindowsbyspecifications
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelateddistinctaggregationwithoutprojection
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelateddistinctaggregationwithprojection
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedglobalaggregationwithoutprojection
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedglobalaggregationwithprojection
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedgroupedaggregationwithoutprojection
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedgroupedaggregationwithprojection
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedinpredicatetojoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedjointojoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedscalarsubquery
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformcorrelatedsinglerowsubquerytoproject
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformexistsapplytocorrelatedjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformfilteringsemijointoinnerjoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformuncorrelatedinpredicatesubquerytosemijoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=transformuncorrelatedsubquerytojoin
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=unwrapsinglecolumnrowinapply
# jmx.current.trino.sql.planner.iterative:name=iterativeoptimizer,rule=valuesexpressionrewrite
# jmx.current.trino.sql.planner.optimizations:name=planoptimizer,optimizer=addexchanges
# jmx.current.trino.sql.planner.optimizations:name=planoptimizer,optimizer=predicatepushdown
# jmx.current.trino.type:name=typeoperatorscache
# ____Page3_______________
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/wz/jjbxsnr13v7dkw2jkbpmqd_dly65gq/T/ipykernel_14947/2318540970.py in <module>
#       1 from fasp.search import DataConnectClient
#       2 cl = DataConnectClient('http://localhost:8089/')
# ----> 3 cl.listTables(verbose=True)
#
# ~/imfenvs/fasp/lib/python3.9/site-packages/fasp/search/data_connect_client.py in listTables(self, requestedCatalog, verbose)
#      58                         else:
#      59                                 next_url = None
# ---> 60                         for t in result['tables']:
#      61                                 if verbose:
#      62                                         print(t['name'])
#
# KeyError: 'tables'

# %% [markdown]
# The listTableColumns function prints a more concise listing

# %%
# init search client
from search_python_client.search import DrsClient, SearchClient
base_url = 'http://localhost:8089/'
search_client = SearchClient(base_url=base_url)

# %%
# get tables
tables_iterator = search_client.get_table_list()
tables = [next(tables_iterator, None) for i in range(10)]
tables = list(filter(None, tables))
print(tables)
# Out:
# [{'name': 'bigquery.blog_unnest.firebase_raw', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.blog_unnest.firebase_raw/info'}}, {'name': 'bigquery.cda.cdav3', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.cda.cdav3/info'}}, {'name': 'bigquery.fasp_scrambled.scr_egapancreatic_sample', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.fasp_scrambled.scr_egapancreatic_sample/info'}}, {'name': 'bigquery.gtex8.program', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.program/info'}}, {'name': 'bigquery.gtex8.project', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.project/info'}}, {'name': 'bigquery.gtex8.sample', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.sample/info'}}, {'name': 'bigquery.gtex8.sequencing', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.sequencing/info'}}, {'name': 'bigquery.gtex8.sraruntable_breast_cram', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.sraruntable_breast_cram/info'}}, {'name': 'bigquery.gtex8.sraruntable_nocram', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.sraruntable_nocram/info'}}, {'name': 'bigquery.gtex8.sraruntable_nocram_nobam', 'data_model': {'$ref': 'http://localhost:8089/table/bigquery.gtex8.sraruntable_nocram_nobam/info'}}]

# %%
query1 = '''SELECT sex, age, study
FROM bigquery.scr_gecco_susceptibility.subject_phenotypes_multi
'''

res = cl.runQuery(query1)
res
# Out:
# _Retrieving the query_
# ____Page1_______________
# ____Page2_______________
# ____Page3_______________
# ____Page4_______________
# ____Page5_______________
# ____Page6_______________
# ____Page7_______________
# ____Page8_______________
# [['Female', 46, 'NHS'],
#  ['Female', 46, 'NHS'],
#  ['Female', 47, 'NHS'],
#  ['Female', 47, 'NHS'],
#  ['Female', 48, 'NHS'],
#  ['Female', 49, 'NHS'],
#  ['Male', 51, 'NHS'],
#  ['Male', 51, 'NHS'],
#  ['Female', 51, 'NHS'],
#  ['Female', 51, 'NHS'],
#  ['Male', 52, 'NHS'],
#  ['Female', 52, 'NHS'],
#  ['Female', 52, 'NHS'],
#  ['Female', 53, 'NHS'],
#  ['Female', 53, 'NHS'],
#  ['Female', 54, 'NHS'],
#  ['Male', 54, 'NHS'],
#  ['Male', 54, 'NHS'],
#  ['Female', 54, 'NHS'],
#  ['Male', 55, 'NHS'],
#  ['Male', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Female', 55, 'NHS'],
#  ['Male', 55, 'NHS'],
#  ['Female', 56, 'NHS'],
#  ['Female', 56, 'NHS'],
#  ['Female', 56, 'NHS'],
#  ['Male', 56, 'NHS'],
#  ['Female', 56, 'NHS'],
#  ['Female', 56, 'NHS'],
#  ['Male', 56, 'NHS'],
#  ['Female', 56, 'NHS'],
#  ['Female', 57, 'NHS'],
#  ['Female', 57, 'NHS'],
#  ['Female', 57, 'NHS'],
#  ['Male', 58, 'NHS'],
#  ['Female', 58, 'NHS'],
#  ['Female', 58, 'NHS'],
#  ['Male', 58, 'NHS'],
#  ['Female', 59, 'NHS'],
#  ['Female', 59, 'NHS'],
#  ['Male', 59, 'NHS'],
#  ['Male', 59, 'NHS'],
#  ['Male', 59, 'NHS'],
#  ['Male', 59, 'NHS'],
#  ['Female', 60, 'NHS'],
#  ['Female', 60, 'NHS'],
#  ['Female', 60, 'NHS'],
#  ['Female', 60, 'NHS'],
#  ['Female', 60, 'NHS'],
#  ['Male', 60, 'NHS'],
#  ['Female', 61, 'NHS'],
#  ['Male', 61, 'NHS'],
#  ['Male', 62, 'NHS'],
#  ['Female', 62, 'NHS'],
#  ['Female', 62, 'NHS'],
#  ['Male', 62, 'NHS'],
#  ['Female', 62, 'NHS'],
#  ['Female', 62, 'NHS'],
#  ['Female', 62, 'NHS'],
#  ['Female', 62, 'NHS'],
#  ['Male', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Male', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Male', 63, 'NHS'],
#  ['Male', 63, 'NHS'],
#  ['Male', 63, 'NHS'],
#  ['Male', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Male', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Female', 63, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Male', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Male', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Male', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Male', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Male', 64, 'NHS'],
#  ['Female', 64, 'NHS'],
#  ['Male', 65, 'NHS'],
#  ['Male', 65, 'NHS'],
#  ['Female', 65, 'NHS'],
#  ['Female', 65, 'NHS'],
#  ['Female', 65, 'NHS'],
#  ['Male', 65, 'NHS'],
#  ['Male', 65, 'NHS'],
#  ['Female', 65, 'NHS'],
#  ['Female', 65, 'NHS'],
#  ['Female', 65, 'NHS'],
#  ['Female', 65, 'NHS'],
#  ['Female', 66, 'NHS'],
#  ['Female', 66, 'NHS'],
#  ['Female', 66, 'NHS'],
#  ['Male', 66, 'NHS'],
#  ['Male', 66, 'NHS'],
#  ['Female', 66, 'NHS'],
#  ['Male', 66, 'NHS'],
#  ['Female', 66, 'NHS'],
#  ['Male', 66, 'NHS'],
#  ['Female', 66, 'NHS'],
#  ['Female', 66, 'NHS'],
#  ['Female', 67, 'NHS'],
#  ['Female', 67, 'NHS'],
#  ['Female', 67, 'NHS'],
#  ['Female', 67, 'NHS'],
#  ['Female', 67, 'NHS'],
#  ['Female', 67, 'NHS'],
#  ['Male', 67, 'NHS'],
#  ['Male', 67, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Male', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Male', 68, 'NHS'],
#  ['Male', 68, 'NHS'],
#  ['Female', 68, 'NHS'],
#  ['Male', 69, 'NHS'],
#  ['Female', 69, 'NHS'],
#  ['Female', 69, 'NHS'],
#  ['Female', 69, 'NHS'],
#  ['Female', 69, 'NHS'],
#  ['Female', 69, 'NHS'],
#  ['Female', 69, 'NHS'],
#  ['Female', 69, 'NHS'],
#  ['Male', 70, 'NHS'],
#  ['Female', 70, 'NHS'],
#  ['Female', 70, 'NHS'],
#  ['Male', 70, 'NHS'],
#  ['Male', 70, 'NHS'],
#  ['Female', 70, 'NHS'],
#  ['Male', 70, 'NHS'],
#  ['Female', 70, 'NHS'],
#  ['Female', 71, 'NHS'],
#  ['Female', 71, 'NHS'],
#  ['Female', 71, 'NHS'],
#  ['Female', 71, 'NHS'],
#  ['Male', 71, 'NHS'],
#  ['Male', 71, 'NHS'],
#  ['Female', 71, 'NHS'],
#  ['Female', 71, 'NHS'],
#  ['Male', 72, 'NHS'],
#  ['Female', 72, 'NHS'],
#  ['Male', 72, 'NHS'],
#  ['Male', 72, 'NHS'],
#  ['Male', 72, 'NHS'],
#  ['Male', 72, 'NHS'],
#  ['Female', 72, 'NHS'],
#  ['Male', 72, 'NHS'],
#  ['Female', 72, 'NHS'],
#  ['Male', 72, 'NHS'],
#  ['Female', 72, 'NHS'],
#  ['Female', 72, 'NHS'],
#  ['Female', 73, 'NHS'],
#  ['Female', 73, 'NHS'],
#  ['Male', 73, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Female', 74, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Female', 74, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Female', 74, 'NHS'],
#  ['Female', 74, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Female', 74, 'NHS'],
#  ['Male', 74, 'NHS'],
#  ['Female', 75, 'NHS'],
#  ['Male', 75, 'NHS'],
#  ['Female', 75, 'NHS'],
#  ['Male', 75, 'NHS'],
#  ['Female', 75, 'NHS'],
#  ['Male', 76, 'NHS'],
#  ['Male', 76, 'NHS'],
#  ['Female', 76, 'NHS'],
#  ['Female', 76, 'NHS'],
#  ['Female', 76, 'NHS'],
#  ['Female', 77, 'NHS'],
#  ['Male', 77, 'NHS'],
#  ['Male', 77, 'NHS'],
#  ['Female', 77, 'NHS'],
#  ['Female', 77, 'NHS'],
#  ['Female', 78, 'NHS'],
#  ['Male', 78, 'NHS'],
#  ['Male', 78, 'NHS'],
#  ['Male', 79, 'NHS'],
#  ['Female', 79, 'NHS'],
#  ['Male', 80, 'NHS'],
#  ['Female', 80, 'NHS'],
#  ['Male', 81, 'NHS'],
#  ['Female', 81, 'NHS'],
#  ['Male', 82, 'NHS'],
#  ['Male', 84, 'NHS'],
#  ['Male', 85, 'NHS'],
#  ['Female', 87, 'NHS'],
#  ['Female', 87, 'NHS'],
#  ['Female', 88, 'NHS'],
#  ['Male', 37, 'WHI'],
#  ['Male', 37, 'WHI'],
#  ['Female', 38, 'WHI'],
#  ['Male', 44, 'WHI'],
#  ['Female', 44, 'WHI'],
#  ['Female', 45, 'WHI'],
#  ['Male', 45, 'WHI'],
#  ['Female', 46, 'WHI'],
#  ['Female', 47, 'WHI'],
#  ['Female', 47, 'WHI'],
#  ['Female', 47, 'WHI'],
#  ['Female', 48, 'WHI'],
#  ['Female', 48, 'WHI'],
#  ['Female', 48, 'WHI'],
#  ['Male', 48, 'WHI'],
#  ['Male', 48, 'WHI'],
#  ['Male', 49, 'WHI'],
#  ['Female', 49, 'WHI'],
#  ['Male', 49, 'WHI'],
#  ['Male', 49, 'WHI'],
#  ['Female', 49, 'WHI'],
#  ['Male', 50, 'WHI'],
#  ['Female', 50, 'WHI'],
#  ['Female', 50, 'WHI'],
#  ['Male', 50, 'WHI'],
#  ['Female', 50, 'WHI'],
#  ['Male', 50, 'WHI'],
#  ['Male', 51, 'WHI'],
#  ['Female', 51, 'WHI'],
#  ['Female', 51, 'WHI'],
#  ['Female', 51, 'WHI'],
#  ['Female', 51, 'WHI'],
#  ['Female', 51, 'WHI'],
#  ['Male', 51, 'WHI'],
#  ['Female', 51, 'WHI'],
#  ['Female', 52, 'WHI'],
#  ['Male', 52, 'WHI'],
#  ['Male', 52, 'WHI'],
#  ['Female', 52, 'WHI'],
#  ['Female', 52, 'WHI'],
#  ['Male', 52, 'WHI'],
#  ['Male', 52, 'WHI'],
#  ['Female', 52, 'WHI'],
#  ['Female', 52, 'WHI'],
#  ['Female', 52, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Male', 53, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Male', 53, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Male', 53, 'WHI'],
#  ['Female', 53, 'WHI'],
#  ['Male', 54, 'WHI'],
#  ['Female', 54, 'WHI'],
#  ['Female', 54, 'WHI'],
#  ['Female', 54, 'WHI'],
#  ['Male', 54, 'WHI'],
#  ['Male', 54, 'WHI'],
#  ['Female', 54, 'WHI'],
#  ['Female', 54, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Female', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Male', 55, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Male', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 56, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Male', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Male', 57, 'WHI'],
#  ['Male', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Male', 57, 'WHI'],
#  ['Male', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Male', 57, 'WHI'],
#  ['Female', 57, 'WHI'],
#  ['Male', 57, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Male', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Male', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Male', 58, 'WHI'],
#  ['Male', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Male', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Male', 58, 'WHI'],
#  ['Female', 58, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Female', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Male', 59, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Male', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 60, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Male', 61, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Female', 62, 'WHI'],
#  ['Male', 62, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Female', 63, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Female', 64, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Male', 65, 'WHI'],
#  ['Female', 65, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Male', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 66, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Male', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Female', 67, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Female', 68, 'WHI'],
#  ['Male', 68, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Male', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 69, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 70, 'WHI'],
#  ['Male', 70, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 71, 'WHI'],
#  ['Male', 71, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Male', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 72, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Female', 73, 'WHI'],
#  ['Male', 73, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Male', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Male', 74, 'WHI'],
#  ['Male', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Male', 74, 'WHI'],
#  ['Male', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ['Female', 74, 'WHI'],
#  ...]

# %%
cl.listTables('dbgap_demo')
# Out:
# _Retrieving the table list_
# ____Page1_______________
# collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_files
# collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi
# collections.public_datasets.dbgap_scr_gecco_susceptibility_gecco_sample_acc
# collections.public_datasets.dbgap_scr_gecco_susceptibility_phs001554_gecco_sddp_manifest
# collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi
# collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_multi
# collections.public_datasets.dbgap_scr_gecco_susceptibility_sb_drs_index
# collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_multi
# collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_phenotypes_multi
# ['collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_files',
#  'collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi',
#  'collections.public_datasets.dbgap_scr_gecco_susceptibility_gecco_sample_acc',
#  'collections.public_datasets.dbgap_scr_gecco_susceptibility_phs001554_gecco_sddp_manifest',
#  'collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi',
#  'collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_multi',
#  'collections.public_datasets.dbgap_scr_gecco_susceptibility_sb_drs_index',
#  'collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_multi',
#  'collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_phenotypes_multi']

# %% [markdown]
# This provides the full schema for sample attributes from the same study.

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi",
#    "description": "Automatically generated schema",
#    "data_model": {
#       "$id": "http://localhost:8089/table/collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi/info",
#       "description": "Automatically generated schema",
#       "$schema": "http://json-schema.org/draft-07/schema#",
#       "properties": {
#          "dbgap_sample_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "sample_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "body_site": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "analyte_type": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "is_tumor": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "dna_source": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "batch": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "read_depth": {
#             "format": "double",
#             "type": "number",
#             "$comment": "double"
#          },
#          "sequencing_center": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          }
#       }
#    }
# }

# %%
cl.listTableColumns('collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi',descriptions=True)
# Out:
# dbgap_sample_id
# varchar
# _______________________________________
# sample_id
# varchar
# _______________________________________
# body_site
# varchar
# _______________________________________
# analyte_type
# varchar
# _______________________________________
# is_tumor
# varchar
# _______________________________________
# dna_source
# varchar
# _______________________________________
# batch
# varchar
# _______________________________________
# read_depth
# double
# _______________________________________
# sequencing_center
# varchar
# _______________________________________

# %% [markdown]
# ### An EGA Table
# The same format of data dictionary was created for an EGA table.

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi',verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi",
#    "description": "Automatically generated schema",
#    "data_model": {
#       "$id": "http://localhost:8089/table/collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi/info",
#       "description": "Automatically generated schema",
#       "$schema": "http://json-schema.org/draft-07/schema#",
#       "properties": {
#          "sample_primary_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "sample_submitter_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "disease_site": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "gender": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "phenotype": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "subject_id": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "ena_checklist": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          },
#          "bam_file": {
#             "format": "varchar",
#             "type": "string",
#             "$comment": "varchar"
#          }
#       }
#    }
# }

# %%
cl.listTableColumns('bigquery.scr_gecco_susceptibility.subject_phenotypes_multi', descriptions=True, enums=True)
# Out:
# dbgap_subject_id
# varchar
# varchar
# _______________________________________
# subject_id
# varchar
# varchar
# _______________________________________
# affection_status
# varchar
# varchar
# _______________________________________
# sex
# varchar
# varchar
# _______________________________________
# age
# bigint
# bigint
# _______________________________________
# race
# varchar
# varchar
# _______________________________________
# ethnicity
# varchar
# varchar
# _______________________________________
# study
# varchar
# varchar
# _______________________________________

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_phenotypes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_gecco_susceptibility_subject_phenotypes_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_phenotypes_multi",
#    "data_model": {
#       "description": "",
#       "$id": "dbgap:pht007609.v1",
#       "properties": {
#          "STUDY": {
#             "$id": "dbgap:phv00357188.v1",
#             "description": "Study acronym",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "CPS-II"
#                },
#                {
#                   "title": "DACHS"
#                },
#                {
#                   "title": "HPFS"
#                },
#                {
#                   "title": "NHS"
#                },
#                {
#                   "title": "PLCO"
#                },
#                {
#                   "title": "WHI"
#                }
#             ]
#          },
#          "SUBJECT_ID": {
#             "$id": "dbgap:phv00357182.v1",
#             "description": "De-identified subject ID",
#             "type": "string",
#             "oneOf": []
#          },
#          "SEX": {
#             "$id": "dbgap:phv00357184.v1",
#             "description": "Sex of participant",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "Female"
#                },
#                {
#                   "title": "Male"
#                }
#             ]
#          },
#          "RACE": {
#             "$id": "dbgap:phv00357186.v1",
#             "description": "Race of participant",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "White"
#                }
#             ]
#          },
#          "ETHNICITY": {
#             "$id": "dbgap:phv00357187.v1",
#             "description": "Ethnicity of participant",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "Unknown"
#                }
#             ]
#          },
#          "AFFECTION_STATUS": {
#             "$id": "dbgap:phv00357183.v1",
#             "description": "Case control status of the subject for colorectal cancer",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "Case"
#                },
#                {
#                   "title": "Control"
#                }
#             ]
#          },
#          "AGE": {
#             "$id": "dbgap:phv00357185.v1",
#             "description": "Participant reference age",
#             "type": "integer",
#             "$unit": "Years",
#             "oneOf": []
#          }
#       }
#    }
# }

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi",
#    "data_model": {
#       "description": "",
#       "$id": "dbgap:pht007610.v1",
#       "properties": {
#          "SEQUENCING_CENTER": {
#             "$id": "dbgap:phv00357196.v1",
#             "description": "Name of the center that conducted sequencing",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "University of Washington Sequencing Center (Seattle, WA, USA)"
#                },
#                {
#                   "const": "2",
#                   "title": "Macrogen USA"
#                }
#             ]
#          },
#          "ANALYTE_TYPE": {
#             "$id": "dbgap:phv00357191.v1",
#             "description": "Analyte Type",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "DNA"
#                }
#             ]
#          },
#          "IS_TUMOR": {
#             "$id": "dbgap:phv00357192.v1",
#             "description": "Tumor status",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "No"
#                }
#             ]
#          },
#          "DNA_SOURCE": {
#             "$id": "dbgap:phv00357193.v1",
#             "description": "DNA origin",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "Blood"
#                },
#                {
#                   "title": "Buffy coat"
#                },
#                {
#                   "title": "Unknown"
#                },
#                {
#                   "title": "Whole blood"
#                }
#             ]
#          },
#          "BATCH": {
#             "$id": "dbgap:phv00357194.v1",
#             "description": "Sequencing batch",
#             "type": "string",
#             "oneOf": []
#          },
#          "READ_DEPTH": {
#             "$id": "dbgap:phv00357195.v1",
#             "description": "Sequencing coverage",
#             "type": "decimal",
#             "$unit": "fold coverage",
#             "oneOf": []
#          },
#          "BODY_SITE": {
#             "$id": "dbgap:phv00357190.v1",
#             "description": "Body site where sample was collected",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "Blood"
#                }
#             ]
#          },
#          "SAMPLE_ID": {
#             "$id": "dbgap:phv00357189.v1",
#             "description": "De-identified Sample ID",
#             "type": "string",
#             "oneOf": []
#          }
#       }
#    }
# }

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_attributes_multi",
#    "data_model": {
#       "description": "",
#       "$id": "dbgap:pht007610.v1",
#       "properties": {
#          "SEQUENCING_CENTER": {
#             "$id": "dbgap:phv00357196.v1",
#             "description": "Name of the center that conducted sequencing",
#             "type": "encoded value",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "University of Washington Sequencing Center (Seattle, WA, USA)"
#                },
#                {
#                   "const": "2",
#                   "title": "Macrogen USA"
#                }
#             ]
#          },
#          "ANALYTE_TYPE": {
#             "$id": "dbgap:phv00357191.v1",
#             "description": "Analyte Type",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "DNA"
#                }
#             ]
#          },
#          "IS_TUMOR": {
#             "$id": "dbgap:phv00357192.v1",
#             "description": "Tumor status",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "No"
#                }
#             ]
#          },
#          "DNA_SOURCE": {
#             "$id": "dbgap:phv00357193.v1",
#             "description": "DNA origin",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "Blood"
#                },
#                {
#                   "title": "Buffy coat"
#                },
#                {
#                   "title": "Unknown"
#                },
#                {
#                   "title": "Whole blood"
#                }
#             ]
#          },
#          "BATCH": {
#             "$id": "dbgap:phv00357194.v1",
#             "description": "Sequencing batch",
#             "type": "string",
#             "oneOf": []
#          },
#          "READ_DEPTH": {
#             "$id": "dbgap:phv00357195.v1",
#             "description": "Sequencing coverage",
#             "type": "decimal",
#             "$unit": "fold coverage",
#             "oneOf": []
#          },
#          "BODY_SITE": {
#             "$id": "dbgap:phv00357190.v1",
#             "description": "Body site where sample was collected",
#             "type": "string",
#             "oneOf": [
#                {
#                   "title": "Blood"
#                }
#             ]
#          },
#          "SAMPLE_ID": {
#             "$id": "dbgap:phv00357189.v1",
#             "description": "De-identified Sample ID",
#             "type": "string",
#             "oneOf": []
#          }
#       }
#    }
# }

# %%
cl.listTableInfo('bigquery.scr_gecco_susceptibility.subject_phenotypes_multi', verbose=True)
# Out:
# _Schema for tablebigquery.scr_gecco_susceptibility.subject_phenotypes_multi_
# {
#    "name": "bigquery.scr_gecco_susceptibility.subject_phenotypes_multi",
#    "data_model": {
#       "description": "",
#       "$id": "dbgap:pht007609.v1",
#       "properties": {
#          "STUDY": {
#             "$id": "dbgap:phv00357188.v1",
#             "description": "Study acronym",
#             "type": "string"
#          },
#          "SUBJECT_ID": {
#             "$id": "dbgap:phv00357182.v1",
#             "description": "De-identified subject ID",
#             "type": "string"
#          },
#          "SEX": {
#             "$id": "dbgap:phv00357184.v1",
#             "description": "Sex of participant",
#             "type": "string"
#          },
#          "RACE": {
#             "$id": "dbgap:phv00357186.v1",
#             "description": "Race of participant",
#             "type": "string"
#          },
#          "ETHNICITY": {
#             "$id": "dbgap:phv00357187.v1",
#             "description": "Ethnicity of participant",
#             "type": "string"
#          },
#          "AFFECTION_STATUS": {
#             "$id": "dbgap:phv00357183.v1",
#             "description": "Case control status of the subject for colorectal cancer",
#             "type": "string"
#          },
#          "AGE": {
#             "$id": "dbgap:phv00357185.v1",
#             "description": "Participant reference age",
#             "type": "integer",
#             "$unit": "Years"
#          }
#       }
#    }
# }

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_ega_scr_egapancreatic_sample_multi",
#    "data_model": {
#       "$id": "scr_EGApancreatic_sample.data_dict.xml.scr_EGApancreatic_sample",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "gender": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "female"
#                },
#                {
#                   "const": "male"
#                }
#             ],
#             "description": "Sex of participant"
#          },
#          "bam_file": {
#             "type": "string",
#             "description": "Relative path for alignment file"
#          },
#          "phenotype": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "lung tissue"
#                },
#                {
#                   "const": "muscle tissue"
#                },
#                {
#                   "const": "pancreatic adenocarcinoma"
#                },
#                {
#                   "const": "skin tissue"
#                },
#                {
#                   "const": "spleen tissue"
#                }
#             ],
#             "description": "Site independent tissue type"
#          },
#          "subject_id": {
#             "type": "string",
#             "description": "Subject Id used locally by submitter"
#          },
#          "disease_site": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "Liver_Metastasis"
#                },
#                {
#                   "const": "Lung_Metastasis"
#                },
#                {
#                   "const": "Lung_Normal"
#                },
#                {
#                   "const": "Lymph_Node_Metastasis"
#                },
#                {
#                   "const": "Muscle_Normal"
#                },
#                {
#                   "const": "Normal Pancreas"
#                },
#                {
#                   "const": "Pancreas_Primary_Tumor"
#                },
#                {
#                   "const": "Peritoneal_Metastasis"
#                },
#                {
#                   "const": "Skin_Normal"
#                },
#                {
#                   "const": "Spleen_Normal"
#                }
#             ],
#             "description": "body site sample was taken from"
#          },
#          "ena-checklist": {
#             "type": "string",
#             "description": "Minimal information checklist used in this study"
#          },
#          "sample_primary_id": {
#             "type": "string",
#             "description": "De-identified sample ID"
#          },
#          "sample_submitter_id": {
#             "type": "string",
#             "description": "Sample id used locally by submitter"
#          }
#       },
#       "type": "object"
#    }
# }

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_gecco_susceptibility_sample_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_gecco_susceptibility_sample_multi",
#    "description": "Scrambled version of sample crossreference data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007608.v1.GECCO_CRC_Susceptibility_Sample",
#       "description": "Scrambled version of sample crossreference data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "sample_id": {
#             "type": "string",
#             "description": "Sample ID"
#          },
#          "sample_use": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "Seq_DNA_SNP",
#                   "title": "SNP genotypes derived from sequence data"
#                }
#             ],
#             "description": "Sample Use"
#          },
#          "subject_id": {
#             "type": "string",
#             "description": "Subject ID"
#          },
#          "sample_source": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "WHI"
#                }
#             ],
#             "description": "Source repository (study) where samples originate"
#          },
#          "source_sample_id": {
#             "type": "string",
#             "description": "Subject ID used in the Source Repository"
#          }
#       },
#       "type": "object"
#    }
# }

# %%
cl.listTableInfo('collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_multi', verbose=True)
# Out:
# _Schema for tablecollections.public_datasets.dbgap_scr_gecco_susceptibility_subject_multi_
# {
#    "name": "collections.public_datasets.dbgap_scr_gecco_susceptibility_subject_multi",
#    "description": "Scrambled version of subject crossreference data for phs001554 Colorectal cancer susceptibility study.",
#    "data_model": {
#       "$id": "phs001554.v1.pht007607.v1.GECCO_CRC_Susceptibility_Subject",
#       "description": "Scrambled version of subject crossreference data for phs001554 Colorectal cancer susceptibility study.",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "consent": {
#             "type": "string",
#             "oneOf": [
#                {
#                   "const": "1",
#                   "title": "General Research Use (GRU)"
#                },
#                {
#                   "const": "2",
#                   "title": "Health/Medical/Biomedical (IRB) (HMB-IRB)"
#                },
#                {
#                   "const": "3",
#                   "title": "Health/Medical/Biomedical (IRB, NPU) (HMB-IRB-NPU)"
#                },
#                {
#                   "const": "4",
#                   "title": "Disease-Specific (Colorectal Cancer, NPU, GSO) (DS-CC-NPU-GSO)"
#                },
#                {
#                   "const": "5",
#                   "title": "Cancer in all age groups, other diseases in adults only, and methods (CADM)"
#                }
#             ],
#             "description": "Consent group as determined by DAC"
#          },
#          "subject_id": {
#             "type": "string",
#             "description": "Subject ID"
#          },
#          "subject_source": {
#             "type": "string",
#             "description": "Source repository where subjects originate"
#          },
#          "source_subject_id": {
#             "type": "string",
#             "description": "Subject ID used in the Source Repository"
#          }
#       },
#       "type": "object"
#    }
# }
