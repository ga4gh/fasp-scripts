# %% [markdown]
# ### Retrieve example from Gen3 Metadata Service
#
# The following is an example response from the Gen3 Metadata service for a specific file

# %%
import requests
service_url = 'https://gen3.biodatacatalyst.nhlbi.nih.gov/mds/metadata/'
example_id = 'dg.4503/00000027-a1c4-4587-a6c9-d35f5818a724'
call_url = f'{service_url}{example_id}'

response = requests.get(call_url)

# %%
response.json()['dbgap']
# Out:
# {'sex': 'female',
#  'body_site': 'peripheral blood',
#  'repository': 'GeneSTAR',
#  'sample_use': ['Seq_DNA_SNP_CNV'],
#  'analyte_type': 'DNA',
#  'biosample_id': 'SAMN06062404',
#  'consent_code': 2,
#  'dbgap_status': 'Loaded',
#  'sra_sample_id': 'SAMN06062404',
#  'dbgap_sample_id': 2170791,
#  'study_accession': 'phs001218.v2.p1',
#  'dbgap_subject_id': 1797782,
#  'sra_data_details': {'runs': '2',
#   'bases': '260957674200',
#   'center': 'Macrogen',
#   'status': 'public',
#   'size_Gb': '49',
#   'platform': 'ILLUMINA',
#   'experiments': '2',
#   'experiment_type': 'WGS'},
#  'study_subject_id': 'phs001218.v2_GS08900974',
#  'consent_short_name': 'DS-CVD-IRB-NPU-MDS',
#  'study_with_consent': 'phs001218.c2',
#  'submitted_sample_id': 'NWD403016',
#  'submitted_subject_id': 'GS08900974',
#  'study_accession_with_consent': 'phs001218.v2.p1.c2'}

# %% [markdown]
# ### Querying SRA for the same data via Data Connect

# %%
from fasp.search import DataConnectClient
searchClient = DataConnectClient('http://localhost:8089',
                                passport='~/Downloads/task-specific-token-20.txt')
#searchClient = DataConnectClient('https://collection-service.staging.dnastack.com/data-connect')

# %%
searchClient.list_table_info('nih_sra_datastore.sra.metadata', verbose=True)
# Out:
# _Schema for tablenih_sra_datastore.sra.metadata_
# {
#    "name": "nih_sra_datastore.sra.metadata",
#    "description": "Metadata Table (sra.metadata) contains information about the run and biological samples. Metadata Table (sra.metadata) contains information about the run and biological samples. The biological sample data is stored in two different columns.  See Record (array) column that you need to use the command UNNEST to query. See https://www.ncbi.nlm.nih.gov/sra/docs/sra-cloud-based-metadata-table/",
#    "data_model": {
#       "$id": "",
#       "description": "Metadata Table (sra.metadata) contains information about the run and biological samples. Metadata Table (sra.metadata) contains information about the run and biological samples. The biological sample data is stored in two different columns.  See Record (array) column that you need to use the command UNNEST to query. See https://www.ncbi.nlm.nih.gov/sra/docs/sra-cloud-based-metadata-table/",
#       "$schema": "http://json-schema.org/draft-07/schema",
#       "properties": {
#          "acc": {
#             "type": "string",
#             "description": "SRA Run accession in the form of SRR######## (ERR or DRR for INSDC partners)"
#          },
#          "assay_type": {
#             "type": "string",
#             "description": "Type of library (i.e. AMPLICON, RNA-Seq, WGS, etc)",
#             "oneOf": [
#                {
#                   "title": "RNA-Seq"
#                },
#                {
#                   "title": "WGS"
#                },
#                {
#                   "title": "EST"
#                },
#                {
#                   "title": "SELEX"
#                },
#                {
#                   "title": "other"
#                },
#                {
#                   "title": "CTS"
#                },
#                {
#                   "title": "CLONE"
#                },
#                {
#                   "title": "Hi-C"
#                },
#                {
#                   "title": "POOLCLONE"
#                },
#                {
#                   "title": "GBS"
#                },
#                {
#                   "title": "MBD-Seq"
#                },
#                {
#                   "title": "miRNA-Seq"
#                },
#                {
#                   "title": "MeDIP-Seq"
#                },
#                {
#                   "title": "RIP-Seq"
#                },
#                {
#                   "title": "ChIP"
#                },
#                {
#                   "title": "MRE-Seq"
#                },
#                {
#                   "title": "FAIRE-seq"
#                },
#                {
#                   "title": "FL-cDNA"
#                },
#                {
#                   "title": "DNase-Hypersensitivity"
#                },
#                {
#                   "title": "ncRNA-Seq"
#                },
#                {
#                   "title": "WCS"
#                },
#                {
#                   "title": "MNase-Seq"
#                },
#                {
#                   "title": "AMPLICON"
#                },
#                {
#                   "title": "WXS"
#                },
#                {
#                   "title": "ChIP-Seq"
#                },
#                {
#                   "title": "Synthetic-Long-Read"
#                },
#                {
#                   "title": "WGA"
#                },
#                {
#                   "title": "FINISHING"
#                },
#                {
#                   "title": "Tethered Chromatin Conformation Capture"
#                },
#                {
#                   "title": "Targeted-Capture"
#                },
#                {
#                   "title": "ATAC-seq"
#                },
#                {
#                   "title": "RAD-Seq"
#                },
#                {
#                   "title": "ChIA-PET"
#                },
#                {
#                   "title": "OTHER"
#                },
#                {
#                   "title": "Bisulfite-Seq"
#                },
#                {
#                   "title": "Tn-Seq"
#                },
#                {
#                   "title": "CLONEEND"
#                },
#                {
#                   "title": "VALIDATION"
#                }
#             ]
#          },
#          "center_name": {
#             "type": "string",
#             "description": "Name of the sequencing center"
#          },
#          "consent": {
#             "type": "string",
#             "description": "Type of consent need to access the data (i.e. public is available to all, others are for dbGaP)"
#          },
#          "experiment": {
#             "type": "string",
#             "description": "The accession in the form of SRX######## (ERX or DRX for INSDC partners)"
#          },
#          "sample_name": {
#             "type": "string",
#             "description": "Name of the sample"
#          },
#          "instrument": {
#             "type": "string",
#             "description": "Name of the sequencing instrument model"
#          },
#          "librarylayout": {
#             "type": "string",
#             "description": "Whether the data is SINGLE or PAIRED",
#             "oneOf": [
#                {
#                   "title": "PAIRED"
#                },
#                {
#                   "title": "SINGLE"
#                }
#             ]
#          },
#          "libraryselection": {
#             "type": "string",
#             "description": "Library selection methodology (i.e. PCR, RANDOM, etc)",
#             "oneOf": [
#                {
#                   "title": "MF"
#                },
#                {
#                   "title": "ChIP-Seq"
#                },
#                {
#                   "title": "unspecified"
#                },
#                {
#                   "title": "size fractionation"
#                },
#                {
#                   "title": "ChIP"
#                },
#                {
#                   "title": "CAGE"
#                },
#                {
#                   "title": "MSLL"
#                },
#                {
#                   "title": "other"
#                },
#                {
#                   "title": "DNase"
#                },
#                {
#                   "title": "Hybrid Selection"
#                },
#                {
#                   "title": "OTHER"
#                },
#                {
#                   "title": "RT-PCR"
#                },
#                {
#                   "title": "RANDOM"
#                },
#                {
#                   "title": "padlock probes capture method"
#                },
#                {
#                   "title": "PCR"
#                },
#                {
#                   "title": "Oligo-dT"
#                },
#                {
#                   "title": "Restriction Digest"
#                },
#                {
#                   "title": "Reduced Representation"
#                },
#                {
#                   "title": "Inverse rRNA"
#                },
#                {
#                   "title": "5-methylcytidine antibody"
#                },
#                {
#                   "title": "MNase"
#                },
#                {
#                   "title": "MBD2 protein methyl-CpG binding domain"
#                },
#                {
#                   "title": "HMPR"
#                },
#                {
#                   "title": "cDNA"
#                },
#                {
#                   "title": "PolyA"
#                },
#                {
#                   "title": "RANDOM PCR"
#                },
#                {
#                   "title": "MDA"
#                },
#                {
#                   "title": "repeat fractionation"
#                },
#                {
#                   "title": "RACE"
#                }
#             ]
#          },
#          "librarysource": {
#             "type": "string",
#             "description": "Source of the biological data (i.e. GENOMIC, METAGENOMIC, etc)",
#             "oneOf": [
#                {
#                   "title": "SYNTHETIC"
#                },
#                {
#                   "title": "TRANSCRIPTOMIC"
#                },
#                {
#                   "title": "OTHER"
#                },
#                {
#                   "title": "VIRAL RNA"
#                },
#                {
#                   "title": "METATRANSCRIPTOMIC"
#                },
#                {
#                   "title": "METAGENOMIC"
#                },
#                {
#                   "title": "TRANSCRIPTOMIC SINGLE CELL"
#                },
#                {
#                   "title": "GENOMIC"
#                },
#                {
#                   "title": "GENOMIC SINGLE CELL"
#                }
#             ]
#          },
#          "platform": {
#             "type": "string",
#             "description": "Name of the sequencing platform (i.e. ILLUMINA)"
#          },
#          "sample_acc": {
#             "type": "string",
#             "description": "SRA Sample accession in the form of SRS######## (ERS or DRS for INSDC partners)"
#          },
#          "biosample": {
#             "type": "string",
#             "description": "BioSample accession in the form of SAMN######## (SAMEA##### or SAMD##### for INSDC partners)"
#          },
#          "organism": {
#             "type": "string",
#             "description": "Scientific name of the organism that was sequenced (as found in the NCBI Taxonomy Browser)"
#          },
#          "sra_study": {
#             "type": "string",
#             "description": "SRA Study accession in the form of SRP######## (ERP or DRP for INSDC partners)"
#          },
#          "releasedate": {
#             "type": "string",
#             "description": "The date on which the data was released"
#          },
#          "bioproject": {
#             "type": "string",
#             "description": "BioProject accession in the form of PRJNA######## (PRJEB####### or PRJDB###### for INSDC partners)"
#          },
#          "mbytes": {
#             "type": "integer",
#             "description": "Number of mega bytes of data in the SRA Run"
#          },
#          "loaddate": {
#             "type": "string",
#             "description": "The date when the data was loaded into SRA"
#          },
#          "avgspotlen": {
#             "type": "integer",
#             "description": "Calculated average read length"
#          },
#          "mbases": {
#             "type": "integer",
#             "description": "Number of mega bases in the SRA Runs"
#          },
#          "insertsize": {
#             "type": "integer",
#             "description": "Submitter provided insert size"
#          },
#          "library_name": {
#             "type": "string",
#             "description": "The name of the library"
#          },
#          "biosamplemodel_sam": {
#             "type": "string",
#             "description": "The BioSample package/model that was picked"
#          },
#          "collection_date_sam": {
#             "type": "string",
#             "description": "The collection date of the sample"
#          },
#          "geo_loc_name_country_calc": {
#             "type": "string",
#             "description": "Name of the country where the sample was collected"
#          },
#          "geo_loc_name_country_continent_calc": {
#             "type": "string",
#             "description": "Name of the continent where the sample was collected"
#          },
#          "geo_loc_name_sam": {
#             "type": "string",
#             "description": "Full location of collection"
#          },
#          "ena_first_public_run": {
#             "type": "string",
#             "description": "Date when INSDC partner record was public"
#          },
#          "ena_last_update_run": {
#             "type": "string",
#             "description": "Date when INSDC partner record was updated"
#          },
#          "sample_name_sam": {
#             "type": "string",
#             "description": "INSDC sample name"
#          },
#          "datastore_filetype": {
#             "type": "string",
#             "description": "Type of files available to download from SRA"
#          },
#          "datastore_provider": {
#             "type": "string",
#             "description": "Locations of where the files are available to download from"
#          },
#          "datastore_region": {
#             "type": "string",
#             "description": "Regions of where the data is located"
#          },
#          "attributes": {
#             "type": "string",
#             "description": "Full list of sample attributes in a nested(array) structure"
#          },
#          "attributes.k": {
#             "type": "string",
#             "description": "Attribute's name"
#          },
#          "attributes.v": {
#             "type": "string",
#             "description": "Attribute's value"
#          },
#          "jattr": {
#             "type": "string",
#             "description": "JSON based string of the sample attributes"
#          }
#       }
#    }
# }

# %% [markdown]
# ### Query the SRA table on the biosample id

# %%
query = f"select * from nih_sra_datastore.sra.metadata where biosample='{response.json()['dbgap']['sra_sample_id']}'"
query
# Out:
# "select * from nih_sra_datastore.sra.metadata where biosample='SAMN06062404'"

# %%
from ipywidgets import IntProgress
from IPython.display import display
max_count = 300

progress_bar = IntProgress(min=0, max=max_count) # instantiate the bar
display(progress_bar) # display the bar
# Out:
# IntProgress(value=0, max=300)

# %%
df = searchClient.run_query(query, return_type='dataframe', progessIndicator=progress_bar)

# %%
df.transpose()
# Out:
#                                                                                      0  \
# acc                                                                         SRR8016410
# assay_type                                                                         WGS
# center_name                                                                   Macrogen
# consent                                                             DS-CVD-IRB-NPU-MDS
# experiment                                                                  SRX4849106
# sample_name                                                                  NWD403016
# instrument                                                                 HiSeq X Ten
# librarylayout                                                                   PAIRED
# libraryselection                                                                RANDOM
# librarysource                                                                  GENOMIC
# platform                                                                      ILLUMINA
# sample_acc                                                                  SRS1903809
# biosample                                                                 SAMN06062404
# organism                                                                  Homo sapiens
# sra_study                                                                    SRP095692
# releasedate                                                   2019-02-27T00:00:00.000Z
# bioproject                                                                 PRJNA343581
# mbytes                                                                           21901
# loaddate                                                                          None
# avgspotlen                                                                         300
# mbases                                                                          130478
# insertsize                                                                        None
# library_name                                                                NWD403016
# biosamplemodel_sam                                                                  []
# collection_date_sam                                                               None
# geo_loc_name_country_calc                                                         None
# geo_loc_name_country_continent_calc                                               None
# geo_loc_name_sam                                                                    []
# ena_first_public_run                                                                []
# ena_last_update_run                                                                 []
# sample_name_sam                                                                     []
# datastore_filetype                                        [crai, cram, vcf, vcf_index]
# datastore_provider                                                            [gs, s3]
# datastore_region                                                 [gs.US, s3.us-east-1]
# attributes                           [{'k': 'sex_calc', 'v': 'female'}, {'k': 'asse...
# jattr                                {"sex_calc": "female", "assemblyname": "GRCh38...
#
#                                                                                      1
# acc                                                                         SRR5154616
# assay_type                                                                         WGS
# center_name                                                                   Macrogen
# consent                                                             DS-CVD-IRB-NPU-MDS
# experiment                                                                  SRX2472219
# sample_name                                                                  NWD403016
# instrument                                                                 HiSeq X Ten
# librarylayout                                                                   PAIRED
# libraryselection                                                                RANDOM
# librarysource                                                                  GENOMIC
# platform                                                                      ILLUMINA
# sample_acc                                                                  SRS1903809
# biosample                                                                 SAMN06062404
# organism                                                                  Homo sapiens
# sra_study                                                                    SRP095692
# releasedate                                                   2019-02-27T00:00:00.000Z
# bioproject                                                                 PRJNA343581
# mbytes                                                                           29163
# loaddate                                                                          None
# avgspotlen                                                                         300
# mbases                                                                          130478
# insertsize                                                                        None
# library_name                                                                 NWD403016
# biosamplemodel_sam                                                                  []
# collection_date_sam                                                               None
# geo_loc_name_country_calc                                                         None
# geo_loc_name_country_continent_calc                                               None
# geo_loc_name_sam                                                                    []
# ena_first_public_run                                                                []
# ena_last_update_run                                                                 []
# sample_name_sam                                                                     []
# datastore_filetype                                                  [bam, run.zq, sra]
# datastore_provider                                                      [gs, ncbi, s3]
# datastore_region                                     [gs.US, ncbi.dbgap, s3.us-east-1]
# attributes                           [{'k': 'sex_calc', 'v': 'female'}, {'k': 'asse...
# jattr                                {"sex_calc": "female", "assemblyname": "GCA_00...

# %%
response.json()['dbgap']
# Out:
# {'sex': 'female',
#  'body_site': 'peripheral blood',
#  'repository': 'GeneSTAR',
#  'sample_use': ['Seq_DNA_SNP_CNV'],
#  'analyte_type': 'DNA',
#  'biosample_id': 'SAMN06062404',
#  'consent_code': 2,
#  'dbgap_status': 'Loaded',
#  'sra_sample_id': 'SAMN06062404',
#  'dbgap_sample_id': 2170791,
#  'study_accession': 'phs001218.v2.p1',
#  'dbgap_subject_id': 1797782,
#  'sra_data_details': {'runs': '2',
#   'bases': '260957674200',
#   'center': 'Macrogen',
#   'status': 'public',
#   'size_Gb': '49',
#   'platform': 'ILLUMINA',
#   'experiments': '2',
#   'experiment_type': 'WGS'},
#  'study_subject_id': 'phs001218.v2_GS08900974',
#  'consent_short_name': 'DS-CVD-IRB-NPU-MDS',
#  'study_with_consent': 'phs001218.c2',
#  'submitted_sample_id': 'NWD403016',
#  'submitted_subject_id': 'GS08900974',
#  'study_accession_with_consent': 'phs001218.v2.p1.c2'}

# %%
query = """
    SELECT att.k attribute, att.v value
 FROM nih_sra_datastore.sra.metadata s, unnest(attributes) att
where s.acc = 'SRR5154616' and att.k != 'primary_search' """

df = searchClient.run_query(query, return_type='dataframe', progessIndicator=progress_bar)

df
# Out:
#                                attribute  \
# 0                               sex_calc
# 1                           assemblyname
# 2                                  bases
# 3                                  bytes
# 4                           consent_code
# 5                   run_file_create_date
# 6                       run_file_version
# 7                 alignment_provider_run
# 8                       analyte_type_sam
# 9             biospecimen_repository_sam
# 10  biospecimen_repository_sample_id_sam
# 11                         body_site_sam
# 12                     gap_accession_sam
# 13                      study_design_sam
# 14                        study_name_sam
# 15              submitted_subject_id_sam
# 16                                   phs
#
#                                                 value
# 0                                              female
# 1                                    GCA_000001405.13
# 2                                        130478837100
# 3                                         30580440819
# 4                                                   2
# 5                            2018-10-18T05:31:00.000Z
# 6                                                   2
# 7                                   Sequencing Center
# 8                                                 DNA
# 9                                            GeneSTAR
# 10                                          NWD403016
# 11                                   peripheral blood
# 12                                          phs001218
# 13                    Prospective Longitudinal Cohort
# 14  NHLBI TOPMed: Genetic Study of Atherosclerosis...
# 15                                         GS08900974
# 16                                       phs001218.c2

# %% [markdown]
# ### Query same files in NCBI DRS

# %%
from fasp.loc import SRADRSClient
dcl = SRADRSClient('https://locate.be-md.ncbi.nlm.nih.gov')
drs_id = dcl.acc2drsID('SRR8016410')

# %%
run_response = dcl.get_object(drs_id)

# %%
for r in run_response['contents']:
    file = dcl.get_object(r['id'])
    print(file)
    for a in file['access_methods']:
        print(a['region'])
        #dcl.get_access_url(r['id'], a['access_id'])
    print('_'*80)
# Out:
# {'access_methods': [{'access_id': '01f5af5012b771d644dc9d66655e5b35371d09daad04096ed610580ef2f3af18', 'region': 'gs.US', 'type': 'https'}, {'access_id': 'a9dd5a3b85e5c3289692315cb59d1b679e4f0c1a49a8b242b30efd10619b50e8', 'region': 's3.us-east-1', 'type': 'https'}], 'checksums': [{'checksum': '2f5a2cbcaefefefd89cd6ffcfb84b959', 'type': 'md5'}], 'created_time': '2018-10-11T12:09:44Z', 'id': '2f5a2cbcaefefefd89cd6ffcfb84b959', 'name': 'NWD403016.freeze5.v1.vcf.gz.csi', 'self_url': 'drs://locate.be-md.ncbi.nlm.nih.gov/2f5a2cbcaefefefd89cd6ffcfb84b959', 'size': 1711170}
# gs.US
# s3.us-east-1
# ________________________________________________________________________________
# {'access_methods': [{'access_id': 'd2be5fff49bec88fb8d2395bb95c14fc95aa02539a0564f3e199e7eeca0d701a', 'region': 'gs.US', 'type': 'https'}, {'access_id': '8a9085401febe6114a84743c3ea6f52760a9aca1661cdf22f96a6d6d3a5f99a1', 'region': 's3.us-east-1', 'type': 'https'}], 'checksums': [{'checksum': '308fa51b0b2ba6aab94315278341343d', 'type': 'md5'}], 'created_time': '2018-10-11T12:09:44Z', 'id': '308fa51b0b2ba6aab94315278341343d', 'name': 'NWD403016.b38.irc.v1.cram', 'self_url': 'drs://locate.be-md.ncbi.nlm.nih.gov/308fa51b0b2ba6aab94315278341343d', 'size': 20280571399}
# gs.US
# s3.us-east-1
# ________________________________________________________________________________
# {'access_methods': [{'access_id': '76220dbc33720528f8efb77dc5f5ba7369cdb8ac557fed207d81e30f65689231', 'region': 'gs.US', 'type': 'https'}, {'access_id': '1318b1aaf92482904ed534f2991498bced6f4510137626bd5760947f7e24e2f9', 'region': 's3.us-east-1', 'type': 'https'}], 'checksums': [{'checksum': '80c20cdd223bfa7c5ae801a1a62f7151', 'type': 'md5'}], 'created_time': '2018-10-11T12:09:44Z', 'id': '80c20cdd223bfa7c5ae801a1a62f7151', 'name': 'NWD403016.freeze5.v1.vcf.gz', 'self_url': 'drs://locate.be-md.ncbi.nlm.nih.gov/80c20cdd223bfa7c5ae801a1a62f7151', 'size': 2682022077}
# gs.US
# s3.us-east-1
# ________________________________________________________________________________
# {'access_methods': [{'access_id': '9faf02933584f88aa6ca26cf4c85cdf5cd64f1841127a1f4b6b5c1a24595ee73', 'region': 'gs.US', 'type': 'https'}, {'access_id': 'ee665f8f5e7e2ed9fd93ee0b2aa4488d6510d5dcb321ece92c4b4aa02120a26b', 'region': 's3.us-east-1', 'type': 'https'}], 'checksums': [{'checksum': 'f12a3897ce282c4201f6ea2fd4314a8d', 'type': 'md5'}], 'created_time': '2018-10-11T12:09:44Z', 'id': 'f12a3897ce282c4201f6ea2fd4314a8d', 'name': 'NWD403016.b38.irc.v1.cram.crai', 'self_url': 'drs://locate.be-md.ncbi.nlm.nih.gov/f12a3897ce282c4201f6ea2fd4314a8d', 'size': 1440693}
# gs.US
# s3.us-east-1
# ________________________________________________________________________________
