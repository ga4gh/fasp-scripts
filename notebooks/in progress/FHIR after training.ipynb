# %% [markdown]
# The new KF FHIR Server

# %%
import sys
import os
import json
import requests

#FHIR_SERVER = 'https://kf-api-fhir-service.kidsfirstdrc.org'
FHIR_SERVER = 'https://ncpi-api-fhir-service-dev.kidsfirstdrc.org'

# Optional: Turn off SSL verification. Useful when dealing with a corporate proxy with self-signed certificates.
# This should be set to True unless you actually see certificate errors.
VERIFY_SSL = False

if not VERIFY_SSL:
    requests.packages.urllib3.disable_warnings()



# Kids First uses cookie-based authentication
# Get my locally saved cookie
full_cookie_path = os.path.expanduser('~/.keys/ncpi_fhir_cookie.json')
with open(full_cookie_path) as f:
        cookies = json.load(f)

# We make a requests.Session to ensure consistent headers/cookie across all the requests we make
s = requests.Session()
s.headers.update({'Accept': 'application/fhir+json'})
s.headers.update(cookies)
s.verify = VERIFY_SSL


# Test out the cookie by querying the server metadata
r = s.get(f"{FHIR_SERVER}/metadata")

if "<!DOCTYPE html>" in r.text:
    sys.stderr.write('ERROR: Could not authenticate with Kids First. The cookie may need to be updated')

# %%
def print_bundle(bundle, truncate_for_github = False):
    if not truncate_for_github:
        return bundle
    
    lines = json.dumps(bundle, indent=2).split('\n')
    if len(lines) <= 20:
        return bundle
    else:   
        print('\n'.join(lines[:20]))
        print('...\nBundle truncated. Change the "print_bundle" function above to print the full content.')

# %%
r = s.get(f"{FHIR_SERVER}/Patient")
bundle = r.json()
print_bundle(bundle)
# Out:
# {'resourceType': 'Bundle',
#  'id': '714078cd-6879-4c30-9b3e-63a8f9fceff1',
#  'meta': {'lastUpdated': '2022-03-01T21:55:40.519+00:00'},
#  'type': 'searchset',
#  'link': [{'relation': 'self', 'url': 'http://localhost:8000/Patient'},
#   {'relation': 'next',
#    'url': 'http://localhost:8000?_getpages=714078cd-6879-4c30-9b3e-63a8f9fceff1&_getpagesoffset=50&_count=50&_bundletype=searchset'}],
#  'entry': [{'fullUrl': 'http://localhost:8000/Patient/697185',
#    'resource': {'resourceType': 'Patient',
#     'id': '697185',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:06.606+00:00',
#      'source': '#n3ytLuyIwQbd1Vjj',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_8EWN3AGB'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C175890'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C175890'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697192',
#    'resource': {'resourceType': 'Patient',
#     'id': '697192',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:07.078+00:00',
#      'source': '#373qNUOXLYA8QVKf',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_FTARZF6Q'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2414367'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2414367'}]},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697203',
#    'resource': {'resourceType': 'Patient',
#     'id': '697203',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:07.705+00:00',
#      'source': '#PjyFttuzZ3byVJJm',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_F32B7FBA'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C83148'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C83148'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697207',
#    'resource': {'resourceType': 'Patient',
#     'id': '697207',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:07.985+00:00',
#      'source': '#aU5CAlxDRXdhQgAM',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_GFGHFJ3S'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2317443'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2317443'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697215',
#    'resource': {'resourceType': 'Patient',
#     'id': '697215',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:08.316+00:00',
#      'source': '#HxT90WJ5Vv8Q9oDx',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_37Q9PTDX'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2637243'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2637243'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697224',
#    'resource': {'resourceType': 'Patient',
#     'id': '697224',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:08.764+00:00',
#      'source': '#AwrcDF1OMWAS5vJZ',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_1G80B33E'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C1207122'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C1207122'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697230',
#    'resource': {'resourceType': 'Patient',
#     'id': '697230',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:09.089+00:00',
#      'source': '#vIheRA4bHoBmURV7',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Not Available'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Available'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_MTE126WM'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C82164'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C82164'}]},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697238',
#    'resource': {'resourceType': 'Patient',
#     'id': '697238',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:09.392+00:00',
#      'source': '#WeC23RciLSV6tUsM',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_C1M4YF1R'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C46617'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C46617'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697246',
#    'resource': {'resourceType': 'Patient',
#     'id': '697246',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:09.721+00:00',
#      'source': '#7DFLxN6hhd8VDNES',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_TPR7K161'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2356188'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2356188'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697257',
#    'resource': {'resourceType': 'Patient',
#     'id': '697257',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:10.353+00:00',
#      'source': '#RBd4KhbDmBdmDMxT',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_5F0RQDSD'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2863809'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2863809'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697264',
#    'resource': {'resourceType': 'Patient',
#     'id': '697264',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:10.610+00:00',
#      'source': '#KhCDOfew18hPcaQr',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_4WVVG0Y3'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3230595'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3230595'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697272',
#    'resource': {'resourceType': 'Patient',
#     'id': '697272',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:10.973+00:00',
#      'source': '#ZYnnvsurOCg5KSqU',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_8BXEQY0V'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C1081908'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C1081908'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697280',
#    'resource': {'resourceType': 'Patient',
#     'id': '697280',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:11.354+00:00',
#      'source': '#7IgVZVE157dPmjIw',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_C6NVBK7E'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C547473'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C547473'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697291',
#    'resource': {'resourceType': 'Patient',
#     'id': '697291',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:11.801+00:00',
#      'source': '#cfSK1QBFOcLZhU2L',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_S0PBN4M7'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C479700'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C479700'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697298',
#    'resource': {'resourceType': 'Patient',
#     'id': '697298',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:12.126+00:00',
#      'source': '#RW546bVpw3FRmdqP',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_BTS1T9E8'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C1254354'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C1254354'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697304',
#    'resource': {'resourceType': 'Patient',
#     'id': '697304',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:12.433+00:00',
#      'source': '#APnd59QijXTK1ueH',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_3PCC148W'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C189666'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C189666'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697313',
#    'resource': {'resourceType': 'Patient',
#     'id': '697313',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:12.751+00:00',
#      'source': '#hea2JuCtFKIg9oFI',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_9QWTD6MT'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3600702'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3600702'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697322',
#    'resource': {'resourceType': 'Patient',
#     'id': '697322',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:13.150+00:00',
#      'source': '#x6VDL90nXy6PwfYr',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_XEVP2MH2'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C1003803'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C1003803'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697332',
#    'resource': {'resourceType': 'Patient',
#     'id': '697332',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:13.546+00:00',
#      'source': '#rF16M0zUoXaq5AOq',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text',
#         'valueString': 'Black or African American'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_GKFQN9WV'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2439951'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2439951'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697336',
#    'resource': {'resourceType': 'Patient',
#     'id': '697336',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:13.898+00:00',
#      'source': '#w9jXds1ela5i7PEE',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_DH8A0SNQ'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C73554'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C73554'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697343',
#    'resource': {'resourceType': 'Patient',
#     'id': '697343',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:14.097+00:00',
#      'source': '#K9PYbfpMtwSPIKUT',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_SEZW6T0H'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C852513'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C852513'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697350',
#    'resource': {'resourceType': 'Patient',
#     'id': '697350',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:14.369+00:00',
#      'source': '#9CkGDt3zdySjPIDb',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_21PQTDTS'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3284100'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3284100'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697359',
#    'resource': {'resourceType': 'Patient',
#     'id': '697359',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:14.736+00:00',
#      'source': '#qj0LL5evHUdsV3hx',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_28HN5YFK'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2892714'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2892714'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697367',
#    'resource': {'resourceType': 'Patient',
#     'id': '697367',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:15.074+00:00',
#      'source': '#PvcpDq9qOHYXVoYe',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_X2XFR0Y2'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C43173'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C43173'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697377',
#    'resource': {'resourceType': 'Patient',
#     'id': '697377',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:15.341+00:00',
#      'source': '#o87aG3GAABpQHbPy',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text',
#         'valueString': 'Black or African American'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_9PJR0ZK7'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C270846'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C270846'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697386',
#    'resource': {'resourceType': 'Patient',
#     'id': '697386',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:15.764+00:00',
#      'source': '#jAGJ2sUeI6JSh3vn',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_AQG194KP'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3279795'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3279795'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697391',
#    'resource': {'resourceType': 'Patient',
#     'id': '697391',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:16.069+00:00',
#      'source': '#CEXzGobU4VKcPJD5',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text',
#         'valueString': 'Black or African American'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_8MWV088Q'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3003906'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3003906'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697397',
#    'resource': {'resourceType': 'Patient',
#     'id': '697397',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:16.282+00:00',
#      'source': '#Lv0BieiN5SrnKRLf',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_BSV6956G'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2484231'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2484231'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697406',
#    'resource': {'resourceType': 'Patient',
#     'id': '697406',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:16.562+00:00',
#      'source': '#cErDsN5v0Ybeuyeu',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Asian'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2028-9',
#          'display': 'Asian'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_N625TJ49'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2553726'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2553726'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697416',
#    'resource': {'resourceType': 'Patient',
#     'id': '697416',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:16.969+00:00',
#      'source': '#2xqCOyTRYWpFJaHF',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_KNKWSGKZ'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3375366'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3375366'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697448',
#    'resource': {'resourceType': 'Patient',
#     'id': '697448',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:18.344+00:00',
#      'source': '#mBNaeOtbsU5EHBP4',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_8AZP6B5B'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3430839'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3430839'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697454',
#    'resource': {'resourceType': 'Patient',
#     'id': '697454',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:18.548+00:00',
#      'source': '#yjf6LVd9puo0MqPc',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_B2RBACZ0'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C1025205'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C1025205'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697460',
#    'resource': {'resourceType': 'Patient',
#     'id': '697460',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:18.766+00:00',
#      'source': '#VDroBiy7S5BFcKfZ',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_MTVQKGX2'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C530376'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C530376'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697467',
#    'resource': {'resourceType': 'Patient',
#     'id': '697467',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:19.092+00:00',
#      'source': '#m4ckM6iy2Ffghm7W',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text',
#         'valueString': 'Black or African American'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_ZWY04DCR'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C849807'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C849807'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697479',
#    'resource': {'resourceType': 'Patient',
#     'id': '697479',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:19.593+00:00',
#      'source': '#JlXGNJZnO7V9FAJA',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_AD5TQCZN'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C850914'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C850914'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697486',
#    'resource': {'resourceType': 'Patient',
#     'id': '697486',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:19.788+00:00',
#      'source': '#3AjqE20Ea3LBOsup',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_Y5RV9WTQ'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C1272312'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C1272312'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697496',
#    'resource': {'resourceType': 'Patient',
#     'id': '697496',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:20.267+00:00',
#      'source': '#c2SLE8kSOwow8Ubk',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_81SYD5S6'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C559404'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C559404'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697503',
#    'resource': {'resourceType': 'Patient',
#     'id': '697503',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:20.507+00:00',
#      'source': '#e66Ychp36lJNLSMj',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
# ...
#       'value': 'Patient-SD_BHJXBDQK-C1163211'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697512',
#    'resource': {'resourceType': 'Patient',
#     'id': '697512',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:20.879+00:00',
#      'source': '#dhfLkWSOiYpuSKkp',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_35X8ASEE'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2414490'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2414490'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697518',
#    'resource': {'resourceType': 'Patient',
#     'id': '697518',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:21.067+00:00',
#      'source': '#HU9ea5QdFWb5vjjK',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_AY68KXSP'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C3504762'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C3504762'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697526',
#    'resource': {'resourceType': 'Patient',
#     'id': '697526',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:21.383+00:00',
#      'source': '#VO12lNyx6U1ZTOfd',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text',
#         'valueString': 'Black or African American'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_8AMEPEA5'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2539704'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2539704'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697535',
#    'resource': {'resourceType': 'Patient',
#     'id': '697535',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:21.727+00:00',
#      'source': '#GgYq1WCBPlhMwfjw',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_E79807KT'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C879819'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C879819'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697543',
#    'resource': {'resourceType': 'Patient',
#     'id': '697543',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:22.139+00:00',
#      'source': '#Q0mHzbhKbnKbQBcD',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_6CKD3XG9'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C545751'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C545751'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697548',
#    'resource': {'resourceType': 'Patient',
#     'id': '697548',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:22.304+00:00',
#      'source': '#tErkRDIe759tJmQt',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_M8GZX3KX'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C59286'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C59286'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697565',
#    'resource': {'resourceType': 'Patient',
#     'id': '697565',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:22.981+00:00',
#      'source': '#4vfVF73MYNbkY3so',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text',
#         'valueString': 'Black or African American'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2054-5',
#          'display': 'Black or African American'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_GSRW8FPK'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C18942'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C18942'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697186',
#    'resource': {'resourceType': 'Patient',
#     'id': '697186',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:06.608+00:00',
#      'source': '#Aly6T0NGfiTA3ti2',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Other'}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_TH8M3W34'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C516723'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C516723'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697195',
#    'resource': {'resourceType': 'Patient',
#     'id': '697195',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:07.206+00:00',
#      'source': '#pqURYuMR2ZwqLNu9',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text',
#         'valueString': 'American Indian or Alaska Native'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '1002-5',
#          'display': 'American Indian or Alaska Native'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2135-2',
#          'display': 'Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_D4JJMH7V'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C1277601'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C1277601'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697201',
#    'resource': {'resourceType': 'Patient',
#     'id': '697201',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:07.625+00:00',
#      'source': '#EtZFkUSzFDfSimdi',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'Asian'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2028-9',
#          'display': 'Asian'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_QRKS53MJ'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C851160'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C851160'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697208',
#    'resource': {'resourceType': 'Patient',
#     'id': '697208',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:07.993+00:00',
#      'source': '#bYfnBfitgLAUwo32',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Reported'}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_Q0FZWQB8'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C549441'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C549441'}],
#     'gender': 'male'},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/Patient/697216',
#    'resource': {'resourceType': 'Patient',
#     'id': '697216',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-06-16T01:56:08.295+00:00',
#      'source': '#eDbkGRWRKK9NgHWR',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/Patient']},
#     'extension': [{'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race',
#       'extension': [{'url': 'text', 'valueString': 'White'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2106-3',
#          'display': 'White'}}]},
#      {'url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity',
#       'extension': [{'url': 'text', 'valueString': 'Not Hispanic or Latino'},
#        {'url': 'ombCategory',
#         'valueCoding': {'system': 'urn:oid:2.16.840.1.113883.6.238',
#          'code': '2186-5',
#          'display': 'Not Hispanic or Latino'}}]}],
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_T06GNH71'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_BHJXBDQK&external_id=C2572176'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'Patient-SD_BHJXBDQK-C2572176'}],
#     'gender': 'female'},
#    'search': {'mode': 'match'}}]}

# %%
r = s.get(f"{FHIR_SERVER}/ResearchSubject")
bundle = r.json()
print_bundle(bundle)
# Out:
# {'resourceType': 'Bundle',
#  'id': 'f84987ce-6edb-466a-8f24-eec54523e23a',
#  'meta': {'lastUpdated': '2022-03-01T22:26:31.747+00:00'},
#  'type': 'searchset',
#  'link': [{'relation': 'self', 'url': 'http://localhost:8000/ResearchSubject'},
#   {'relation': 'next',
#    'url': 'http://localhost:8000?_getpages=f84987ce-6edb-466a-8f24-eec54523e23a&_getpagesoffset=50&_count=50&_bundletype=searchset'}],
#  'entry': [{'fullUrl': 'http://localhost:8000/ResearchSubject/539892',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539892',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.486+00:00',
#      'source': '#l4Q9C6v8ajPLXNuT',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_09TAPX9A'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12383_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12383_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539322'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539898',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539898',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.537+00:00',
#      'source': '#SmT2If8pIBe8TmHF',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_44CNW481'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12329_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12329_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539304'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539903',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539903',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.594+00:00',
#      'source': '#res6hAZXcjmG4A2v',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_HZX8RZT6'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH4166_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH4166_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539317'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539911',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539911',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.729+00:00',
#      'source': '#ANGxLsLbiVFb3Rgk',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_7P06CT8Y'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13878_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13878_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539339'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539913',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539913',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.786+00:00',
#      'source': '#GrpOkeC18UlKUVj7',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_K6BC3GDW'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10837_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10837_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539332'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539887',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539887',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.461+00:00',
#      'source': '#1PjFBpuWONV46jad',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_RHX7VZTG'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH3504_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH3504_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539341'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539893',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539893',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.516+00:00',
#      'source': '#Xd3pYuVA4PsnOFfd',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_DZA8SSH9'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12841_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12841_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539329'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539899',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539899',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.573+00:00',
#      'source': '#FKiwpEBRKWLnJ4rx',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_FBTXHG5D'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12869_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12869_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539321'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539928',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539928',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.137+00:00',
#      'source': '#4zT2aHDM6e96qViP',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_5R8TTHV4'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13413_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13413_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539354'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539880',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539880',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.361+00:00',
#      'source': '#eMuozE2bEussPO2U',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_TXBYKFMP'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10490_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10490_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539312'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539891',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539891',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.478+00:00',
#      'source': '#tCKgXFp038LJW3F1',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_BEC5M178'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12841_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12841_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539309'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539897',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539897',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.531+00:00',
#      'source': '#ODi1OVXJEZXNvaZh',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_KSPRP0TG'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10133_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10133_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539325'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539906',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539906',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.634+00:00',
#      'source': '#g8wNBvd0Ou0SiZdM',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_V1YGBZTK'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10133_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10133_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539319'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539908',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539908',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.692+00:00',
#      'source': '#ERKuIPhBobWULvO6',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_881M59K0'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10134_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10134_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539343'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539921',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539921',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.957+00:00',
#      'source': '#bo22pRc2Z6jbYVu5',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_21PSTG5J'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13704_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13704_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539326'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539932',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539932',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.182+00:00',
#      'source': '#A0UEUytgQypSCzui',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_XATAS1Q2'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12883_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12883_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539360'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539882',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539882',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.376+00:00',
#      'source': '#9bhKK9T6Nb8uQyZU',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_2A28455R'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10425_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10425_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539303'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539890',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539890',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.475+00:00',
#      'source': '#VwvKuH2cgDlwzPYt',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_RP789F44'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH3504_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH3504_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539318'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539894',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539894',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.519+00:00',
#      'source': '#sneVwaHyVOnWd0iP',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_MQCGAX4B'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH3504_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH3504_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539323'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539904',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539904',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.614+00:00',
#      'source': '#PcXkATgjuvlGLQwm',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_2ZAZ24JW'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13878_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13878_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539337'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539883',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539883',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.391+00:00',
#      'source': '#1ieBxWtDBcZu5t6V',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_K1W9Y75P'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10490_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10490_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539313'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539886',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539886',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.459+00:00',
#      'source': '#Zc0EickEVSVkeYUK',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_QE3WW3TR'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12841_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12841_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539315'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539902',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539902',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.588+00:00',
#      'source': '#5gnxEUlxyTR5v824',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_PGQG4Y4W'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12869_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12869_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539327'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539881',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539881',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.373+00:00',
#      'source': '#94lArGBpQG3rdjxa',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_XNXCHGGH'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10425_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10425_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539310'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539896',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539896',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.523+00:00',
#      'source': '#TpANH1tKDGGpo8we',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_WSZ1V378'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12329_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12329_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539307'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539900',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539900',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.577+00:00',
#      'source': '#qvQal1fA2UwoKcnJ',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_65EGXKB5'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12383_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12383_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539311'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539905',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539905',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.623+00:00',
#      'source': '#P9sqA0FVIfzya2CZ',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_YH8WXXD1'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12383_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12383_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539320'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539909',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539909',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.695+00:00',
#      'source': '#rdQRVBZvV3kpLHQo',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_Y01J9JX2'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10134_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10134_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539324'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539884',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539884',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.409+00:00',
#      'source': '#5Qqhq2zoePw3imfb',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_FZQ0GPDW'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10425_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10425_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539302'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539888',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539888',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.466+00:00',
#      'source': '#f8zySShFTot5AgjS',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_WSE774VD'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH4166_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH4166_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539306'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539901',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539901',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.583+00:00',
#      'source': '#yI5lap2S19Xj2PJJ',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_28M17ZPH'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12869_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12869_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539330'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539885',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539885',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.419+00:00',
#      'source': '#CPyddG4UaZcNGEzk',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_PEAWWWYK'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10490_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10490_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539308'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539889',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539889',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.467+00:00',
#      'source': '#NGmtrOesZxVLdCXg',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_RRS97AP3'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12329_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12329_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539305'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539895',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539895',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.523+00:00',
#      'source': '#QDi0YZCzXtaKHTVJ',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_EFAE37PG'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH4166_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH4166_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539328'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539922',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539922',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.966+00:00',
#      'source': '#t58TxTbuDdAYeRyq',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_G0ZS9E8A'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13704_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13704_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539349'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539940',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539940',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.244+00:00',
#      'source': '#wSBuzYVseb6HtQ6t',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_G7MG2AVX'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH4166_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH4166_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539370'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539943',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539943',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.289+00:00',
#      'source': '#nES1GLiv48jSEW6G',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_TRB8ZV7C'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12892_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12892_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539361'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539946',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539946',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.408+00:00',
#      'source': '#EWl3Tge0unmU0zAk',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_DAYG8A7Q'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12892_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12892_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539363'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539907',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539907',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.652+00:00',
#      'source': '#41HU8gClw0d4mmrR',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_KGMRND0K'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10133_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10133_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539346'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539924',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539924',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.980+00:00',
#      'source': '#SPVWMM4AXo6KVB9O',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_XW5PCVZ6'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13704_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13704_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539340'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539925',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539925',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.029+00:00',
#      'source': '#uoIvwLdOU1s6dC6h',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_0DBRJP3G'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12847_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12847_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539359'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539938',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539938',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.221+00:00',
#      'source': '#qWxWyL675WKhgH0P',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_WK5577XP'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12330_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12330_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539355'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539910',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539910',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.730+00:00',
#      'source': '#TbpD7KrTwAVmB3Wx',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_EDK17M1G'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13878_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13878_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539336'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539914',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539914',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.794+00:00',
#      'source': '#hrLjvrGouTzWaQgy',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_SV23TKGA'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10837_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10837_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539316'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539917',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539917',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:18.852+00:00',
#      'source': '#YjgMHqCKfL4WDpNV',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_64333MBJ'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12838_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12838_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539335'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539927',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539927',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.107+00:00',
#      'source': '#BTFoNoZxmnTfMxBR',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_N224TMNJ'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH13413_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH13413_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539338'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539930',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539930',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.166+00:00',
#      'source': '#PpDHDdxEAju9qaAh',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_N61MVGB2'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH12883_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH12883_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539366'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539937',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539937',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.218+00:00',
#      'source': '#vARkPCqaNMxvJNyB',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_V9YS3VRF'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10492_1'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10492_1'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539356'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539941',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539941',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.262+00:00',
#      'source': '#sTa7xgwGOVtbcdig',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_9QWBMB8R'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH10492_3'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH10492_3'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539368'}},
#    'search': {'mode': 'match'}},
#   {'fullUrl': 'http://localhost:8000/ResearchSubject/539969',
#    'resource': {'resourceType': 'ResearchSubject',
#     'id': '539969',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2021-04-28T23:43:19.772+00:00',
#      'source': '#jCn5A4eGeSQ8zM4H',
#      'profile': ['http://hl7.org/fhir/StructureDefinition/ResearchSubject']},
#     'identifier': [{'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': 'PT_NX2RWGG0'},
#      {'system': 'https://kf-api-dataservice.kidsfirstdrc.org/participants/',
#       'value': '?study_id=SD_7NQ9151J&external_id=BH4174_2'},
#      {'system': 'urn:kids-first:unique-string',
#       'value': 'ResearchSubject|SD_7NQ9151J|BH4174_2'}],
#     'status': 'off-study',
#     'study': {'reference': 'ResearchStudy/539879'},
#     'individual': {'reference': 'Patient/539389'}},
#    'search': {'mode': 'match'}}]}
