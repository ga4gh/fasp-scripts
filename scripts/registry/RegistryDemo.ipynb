# %%
from fasp.loc import GA4GHRegistry
cl = GA4GHRegistry('https://registry.ga4gh.org/v1')
services = cl.getRegisteredServices()
# Out:
# Searching the GA4GH registry for all services

# %%
import pandas as pd
df = pd.DataFrame.from_dict(services)
df
# Out:
#                                          id  \
# 0               com.dnastack.beacon-network
# 1                       com.dnastack.search
# 2                  com.dnastack.search.test
# 3                     com.dnastack.wes.demo
# 4                       com.sb.cavatica.drs
# 5                            com.sb.cgc.drs
# 6          com.sbgenomics.cgc-ga4gh-api.wes
# 7                        edu.caltech.rnaget
# 8                            edu.chop.kfdrc
# 9                             eu.crg.rnaget
# 10              fi.rahtiapp.registry-beacon
# 11                     gov.nih.nci.dcfs.drs
# 12        gov.nih.nhlbi.biodatacatalyst.drs
# 13                          io.theanvil.drs
# 14  org.autismspeaks.mssng.service-registry
# 15               org.dockstore.dockstoreapi
# 16          org.ga4gh.htsgetreference.reads
# 17       org.ga4gh.htsgetreference.variants
# 18                       org.ga4gh.registry
# 19       pro.biocontainers.biocontainersapi
# 20        uk.ac.ebi.cram-reference-registry
# 21                   uk.ac.ebi.insdc.refget
# 22                uk.ac.ebi.refget.ref-impl
# 23              uk.ac.ebi.refget-serverless
#
#                                             name  \
# 0                        DNAstack Beacon Network
# 1             ga4gh-search-adapter-presto-public
# 2                 DNAstack Discovery Search test
# 3                      DNAstack Demo WES Service
# 4                               Cavatica DRS API
# 5                  Cancer Genomics Cloud DRS API
# 6                              CGC GA4GH WES API
# 7        Caltech RNAget Reference Implementation
# 8    The Kids First Data Resource Center (KFDRC)
# 9            CRG RNAget Reference Implementation
# 10                     ELIXIR-FI Beacon Registry
# 11                                      NCI DCFS
# 12                              BioData Catalyst
# 13                                         AnVIL
# 14                  MSSNG GA4GH Service Registry
# 15                                     Dockstore
# 16       GA4GH htsget reference server reads API
# 17    GA4GH htsget reference server variants API
# 18  GA4GH Standards and Implementations Registry
# 19                                 Biocontainers
# 20                       CRAM Reference Registry
# 21                           INSDC Refget Mirror
# 22               Refget reference implementation
# 23                      Serverless refget on AWS
#
#                                                  type  \
# 0   {'group': 'org.ga4gh', 'artifact': 'service-re...
# 1   {'group': 'org.ga4gh', 'artifact': 'search', '...
# 2   {'group': 'org.ga4gh', 'artifact': 'search', '...
# 3   {'group': 'org.ga4gh', 'artifact': 'wes', 'ver...
# 4   {'group': 'org.ga4gh', 'artifact': 'drs', 'ver...
# 5   {'group': 'org.ga4gh', 'artifact': 'drs', 'ver...
# 6   {'group': 'org.ga4gh', 'artifact': 'wes', 'ver...
# 7   {'group': 'org.ga4gh', 'artifact': 'rnaget', '...
# 8   {'group': 'org.ga4gh', 'artifact': 'drs', 'ver...
# 9   {'group': 'org.ga4gh', 'artifact': 'rnaget', '...
# 10  {'group': 'org.ga4gh', 'artifact': 'service-re...
# 11  {'group': 'org.ga4gh', 'artifact': 'drs', 'ver...
# 12  {'group': 'org.ga4gh', 'artifact': 'drs', 'ver...
# 13  {'group': 'org.ga4gh', 'artifact': 'drs', 'ver...
# 14  {'group': 'org.ga4gh', 'artifact': 'service-re...
# 15  {'group': 'org.ga4gh', 'artifact': 'trs', 'ver...
# 16  {'group': 'org.ga4gh', 'artifact': 'htsget', '...
# 17  {'group': 'org.ga4gh', 'artifact': 'htsget', '...
# 18  {'group': 'org.ga4gh', 'artifact': 'service-re...
# 19  {'group': 'org.ga4gh', 'artifact': 'trs', 'ver...
# 20  {'group': 'org.ga4gh', 'artifact': 'refget', '...
# 21  {'group': 'org.ga4gh', 'artifact': 'refget', '...
# 22  {'group': 'org.ga4gh', 'artifact': 'refget', '...
# 23  {'group': 'org.ga4gh', 'artifact': 'refget', '...
#
#                                          organization           version  \
# 0   {'id': 'com.dnastack', 'name': 'DNAstack', 'ur...  1.1-149-ga8b0cf5
# 1   {'id': 'com.dnastack', 'name': 'DNAstack', 'ur...  0.4-189-gbfc2688
# 2   {'id': 'com.dnastack', 'name': 'DNAstack', 'ur...             0.1.0
# 3   {'id': 'com.dnastack', 'name': 'DNAstack', 'ur...             1.0.0
# 4   {'id': 'com.sb', 'name': 'Seven Bridges', 'url...             1.0.0
# 5   {'id': 'com.sb', 'name': 'Seven Bridges', 'url...             1.0.0
# 6   {'id': 'com.sb', 'name': 'Seven Bridges', 'url...           1.0.1.4
# 7   {'id': 'edu.caltech', 'name': 'California Inst...             1.0.0
# 8   {'id': 'edu.chop', 'name': 'Childrens Hospital...           2020.08
# 9   {'id': 'eu.crg', 'name': 'Centre for Genomic R...             1.0.0
# 10  {'id': 'fi.csc', 'name': 'CSC - IT Center for ...             1.1.0
# 11  {'id': 'gov.nih.nci.dcfs', 'name': 'NCI Data C...            2.12.0
# 12  {'id': 'gov.nih.nhlbi.biodatacatalyst', 'name'...            2.12.0
# 13  {'id': 'io.theanvil', 'name': 'AnVIL', 'url': ...            2.12.0
# 14  {'id': 'org.autismspeaks', 'name': 'Autism Spe...  2.0-113-g274a2aa
# 15  {'id': 'org.dockstore', 'name': 'Dockstore', '...             1.8.1
# 16  {'id': 'org.ga4gh', 'name': 'Global Alliance f...             1.3.0
# 17  {'id': 'org.ga4gh', 'name': 'Global Alliance f...             1.3.0
# 18  {'id': 'org.ga4gh', 'name': 'Global Alliance f...             1.0.0
# 19  {'id': 'pro.biocontainers', 'name': 'Biocontai...             1.0.0
# 20  {'id': 'uk.ac.ebi', 'name': 'European Bioinfor...             1.0.0
# 21  {'id': 'uk.ac.ebi', 'name': 'European Bioinfor...             0.3.0
# 22  {'id': 'uk.ac.ebi', 'name': 'European Bioinfor...             1.0.0
# 23  {'id': 'uk.ac.ebi', 'name': 'European Bioinfor...             1.0.0
#
#                                                   url  \
# 0                   https://beacon-network.org/api/v2
# 1   https://ga4gh-search-adapter-presto-public.pro...
# 2   https://storage.googleapis.com/ga4gh-tables-ex...
# 3   https://ddap-wes-service.prod.dnastack.com/ga4...
# 4           https://cavatica-ga4gh-api.sbgenomics.com
# 5                https://cgc-ga4gh-api.sbgenomics.com
# 6   https://cgc-ga4gh-api.sbgenomics.com/ga4gh/wes...
# 7                   https://felcat.caltech.edu/rnaget
# 8                       https://data.kidsfirstdrc.org
# 9                       https://genome.crg.cat/rnaget
# 10                https://registry-beacon.rahtiapp.fi
# 11                   https://nci-crdc.datacommons.io/
# 12        https://gen3.biodatacatalyst.nhlbi.nih.gov/
# 13                          https://gen3.theanvil.io/
# 14              https://ga4gh-service-registry.mss.ng
# 15            https://dockstore.org/api/api/ga4gh/v2/
# 16                     https://htsget.ga4gh.org/reads
# 17                  https://htsget.ga4gh.org/variants
# 18                      https://registry.ga4gh.org/v1
# 19         https://api.biocontainers.pro/api/ga4gh/v2
# 20                     https://www.ebi.ac.uk/ena/cram
# 21              https://refget-insdc.jeremy-codes.com
# 22                       https://refget.herokuapp.com
# 23  https://spjb6ejone.execute-api.us-east-2.amazo...
#
#                                           description  \
# 0   The Beacon Network is a search engine across t...
# 1   Supports data discovery by searching heterogen...
# 2                                                 NaN
# 3               Demo Workflow Execution Service (WES)
# 4   The Data Repository Service (DRS) API provides...
# 5   The Data Repository Service (DRS) API provides...
# 6   This service provides a standard way for users...
# 7   RNAget implementation serving compliance test ...
# 8   Full implementation of the DRS 1.1 standard wi...
# 9   RNAget implementation serving compliance test ...
# 10  ELIXIR-FI Beacon Registry at CSC for Beacon ne...
# 11  DRS server that follows the Gen3 implementatio...
# 12  Full implementation of the DRS 1.1 standard wi...
# 13  DRS server that follows the Gen3 implementatio...
# 14  Provides links to GA4GH services offered by th...
# 15                       Dockstore TRS implementation
# 16  Reference web service of the GA4GH htsget prot...
# 17  Reference web service of the GA4GH htsget prot...
# 18  Flexible API registry of all GA4GH standards a...
# 19                   Biocontainers TRS implementation
# 20  ENA’s CRAM Reference Registry is the original ...
# 21  This web service serves genomic reference sequ...
# 22  Refget’s reference implementation is implement...
# 23  The refget-cloud codebase used in the AWS ECS ...
#
#                             contactUrl  \
# 0          mailto:support@dnastack.com
# 1          mailto:support@dnastack.com
# 2                                  NaN
# 3          mailto:support@dnastack.com
# 4      mailto:support@sevenbridges.com
# 5      mailto:support@sevenbridges.com
# 6      mailto:support@sevenbridges.com
# 7                      sau@caltech.edu
# 8        mailto:heathap@email.chop.edu
# 9                emilio.palumbo@crg.eu
# 10     https://www.csc.fi/contact-info
# 11       mailto:mlukowski@uchicago.edu
# 12        mailto:aculotti@uchicago.edu
# 13        mailto:aculotti@uchicago.edu
# 14  mailto:asgenetics@autismspeaks.org
# 15                                 NaN
# 16       mailto:jeremy.adams@ga4gh.org
# 17       mailto:jeremy.adams@ga4gh.org
# 18       mailto:jeremy.adams@ga4gh.org
# 19                                 NaN
# 20             mailto:ayates@ebi.ac.uk
# 21       mailto:jeremy.adams@ga4gh.org
# 22             mailto:ayates@ebi.ac.uk
# 23       mailto:jeremy.adams@ga4gh.org
#
#                                      documentationUrl environment  \
# 0   https://beacon-network.org/#/developers/api/be...        prod
# 1   https://github.com/ga4gh-discovery/ga4gh-disco...        prod
# 2                                                 NaN         dev
# 3   https://github.com/ga4gh/workflow-execution-se...        demo
# 4     https://docs.cavatica.org/docs/drs-api-overview  production
# 5   https://docs.cancergenomicscloud.org/docs/drs-...  production
# 6   https://docs.cancergenomicscloud.org/wes-api-o...  production
# 7                   https://felcat.caltech.edu/rnaget  production
# 8   https://petstore.swagger.io/?url=https://raw.g...  production
# 9                       https://genome.crg.cat/rnaget  production
# 10   https://beacon-network.readthedocs.io/en/latest/         dev
# 11  http://petstore.swagger.io/?url=https://raw.gi...         NaN
# 12  http://petstore.swagger.io/?url=https://raw.gi...         NaN
# 13  http://petstore.swagger.io/?url=https://raw.gi...         NaN
# 14  https://github.com/ga4gh-discovery/ga4gh-servi...        prod
# 15  https://dockstore.org/api/static/swagger-ui/in...         NaN
# 16  https://ga4gh.github.io/htsget-refserver/docs/...  production
# 17  https://ga4gh.github.io/htsget-refserver/docs/...  production
# 18  https://ga4gh.github.io/ga4gh-registry/docs/in...         NaN
# 19  https://biocontainers-edu.biocontainers.pro/en...         NaN
# 20  https://ena-docs.readthedocs.io/en/latest/retr...         NaN
# 21   https://refget-insdc.jeremy-codes.com/index.html         NaN
# 22   https://github.com/andrewyatz/refget-server-perl         NaN
# 23              https://github.com/ga4gh/refget-cloud         NaN
#
#                createdAt             updatedAt curiePrefix
# 0                    NaN                   NaN         NaN
# 1   2020-09-14T18:41:09Z  2020-09-14T18:41:09Z         NaN
# 2                    NaN                   NaN         NaN
# 3   2020-09-14T18:45:21Z  2020-09-14T18:45:21Z         NaN
# 4   2020-09-10T00:41:57Z  2020-09-10T00:41:57Z       sbcav
# 5   2020-09-10T00:41:57Z  2020-09-10T00:41:57Z       sbcgc
# 6   2020-11-10T18:45:39Z  2020-11-10T18:45:39Z         NaN
# 7                    NaN                   NaN         NaN
# 8   2020-10-06T13:11:38Z  2020-10-06T13:11:38Z         NaN
# 9                    NaN                   NaN         NaN
# 10  2019-09-04T12:00:00Z  2020-07-23T18:03:14Z         NaN
# 11  2020-07-24T12:00:00Z  2020-07-24T12:00:00Z        crdc
# 12  2020-07-24T12:00:00Z  2020-07-24T12:00:00Z         bdc
# 13  2020-07-24T12:00:00Z  2020-07-24T12:00:00Z         anv
# 14                   NaN                   NaN         NaN
# 15                   NaN                   NaN         NaN
# 16  2019-09-15T12:00:00Z  2020-09-04T14:40:00Z         NaN
# 17  2020-08-31T08:00:00Z  2020-09-04T14:40:00Z         NaN
# 18                   NaN                   NaN         NaN
# 19                   NaN                   NaN         NaN
# 20  2020-08-07T13:19:49Z  2020-08-07T13:19:49Z         NaN
# 21                   NaN                   NaN         NaN
# 22  2020-08-07T13:19:49Z  2020-08-07T13:19:49Z         NaN
# 23  2020-08-07T13:19:49Z  2020-08-07T13:19:49Z         NaN

# %%
newservices = []
for srvc in services:
    # get a subset of the service attributes
    subs = dict((k, srvc.get(k, None)) for k in ('name', 'url', 'environment', 'id','version','description','updatedAt'))
    # add some relevant nested attributes
    subs['api'] = srvc['type']['artifact']
    subs['api version'] = srvc['type']['version']
    subs['organization name'] = srvc['organization']['name']
    newservices.append(subs)

# %%
# create a dataframe containing our revised data
reduced_df = pd.DataFrame.from_dict(newservices)
# Sort - by service type
reduced_df.sort_values(by=['api'], inplace=True)

# %%
reduced_df.to_html('currentServices.html', 
                  columns=['api','api version','organization name', 'environment', 'url','updatedAt',
                           'name', 'id','version','description']  
                  )
